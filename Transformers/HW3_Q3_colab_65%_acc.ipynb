# %%
# %cd drive/My Drive/CS5814/HW3
# Out:
# /content/drive/My Drive/CS5814/HW3

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.49)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.5.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 4.1 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3

# %%
import json
import os
import random
import gc
import xlsxwriter
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from tqdm import tqdm
from transformers import AdamW, AutoTokenizer, AutoModelForSequenceClassification
from transformers import RobertaTokenizer, RobertaConfig, RobertaModel
import pickle

import torch.nn as nn

torch.cuda.empty_cache()
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
def preprocess_data(file_loc='code_dataset.jsonl', generate_histogram=False):
    """
    Loads and processing the jsonl file,

    :param file_loc: location of target jsonl file
    :param generate_histogram: Flag to display histogram of function lengths
    :return: dataframe of preprocessed jsons
    """

    with open(file_loc, 'r') as json_file:
        json_list = list(json_file)

    code_list = []
    for json_str in json_list:
        result = json.loads(json_str)
        code_list.append(result)

    code_df = pd.DataFrame(code_list)

    total = code_df['target'].sum()
    proportion = total / code_df.shape[0]

    print("Insecure code counts: {}, Total code counts: {}, Proportion {}".format(total, code_df.shape[0], proportion))

    if generate_histogram:
        plt.hist(code_df['func'].str.len(), bins=100)
        plt.show()

    return code_df

# %%
def split_data(input_data, attention_data, label_data, train_ratio=0.8, val_ratio=0.10, max_len=512):
    """
    Splits data in accordance with provdied ratios, additionally discards functions with > max_len tokens
        as these will not be processed by the model will (can truncate, yet may truncate the error in the code)

    :param input_data: input functions
    :param attention_data: attention map
    :param label_data: target labels
    :param train_ratio: ratio of data to train on
    :param val_ratio: ratio of data to validate with (test is inferred from this and train)
    :param max_len: max number of tokens allowed for training date

    :return: 3 tuples for train val and test containing (input, attention, target)
    """
    # Removing excessively long elements from dataset
    valid_token_index = [i for i in range(len(input_data)) if len(input_data[i]) <= max_len]
    X_data = np.array(input_data)[valid_token_index]
    A_data = np.array(attention_data)[valid_token_index]
    Y_data = np.array(label_data)[valid_token_index]

    dataset_size = len(X_data)

    # Determining index to split dataset
    random_id = random.sample(range(dataset_size), dataset_size)
    train_split_id = int(train_ratio * dataset_size)
    val_split_id = int((train_ratio + val_ratio) * dataset_size)

    train_ids = random_id[:train_split_id]
    val_ids = random_id[train_split_id:val_split_id]
    test_ids = random_id[val_split_id:]

    X_train = torch.tensor(list(X_data[train_ids]))
    A_train = torch.tensor(list(A_data[train_ids]))
    Y_train = torch.tensor(list(Y_data[train_ids]))

    X_val = torch.tensor(list(X_data[val_ids]))
    A_val = torch.tensor(list(A_data[val_ids]))
    Y_val = torch.tensor(list(Y_data[val_ids]))

    X_test = torch.tensor(list(X_data[test_ids]))
    A_test = torch.tensor(list(A_data[test_ids]))
    Y_test = torch.tensor(list(Y_data[test_ids]))

    return (X_train, A_train, Y_train), (X_val, A_val, Y_val), (X_test, A_test, Y_test)

# %%
def tokenize(code_df, model_name='codebert-base'):
    """
    Apply the tokenizer from the huggingface pretrained model

    :param code_df: dataframe of preprocess code (from jsonl)
    :param model_name: model name (targeting local install)
    :return: 3 tuples for train val and test containing (input, attention, target)
    """
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    inputs = tokenizer(code_df['func'].tolist(), truncation=False, padding='max_length', max_length=512)

    input_data = inputs['input_ids']
    attention_data = inputs['attention_mask']
    label_data = torch.tensor(code_df['target'].tolist())  # TODO - this can be directly converted to a np array

    print("Data points: {}".format(len(input_data)))

    return split_data(input_data, attention_data, label_data, max_len=512)

# %%
def tokenize_256(code_df, model_name='codebert-base'):
    """
    Apply the tokenizer from the huggingface pretrained model

    :param code_df: dataframe of preprocess code (from jsonl)
    :param model_name: model name (targeting local install)
    :return: 3 tuples for train val and test containing (input, attention, target)
    """
    tokenizer = RobertaTokenizer.from_pretrained(model_name)

    inputs = tokenizer.batch_encode_plus(code_df['func'].tolist(), truncation=False)

    input_data = inputs['input_ids']
    attention_data = inputs['attention_mask']
    label_data = torch.tensor(code_df['target'].tolist())  # TODO - this can be directly converted to a np array

    pruned_data = list(np.array(code_df['func'])[[i for i in range(len(input_data)) if len(input_data[i]) <= 256]])

    inputs = tokenizer.batch_encode_plus(pruned_data, truncation=False, padding='max_length', max_length=256)
    input_data = inputs['input_ids']
    attention_data = inputs['attention_mask']
    label_data = torch.tensor(code_df['target'].tolist())  # TODO - this can be directly converted to a np array


    return split_data(input_data, attention_data, label_data, max_len=512)

# %%
def train(model, train_data, val_data, epochs=5, batch_size=16, learning_rate=2e-5, validate_per=500,
          run_name="temp", run_descrption=None):
    """
    Main fine-tuning training loop for the provided model

    :param model: model loaded with predefined weights
    :param train_data: tuple of X_train, A_train, Y_train (X = inputs, A = attention, Y = target)
    :param val_data: tuple X_val, A_val, Y_val
    :param epochs: number of epochs for training
    :param batch_size: batch size (see note below about batch_hack)
    :param learning_rate: optimizer learning rate
    :param validate_per: number of weight updates before validation occurs
                            (notes: - if batch_size = 32, and validate_per = 32, validation will occur every batch
                                    - this is wrt the start of each epoch
                                    - validation will always occour at the start of each epoch (step 0))
    :param run_name: name used to saving checkpoints and log files within codebert_finetune_runs
    :param run_descrption: string that is saved to info.txt describing the run


    :return: None (models are saved in checkpoints along with log data)
    """


    # Saving run description.txt
    if run_descrption is not None:
        with open("{}/info.txt".format(dir_name), "a+") as f:
            f.write(run_descrption)

    # Unpacking data
    X_train, A_train, Y_train = train_data
    X_val, A_val, Y_val = val_data


    batch_hack = batch_size  # See note below regarding limited GPU memory

    # Initializing arrays for tracking loss
    train_loss_hist = []
    val_loss_hist = []
    train_pred_hist = []
    # Counter to track batches (see note below related to GPU memory)
    batch_count = 0
    # validate_per_batch = int(validate_per/batch_hack)

    # Moving model to GPU if configured
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = AdamW(model.parameters(), lr=learning_rate)

    validate_per = int(validate_per/batch_size)

    for epoch in range(epochs):

        # Generating random index for manual shuffling of data each epoch as note using DataLoaders
        permutation = torch.randperm(X_train.shape[0])

        # Note here that only a single element is loaded at each iteration (batch size = 1) due to GPU memory constraint
        for batch_id, i in enumerate(range(0, X_train.shape[0], batch_hack)):

            # Loading batch and moving to device
            indices = permutation[i:i + batch_hack]
            batch_X, batch_Y, batch_A = X_train[indices].to(device), Y_train[indices].to(device), A_train[indices].to(device)

            model.train()

            # Forward pass
            outputs = model(batch_X,labels=batch_Y, attention_mask=batch_A)
            #loss = criterion(loss_clsf.float(), batch_Y_one_hot.float())
            loss = outputs.loss
            #print(loss)

            # Backward pass
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            loss_clsf = nn.Softmax(dim=1)(outputs.logits)
            acc = np.average(torch.eq(batch_Y.cpu(), loss_clsf.argmax(axis=1).cpu()))
            #rint(correct)

            # Tracking loss
            train_loss_hist.append(float(loss.item()))
            train_pred_hist.append(acc)

            # Training output
            train_output = "Epoch:{} Step:{} Training_loss:{:.6f}, Acc_avg:{:.2f}%".format(epoch, i, loss.item(), np.sum(100*train_pred_hist[-50:])/min(len(train_pred_hist), 50))
            print(train_output+" Training_loss_avg:{:.6f}".format(np.average(train_loss_hist[-50:])))
            with open("{}/train_loss.txt".format(dir_name), "a+") as f:
                f.write(train_output+"\n")

            # Validation
            if batch_id % validate_per == 0:
                val_loss_total = 0
                model.eval()
                print("Validating:")
                val_acc = []
                for val_badtch_id, j in tqdm(enumerate(range(0, X_val.shape[0], batch_hack))):
                    # Loading singular validation data (overwrites train data as can only load 1 intp GPU)
                    batch_X, batch_Y, batch_A = X_val[j:j+batch_hack].to(device), Y_val[j:j+batch_hack].to(device), A_val[j:j+batch_hack].to(device)

                    with torch.no_grad():
                        val_outputs = model(batch_X, labels=batch_Y, attention_mask=batch_A)
                    val_loss_total += float(val_outputs['loss'].item())

                    
                    val_clsf = nn.Softmax(dim=1)(val_outputs.logits)
                    val_acc.append(np.average(torch.eq(batch_Y.cpu(), val_clsf.argmax(axis=1).cpu())))

                    del batch_X
                    del batch_Y

                # Adding average loss to tracker
                val_average = val_loss_total / (val_badtch_id+1)
                val_loss_hist.append(val_average)

                # Validation output and logging
                val_output = "Epoch:{} Step:{} Val_loss:{:.6f}, Val_Acc_avg:{:.2f}%".format(epoch, i, val_average, np.sum(100*val_acc[-50:])/min(len(val_acc), 50))
                print(val_output)
                with open("{}/val_los.txt".format(dir_name), "a+") as f:
                    f.write(val_output+"\n")

        # End of epoch checkpoint
        model.save_pretrained("{}/epoch_{}".format(dir_name, epoch + 1))

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """

    run_name = "test_colab_GPU_highRAM_8_val_8"
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False

    code_df = preprocess_data(file_loc='code_dataset.jsonl')
    train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

    # Loading model from checkpoint if location provided
    if online:
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=2e-5,
          validate_per=100,
          run_name=run_name,
          run_descrption="Colab with highRam, lr=2e-5, validate per 100, batch 16")

# %%
gc.collect()
torch.cuda.empty_cache()
main()

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """

    run_name = "test_colab_GPU_highRAM_8_lr_5e-6"
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False

    code_df = preprocess_data(file_loc='code_dataset.jsonl')
    train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

    # Loading model from checkpoint if location provided
    if online:
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=5e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="Colab with highRam, lr=5e-6, validate per 259, batch 8")

# %%
gc.collect()
torch.cuda.empty_cache()
main()

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """

    run_name = "test_colab_GPU_highRAM_8_lr_5e-6_10epochs"
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False

    code_df = preprocess_data(file_loc='code_dataset.jsonl')
    train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

    # Loading model from checkpoint if location provided
    if online:
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=10,
          batch_size=8,
          learning_rate=5e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="Colab with highRam, lr=5e-6, validate per 250, batch 8, 10epochs")

# %%
gc.collect()
torch.cuda.empty_cache()
main()

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """

    run_name = "test_colab_GPU_highRAM_very__verylow_very_lr_(5e-7)"
    model_name = 'codebert-base'
    checkpoint_location = '/content/drive/MyDrive/CS5814/HW3/codebert_finetune_runs/test_colab_GPU_highRAM_8_lr_5e-6/epoch_5'
    online = False

    code_df = preprocess_data(file_loc='code_dataset.jsonl')
    train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

    # Loading model from checkpoint if location provided
    if online:
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=5e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="Colab with highRam, lr=5e-7, validate per 250, batch 8, 5epochs")

# %%
gc.collect()
torch.cuda.empty_cache()
main()

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """

    run_name = "Softmax + CEL_3e-6 acc 3 good?"
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False

    code_df = preprocess_data(file_loc='code_dataset.jsonl')
    train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

    # Loading model from checkpoint if location provided
    if online:
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=3e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="Colab with Softmax + CrossEntropyLoss, lr=3e-6, validate per 250, batch 8, 5 epochs")

# %%
torch.cuda.empty_cache()
main()
# Out:
# Insecure code counts: 3729, Total code counts: 8000, Proportion 0.466125
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Some weights of the model checkpoint at codebert-base were not used when initializing RobertaForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at codebert-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:0 Step:0 Training_loss:0.633118, Acc_avg:62.50% Training_loss_avg:0.633118
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:0 Val_loss:0.673894, Val_Acc_avg:56.94%
# Epoch:0 Step:8 Training_loss:0.675437, Acc_avg:68.75% Training_loss_avg:0.654277
# Epoch:0 Step:16 Training_loss:0.779569, Acc_avg:58.33% Training_loss_avg:0.696041
# Epoch:0 Step:24 Training_loss:0.750523, Acc_avg:53.12% Training_loss_avg:0.709662
# Epoch:0 Step:32 Training_loss:0.651663, Acc_avg:57.50% Training_loss_avg:0.698062
# Epoch:0 Step:40 Training_loss:0.725335, Acc_avg:54.17% Training_loss_avg:0.702607
# Epoch:0 Step:48 Training_loss:0.818100, Acc_avg:50.00% Training_loss_avg:0.719106
# Epoch:0 Step:56 Training_loss:0.605680, Acc_avg:53.12% Training_loss_avg:0.704928
# Epoch:0 Step:64 Training_loss:0.646780, Acc_avg:55.56% Training_loss_avg:0.698467
# Epoch:0 Step:72 Training_loss:0.807646, Acc_avg:52.50% Training_loss_avg:0.709385
# Epoch:0 Step:80 Training_loss:0.726775, Acc_avg:51.14% Training_loss_avg:0.710966
# Epoch:0 Step:88 Training_loss:0.629971, Acc_avg:53.12% Training_loss_avg:0.704216
# Epoch:0 Step:96 Training_loss:0.709214, Acc_avg:52.88% Training_loss_avg:0.704601
# Epoch:0 Step:104 Training_loss:0.625205, Acc_avg:54.46% Training_loss_avg:0.698930
# Epoch:0 Step:112 Training_loss:0.710893, Acc_avg:55.00% Training_loss_avg:0.699727
# Epoch:0 Step:120 Training_loss:0.722622, Acc_avg:54.69% Training_loss_avg:0.701158
# Epoch:0 Step:128 Training_loss:0.643689, Acc_avg:55.15% Training_loss_avg:0.697778
# Epoch:0 Step:136 Training_loss:0.682494, Acc_avg:56.25% Training_loss_avg:0.696929
# Epoch:0 Step:144 Training_loss:0.708131, Acc_avg:55.26% Training_loss_avg:0.697518
# Epoch:0 Step:152 Training_loss:0.748320, Acc_avg:53.75% Training_loss_avg:0.700058
# Epoch:0 Step:160 Training_loss:0.671687, Acc_avg:54.17% Training_loss_avg:0.698707
# Epoch:0 Step:168 Training_loss:0.634354, Acc_avg:54.55% Training_loss_avg:0.695782
# Epoch:0 Step:176 Training_loss:0.684331, Acc_avg:53.80% Training_loss_avg:0.695284
# Epoch:0 Step:184 Training_loss:0.732768, Acc_avg:53.65% Training_loss_avg:0.696846
# Epoch:0 Step:192 Training_loss:0.649553, Acc_avg:54.00% Training_loss_avg:0.694954
# Epoch:0 Step:200 Training_loss:0.617307, Acc_avg:54.81% Training_loss_avg:0.691968
# Epoch:0 Step:208 Training_loss:0.710583, Acc_avg:55.09% Training_loss_avg:0.692657
# Epoch:0 Step:216 Training_loss:0.680113, Acc_avg:55.36% Training_loss_avg:0.692209
# Epoch:0 Step:224 Training_loss:0.616265, Acc_avg:56.03% Training_loss_avg:0.689591
# Epoch:0 Step:232 Training_loss:0.619051, Acc_avg:56.25% Training_loss_avg:0.687239
# Epoch:0 Step:240 Training_loss:0.665403, Acc_avg:56.85% Training_loss_avg:0.686535
# Epoch:0 Step:248 Training_loss:0.748358, Acc_avg:56.64% Training_loss_avg:0.688467
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:248 Val_loss:0.673586, Val_Acc_avg:59.25%
# Epoch:0 Step:256 Training_loss:0.587489, Acc_avg:57.20% Training_loss_avg:0.685407
# Epoch:0 Step:264 Training_loss:0.622195, Acc_avg:57.35% Training_loss_avg:0.683548
# Epoch:0 Step:272 Training_loss:0.768407, Acc_avg:56.79% Training_loss_avg:0.685972
# Epoch:0 Step:280 Training_loss:0.771040, Acc_avg:56.25% Training_loss_avg:0.688335
# Epoch:0 Step:288 Training_loss:0.690655, Acc_avg:56.42% Training_loss_avg:0.688398
# Epoch:0 Step:296 Training_loss:0.682747, Acc_avg:56.58% Training_loss_avg:0.688249
# Epoch:0 Step:304 Training_loss:0.623555, Acc_avg:57.05% Training_loss_avg:0.686590
# Epoch:0 Step:312 Training_loss:0.648722, Acc_avg:57.19% Training_loss_avg:0.685644
# Epoch:0 Step:320 Training_loss:0.784786, Acc_avg:56.71% Training_loss_avg:0.688062
# Epoch:0 Step:328 Training_loss:0.716739, Acc_avg:55.95% Training_loss_avg:0.688745
# Epoch:0 Step:336 Training_loss:0.889229, Acc_avg:54.94% Training_loss_avg:0.693407
# Epoch:0 Step:344 Training_loss:0.661088, Acc_avg:55.11% Training_loss_avg:0.692672
# Epoch:0 Step:352 Training_loss:0.681475, Acc_avg:55.28% Training_loss_avg:0.692424
# Epoch:0 Step:360 Training_loss:0.713131, Acc_avg:54.89% Training_loss_avg:0.692874
# Epoch:0 Step:368 Training_loss:0.648551, Acc_avg:55.32% Training_loss_avg:0.691931
# Epoch:0 Step:376 Training_loss:0.828586, Acc_avg:54.69% Training_loss_avg:0.694778
# Epoch:0 Step:384 Training_loss:0.723367, Acc_avg:54.34% Training_loss_avg:0.695361
# Epoch:0 Step:392 Training_loss:0.703710, Acc_avg:54.25% Training_loss_avg:0.695528
# Epoch:0 Step:400 Training_loss:0.797831, Acc_avg:53.50% Training_loss_avg:0.698822
# Epoch:0 Step:408 Training_loss:0.675573, Acc_avg:53.25% Training_loss_avg:0.698825
# Epoch:0 Step:416 Training_loss:0.728654, Acc_avg:53.25% Training_loss_avg:0.697807
# Epoch:0 Step:424 Training_loss:0.735500, Acc_avg:53.00% Training_loss_avg:0.697506
# Epoch:0 Step:432 Training_loss:0.745387, Acc_avg:52.25% Training_loss_avg:0.699381
# Epoch:0 Step:440 Training_loss:0.616765, Acc_avg:53.25% Training_loss_avg:0.697210
# Epoch:0 Step:448 Training_loss:0.622069, Acc_avg:54.50% Training_loss_avg:0.693289
# Epoch:0 Step:456 Training_loss:0.739230, Acc_avg:53.75% Training_loss_avg:0.695960
# Epoch:0 Step:464 Training_loss:0.660836, Acc_avg:53.75% Training_loss_avg:0.696241
# Epoch:0 Step:472 Training_loss:0.731702, Acc_avg:53.75% Training_loss_avg:0.694722
# Epoch:0 Step:480 Training_loss:0.693090, Acc_avg:54.00% Training_loss_avg:0.694048
# Epoch:0 Step:488 Training_loss:0.705312, Acc_avg:53.75% Training_loss_avg:0.695555
# Epoch:0 Step:496 Training_loss:0.653596, Acc_avg:54.00% Training_loss_avg:0.694443
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:496 Val_loss:0.688325, Val_Acc_avg:54.62%
# Epoch:0 Step:504 Training_loss:0.697506, Acc_avg:53.50% Training_loss_avg:0.695889
# Epoch:0 Step:512 Training_loss:0.681556, Acc_avg:53.25% Training_loss_avg:0.695302
# Epoch:0 Step:520 Training_loss:0.664397, Acc_avg:53.75% Training_loss_avg:0.694138
# Epoch:0 Step:528 Training_loss:0.733375, Acc_avg:53.00% Training_loss_avg:0.695931
# Epoch:0 Step:536 Training_loss:0.746494, Acc_avg:52.00% Training_loss_avg:0.697211
# Epoch:0 Step:544 Training_loss:0.697829, Acc_avg:52.25% Training_loss_avg:0.697005
# Epoch:0 Step:552 Training_loss:0.688415, Acc_avg:53.00% Training_loss_avg:0.695807
# Epoch:0 Step:560 Training_loss:0.693687, Acc_avg:52.75% Training_loss_avg:0.696247
# Epoch:0 Step:568 Training_loss:0.677974, Acc_avg:52.75% Training_loss_avg:0.697120
# Epoch:0 Step:576 Training_loss:0.669706, Acc_avg:53.25% Training_loss_avg:0.696827
# Epoch:0 Step:584 Training_loss:0.680473, Acc_avg:53.50% Training_loss_avg:0.695781
# Epoch:0 Step:592 Training_loss:0.697214, Acc_avg:53.00% Training_loss_avg:0.696735
# Epoch:0 Step:600 Training_loss:0.615402, Acc_avg:53.00% Training_loss_avg:0.696696
# Epoch:0 Step:608 Training_loss:0.651996, Acc_avg:53.25% Training_loss_avg:0.695525
# Epoch:0 Step:616 Training_loss:0.676756, Acc_avg:53.00% Training_loss_avg:0.695458
# Epoch:0 Step:624 Training_loss:0.648645, Acc_avg:52.75% Training_loss_avg:0.696105
# Epoch:0 Step:632 Training_loss:0.703860, Acc_avg:52.75% Training_loss_avg:0.697801
# Epoch:0 Step:640 Training_loss:0.729501, Acc_avg:51.75% Training_loss_avg:0.699083
# Epoch:0 Step:648 Training_loss:0.761707, Acc_avg:51.50% Training_loss_avg:0.699350
# Epoch:0 Step:656 Training_loss:0.722121, Acc_avg:50.75% Training_loss_avg:0.702043
# Epoch:0 Step:664 Training_loss:0.590094, Acc_avg:51.25% Training_loss_avg:0.701401
# Epoch:0 Step:672 Training_loss:0.677995, Acc_avg:52.00% Training_loss_avg:0.699593
# Epoch:0 Step:680 Training_loss:0.736920, Acc_avg:52.00% Training_loss_avg:0.698910
# Epoch:0 Step:688 Training_loss:0.699240, Acc_avg:51.75% Training_loss_avg:0.699082
# Epoch:0 Step:696 Training_loss:0.708713, Acc_avg:51.50% Training_loss_avg:0.699601
# Epoch:0 Step:704 Training_loss:0.739731, Acc_avg:51.00% Training_loss_avg:0.701925
# Epoch:0 Step:712 Training_loss:0.628983, Acc_avg:51.25% Training_loss_avg:0.701530
# Epoch:0 Step:720 Training_loss:0.725301, Acc_avg:51.50% Training_loss_avg:0.700340
# Epoch:0 Step:728 Training_loss:0.722451, Acc_avg:52.00% Training_loss_avg:0.700455
# Epoch:0 Step:736 Training_loss:0.798966, Acc_avg:52.25% Training_loss_avg:0.698649
# Epoch:0 Step:744 Training_loss:0.766286, Acc_avg:51.75% Training_loss_avg:0.700753
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:744 Val_loss:0.674684, Val_Acc_avg:59.25%
# Epoch:0 Step:752 Training_loss:0.790463, Acc_avg:51.25% Training_loss_avg:0.702933
# Epoch:0 Step:760 Training_loss:0.681762, Acc_avg:51.50% Training_loss_avg:0.702306
# Epoch:0 Step:768 Training_loss:0.584669, Acc_avg:51.50% Training_loss_avg:0.701028
# Epoch:0 Step:776 Training_loss:0.740703, Acc_avg:51.75% Training_loss_avg:0.699270
# Epoch:0 Step:784 Training_loss:0.635990, Acc_avg:52.25% Training_loss_avg:0.697523
# Epoch:0 Step:792 Training_loss:0.617338, Acc_avg:52.75% Training_loss_avg:0.695795
# Epoch:0 Step:800 Training_loss:0.613840, Acc_avg:54.00% Training_loss_avg:0.692115
# Epoch:0 Step:808 Training_loss:0.673402, Acc_avg:53.75% Training_loss_avg:0.692072
# Epoch:0 Step:816 Training_loss:0.680003, Acc_avg:54.50% Training_loss_avg:0.691099
# Epoch:0 Step:824 Training_loss:0.653167, Acc_avg:55.00% Training_loss_avg:0.689452
# Epoch:0 Step:832 Training_loss:0.637615, Acc_avg:55.50% Training_loss_avg:0.687297
# Epoch:0 Step:840 Training_loss:0.673419, Acc_avg:55.00% Training_loss_avg:0.688430
# Epoch:0 Step:848 Training_loss:0.681866, Acc_avg:54.25% Training_loss_avg:0.689626
# Epoch:0 Step:856 Training_loss:0.753345, Acc_avg:54.00% Training_loss_avg:0.689908
# Epoch:0 Step:864 Training_loss:0.616720, Acc_avg:54.00% Training_loss_avg:0.689026
# Epoch:0 Step:872 Training_loss:0.708577, Acc_avg:54.50% Training_loss_avg:0.688563
# Epoch:0 Step:880 Training_loss:0.800875, Acc_avg:53.75% Training_loss_avg:0.690719
# Epoch:0 Step:888 Training_loss:0.678238, Acc_avg:53.50% Training_loss_avg:0.690178
# Epoch:0 Step:896 Training_loss:0.774521, Acc_avg:52.75% Training_loss_avg:0.692596
# Epoch:0 Step:904 Training_loss:0.594872, Acc_avg:53.25% Training_loss_avg:0.690543
# Epoch:0 Step:912 Training_loss:0.713662, Acc_avg:53.25% Training_loss_avg:0.691186
# Epoch:0 Step:920 Training_loss:0.772708, Acc_avg:52.25% Training_loss_avg:0.693352
# Epoch:0 Step:928 Training_loss:0.768550, Acc_avg:52.50% Training_loss_avg:0.694055
# Epoch:0 Step:936 Training_loss:0.799034, Acc_avg:52.00% Training_loss_avg:0.695106
# Epoch:0 Step:944 Training_loss:0.683598, Acc_avg:52.00% Training_loss_avg:0.694822
# Epoch:0 Step:952 Training_loss:0.658547, Acc_avg:52.50% Training_loss_avg:0.694224
# Epoch:0 Step:960 Training_loss:0.625416, Acc_avg:53.25% Training_loss_avg:0.692859
# Epoch:0 Step:968 Training_loss:0.682036, Acc_avg:53.50% Training_loss_avg:0.692940
# Epoch:0 Step:976 Training_loss:0.739468, Acc_avg:52.75% Training_loss_avg:0.694335
# Epoch:0 Step:984 Training_loss:0.748103, Acc_avg:52.00% Training_loss_avg:0.695688
# Epoch:0 Step:992 Training_loss:0.762161, Acc_avg:51.75% Training_loss_avg:0.696987
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:992 Val_loss:0.678709, Val_Acc_avg:47.69%
# Epoch:0 Step:1000 Training_loss:0.706854, Acc_avg:51.50% Training_loss_avg:0.698816
# Epoch:0 Step:1008 Training_loss:0.681189, Acc_avg:51.25% Training_loss_avg:0.699400
# Epoch:0 Step:1016 Training_loss:0.711231, Acc_avg:51.00% Training_loss_avg:0.700089
# Epoch:0 Step:1024 Training_loss:0.702105, Acc_avg:50.50% Training_loss_avg:0.701158
# Epoch:0 Step:1032 Training_loss:0.757104, Acc_avg:50.00% Training_loss_avg:0.702223
# Epoch:0 Step:1040 Training_loss:0.738499, Acc_avg:50.50% Training_loss_avg:0.702403
# Epoch:0 Step:1048 Training_loss:0.749651, Acc_avg:50.50% Training_loss_avg:0.702162
# Epoch:0 Step:1056 Training_loss:0.688095, Acc_avg:51.00% Training_loss_avg:0.701482
# Epoch:0 Step:1064 Training_loss:0.662426, Acc_avg:50.50% Training_loss_avg:0.702928
# Epoch:0 Step:1072 Training_loss:0.709186, Acc_avg:50.00% Training_loss_avg:0.703552
# Epoch:0 Step:1080 Training_loss:0.662831, Acc_avg:50.25% Training_loss_avg:0.702070
# Epoch:0 Step:1088 Training_loss:0.712658, Acc_avg:50.25% Training_loss_avg:0.702339
# Epoch:0 Step:1096 Training_loss:0.661591, Acc_avg:50.25% Training_loss_avg:0.701396
# Epoch:0 Step:1104 Training_loss:0.682391, Acc_avg:50.50% Training_loss_avg:0.700249
# Epoch:0 Step:1112 Training_loss:0.698041, Acc_avg:50.25% Training_loss_avg:0.701630
# Epoch:0 Step:1120 Training_loss:0.714682, Acc_avg:50.50% Training_loss_avg:0.701418
# Epoch:0 Step:1128 Training_loss:0.725547, Acc_avg:50.50% Training_loss_avg:0.701480
# Epoch:0 Step:1136 Training_loss:0.715323, Acc_avg:51.25% Training_loss_avg:0.699807
# Epoch:0 Step:1144 Training_loss:0.647114, Acc_avg:52.00% Training_loss_avg:0.697424
# Epoch:0 Step:1152 Training_loss:0.692482, Acc_avg:52.25% Training_loss_avg:0.695464
# Epoch:0 Step:1160 Training_loss:0.730154, Acc_avg:52.00% Training_loss_avg:0.696432
# Epoch:0 Step:1168 Training_loss:0.726963, Acc_avg:51.00% Training_loss_avg:0.699278
# Epoch:0 Step:1176 Training_loss:0.706297, Acc_avg:51.25% Training_loss_avg:0.698590
# Epoch:0 Step:1184 Training_loss:0.694644, Acc_avg:51.25% Training_loss_avg:0.699763
# Epoch:0 Step:1192 Training_loss:0.738029, Acc_avg:50.50% Training_loss_avg:0.702177
# Epoch:0 Step:1200 Training_loss:0.735357, Acc_avg:49.50% Training_loss_avg:0.704607
# Epoch:0 Step:1208 Training_loss:0.730625, Acc_avg:49.25% Training_loss_avg:0.705751
# Epoch:0 Step:1216 Training_loss:0.671586, Acc_avg:48.75% Training_loss_avg:0.705583
# Epoch:0 Step:1224 Training_loss:0.697533, Acc_avg:48.75% Training_loss_avg:0.706470
# Epoch:0 Step:1232 Training_loss:0.715647, Acc_avg:47.75% Training_loss_avg:0.708031
# Epoch:0 Step:1240 Training_loss:0.695850, Acc_avg:48.00% Training_loss_avg:0.708480
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:1240 Val_loss:0.698467, Val_Acc_avg:52.31%
# Epoch:0 Step:1248 Training_loss:0.724404, Acc_avg:47.75% Training_loss_avg:0.709330
# Epoch:0 Step:1256 Training_loss:0.692155, Acc_avg:48.25% Training_loss_avg:0.708107
# Epoch:0 Step:1264 Training_loss:0.716552, Acc_avg:47.25% Training_loss_avg:0.710103
# Epoch:0 Step:1272 Training_loss:0.666370, Acc_avg:47.25% Training_loss_avg:0.709259
# Epoch:0 Step:1280 Training_loss:0.673482, Acc_avg:48.50% Training_loss_avg:0.706711
# Epoch:0 Step:1288 Training_loss:0.697000, Acc_avg:48.50% Training_loss_avg:0.707086
# Epoch:0 Step:1296 Training_loss:0.678200, Acc_avg:49.50% Training_loss_avg:0.705160
# Epoch:0 Step:1304 Training_loss:0.709370, Acc_avg:49.00% Training_loss_avg:0.707450
# Epoch:0 Step:1312 Training_loss:0.700345, Acc_avg:48.75% Training_loss_avg:0.707184
# Epoch:0 Step:1320 Training_loss:0.744075, Acc_avg:48.75% Training_loss_avg:0.706611
# Epoch:0 Step:1328 Training_loss:0.713192, Acc_avg:48.50% Training_loss_avg:0.705504
# Epoch:0 Step:1336 Training_loss:0.729165, Acc_avg:49.50% Training_loss_avg:0.704106
# Epoch:0 Step:1344 Training_loss:0.645990, Acc_avg:50.00% Training_loss_avg:0.703354
# Epoch:0 Step:1352 Training_loss:0.660348, Acc_avg:50.00% Training_loss_avg:0.703390
# Epoch:0 Step:1360 Training_loss:0.686655, Acc_avg:49.75% Training_loss_avg:0.704615
# Epoch:0 Step:1368 Training_loss:0.676725, Acc_avg:49.75% Training_loss_avg:0.704509
# Epoch:0 Step:1376 Training_loss:0.741124, Acc_avg:50.25% Training_loss_avg:0.704542
# Epoch:0 Step:1384 Training_loss:0.658047, Acc_avg:51.00% Training_loss_avg:0.702741
# Epoch:0 Step:1392 Training_loss:0.660818, Acc_avg:52.00% Training_loss_avg:0.700714
# Epoch:0 Step:1400 Training_loss:0.694251, Acc_avg:51.75% Training_loss_avg:0.700462
# Epoch:0 Step:1408 Training_loss:0.688905, Acc_avg:51.50% Training_loss_avg:0.700616
# Epoch:0 Step:1416 Training_loss:0.650709, Acc_avg:52.00% Training_loss_avg:0.699406
# Epoch:0 Step:1424 Training_loss:0.781124, Acc_avg:51.75% Training_loss_avg:0.700986
# Epoch:0 Step:1432 Training_loss:0.660421, Acc_avg:52.25% Training_loss_avg:0.699053
# Epoch:0 Step:1440 Training_loss:0.744001, Acc_avg:52.25% Training_loss_avg:0.699163
# Epoch:0 Step:1448 Training_loss:0.652042, Acc_avg:53.00% Training_loss_avg:0.697210
# Epoch:0 Step:1456 Training_loss:0.750693, Acc_avg:52.50% Training_loss_avg:0.698462
# Epoch:0 Step:1464 Training_loss:0.727015, Acc_avg:52.00% Training_loss_avg:0.699754
# Epoch:0 Step:1472 Training_loss:0.766171, Acc_avg:51.25% Training_loss_avg:0.700894
# Epoch:0 Step:1480 Training_loss:0.621107, Acc_avg:51.75% Training_loss_avg:0.700059
# Epoch:0 Step:1488 Training_loss:0.696233, Acc_avg:51.75% Training_loss_avg:0.699731
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1488 Val_loss:0.675637, Val_Acc_avg:56.94%
# Epoch:0 Step:1496 Training_loss:0.808376, Acc_avg:51.25% Training_loss_avg:0.702667
# Epoch:0 Step:1504 Training_loss:0.654480, Acc_avg:51.50% Training_loss_avg:0.702108
# Epoch:0 Step:1512 Training_loss:0.671999, Acc_avg:51.50% Training_loss_avg:0.701587
# Epoch:0 Step:1520 Training_loss:0.679135, Acc_avg:51.50% Training_loss_avg:0.700877
# Epoch:0 Step:1528 Training_loss:0.660422, Acc_avg:51.75% Training_loss_avg:0.699574
# Epoch:0 Step:1536 Training_loss:0.649658, Acc_avg:52.00% Training_loss_avg:0.698261
# Epoch:0 Step:1544 Training_loss:0.745932, Acc_avg:51.25% Training_loss_avg:0.700237
# Epoch:0 Step:1552 Training_loss:0.700784, Acc_avg:51.25% Training_loss_avg:0.700403
# Epoch:0 Step:1560 Training_loss:0.635718, Acc_avg:51.75% Training_loss_avg:0.698514
# Epoch:0 Step:1568 Training_loss:0.632935, Acc_avg:52.75% Training_loss_avg:0.696634
# Epoch:0 Step:1576 Training_loss:0.686631, Acc_avg:53.25% Training_loss_avg:0.696241
# Epoch:0 Step:1584 Training_loss:0.761745, Acc_avg:52.75% Training_loss_avg:0.697583
# Epoch:0 Step:1592 Training_loss:0.670811, Acc_avg:53.50% Training_loss_avg:0.696238
# Epoch:0 Step:1600 Training_loss:0.712662, Acc_avg:53.75% Training_loss_avg:0.695784
# Epoch:0 Step:1608 Training_loss:0.697737, Acc_avg:53.75% Training_loss_avg:0.695127
# Epoch:0 Step:1616 Training_loss:0.681601, Acc_avg:54.00% Training_loss_avg:0.695327
# Epoch:0 Step:1624 Training_loss:0.663997, Acc_avg:54.50% Training_loss_avg:0.694656
# Epoch:0 Step:1632 Training_loss:0.648587, Acc_avg:55.75% Training_loss_avg:0.693315
# Epoch:0 Step:1640 Training_loss:0.667195, Acc_avg:55.50% Training_loss_avg:0.692742
# Epoch:0 Step:1648 Training_loss:0.715300, Acc_avg:55.50% Training_loss_avg:0.692560
# Epoch:0 Step:1656 Training_loss:0.732011, Acc_avg:55.75% Training_loss_avg:0.693357
# Epoch:0 Step:1664 Training_loss:0.625027, Acc_avg:56.75% Training_loss_avg:0.691526
# Epoch:0 Step:1672 Training_loss:0.698709, Acc_avg:56.75% Training_loss_avg:0.692173
# Epoch:0 Step:1680 Training_loss:0.668525, Acc_avg:56.50% Training_loss_avg:0.692074
# Epoch:0 Step:1688 Training_loss:0.610843, Acc_avg:57.25% Training_loss_avg:0.690351
# Epoch:0 Step:1696 Training_loss:0.676662, Acc_avg:57.00% Training_loss_avg:0.690320
# Epoch:0 Step:1704 Training_loss:0.778534, Acc_avg:56.50% Training_loss_avg:0.691703
# Epoch:0 Step:1712 Training_loss:0.685192, Acc_avg:57.00% Training_loss_avg:0.691400
# Epoch:0 Step:1720 Training_loss:0.675984, Acc_avg:57.75% Training_loss_avg:0.690039
# Epoch:0 Step:1728 Training_loss:0.670276, Acc_avg:58.50% Training_loss_avg:0.689180
# Epoch:0 Step:1736 Training_loss:0.671296, Acc_avg:58.75% Training_loss_avg:0.688023
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1736 Val_loss:0.674698, Val_Acc_avg:54.62%
# Epoch:0 Step:1744 Training_loss:0.647756, Acc_avg:58.50% Training_loss_avg:0.688058
# Epoch:0 Step:1752 Training_loss:0.649183, Acc_avg:58.25% Training_loss_avg:0.687835
# Epoch:0 Step:1760 Training_loss:0.618557, Acc_avg:58.50% Training_loss_avg:0.686473
# Epoch:0 Step:1768 Training_loss:0.636756, Acc_avg:58.50% Training_loss_avg:0.685674
# Epoch:0 Step:1776 Training_loss:0.621527, Acc_avg:59.00% Training_loss_avg:0.683282
# Epoch:0 Step:1784 Training_loss:0.711278, Acc_avg:58.75% Training_loss_avg:0.684346
# Epoch:0 Step:1792 Training_loss:0.640794, Acc_avg:58.50% Training_loss_avg:0.683946
# Epoch:0 Step:1800 Training_loss:0.692649, Acc_avg:58.50% Training_loss_avg:0.683914
# Epoch:0 Step:1808 Training_loss:0.677521, Acc_avg:58.50% Training_loss_avg:0.683686
# Epoch:0 Step:1816 Training_loss:0.746268, Acc_avg:58.00% Training_loss_avg:0.685597
# Epoch:0 Step:1824 Training_loss:0.750588, Acc_avg:58.50% Training_loss_avg:0.684986
# Epoch:0 Step:1832 Training_loss:0.625987, Acc_avg:58.75% Training_loss_avg:0.684298
# Epoch:0 Step:1840 Training_loss:0.651530, Acc_avg:59.00% Training_loss_avg:0.682448
# Epoch:0 Step:1848 Training_loss:0.689902, Acc_avg:58.75% Training_loss_avg:0.683206
# Epoch:0 Step:1856 Training_loss:0.732150, Acc_avg:58.75% Training_loss_avg:0.682835
# Epoch:0 Step:1864 Training_loss:0.696225, Acc_avg:59.00% Training_loss_avg:0.682219
# Epoch:0 Step:1872 Training_loss:0.735455, Acc_avg:59.75% Training_loss_avg:0.681605
# Epoch:0 Step:1880 Training_loss:0.678256, Acc_avg:59.50% Training_loss_avg:0.682748
# Epoch:0 Step:1888 Training_loss:0.713373, Acc_avg:59.25% Training_loss_avg:0.683090
# Epoch:0 Step:1896 Training_loss:0.652914, Acc_avg:60.00% Training_loss_avg:0.679981
# Epoch:0 Step:1904 Training_loss:0.776586, Acc_avg:59.25% Training_loss_avg:0.682423
# Epoch:0 Step:1912 Training_loss:0.647170, Acc_avg:59.50% Training_loss_avg:0.681927
# Epoch:0 Step:1920 Training_loss:0.673125, Acc_avg:59.25% Training_loss_avg:0.681806
# Epoch:0 Step:1928 Training_loss:0.635624, Acc_avg:59.50% Training_loss_avg:0.681310
# Epoch:0 Step:1936 Training_loss:0.632582, Acc_avg:59.25% Training_loss_avg:0.680969
# Epoch:0 Step:1944 Training_loss:0.635593, Acc_avg:60.00% Training_loss_avg:0.678762
# Epoch:0 Step:1952 Training_loss:0.603618, Acc_avg:60.50% Training_loss_avg:0.676819
# Epoch:0 Step:1960 Training_loss:0.822132, Acc_avg:59.75% Training_loss_avg:0.680547
# Epoch:0 Step:1968 Training_loss:0.663652, Acc_avg:59.75% Training_loss_avg:0.681161
# Epoch:0 Step:1976 Training_loss:0.626469, Acc_avg:59.75% Training_loss_avg:0.679958
# Epoch:0 Step:1984 Training_loss:0.585150, Acc_avg:60.75% Training_loss_avg:0.676426
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1984 Val_loss:0.672317, Val_Acc_avg:59.25%
# Epoch:0 Step:1992 Training_loss:0.659366, Acc_avg:60.50% Training_loss_avg:0.676197
# Epoch:0 Step:2000 Training_loss:0.565024, Acc_avg:61.25% Training_loss_avg:0.673245
# Epoch:0 Step:2008 Training_loss:0.646151, Acc_avg:61.75% Training_loss_avg:0.672213
# Epoch:0 Step:2016 Training_loss:0.646275, Acc_avg:61.75% Training_loss_avg:0.671506
# Epoch:0 Step:2024 Training_loss:0.784107, Acc_avg:61.25% Training_loss_avg:0.673909
# Epoch:0 Step:2032 Training_loss:0.689633, Acc_avg:60.75% Training_loss_avg:0.674730
# Epoch:0 Step:2040 Training_loss:0.707167, Acc_avg:60.50% Training_loss_avg:0.675529
# Epoch:0 Step:2048 Training_loss:0.860641, Acc_avg:60.25% Training_loss_avg:0.678436
# Epoch:0 Step:2056 Training_loss:0.775694, Acc_avg:59.50% Training_loss_avg:0.679309
# Epoch:0 Step:2064 Training_loss:0.731487, Acc_avg:58.75% Training_loss_avg:0.681439
# Epoch:0 Step:2072 Training_loss:0.699891, Acc_avg:58.75% Training_loss_avg:0.681462
# Epoch:0 Step:2080 Training_loss:0.744560, Acc_avg:58.50% Training_loss_avg:0.682983
# Epoch:0 Step:2088 Training_loss:0.549734, Acc_avg:58.25% Training_loss_avg:0.681761
# Epoch:0 Step:2096 Training_loss:0.533849, Acc_avg:58.75% Training_loss_avg:0.678905
# Epoch:0 Step:2104 Training_loss:0.705698, Acc_avg:59.50% Training_loss_avg:0.677448
# Epoch:0 Step:2112 Training_loss:0.644720, Acc_avg:59.50% Training_loss_avg:0.676638
# Epoch:0 Step:2120 Training_loss:0.686419, Acc_avg:59.50% Training_loss_avg:0.676847
# Epoch:0 Step:2128 Training_loss:0.580043, Acc_avg:59.75% Training_loss_avg:0.675042
# Epoch:0 Step:2136 Training_loss:0.668261, Acc_avg:59.75% Training_loss_avg:0.674982
# Epoch:0 Step:2144 Training_loss:0.725503, Acc_avg:59.50% Training_loss_avg:0.676537
# Epoch:0 Step:2152 Training_loss:0.736597, Acc_avg:59.00% Training_loss_avg:0.678285
# Epoch:0 Step:2160 Training_loss:0.647417, Acc_avg:58.50% Training_loss_avg:0.678862
# Epoch:0 Step:2168 Training_loss:0.629686, Acc_avg:58.50% Training_loss_avg:0.678721
# Epoch:0 Step:2176 Training_loss:0.663394, Acc_avg:58.25% Training_loss_avg:0.679558
# Epoch:0 Step:2184 Training_loss:0.680125, Acc_avg:58.25% Training_loss_avg:0.678935
# Epoch:0 Step:2192 Training_loss:0.742071, Acc_avg:57.50% Training_loss_avg:0.680961
# Epoch:0 Step:2200 Training_loss:0.705575, Acc_avg:57.75% Training_loss_avg:0.681219
# Epoch:0 Step:2208 Training_loss:0.671943, Acc_avg:58.00% Training_loss_avg:0.681108
# Epoch:0 Step:2216 Training_loss:0.604099, Acc_avg:58.75% Training_loss_avg:0.678264
# Epoch:0 Step:2224 Training_loss:0.632959, Acc_avg:59.25% Training_loss_avg:0.675912
# Epoch:0 Step:2232 Training_loss:0.737300, Acc_avg:58.50% Training_loss_avg:0.678138
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:2232 Val_loss:0.671919, Val_Acc_avg:56.94%
# Epoch:0 Step:2240 Training_loss:0.640401, Acc_avg:58.75% Training_loss_avg:0.677915
# Epoch:0 Step:2248 Training_loss:0.613197, Acc_avg:59.00% Training_loss_avg:0.676381
# Epoch:0 Step:2256 Training_loss:0.669889, Acc_avg:59.50% Training_loss_avg:0.675136
# Epoch:0 Step:2264 Training_loss:0.767562, Acc_avg:59.00% Training_loss_avg:0.676563
# Epoch:0 Step:2272 Training_loss:0.762321, Acc_avg:58.75% Training_loss_avg:0.677100
# Epoch:0 Step:2280 Training_loss:0.613891, Acc_avg:58.75% Training_loss_avg:0.675813
# Epoch:0 Step:2288 Training_loss:0.759069, Acc_avg:59.00% Training_loss_avg:0.676727
# Epoch:0 Step:2296 Training_loss:0.725534, Acc_avg:58.75% Training_loss_avg:0.678179
# Epoch:0 Step:2304 Training_loss:0.587636, Acc_avg:59.50% Training_loss_avg:0.674400
# Epoch:0 Step:2312 Training_loss:0.629180, Acc_avg:59.25% Training_loss_avg:0.674040
# Epoch:0 Step:2320 Training_loss:0.735448, Acc_avg:59.00% Training_loss_avg:0.675287
# Epoch:0 Step:2328 Training_loss:0.586955, Acc_avg:59.25% Training_loss_avg:0.674313
# Epoch:0 Step:2336 Training_loss:0.793432, Acc_avg:58.50% Training_loss_avg:0.677530
# Epoch:0 Step:2344 Training_loss:0.731966, Acc_avg:58.00% Training_loss_avg:0.679458
# Epoch:0 Step:2352 Training_loss:0.649871, Acc_avg:57.50% Training_loss_avg:0.680383
# Epoch:0 Step:2360 Training_loss:0.666344, Acc_avg:58.25% Training_loss_avg:0.677267
# Epoch:0 Step:2368 Training_loss:0.714677, Acc_avg:57.75% Training_loss_avg:0.678288
# Epoch:0 Step:2376 Training_loss:0.710644, Acc_avg:56.75% Training_loss_avg:0.679971
# Epoch:0 Step:2384 Training_loss:0.798668, Acc_avg:55.50% Training_loss_avg:0.684241
# Epoch:0 Step:2392 Training_loss:0.708675, Acc_avg:55.25% Training_loss_avg:0.685228
# Epoch:0 Step:2400 Training_loss:0.698788, Acc_avg:54.50% Training_loss_avg:0.687903
# Epoch:0 Step:2408 Training_loss:0.678233, Acc_avg:54.50% Training_loss_avg:0.688545
# Epoch:0 Step:2416 Training_loss:0.695452, Acc_avg:54.50% Training_loss_avg:0.689528
# Epoch:0 Step:2424 Training_loss:0.720478, Acc_avg:54.50% Training_loss_avg:0.688256
# Epoch:0 Step:2432 Training_loss:0.768588, Acc_avg:54.25% Training_loss_avg:0.689835
# Epoch:0 Step:2440 Training_loss:0.726699, Acc_avg:54.00% Training_loss_avg:0.690225
# Epoch:0 Step:2448 Training_loss:0.737308, Acc_avg:54.00% Training_loss_avg:0.687759
# Epoch:0 Step:2456 Training_loss:0.711653, Acc_avg:54.25% Training_loss_avg:0.686478
# Epoch:0 Step:2464 Training_loss:0.704559, Acc_avg:54.50% Training_loss_avg:0.685939
# Epoch:0 Step:2472 Training_loss:0.698939, Acc_avg:54.50% Training_loss_avg:0.685920
# Epoch:0 Step:2480 Training_loss:0.673036, Acc_avg:54.50% Training_loss_avg:0.684490
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:2480 Val_loss:0.683071, Val_Acc_avg:52.31%
# Epoch:0 Step:2488 Training_loss:0.651610, Acc_avg:54.25% Training_loss_avg:0.686527
# Epoch:0 Step:2496 Training_loss:0.684413, Acc_avg:53.50% Training_loss_avg:0.689539
# Epoch:0 Step:2504 Training_loss:0.702765, Acc_avg:53.25% Training_loss_avg:0.689480
# Epoch:0 Step:2512 Training_loss:0.645277, Acc_avg:53.50% Training_loss_avg:0.689491
# Epoch:0 Step:2520 Training_loss:0.714433, Acc_avg:53.00% Training_loss_avg:0.690051
# Epoch:0 Step:2528 Training_loss:0.699144, Acc_avg:52.25% Training_loss_avg:0.692433
# Epoch:0 Step:2536 Training_loss:0.682803, Acc_avg:52.00% Training_loss_avg:0.692724
# Epoch:0 Step:2544 Training_loss:0.658111, Acc_avg:52.50% Training_loss_avg:0.691376
# Epoch:0 Step:2552 Training_loss:0.683500, Acc_avg:53.00% Training_loss_avg:0.690314
# Epoch:0 Step:2560 Training_loss:0.778614, Acc_avg:52.00% Training_loss_avg:0.692938
# Epoch:0 Step:2568 Training_loss:0.657840, Acc_avg:52.25% Training_loss_avg:0.693501
# Epoch:0 Step:2576 Training_loss:0.671833, Acc_avg:52.50% Training_loss_avg:0.693670
# Epoch:0 Step:2584 Training_loss:0.636719, Acc_avg:52.75% Training_loss_avg:0.692802
# Epoch:0 Step:2592 Training_loss:0.694588, Acc_avg:53.00% Training_loss_avg:0.691852
# Epoch:0 Step:2600 Training_loss:0.658440, Acc_avg:53.00% Training_loss_avg:0.690910
# Epoch:0 Step:2608 Training_loss:0.671826, Acc_avg:53.00% Training_loss_avg:0.690907
# Epoch:0 Step:2616 Training_loss:0.664936, Acc_avg:52.75% Training_loss_avg:0.692124
# Epoch:0 Step:2624 Training_loss:0.693537, Acc_avg:52.75% Training_loss_avg:0.693336
# Epoch:0 Step:2632 Training_loss:0.609720, Acc_avg:53.50% Training_loss_avg:0.690784
# Epoch:0 Step:2640 Training_loss:0.683829, Acc_avg:53.00% Training_loss_avg:0.691653
# Epoch:0 Step:2648 Training_loss:0.708239, Acc_avg:52.25% Training_loss_avg:0.693553
# Epoch:0 Step:2656 Training_loss:0.684320, Acc_avg:52.50% Training_loss_avg:0.693842
# Epoch:0 Step:2664 Training_loss:0.703239, Acc_avg:53.00% Training_loss_avg:0.692556
# Epoch:0 Step:2672 Training_loss:0.725216, Acc_avg:53.25% Training_loss_avg:0.691814
# Epoch:0 Step:2680 Training_loss:0.680872, Acc_avg:52.75% Training_loss_avg:0.693153
# Epoch:0 Step:2688 Training_loss:0.723136, Acc_avg:52.50% Training_loss_avg:0.692434
# Epoch:0 Step:2696 Training_loss:0.681937, Acc_avg:52.75% Training_loss_avg:0.691563
# Epoch:0 Step:2704 Training_loss:0.691513, Acc_avg:52.00% Training_loss_avg:0.693640
# Epoch:0 Step:2712 Training_loss:0.741995, Acc_avg:51.25% Training_loss_avg:0.695896
# Epoch:0 Step:2720 Training_loss:0.673534, Acc_avg:51.75% Training_loss_avg:0.694658
# Epoch:0 Step:2728 Training_loss:0.655267, Acc_avg:51.25% Training_loss_avg:0.696024
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:0 Step:2728 Val_loss:0.680177, Val_Acc_avg:59.25%
# Epoch:0 Step:2736 Training_loss:0.711233, Acc_avg:51.75% Training_loss_avg:0.694380
# Epoch:0 Step:2744 Training_loss:0.734969, Acc_avg:51.25% Training_loss_avg:0.694440
# Epoch:0 Step:2752 Training_loss:0.631460, Acc_avg:51.75% Training_loss_avg:0.694072
# Epoch:0 Step:2760 Training_loss:0.752168, Acc_avg:51.25% Training_loss_avg:0.695789
# Epoch:0 Step:2768 Training_loss:0.709984, Acc_avg:51.25% Training_loss_avg:0.695695
# Epoch:0 Step:2776 Training_loss:0.741533, Acc_avg:51.50% Training_loss_avg:0.696313
# Epoch:0 Step:2784 Training_loss:0.704575, Acc_avg:51.75% Training_loss_avg:0.694431
# Epoch:0 Step:2792 Training_loss:0.696760, Acc_avg:51.50% Training_loss_avg:0.694192
# Epoch:0 Step:2800 Training_loss:0.719350, Acc_avg:51.25% Training_loss_avg:0.694604
# Epoch:0 Step:2808 Training_loss:0.705699, Acc_avg:51.00% Training_loss_avg:0.695153
# Epoch:0 Step:2816 Training_loss:0.752212, Acc_avg:50.50% Training_loss_avg:0.696288
# Epoch:0 Step:2824 Training_loss:0.727665, Acc_avg:50.50% Training_loss_avg:0.696432
# Epoch:0 Step:2832 Training_loss:0.663265, Acc_avg:51.25% Training_loss_avg:0.694325
# Epoch:0 Step:2840 Training_loss:0.678100, Acc_avg:51.50% Training_loss_avg:0.693353
# Epoch:0 Step:2848 Training_loss:0.711845, Acc_avg:52.00% Training_loss_avg:0.692844
# Epoch:0 Step:2856 Training_loss:0.637287, Acc_avg:53.00% Training_loss_avg:0.691357
# Epoch:0 Step:2864 Training_loss:0.652934, Acc_avg:53.25% Training_loss_avg:0.690324
# Epoch:0 Step:2872 Training_loss:0.633634, Acc_avg:54.00% Training_loss_avg:0.689018
# Epoch:0 Step:2880 Training_loss:0.791411, Acc_avg:53.50% Training_loss_avg:0.691386
# Epoch:0 Step:2888 Training_loss:0.678837, Acc_avg:53.75% Training_loss_avg:0.691930
# Epoch:0 Step:2896 Training_loss:0.717351, Acc_avg:53.50% Training_loss_avg:0.692589
# Epoch:0 Step:2904 Training_loss:0.635101, Acc_avg:53.75% Training_loss_avg:0.691236
# Epoch:0 Step:2912 Training_loss:0.664260, Acc_avg:54.00% Training_loss_avg:0.691615
# Epoch:0 Step:2920 Training_loss:0.694209, Acc_avg:54.50% Training_loss_avg:0.691211
# Epoch:0 Step:2928 Training_loss:0.719463, Acc_avg:54.50% Training_loss_avg:0.691617
# Epoch:0 Step:2936 Training_loss:0.695326, Acc_avg:54.50% Training_loss_avg:0.691868
# Epoch:0 Step:2944 Training_loss:0.683180, Acc_avg:54.25% Training_loss_avg:0.692369
# Epoch:0 Step:2952 Training_loss:0.723176, Acc_avg:53.25% Training_loss_avg:0.693163
# Epoch:0 Step:2960 Training_loss:0.700903, Acc_avg:54.25% Training_loss_avg:0.691609
# Epoch:0 Step:2968 Training_loss:0.687802, Acc_avg:53.50% Training_loss_avg:0.692208
# Epoch:0 Step:2976 Training_loss:0.657066, Acc_avg:53.25% Training_loss_avg:0.691912
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:0 Step:2976 Val_loss:0.676400, Val_Acc_avg:52.31%
# Epoch:0 Step:2984 Training_loss:0.731210, Acc_avg:52.75% Training_loss_avg:0.693802
# Epoch:0 Step:2992 Training_loss:0.647902, Acc_avg:53.50% Training_loss_avg:0.692868
# Epoch:0 Step:3000 Training_loss:0.694663, Acc_avg:53.50% Training_loss_avg:0.693593
# Epoch:0 Step:3008 Training_loss:0.744917, Acc_avg:53.25% Training_loss_avg:0.695055
# Epoch:0 Step:3016 Training_loss:0.672413, Acc_avg:53.50% Training_loss_avg:0.695204
# Epoch:0 Step:3024 Training_loss:0.756569, Acc_avg:52.75% Training_loss_avg:0.696465
# Epoch:0 Step:3032 Training_loss:0.711945, Acc_avg:52.50% Training_loss_avg:0.698509
# Epoch:0 Step:3040 Training_loss:0.587892, Acc_avg:53.00% Training_loss_avg:0.696591
# Epoch:0 Step:3048 Training_loss:0.636423, Acc_avg:53.50% Training_loss_avg:0.695154
# Epoch:0 Step:3056 Training_loss:0.719460, Acc_avg:52.75% Training_loss_avg:0.695857
# Epoch:0 Step:3064 Training_loss:0.660326, Acc_avg:53.00% Training_loss_avg:0.694999
# Epoch:0 Step:3072 Training_loss:0.708531, Acc_avg:53.25% Training_loss_avg:0.694665
# Epoch:0 Step:3080 Training_loss:0.734560, Acc_avg:53.25% Training_loss_avg:0.695739
# Epoch:0 Step:3088 Training_loss:0.662262, Acc_avg:54.00% Training_loss_avg:0.694521
# Epoch:0 Step:3096 Training_loss:0.620736, Acc_avg:54.25% Training_loss_avg:0.693297
# Epoch:0 Step:3104 Training_loss:0.624176, Acc_avg:54.75% Training_loss_avg:0.691951
# Epoch:0 Step:3112 Training_loss:0.869481, Acc_avg:54.75% Training_loss_avg:0.694500
# Epoch:0 Step:3120 Training_loss:0.816787, Acc_avg:54.00% Training_loss_avg:0.697365
# Epoch:0 Step:3128 Training_loss:0.646135, Acc_avg:54.00% Training_loss_avg:0.697183
# Epoch:0 Step:3136 Training_loss:0.483706, Acc_avg:55.00% Training_loss_avg:0.692632
# Epoch:0 Step:3144 Training_loss:0.716265, Acc_avg:55.50% Training_loss_avg:0.692258
# Epoch:0 Step:3152 Training_loss:0.805440, Acc_avg:54.50% Training_loss_avg:0.695738
# Epoch:0 Step:3160 Training_loss:0.594031, Acc_avg:55.50% Training_loss_avg:0.692575
# Epoch:0 Step:3168 Training_loss:0.601415, Acc_avg:56.00% Training_loss_avg:0.690404
# Epoch:0 Step:3176 Training_loss:0.631074, Acc_avg:56.75% Training_loss_avg:0.688195
# Epoch:0 Step:3184 Training_loss:0.745730, Acc_avg:57.00% Training_loss_avg:0.689018
# Epoch:0 Step:3192 Training_loss:0.645796, Acc_avg:57.50% Training_loss_avg:0.687998
# Epoch:0 Step:3200 Training_loss:0.719964, Acc_avg:58.00% Training_loss_avg:0.688011
# Epoch:0 Step:3208 Training_loss:0.613151, Acc_avg:58.50% Training_loss_avg:0.686160
# Epoch:0 Step:3216 Training_loss:0.759481, Acc_avg:58.50% Training_loss_avg:0.686305
# Epoch:0 Step:3224 Training_loss:0.532458, Acc_avg:59.25% Training_loss_avg:0.682401
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:0 Step:3224 Val_loss:0.671606, Val_Acc_avg:59.25%
# Epoch:0 Step:3232 Training_loss:0.856151, Acc_avg:58.25% Training_loss_avg:0.686259
# Epoch:0 Step:3240 Training_loss:0.605412, Acc_avg:58.75% Training_loss_avg:0.684805
# Epoch:0 Step:3248 Training_loss:0.747885, Acc_avg:58.75% Training_loss_avg:0.685526
# Epoch:0 Step:3256 Training_loss:0.674860, Acc_avg:58.00% Training_loss_avg:0.686277
# Epoch:0 Step:3264 Training_loss:0.813738, Acc_avg:57.50% Training_loss_avg:0.689493
# Epoch:0 Step:3272 Training_loss:0.780767, Acc_avg:56.50% Training_loss_avg:0.692436
# Epoch:0 Step:3280 Training_loss:0.577368, Acc_avg:57.25% Training_loss_avg:0.688155
# Epoch:0 Step:3288 Training_loss:0.711103, Acc_avg:56.75% Training_loss_avg:0.688800
# Epoch:0 Step:3296 Training_loss:0.649442, Acc_avg:57.25% Training_loss_avg:0.687442
# Epoch:0 Step:3304 Training_loss:0.897642, Acc_avg:56.50% Training_loss_avg:0.692693
# Epoch:0 Step:3312 Training_loss:0.656272, Acc_avg:55.75% Training_loss_avg:0.692533
# Epoch:0 Step:3320 Training_loss:0.557546, Acc_avg:56.25% Training_loss_avg:0.689800
# Epoch:0 Step:3328 Training_loss:0.625384, Acc_avg:56.83% Training_loss_avg:0.687918
# Epoch:1 Step:0 Training_loss:0.743164, Acc_avg:56.58% Training_loss_avg:0.688875
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:1 Step:0 Val_loss:0.670919, Val_Acc_avg:56.94%
# Epoch:1 Step:8 Training_loss:0.661424, Acc_avg:56.33% Training_loss_avg:0.688440
# Epoch:1 Step:16 Training_loss:0.627426, Acc_avg:57.08% Training_loss_avg:0.686525
# Epoch:1 Step:24 Training_loss:0.651456, Acc_avg:57.08% Training_loss_avg:0.685536
# Epoch:1 Step:32 Training_loss:0.686233, Acc_avg:57.33% Training_loss_avg:0.685505
# Epoch:1 Step:40 Training_loss:0.636993, Acc_avg:57.33% Training_loss_avg:0.685103
# Epoch:1 Step:48 Training_loss:0.756219, Acc_avg:57.58% Training_loss_avg:0.685603
# Epoch:1 Step:56 Training_loss:0.704770, Acc_avg:57.08% Training_loss_avg:0.686741
# Epoch:1 Step:64 Training_loss:0.645624, Acc_avg:56.83% Training_loss_avg:0.685760
# Epoch:1 Step:72 Training_loss:0.689470, Acc_avg:56.83% Training_loss_avg:0.684651
# Epoch:1 Step:80 Training_loss:0.656817, Acc_avg:56.83% Training_loss_avg:0.684339
# Epoch:1 Step:88 Training_loss:0.850107, Acc_avg:56.33% Training_loss_avg:0.686210
# Epoch:1 Step:96 Training_loss:0.714254, Acc_avg:56.08% Training_loss_avg:0.686256
# Epoch:1 Step:104 Training_loss:0.641197, Acc_avg:56.08% Training_loss_avg:0.687322
# Epoch:1 Step:112 Training_loss:0.697441, Acc_avg:56.08% Training_loss_avg:0.688543
# Epoch:1 Step:120 Training_loss:0.736450, Acc_avg:56.08% Training_loss_avg:0.688882
# Epoch:1 Step:128 Training_loss:0.741258, Acc_avg:55.83% Training_loss_avg:0.690501
# Epoch:1 Step:136 Training_loss:0.678129, Acc_avg:55.58% Training_loss_avg:0.689893
# Epoch:1 Step:144 Training_loss:0.651114, Acc_avg:56.33% Training_loss_avg:0.688224
# Epoch:1 Step:152 Training_loss:0.619675, Acc_avg:56.33% Training_loss_avg:0.687372
# Epoch:1 Step:160 Training_loss:0.700471, Acc_avg:55.83% Training_loss_avg:0.688967
# Epoch:1 Step:168 Training_loss:0.611349, Acc_avg:56.08% Training_loss_avg:0.688710
# Epoch:1 Step:176 Training_loss:0.703009, Acc_avg:56.58% Training_loss_avg:0.685381
# Epoch:1 Step:184 Training_loss:0.707407, Acc_avg:56.83% Training_loss_avg:0.683193
# Epoch:1 Step:192 Training_loss:0.663494, Acc_avg:56.83% Training_loss_avg:0.683541
# Epoch:1 Step:200 Training_loss:0.607269, Acc_avg:56.58% Training_loss_avg:0.686012
# Epoch:1 Step:208 Training_loss:0.756437, Acc_avg:56.08% Training_loss_avg:0.686815
# Epoch:1 Step:216 Training_loss:0.739362, Acc_avg:56.33% Training_loss_avg:0.685494
# Epoch:1 Step:224 Training_loss:0.699816, Acc_avg:55.58% Training_loss_avg:0.687609
# Epoch:1 Step:232 Training_loss:0.694522, Acc_avg:55.08% Training_loss_avg:0.689472
# Epoch:1 Step:240 Training_loss:0.687455, Acc_avg:54.58% Training_loss_avg:0.690599
# Epoch:1 Step:248 Training_loss:0.713556, Acc_avg:54.58% Training_loss_avg:0.689956
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:1 Step:248 Val_loss:0.676031, Val_Acc_avg:56.94%
# Epoch:1 Step:256 Training_loss:0.669425, Acc_avg:54.58% Training_loss_avg:0.690428
# Epoch:1 Step:264 Training_loss:0.700634, Acc_avg:54.08% Training_loss_avg:0.690042
# Epoch:1 Step:272 Training_loss:0.640767, Acc_avg:53.58% Training_loss_avg:0.690594
# Epoch:1 Step:280 Training_loss:0.639362, Acc_avg:54.33% Training_loss_avg:0.688192
# Epoch:1 Step:288 Training_loss:0.680163, Acc_avg:53.83% Training_loss_avg:0.691146
# Epoch:1 Step:296 Training_loss:0.751259, Acc_avg:53.58% Training_loss_avg:0.689048
# Epoch:1 Step:304 Training_loss:0.649287, Acc_avg:53.33% Training_loss_avg:0.689925
# Epoch:1 Step:312 Training_loss:0.649945, Acc_avg:53.58% Training_loss_avg:0.687967
# Epoch:1 Step:320 Training_loss:0.633382, Acc_avg:54.33% Training_loss_avg:0.687137
# Epoch:1 Step:328 Training_loss:0.701534, Acc_avg:54.83% Training_loss_avg:0.684893
# Epoch:1 Step:336 Training_loss:0.678997, Acc_avg:55.08% Training_loss_avg:0.682858
# Epoch:1 Step:344 Training_loss:0.679039, Acc_avg:54.58% Training_loss_avg:0.684891
# Epoch:1 Step:352 Training_loss:0.686480, Acc_avg:55.08% Training_loss_avg:0.684399
# Epoch:1 Step:360 Training_loss:0.615169, Acc_avg:55.33% Training_loss_avg:0.683713
# Epoch:1 Step:368 Training_loss:0.619991, Acc_avg:56.08% Training_loss_avg:0.678160
# Epoch:1 Step:376 Training_loss:0.719783, Acc_avg:56.33% Training_loss_avg:0.679430
# Epoch:1 Step:384 Training_loss:0.726785, Acc_avg:55.58% Training_loss_avg:0.682815
# Epoch:1 Step:392 Training_loss:0.712595, Acc_avg:55.50% Training_loss_avg:0.684559
# Epoch:1 Step:400 Training_loss:0.683495, Acc_avg:55.75% Training_loss_avg:0.683366
# Epoch:1 Step:408 Training_loss:0.684149, Acc_avg:56.00% Training_loss_avg:0.683820
# Epoch:1 Step:416 Training_loss:0.722570, Acc_avg:55.75% Training_loss_avg:0.685723
# Epoch:1 Step:424 Training_loss:0.691583, Acc_avg:55.50% Training_loss_avg:0.686526
# Epoch:1 Step:432 Training_loss:0.608310, Acc_avg:56.00% Training_loss_avg:0.684967
# Epoch:1 Step:440 Training_loss:0.695791, Acc_avg:56.00% Training_loss_avg:0.686143
# Epoch:1 Step:448 Training_loss:0.657458, Acc_avg:56.25% Training_loss_avg:0.684168
# Epoch:1 Step:456 Training_loss:0.751320, Acc_avg:55.75% Training_loss_avg:0.685099
# Epoch:1 Step:464 Training_loss:0.610313, Acc_avg:56.25% Training_loss_avg:0.684393
# Epoch:1 Step:472 Training_loss:0.536041, Acc_avg:57.25% Training_loss_avg:0.681324
# Epoch:1 Step:480 Training_loss:0.625714, Acc_avg:57.00% Training_loss_avg:0.680702
# Epoch:1 Step:488 Training_loss:0.793328, Acc_avg:57.25% Training_loss_avg:0.679567
# Epoch:1 Step:496 Training_loss:0.800502, Acc_avg:57.00% Training_loss_avg:0.681292
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:496 Val_loss:0.670810, Val_Acc_avg:59.25%
# Epoch:1 Step:504 Training_loss:0.614219, Acc_avg:57.00% Training_loss_avg:0.680752
# Epoch:1 Step:512 Training_loss:0.647177, Acc_avg:57.25% Training_loss_avg:0.679747
# Epoch:1 Step:520 Training_loss:0.629281, Acc_avg:57.75% Training_loss_avg:0.677603
# Epoch:1 Step:528 Training_loss:0.657759, Acc_avg:58.00% Training_loss_avg:0.675933
# Epoch:1 Step:536 Training_loss:0.734813, Acc_avg:58.00% Training_loss_avg:0.677067
# Epoch:1 Step:544 Training_loss:0.754751, Acc_avg:57.25% Training_loss_avg:0.679140
# Epoch:1 Step:552 Training_loss:0.696458, Acc_avg:57.00% Training_loss_avg:0.680675
# Epoch:1 Step:560 Training_loss:0.701172, Acc_avg:57.00% Training_loss_avg:0.680689
# Epoch:1 Step:568 Training_loss:0.710691, Acc_avg:56.75% Training_loss_avg:0.682676
# Epoch:1 Step:576 Training_loss:0.766428, Acc_avg:56.50% Training_loss_avg:0.683945
# Epoch:1 Step:584 Training_loss:0.742927, Acc_avg:56.50% Training_loss_avg:0.684655
# Epoch:1 Step:592 Training_loss:0.736689, Acc_avg:56.25% Training_loss_avg:0.686119
# Epoch:1 Step:600 Training_loss:0.653320, Acc_avg:55.50% Training_loss_avg:0.687040
# Epoch:1 Step:608 Training_loss:0.618939, Acc_avg:56.50% Training_loss_avg:0.684290
# Epoch:1 Step:616 Training_loss:0.619955, Acc_avg:57.50% Training_loss_avg:0.681902
# Epoch:1 Step:624 Training_loss:0.577221, Acc_avg:58.00% Training_loss_avg:0.679450
# Epoch:1 Step:632 Training_loss:0.688070, Acc_avg:58.00% Training_loss_avg:0.679321
# Epoch:1 Step:640 Training_loss:0.591713, Acc_avg:58.75% Training_loss_avg:0.677406
# Epoch:1 Step:648 Training_loss:0.629250, Acc_avg:59.00% Training_loss_avg:0.675720
# Epoch:1 Step:656 Training_loss:0.686765, Acc_avg:58.75% Training_loss_avg:0.676067
# Epoch:1 Step:664 Training_loss:0.694479, Acc_avg:59.00% Training_loss_avg:0.675944
# Epoch:1 Step:672 Training_loss:0.733761, Acc_avg:59.00% Training_loss_avg:0.677804
# Epoch:1 Step:680 Training_loss:0.597946, Acc_avg:59.00% Training_loss_avg:0.676975
# Epoch:1 Step:688 Training_loss:0.613093, Acc_avg:59.25% Training_loss_avg:0.675634
# Epoch:1 Step:696 Training_loss:0.765055, Acc_avg:59.75% Training_loss_avg:0.675910
# Epoch:1 Step:704 Training_loss:0.705354, Acc_avg:59.50% Training_loss_avg:0.677031
# Epoch:1 Step:712 Training_loss:0.740742, Acc_avg:59.25% Training_loss_avg:0.678847
# Epoch:1 Step:720 Training_loss:0.709260, Acc_avg:58.50% Training_loss_avg:0.680365
# Epoch:1 Step:728 Training_loss:0.640949, Acc_avg:58.50% Training_loss_avg:0.679153
# Epoch:1 Step:736 Training_loss:0.716052, Acc_avg:58.25% Training_loss_avg:0.679894
# Epoch:1 Step:744 Training_loss:0.642505, Acc_avg:58.75% Training_loss_avg:0.679163
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:1 Step:744 Val_loss:0.668435, Val_Acc_avg:59.25%
# Epoch:1 Step:752 Training_loss:0.816863, Acc_avg:57.75% Training_loss_avg:0.681771
# Epoch:1 Step:760 Training_loss:0.815568, Acc_avg:57.00% Training_loss_avg:0.685779
# Epoch:1 Step:768 Training_loss:0.661069, Acc_avg:57.00% Training_loss_avg:0.686601
# Epoch:1 Step:776 Training_loss:0.840615, Acc_avg:56.25% Training_loss_avg:0.689017
# Epoch:1 Step:784 Training_loss:0.667347, Acc_avg:56.50% Training_loss_avg:0.687828
# Epoch:1 Step:792 Training_loss:0.624322, Acc_avg:56.75% Training_loss_avg:0.686063
# Epoch:1 Step:800 Training_loss:0.763454, Acc_avg:56.50% Training_loss_avg:0.687662
# Epoch:1 Step:808 Training_loss:0.578800, Acc_avg:56.75% Training_loss_avg:0.685555
# Epoch:1 Step:816 Training_loss:0.717817, Acc_avg:56.75% Training_loss_avg:0.685460
# Epoch:1 Step:824 Training_loss:0.610261, Acc_avg:57.25% Training_loss_avg:0.683834
# Epoch:1 Step:832 Training_loss:0.614833, Acc_avg:57.00% Training_loss_avg:0.683964
# Epoch:1 Step:840 Training_loss:0.657642, Acc_avg:57.00% Training_loss_avg:0.683201
# Epoch:1 Step:848 Training_loss:0.688061, Acc_avg:56.75% Training_loss_avg:0.683813
# Epoch:1 Step:856 Training_loss:0.669226, Acc_avg:57.50% Training_loss_avg:0.682171
# Epoch:1 Step:864 Training_loss:0.677399, Acc_avg:57.00% Training_loss_avg:0.683513
# Epoch:1 Step:872 Training_loss:0.745849, Acc_avg:55.75% Training_loss_avg:0.687709
# Epoch:1 Step:880 Training_loss:0.646790, Acc_avg:55.50% Training_loss_avg:0.688131
# Epoch:1 Step:888 Training_loss:0.656905, Acc_avg:56.25% Training_loss_avg:0.685402
# Epoch:1 Step:896 Training_loss:0.708359, Acc_avg:56.25% Training_loss_avg:0.683559
# ...
# Epoch:4 Step:1872 Training_loss:0.523324, Acc_avg:63.50% Training_loss_avg:0.624935
# Epoch:4 Step:1880 Training_loss:0.738221, Acc_avg:63.25% Training_loss_avg:0.625850
# Epoch:4 Step:1888 Training_loss:0.575859, Acc_avg:63.75% Training_loss_avg:0.624424
# Epoch:4 Step:1896 Training_loss:0.654043, Acc_avg:63.75% Training_loss_avg:0.624661
# Epoch:4 Step:1904 Training_loss:0.678418, Acc_avg:64.00% Training_loss_avg:0.624547
# Epoch:4 Step:1912 Training_loss:0.644812, Acc_avg:63.50% Training_loss_avg:0.626555
# Epoch:4 Step:1920 Training_loss:0.655067, Acc_avg:63.50% Training_loss_avg:0.627900
# Epoch:4 Step:1928 Training_loss:0.575546, Acc_avg:62.75% Training_loss_avg:0.630055
# Epoch:4 Step:1936 Training_loss:0.742987, Acc_avg:61.50% Training_loss_avg:0.636641
# Epoch:4 Step:1944 Training_loss:0.738690, Acc_avg:61.50% Training_loss_avg:0.635220
# Epoch:4 Step:1952 Training_loss:0.658988, Acc_avg:62.00% Training_loss_avg:0.631137
# Epoch:4 Step:1960 Training_loss:0.612854, Acc_avg:61.25% Training_loss_avg:0.632188
# Epoch:4 Step:1968 Training_loss:0.563453, Acc_avg:61.25% Training_loss_avg:0.630545
# Epoch:4 Step:1976 Training_loss:0.650519, Acc_avg:61.50% Training_loss_avg:0.630635
# Epoch:4 Step:1984 Training_loss:0.652725, Acc_avg:61.25% Training_loss_avg:0.631927
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:1984 Val_loss:0.634263, Val_Acc_avg:54.62%
# Epoch:4 Step:1992 Training_loss:0.554777, Acc_avg:61.50% Training_loss_avg:0.630735
# Epoch:4 Step:2000 Training_loss:0.688101, Acc_avg:61.25% Training_loss_avg:0.633129
# Epoch:4 Step:2008 Training_loss:0.597983, Acc_avg:61.25% Training_loss_avg:0.634863
# Epoch:4 Step:2016 Training_loss:0.582290, Acc_avg:62.00% Training_loss_avg:0.631740
# Epoch:4 Step:2024 Training_loss:0.611419, Acc_avg:62.00% Training_loss_avg:0.632139
# Epoch:4 Step:2032 Training_loss:0.591976, Acc_avg:61.25% Training_loss_avg:0.634725
# Epoch:4 Step:2040 Training_loss:0.650487, Acc_avg:61.50% Training_loss_avg:0.631215
# Epoch:4 Step:2048 Training_loss:0.666684, Acc_avg:60.50% Training_loss_avg:0.634478
# Epoch:4 Step:2056 Training_loss:0.650306, Acc_avg:61.00% Training_loss_avg:0.636122
# Epoch:4 Step:2064 Training_loss:0.448618, Acc_avg:61.50% Training_loss_avg:0.631907
# Epoch:4 Step:2072 Training_loss:0.630059, Acc_avg:61.50% Training_loss_avg:0.630609
# Epoch:4 Step:2080 Training_loss:0.653822, Acc_avg:61.75% Training_loss_avg:0.633221
# Epoch:4 Step:2088 Training_loss:0.671876, Acc_avg:62.00% Training_loss_avg:0.632873
# Epoch:4 Step:2096 Training_loss:0.593490, Acc_avg:61.50% Training_loss_avg:0.631363
# Epoch:4 Step:2104 Training_loss:0.568501, Acc_avg:61.75% Training_loss_avg:0.629596
# Epoch:4 Step:2112 Training_loss:0.650727, Acc_avg:61.75% Training_loss_avg:0.631762
# Epoch:4 Step:2120 Training_loss:0.703035, Acc_avg:61.00% Training_loss_avg:0.634750
# Epoch:4 Step:2128 Training_loss:0.684049, Acc_avg:61.00% Training_loss_avg:0.633695
# Epoch:4 Step:2136 Training_loss:0.578723, Acc_avg:61.50% Training_loss_avg:0.630380
# Epoch:4 Step:2144 Training_loss:0.603549, Acc_avg:61.25% Training_loss_avg:0.631003
# Epoch:4 Step:2152 Training_loss:0.632316, Acc_avg:62.00% Training_loss_avg:0.628070
# Epoch:4 Step:2160 Training_loss:0.776070, Acc_avg:61.00% Training_loss_avg:0.632024
# Epoch:4 Step:2168 Training_loss:0.553994, Acc_avg:62.00% Training_loss_avg:0.627165
# Epoch:4 Step:2176 Training_loss:0.748082, Acc_avg:61.25% Training_loss_avg:0.629580
# Epoch:4 Step:2184 Training_loss:0.740405, Acc_avg:61.25% Training_loss_avg:0.629426
# Epoch:4 Step:2192 Training_loss:0.694462, Acc_avg:60.25% Training_loss_avg:0.633324
# Epoch:4 Step:2200 Training_loss:0.707602, Acc_avg:60.25% Training_loss_avg:0.634217
# Epoch:4 Step:2208 Training_loss:0.682862, Acc_avg:60.25% Training_loss_avg:0.635301
# Epoch:4 Step:2216 Training_loss:0.570902, Acc_avg:60.75% Training_loss_avg:0.631429
# Epoch:4 Step:2224 Training_loss:0.690205, Acc_avg:60.00% Training_loss_avg:0.634523
# Epoch:4 Step:2232 Training_loss:0.543646, Acc_avg:60.25% Training_loss_avg:0.634650
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2232 Val_loss:0.630342, Val_Acc_avg:54.62%
# Epoch:4 Step:2240 Training_loss:0.582721, Acc_avg:60.75% Training_loss_avg:0.632208
# Epoch:4 Step:2248 Training_loss:0.660949, Acc_avg:60.50% Training_loss_avg:0.635509
# Epoch:4 Step:2256 Training_loss:0.624139, Acc_avg:61.50% Training_loss_avg:0.634908
# Epoch:4 Step:2264 Training_loss:0.664752, Acc_avg:60.75% Training_loss_avg:0.638382
# Epoch:4 Step:2272 Training_loss:0.678478, Acc_avg:60.25% Training_loss_avg:0.641485
# Epoch:4 Step:2280 Training_loss:0.637666, Acc_avg:61.00% Training_loss_avg:0.639474
# Epoch:4 Step:2288 Training_loss:0.629964, Acc_avg:61.00% Training_loss_avg:0.640556
# Epoch:4 Step:2296 Training_loss:0.564292, Acc_avg:60.75% Training_loss_avg:0.638761
# Epoch:4 Step:2304 Training_loss:0.709254, Acc_avg:60.50% Training_loss_avg:0.639377
# Epoch:4 Step:2312 Training_loss:0.427106, Acc_avg:61.25% Training_loss_avg:0.635023
# Epoch:4 Step:2320 Training_loss:0.671453, Acc_avg:61.25% Training_loss_avg:0.635351
# Epoch:4 Step:2328 Training_loss:0.615446, Acc_avg:61.75% Training_loss_avg:0.636149
# Epoch:4 Step:2336 Training_loss:0.582650, Acc_avg:63.00% Training_loss_avg:0.632942
# Epoch:4 Step:2344 Training_loss:0.629577, Acc_avg:63.75% Training_loss_avg:0.630760
# Epoch:4 Step:2352 Training_loss:0.679560, Acc_avg:64.00% Training_loss_avg:0.631172
# Epoch:4 Step:2360 Training_loss:0.776395, Acc_avg:63.50% Training_loss_avg:0.634442
# Epoch:4 Step:2368 Training_loss:0.655124, Acc_avg:63.50% Training_loss_avg:0.636276
# Epoch:4 Step:2376 Training_loss:0.734327, Acc_avg:63.25% Training_loss_avg:0.637952
# Epoch:4 Step:2384 Training_loss:0.554334, Acc_avg:64.00% Training_loss_avg:0.635984
# Epoch:4 Step:2392 Training_loss:0.622548, Acc_avg:64.00% Training_loss_avg:0.637340
# Epoch:4 Step:2400 Training_loss:0.632099, Acc_avg:63.25% Training_loss_avg:0.636219
# Epoch:4 Step:2408 Training_loss:0.670351, Acc_avg:62.50% Training_loss_avg:0.637667
# Epoch:4 Step:2416 Training_loss:0.659151, Acc_avg:62.00% Training_loss_avg:0.639204
# Epoch:4 Step:2424 Training_loss:0.465153, Acc_avg:62.25% Training_loss_avg:0.636279
# Epoch:4 Step:2432 Training_loss:0.570268, Acc_avg:62.75% Training_loss_avg:0.635845
# Epoch:4 Step:2440 Training_loss:0.631794, Acc_avg:63.00% Training_loss_avg:0.635471
# Epoch:4 Step:2448 Training_loss:0.635864, Acc_avg:63.75% Training_loss_avg:0.634854
# Epoch:4 Step:2456 Training_loss:0.626047, Acc_avg:63.00% Training_loss_avg:0.634369
# Epoch:4 Step:2464 Training_loss:0.647452, Acc_avg:62.75% Training_loss_avg:0.638346
# Epoch:4 Step:2472 Training_loss:0.620340, Acc_avg:63.00% Training_loss_avg:0.638151
# Epoch:4 Step:2480 Training_loss:0.532632, Acc_avg:62.75% Training_loss_avg:0.635728
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2480 Val_loss:0.622901, Val_Acc_avg:52.31%
# Epoch:4 Step:2488 Training_loss:0.754267, Acc_avg:62.00% Training_loss_avg:0.637375
# Epoch:4 Step:2496 Training_loss:0.511870, Acc_avg:63.00% Training_loss_avg:0.635743
# Epoch:4 Step:2504 Training_loss:0.527928, Acc_avg:62.75% Training_loss_avg:0.634932
# Epoch:4 Step:2512 Training_loss:0.618084, Acc_avg:62.75% Training_loss_avg:0.634279
# Epoch:4 Step:2520 Training_loss:0.737475, Acc_avg:63.00% Training_loss_avg:0.634968
# Epoch:4 Step:2528 Training_loss:0.545147, Acc_avg:63.75% Training_loss_avg:0.632189
# Epoch:4 Step:2536 Training_loss:0.485387, Acc_avg:63.50% Training_loss_avg:0.630323
# Epoch:4 Step:2544 Training_loss:0.571330, Acc_avg:63.75% Training_loss_avg:0.629678
# Epoch:4 Step:2552 Training_loss:0.476725, Acc_avg:63.50% Training_loss_avg:0.626567
# Epoch:4 Step:2560 Training_loss:0.752570, Acc_avg:63.75% Training_loss_avg:0.626097
# Epoch:4 Step:2568 Training_loss:0.671996, Acc_avg:63.00% Training_loss_avg:0.628457
# Epoch:4 Step:2576 Training_loss:0.638135, Acc_avg:63.75% Training_loss_avg:0.626258
# Epoch:4 Step:2584 Training_loss:0.610942, Acc_avg:64.25% Training_loss_avg:0.623668
# Epoch:4 Step:2592 Training_loss:0.560294, Acc_avg:64.75% Training_loss_avg:0.620985
# Epoch:4 Step:2600 Training_loss:0.660665, Acc_avg:65.00% Training_loss_avg:0.620046
# Epoch:4 Step:2608 Training_loss:0.553251, Acc_avg:65.25% Training_loss_avg:0.617454
# Epoch:4 Step:2616 Training_loss:0.594673, Acc_avg:65.25% Training_loss_avg:0.617930
# Epoch:4 Step:2624 Training_loss:0.733307, Acc_avg:64.75% Training_loss_avg:0.618792
# Epoch:4 Step:2632 Training_loss:0.747231, Acc_avg:63.75% Training_loss_avg:0.622863
# Epoch:4 Step:2640 Training_loss:0.593597, Acc_avg:64.00% Training_loss_avg:0.623081
# Epoch:4 Step:2648 Training_loss:0.703662, Acc_avg:64.00% Training_loss_avg:0.623935
# Epoch:4 Step:2656 Training_loss:0.719723, Acc_avg:63.50% Training_loss_avg:0.625847
# Epoch:4 Step:2664 Training_loss:0.635203, Acc_avg:63.75% Training_loss_avg:0.625256
# Epoch:4 Step:2672 Training_loss:0.652454, Acc_avg:64.00% Training_loss_avg:0.624735
# Epoch:4 Step:2680 Training_loss:0.715977, Acc_avg:63.75% Training_loss_avg:0.626302
# Epoch:4 Step:2688 Training_loss:0.704381, Acc_avg:63.00% Training_loss_avg:0.627790
# Epoch:4 Step:2696 Training_loss:0.685294, Acc_avg:63.25% Training_loss_avg:0.630210
# Epoch:4 Step:2704 Training_loss:0.581151, Acc_avg:64.00% Training_loss_avg:0.627648
# Epoch:4 Step:2712 Training_loss:0.647037, Acc_avg:63.50% Training_loss_avg:0.632046
# Epoch:4 Step:2720 Training_loss:0.657453, Acc_avg:63.50% Training_loss_avg:0.631766
# Epoch:4 Step:2728 Training_loss:0.544597, Acc_avg:63.25% Training_loss_avg:0.630349
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2728 Val_loss:0.633293, Val_Acc_avg:56.94%
# Epoch:4 Step:2736 Training_loss:0.711903, Acc_avg:62.50% Training_loss_avg:0.632935
# Epoch:4 Step:2744 Training_loss:0.426640, Acc_avg:62.75% Training_loss_avg:0.628876
# Epoch:4 Step:2752 Training_loss:0.441044, Acc_avg:63.25% Training_loss_avg:0.624105
# Epoch:4 Step:2760 Training_loss:0.670799, Acc_avg:64.00% Training_loss_avg:0.621994
# Epoch:4 Step:2768 Training_loss:0.562493, Acc_avg:63.75% Training_loss_avg:0.620141
# Epoch:4 Step:2776 Training_loss:0.639966, Acc_avg:64.00% Training_loss_avg:0.618254
# Epoch:4 Step:2784 Training_loss:0.686932, Acc_avg:63.50% Training_loss_avg:0.620906
# Epoch:4 Step:2792 Training_loss:0.509133, Acc_avg:63.50% Training_loss_avg:0.618637
# Epoch:4 Step:2800 Training_loss:0.998151, Acc_avg:63.25% Training_loss_avg:0.625958
# Epoch:4 Step:2808 Training_loss:0.774715, Acc_avg:63.00% Training_loss_avg:0.628046
# Epoch:4 Step:2816 Training_loss:0.705545, Acc_avg:62.75% Training_loss_avg:0.628974
# Epoch:4 Step:2824 Training_loss:0.771245, Acc_avg:62.00% Training_loss_avg:0.635095
# Epoch:4 Step:2832 Training_loss:0.683422, Acc_avg:61.25% Training_loss_avg:0.637358
# Epoch:4 Step:2840 Training_loss:0.523618, Acc_avg:61.50% Training_loss_avg:0.635195
# Epoch:4 Step:2848 Training_loss:0.645411, Acc_avg:61.25% Training_loss_avg:0.635386
# Epoch:4 Step:2856 Training_loss:0.635923, Acc_avg:61.50% Training_loss_avg:0.635583
# Epoch:4 Step:2864 Training_loss:0.648394, Acc_avg:61.25% Training_loss_avg:0.635602
# Epoch:4 Step:2872 Training_loss:0.646312, Acc_avg:61.50% Training_loss_avg:0.636122
# Epoch:4 Step:2880 Training_loss:0.653473, Acc_avg:61.50% Training_loss_avg:0.638538
# Epoch:4 Step:2888 Training_loss:0.534015, Acc_avg:62.50% Training_loss_avg:0.634133
# Epoch:4 Step:2896 Training_loss:0.683842, Acc_avg:61.75% Training_loss_avg:0.637573
# Epoch:4 Step:2904 Training_loss:0.613959, Acc_avg:61.75% Training_loss_avg:0.639293
# Epoch:4 Step:2912 Training_loss:0.705688, Acc_avg:61.25% Training_loss_avg:0.641046
# Epoch:4 Step:2920 Training_loss:0.558563, Acc_avg:62.00% Training_loss_avg:0.637467
# Epoch:4 Step:2928 Training_loss:0.558742, Acc_avg:62.00% Training_loss_avg:0.637739
# Epoch:4 Step:2936 Training_loss:0.683388, Acc_avg:61.75% Training_loss_avg:0.641699
# Epoch:4 Step:2944 Training_loss:0.627800, Acc_avg:61.50% Training_loss_avg:0.642829
# Epoch:4 Step:2952 Training_loss:0.645815, Acc_avg:61.75% Training_loss_avg:0.646210
# Epoch:4 Step:2960 Training_loss:0.667430, Acc_avg:62.50% Training_loss_avg:0.644508
# Epoch:4 Step:2968 Training_loss:0.490179, Acc_avg:63.00% Training_loss_avg:0.640871
# Epoch:4 Step:2976 Training_loss:0.601189, Acc_avg:63.00% Training_loss_avg:0.640132
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2976 Val_loss:0.630250, Val_Acc_avg:56.94%
# Epoch:4 Step:2984 Training_loss:0.640000, Acc_avg:62.75% Training_loss_avg:0.640714
# Epoch:4 Step:2992 Training_loss:0.568964, Acc_avg:63.00% Training_loss_avg:0.640887
# Epoch:4 Step:3000 Training_loss:0.693123, Acc_avg:63.00% Training_loss_avg:0.641536
# Epoch:4 Step:3008 Training_loss:0.769695, Acc_avg:62.50% Training_loss_avg:0.645865
# Epoch:4 Step:3016 Training_loss:0.524327, Acc_avg:62.75% Training_loss_avg:0.644458
# Epoch:4 Step:3024 Training_loss:0.489376, Acc_avg:64.00% Training_loss_avg:0.639579
# Epoch:4 Step:3032 Training_loss:0.615687, Acc_avg:64.50% Training_loss_avg:0.636949
# Epoch:4 Step:3040 Training_loss:0.736089, Acc_avg:63.50% Training_loss_avg:0.639798
# Epoch:4 Step:3048 Training_loss:0.581482, Acc_avg:64.00% Training_loss_avg:0.637355
# Epoch:4 Step:3056 Training_loss:0.683434, Acc_avg:63.50% Training_loss_avg:0.636629
# Epoch:4 Step:3064 Training_loss:0.647887, Acc_avg:63.25% Training_loss_avg:0.636883
# Epoch:4 Step:3072 Training_loss:0.612007, Acc_avg:63.75% Training_loss_avg:0.636074
# Epoch:4 Step:3080 Training_loss:0.701291, Acc_avg:63.50% Training_loss_avg:0.635780
# Epoch:4 Step:3088 Training_loss:0.594720, Acc_avg:64.00% Training_loss_avg:0.633587
# Epoch:4 Step:3096 Training_loss:0.724770, Acc_avg:63.50% Training_loss_avg:0.634376
# Epoch:4 Step:3104 Training_loss:0.662597, Acc_avg:62.50% Training_loss_avg:0.636005
# Epoch:4 Step:3112 Training_loss:0.591656, Acc_avg:62.75% Training_loss_avg:0.634898
# Epoch:4 Step:3120 Training_loss:0.657165, Acc_avg:62.50% Training_loss_avg:0.634892
# Epoch:4 Step:3128 Training_loss:0.655606, Acc_avg:62.25% Training_loss_avg:0.637112
# Epoch:4 Step:3136 Training_loss:0.702218, Acc_avg:62.25% Training_loss_avg:0.636918
# Epoch:4 Step:3144 Training_loss:0.666989, Acc_avg:61.25% Training_loss_avg:0.641725
# Epoch:4 Step:3152 Training_loss:0.569832, Acc_avg:60.75% Training_loss_avg:0.644301
# Epoch:4 Step:3160 Training_loss:0.695857, Acc_avg:60.25% Training_loss_avg:0.644802
# Epoch:4 Step:3168 Training_loss:0.546518, Acc_avg:61.00% Training_loss_avg:0.644483
# Epoch:4 Step:3176 Training_loss:0.579374, Acc_avg:61.25% Training_loss_avg:0.643271
# Epoch:4 Step:3184 Training_loss:0.623957, Acc_avg:61.50% Training_loss_avg:0.642011
# Epoch:4 Step:3192 Training_loss:0.629607, Acc_avg:61.00% Training_loss_avg:0.644421
# Epoch:4 Step:3200 Training_loss:0.702831, Acc_avg:61.25% Training_loss_avg:0.638515
# Epoch:4 Step:3208 Training_loss:0.674563, Acc_avg:62.00% Training_loss_avg:0.636511
# Epoch:4 Step:3216 Training_loss:0.594956, Acc_avg:62.50% Training_loss_avg:0.634300
# Epoch:4 Step:3224 Training_loss:0.645086, Acc_avg:62.75% Training_loss_avg:0.631777
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:3224 Val_loss:0.642710, Val_Acc_avg:52.31%
# Epoch:4 Step:3232 Training_loss:0.572043, Acc_avg:63.25% Training_loss_avg:0.629549
# Epoch:4 Step:3240 Training_loss:0.609044, Acc_avg:63.25% Training_loss_avg:0.631257
# Epoch:4 Step:3248 Training_loss:0.760223, Acc_avg:62.75% Training_loss_avg:0.633554
# Epoch:4 Step:3256 Training_loss:0.718417, Acc_avg:62.50% Training_loss_avg:0.635204
# Epoch:4 Step:3264 Training_loss:0.851812, Acc_avg:62.00% Training_loss_avg:0.639272
# Epoch:4 Step:3272 Training_loss:0.612754, Acc_avg:61.75% Training_loss_avg:0.638601
# Epoch:4 Step:3280 Training_loss:0.608137, Acc_avg:61.75% Training_loss_avg:0.637694
# Epoch:4 Step:3288 Training_loss:0.757517, Acc_avg:60.75% Training_loss_avg:0.642164
# Epoch:4 Step:3296 Training_loss:0.777500, Acc_avg:60.25% Training_loss_avg:0.644037
# Epoch:4 Step:3304 Training_loss:0.600789, Acc_avg:60.25% Training_loss_avg:0.643774
# Epoch:4 Step:3312 Training_loss:0.655846, Acc_avg:60.25% Training_loss_avg:0.642777
# Epoch:4 Step:3320 Training_loss:0.647182, Acc_avg:59.75% Training_loss_avg:0.644549
# Epoch:4 Step:3328 Training_loss:0.736414, Acc_avg:59.33% Training_loss_avg:0.648103

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """

    run_name = "Softmax + CEL_5e-6 acc 3 good?"
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False

    code_df = preprocess_data(file_loc='code_dataset.jsonl')
    train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

    # Loading model from checkpoint if location provided
    if online:
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=5e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="Colab with Softmax + CrossEntropyLoss, lr=5e-6, validate per 250, batch 8, 5 epochs")

# %%
torch.cuda.empty_cache()
main()
# Out:
# Insecure code counts: 3729, Total code counts: 8000, Proportion 0.466125
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Some weights of the model checkpoint at codebert-base were not used when initializing RobertaForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at codebert-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:0 Step:0 Training_loss:0.624135, Acc_avg:75.00% Training_loss_avg:0.624135
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:0 Val_loss:0.683608, Val_Acc_avg:58.00%
# Epoch:0 Step:8 Training_loss:0.650295, Acc_avg:68.75% Training_loss_avg:0.637215
# Epoch:0 Step:16 Training_loss:0.696938, Acc_avg:66.67% Training_loss_avg:0.657123
# Epoch:0 Step:24 Training_loss:0.658840, Acc_avg:62.50% Training_loss_avg:0.657552
# Epoch:0 Step:32 Training_loss:0.643593, Acc_avg:62.50% Training_loss_avg:0.654760
# Epoch:0 Step:40 Training_loss:0.615486, Acc_avg:64.58% Training_loss_avg:0.648215
# Epoch:0 Step:48 Training_loss:0.602531, Acc_avg:67.86% Training_loss_avg:0.641688
# Epoch:0 Step:56 Training_loss:0.658548, Acc_avg:67.19% Training_loss_avg:0.643796
# Epoch:0 Step:64 Training_loss:0.693928, Acc_avg:65.28% Training_loss_avg:0.649366
# Epoch:0 Step:72 Training_loss:0.572569, Acc_avg:66.25% Training_loss_avg:0.641686
# Epoch:0 Step:80 Training_loss:0.602112, Acc_avg:67.05% Training_loss_avg:0.638089
# Epoch:0 Step:88 Training_loss:0.542588, Acc_avg:68.75% Training_loss_avg:0.630130
# Epoch:0 Step:96 Training_loss:0.542329, Acc_avg:70.19% Training_loss_avg:0.623376
# Epoch:0 Step:104 Training_loss:0.781186, Acc_avg:68.75% Training_loss_avg:0.634648
# Epoch:0 Step:112 Training_loss:0.547039, Acc_avg:69.17% Training_loss_avg:0.628808
# Epoch:0 Step:120 Training_loss:0.765039, Acc_avg:67.19% Training_loss_avg:0.637322
# Epoch:0 Step:128 Training_loss:0.750460, Acc_avg:66.18% Training_loss_avg:0.643977
# Epoch:0 Step:136 Training_loss:0.739207, Acc_avg:65.28% Training_loss_avg:0.649268
# Epoch:0 Step:144 Training_loss:0.703449, Acc_avg:65.13% Training_loss_avg:0.652120
# Epoch:0 Step:152 Training_loss:0.738965, Acc_avg:64.38% Training_loss_avg:0.656462
# Epoch:0 Step:160 Training_loss:0.573819, Acc_avg:64.88% Training_loss_avg:0.652527
# Epoch:0 Step:168 Training_loss:0.751543, Acc_avg:64.20% Training_loss_avg:0.657027
# Epoch:0 Step:176 Training_loss:0.715448, Acc_avg:64.13% Training_loss_avg:0.659567
# Epoch:0 Step:184 Training_loss:0.960745, Acc_avg:62.50% Training_loss_avg:0.672116
# Epoch:0 Step:192 Training_loss:0.762503, Acc_avg:61.50% Training_loss_avg:0.675732
# Epoch:0 Step:200 Training_loss:0.501682, Acc_avg:62.50% Training_loss_avg:0.669038
# Epoch:0 Step:208 Training_loss:0.671642, Acc_avg:62.50% Training_loss_avg:0.669134
# Epoch:0 Step:216 Training_loss:0.801828, Acc_avg:61.61% Training_loss_avg:0.673873
# Epoch:0 Step:224 Training_loss:0.702304, Acc_avg:61.64% Training_loss_avg:0.674853
# Epoch:0 Step:232 Training_loss:0.618684, Acc_avg:62.08% Training_loss_avg:0.672981
# Epoch:0 Step:240 Training_loss:0.936405, Acc_avg:60.48% Training_loss_avg:0.681479
# Epoch:0 Step:248 Training_loss:0.567855, Acc_avg:61.33% Training_loss_avg:0.677928
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:248 Val_loss:0.680112, Val_Acc_avg:56.00%
# Epoch:0 Step:256 Training_loss:0.770665, Acc_avg:60.98% Training_loss_avg:0.680738
# Epoch:0 Step:264 Training_loss:0.706674, Acc_avg:60.66% Training_loss_avg:0.681501
# Epoch:0 Step:272 Training_loss:0.662347, Acc_avg:61.07% Training_loss_avg:0.680954
# Epoch:0 Step:280 Training_loss:0.712489, Acc_avg:60.42% Training_loss_avg:0.681830
# Epoch:0 Step:288 Training_loss:0.685709, Acc_avg:60.14% Training_loss_avg:0.681935
# Epoch:0 Step:296 Training_loss:0.721559, Acc_avg:59.87% Training_loss_avg:0.682977
# Epoch:0 Step:304 Training_loss:0.695100, Acc_avg:59.94% Training_loss_avg:0.683288
# Epoch:0 Step:312 Training_loss:0.803164, Acc_avg:59.06% Training_loss_avg:0.686285
# Epoch:0 Step:320 Training_loss:0.605570, Acc_avg:59.76% Training_loss_avg:0.684316
# Epoch:0 Step:328 Training_loss:0.710420, Acc_avg:59.52% Training_loss_avg:0.684938
# Epoch:0 Step:336 Training_loss:0.687236, Acc_avg:59.30% Training_loss_avg:0.684991
# Epoch:0 Step:344 Training_loss:0.700094, Acc_avg:59.38% Training_loss_avg:0.685335
# Epoch:0 Step:352 Training_loss:0.702753, Acc_avg:58.89% Training_loss_avg:0.685722
# Epoch:0 Step:360 Training_loss:0.712827, Acc_avg:58.70% Training_loss_avg:0.686311
# Epoch:0 Step:368 Training_loss:0.616535, Acc_avg:59.04% Training_loss_avg:0.684826
# Epoch:0 Step:376 Training_loss:0.666757, Acc_avg:59.11% Training_loss_avg:0.684450
# Epoch:0 Step:384 Training_loss:0.713386, Acc_avg:58.67% Training_loss_avg:0.685040
# Epoch:0 Step:392 Training_loss:0.737784, Acc_avg:58.25% Training_loss_avg:0.686095
# Epoch:0 Step:400 Training_loss:0.616228, Acc_avg:58.25% Training_loss_avg:0.685937
# Epoch:0 Step:408 Training_loss:0.659186, Acc_avg:58.50% Training_loss_avg:0.686115
# Epoch:0 Step:416 Training_loss:0.678454, Acc_avg:58.50% Training_loss_avg:0.685745
# Epoch:0 Step:424 Training_loss:0.690791, Acc_avg:58.75% Training_loss_avg:0.686384
# Epoch:0 Step:432 Training_loss:0.743349, Acc_avg:58.25% Training_loss_avg:0.688379
# Epoch:0 Step:440 Training_loss:0.664085, Acc_avg:58.00% Training_loss_avg:0.689351
# Epoch:0 Step:448 Training_loss:0.714606, Acc_avg:56.50% Training_loss_avg:0.691593
# Epoch:0 Step:456 Training_loss:0.659462, Acc_avg:56.75% Training_loss_avg:0.691611
# Epoch:0 Step:464 Training_loss:0.739492, Acc_avg:56.25% Training_loss_avg:0.692522
# Epoch:0 Step:472 Training_loss:0.670770, Acc_avg:55.75% Training_loss_avg:0.694486
# Epoch:0 Step:480 Training_loss:0.675523, Acc_avg:55.75% Training_loss_avg:0.695955
# Epoch:0 Step:488 Training_loss:0.699683, Acc_avg:55.00% Training_loss_avg:0.699097
# Epoch:0 Step:496 Training_loss:0.689132, Acc_avg:54.50% Training_loss_avg:0.702033
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:496 Val_loss:0.685043, Val_Acc_avg:50.00%
# Epoch:0 Step:504 Training_loss:0.690335, Acc_avg:54.75% Training_loss_avg:0.700216
# Epoch:0 Step:512 Training_loss:0.696110, Acc_avg:54.00% Training_loss_avg:0.703197
# Epoch:0 Step:520 Training_loss:0.683729, Acc_avg:54.25% Training_loss_avg:0.701571
# Epoch:0 Step:528 Training_loss:0.693707, Acc_avg:54.25% Training_loss_avg:0.700436
# Epoch:0 Step:536 Training_loss:0.678705, Acc_avg:54.50% Training_loss_avg:0.699226
# Epoch:0 Step:544 Training_loss:0.693911, Acc_avg:54.00% Training_loss_avg:0.699035
# Epoch:0 Step:552 Training_loss:0.771102, Acc_avg:53.75% Training_loss_avg:0.699678
# Epoch:0 Step:560 Training_loss:0.719531, Acc_avg:53.00% Training_loss_avg:0.702592
# Epoch:0 Step:568 Training_loss:0.721723, Acc_avg:53.00% Training_loss_avg:0.701996
# Epoch:0 Step:576 Training_loss:0.667562, Acc_avg:53.25% Training_loss_avg:0.701038
# Epoch:0 Step:584 Training_loss:0.697605, Acc_avg:53.75% Training_loss_avg:0.695775
# Epoch:0 Step:592 Training_loss:0.720365, Acc_avg:53.75% Training_loss_avg:0.694932
# Epoch:0 Step:600 Training_loss:0.670765, Acc_avg:53.25% Training_loss_avg:0.698314
# Epoch:0 Step:608 Training_loss:0.706306, Acc_avg:52.75% Training_loss_avg:0.699007
# Epoch:0 Step:616 Training_loss:0.707673, Acc_avg:52.75% Training_loss_avg:0.697124
# Epoch:0 Step:624 Training_loss:0.756516, Acc_avg:52.00% Training_loss_avg:0.698208
# Epoch:0 Step:632 Training_loss:0.658967, Acc_avg:51.50% Training_loss_avg:0.699014
# Epoch:0 Step:640 Training_loss:0.742526, Acc_avg:51.75% Training_loss_avg:0.695136
# Epoch:0 Step:648 Training_loss:0.695778, Acc_avg:51.25% Training_loss_avg:0.697695
# Epoch:0 Step:656 Training_loss:0.666193, Acc_avg:51.50% Training_loss_avg:0.695605
# Epoch:0 Step:664 Training_loss:0.642688, Acc_avg:52.00% Training_loss_avg:0.694326
# Epoch:0 Step:672 Training_loss:0.752185, Acc_avg:51.25% Training_loss_avg:0.696123
# Epoch:0 Step:680 Training_loss:0.670288, Acc_avg:51.50% Training_loss_avg:0.695278
# Epoch:0 Step:688 Training_loss:0.726313, Acc_avg:51.25% Training_loss_avg:0.696091
# Epoch:0 Step:696 Training_loss:0.682630, Acc_avg:51.00% Training_loss_avg:0.695312
# Epoch:0 Step:704 Training_loss:0.759021, Acc_avg:50.25% Training_loss_avg:0.696590
# Epoch:0 Step:712 Training_loss:0.720304, Acc_avg:50.50% Training_loss_avg:0.694933
# Epoch:0 Step:720 Training_loss:0.679116, Acc_avg:50.00% Training_loss_avg:0.696404
# Epoch:0 Step:728 Training_loss:0.705124, Acc_avg:50.00% Training_loss_avg:0.696298
# Epoch:0 Step:736 Training_loss:0.729730, Acc_avg:49.75% Training_loss_avg:0.697148
# Epoch:0 Step:744 Training_loss:0.683367, Acc_avg:49.50% Training_loss_avg:0.696814
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:744 Val_loss:0.687672, Val_Acc_avg:50.00%
# Epoch:0 Step:752 Training_loss:0.661102, Acc_avg:50.00% Training_loss_avg:0.695981
# Epoch:0 Step:760 Training_loss:0.704365, Acc_avg:49.75% Training_loss_avg:0.695811
# Epoch:0 Step:768 Training_loss:0.694276, Acc_avg:49.75% Training_loss_avg:0.697366
# Epoch:0 Step:776 Training_loss:0.709024, Acc_avg:49.25% Training_loss_avg:0.698211
# Epoch:0 Step:784 Training_loss:0.701040, Acc_avg:49.00% Training_loss_avg:0.697965
# Epoch:0 Step:792 Training_loss:0.742547, Acc_avg:49.00% Training_loss_avg:0.698060
# Epoch:0 Step:800 Training_loss:0.698553, Acc_avg:48.25% Training_loss_avg:0.699706
# Epoch:0 Step:808 Training_loss:0.672132, Acc_avg:47.75% Training_loss_avg:0.699965
# Epoch:0 Step:816 Training_loss:0.728066, Acc_avg:47.00% Training_loss_avg:0.700957
# Epoch:0 Step:824 Training_loss:0.686228, Acc_avg:47.25% Training_loss_avg:0.700866
# Epoch:0 Step:832 Training_loss:0.682774, Acc_avg:47.75% Training_loss_avg:0.699655
# Epoch:0 Step:840 Training_loss:0.648269, Acc_avg:48.00% Training_loss_avg:0.699338
# Epoch:0 Step:848 Training_loss:0.653535, Acc_avg:49.25% Training_loss_avg:0.698117
# Epoch:0 Step:856 Training_loss:0.595508, Acc_avg:49.25% Training_loss_avg:0.696838
# Epoch:0 Step:864 Training_loss:0.665359, Acc_avg:49.75% Training_loss_avg:0.695355
# Epoch:0 Step:872 Training_loss:0.646021, Acc_avg:50.00% Training_loss_avg:0.694860
# Epoch:0 Step:880 Training_loss:0.713655, Acc_avg:49.25% Training_loss_avg:0.695623
# Epoch:0 Step:888 Training_loss:0.680281, Acc_avg:49.50% Training_loss_avg:0.695235
# Epoch:0 Step:896 Training_loss:0.698715, Acc_avg:49.50% Training_loss_avg:0.695427
# Epoch:0 Step:904 Training_loss:0.762932, Acc_avg:49.25% Training_loss_avg:0.696878
# Epoch:0 Step:912 Training_loss:0.657664, Acc_avg:49.75% Training_loss_avg:0.696110
# Epoch:0 Step:920 Training_loss:0.611725, Acc_avg:50.25% Training_loss_avg:0.694669
# Epoch:0 Step:928 Training_loss:0.701187, Acc_avg:50.25% Training_loss_avg:0.694819
# Epoch:0 Step:936 Training_loss:0.799305, Acc_avg:49.75% Training_loss_avg:0.697231
# Epoch:0 Step:944 Training_loss:0.599702, Acc_avg:50.25% Training_loss_avg:0.695347
# Epoch:0 Step:952 Training_loss:0.708519, Acc_avg:50.25% Training_loss_avg:0.694095
# Epoch:0 Step:960 Training_loss:0.793737, Acc_avg:50.00% Training_loss_avg:0.695579
# Epoch:0 Step:968 Training_loss:0.703253, Acc_avg:50.25% Training_loss_avg:0.695210
# Epoch:0 Step:976 Training_loss:0.611585, Acc_avg:50.25% Training_loss_avg:0.694090
# Epoch:0 Step:984 Training_loss:0.689247, Acc_avg:50.75% Training_loss_avg:0.693923
# Epoch:0 Step:992 Training_loss:0.790059, Acc_avg:50.75% Training_loss_avg:0.695317
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:992 Val_loss:0.679191, Val_Acc_avg:58.00%
# Epoch:0 Step:1000 Training_loss:0.795501, Acc_avg:50.25% Training_loss_avg:0.697812
# Epoch:0 Step:1008 Training_loss:0.636549, Acc_avg:51.00% Training_loss_avg:0.696417
# Epoch:0 Step:1016 Training_loss:0.781532, Acc_avg:50.75% Training_loss_avg:0.697894
# Epoch:0 Step:1024 Training_loss:0.638510, Acc_avg:51.50% Training_loss_avg:0.695534
# Epoch:0 Step:1032 Training_loss:0.704292, Acc_avg:51.50% Training_loss_avg:0.696440
# Epoch:0 Step:1040 Training_loss:0.741603, Acc_avg:51.75% Training_loss_avg:0.696422
# Epoch:0 Step:1048 Training_loss:0.659836, Acc_avg:51.75% Training_loss_avg:0.695703
# Epoch:0 Step:1056 Training_loss:0.709616, Acc_avg:51.50% Training_loss_avg:0.696571
# Epoch:0 Step:1064 Training_loss:0.583484, Acc_avg:51.75% Training_loss_avg:0.695387
# Epoch:0 Step:1072 Training_loss:0.734499, Acc_avg:52.00% Training_loss_avg:0.695034
# Epoch:0 Step:1080 Training_loss:0.702265, Acc_avg:52.25% Training_loss_avg:0.695673
# Epoch:0 Step:1088 Training_loss:0.777866, Acc_avg:52.00% Training_loss_avg:0.696704
# Epoch:0 Step:1096 Training_loss:0.634313, Acc_avg:52.50% Training_loss_avg:0.695738
# Epoch:0 Step:1104 Training_loss:0.671071, Acc_avg:53.25% Training_loss_avg:0.693979
# Epoch:0 Step:1112 Training_loss:0.716040, Acc_avg:53.50% Training_loss_avg:0.693894
# Epoch:0 Step:1120 Training_loss:0.741145, Acc_avg:52.75% Training_loss_avg:0.695134
# Epoch:0 Step:1128 Training_loss:0.600880, Acc_avg:53.50% Training_loss_avg:0.693049
# Epoch:0 Step:1136 Training_loss:0.754427, Acc_avg:53.25% Training_loss_avg:0.693543
# Epoch:0 Step:1144 Training_loss:0.726310, Acc_avg:53.00% Training_loss_avg:0.694402
# Epoch:0 Step:1152 Training_loss:0.759527, Acc_avg:52.25% Training_loss_avg:0.696371
# Epoch:0 Step:1160 Training_loss:0.668148, Acc_avg:52.50% Training_loss_avg:0.695646
# Epoch:0 Step:1168 Training_loss:0.668993, Acc_avg:52.25% Training_loss_avg:0.695141
# Epoch:0 Step:1176 Training_loss:0.717241, Acc_avg:52.50% Training_loss_avg:0.695305
# Epoch:0 Step:1184 Training_loss:0.677928, Acc_avg:53.25% Training_loss_avg:0.694843
# Epoch:0 Step:1192 Training_loss:0.756700, Acc_avg:53.00% Training_loss_avg:0.695126
# Epoch:0 Step:1200 Training_loss:0.694820, Acc_avg:53.25% Training_loss_avg:0.695051
# Epoch:0 Step:1208 Training_loss:0.676713, Acc_avg:53.50% Training_loss_avg:0.695143
# Epoch:0 Step:1216 Training_loss:0.677072, Acc_avg:54.25% Training_loss_avg:0.694123
# Epoch:0 Step:1224 Training_loss:0.668957, Acc_avg:54.00% Training_loss_avg:0.693777
# Epoch:0 Step:1232 Training_loss:0.720286, Acc_avg:53.50% Training_loss_avg:0.694528
# Epoch:0 Step:1240 Training_loss:0.740548, Acc_avg:52.75% Training_loss_avg:0.696373
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1240 Val_loss:0.683999, Val_Acc_avg:56.00%
# Epoch:0 Step:1248 Training_loss:0.708312, Acc_avg:52.25% Training_loss_avg:0.697469
# Epoch:0 Step:1256 Training_loss:0.698451, Acc_avg:52.00% Training_loss_avg:0.699528
# Epoch:0 Step:1264 Training_loss:0.674368, Acc_avg:52.00% Training_loss_avg:0.699708
# Epoch:0 Step:1272 Training_loss:0.689322, Acc_avg:51.50% Training_loss_avg:0.700574
# Epoch:0 Step:1280 Training_loss:0.649749, Acc_avg:52.00% Training_loss_avg:0.699296
# Epoch:0 Step:1288 Training_loss:0.688321, Acc_avg:51.75% Training_loss_avg:0.699457
# Epoch:0 Step:1296 Training_loss:0.754807, Acc_avg:51.00% Training_loss_avg:0.700578
# Epoch:0 Step:1304 Training_loss:0.677457, Acc_avg:51.25% Training_loss_avg:0.698869
# Epoch:0 Step:1312 Training_loss:0.713383, Acc_avg:51.00% Training_loss_avg:0.699983
# Epoch:0 Step:1320 Training_loss:0.686295, Acc_avg:50.75% Training_loss_avg:0.701475
# Epoch:0 Step:1328 Training_loss:0.675615, Acc_avg:50.75% Training_loss_avg:0.700963
# Epoch:0 Step:1336 Training_loss:0.653762, Acc_avg:51.75% Training_loss_avg:0.698052
# Epoch:0 Step:1344 Training_loss:0.748191, Acc_avg:51.25% Training_loss_avg:0.701022
# Epoch:0 Step:1352 Training_loss:0.705018, Acc_avg:51.50% Training_loss_avg:0.700952
# Epoch:0 Step:1360 Training_loss:0.747505, Acc_avg:51.75% Training_loss_avg:0.700027
# Epoch:0 Step:1368 Training_loss:0.679277, Acc_avg:51.75% Training_loss_avg:0.699548
# Epoch:0 Step:1376 Training_loss:0.721403, Acc_avg:51.00% Training_loss_avg:0.701744
# Epoch:0 Step:1384 Training_loss:0.661098, Acc_avg:50.75% Training_loss_avg:0.701181
# Epoch:0 Step:1392 Training_loss:0.732031, Acc_avg:50.75% Training_loss_avg:0.700021
# Epoch:0 Step:1400 Training_loss:0.680761, Acc_avg:51.00% Training_loss_avg:0.697726
# Epoch:0 Step:1408 Training_loss:0.653585, Acc_avg:50.75% Training_loss_avg:0.698067
# Epoch:0 Step:1416 Training_loss:0.670794, Acc_avg:51.50% Training_loss_avg:0.695852
# Epoch:0 Step:1424 Training_loss:0.722366, Acc_avg:51.00% Training_loss_avg:0.697529
# Epoch:0 Step:1432 Training_loss:0.737343, Acc_avg:51.00% Training_loss_avg:0.698190
# Epoch:0 Step:1440 Training_loss:0.652987, Acc_avg:51.50% Training_loss_avg:0.696418
# Epoch:0 Step:1448 Training_loss:0.734585, Acc_avg:51.00% Training_loss_avg:0.697913
# Epoch:0 Step:1456 Training_loss:0.704071, Acc_avg:51.50% Training_loss_avg:0.697802
# Epoch:0 Step:1464 Training_loss:0.637010, Acc_avg:51.00% Training_loss_avg:0.698872
# Epoch:0 Step:1472 Training_loss:0.693002, Acc_avg:51.00% Training_loss_avg:0.698042
# Epoch:0 Step:1480 Training_loss:0.675177, Acc_avg:51.00% Training_loss_avg:0.697501
# Epoch:0 Step:1488 Training_loss:0.704364, Acc_avg:51.50% Training_loss_avg:0.696031
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1488 Val_loss:0.681537, Val_Acc_avg:56.00%
# Epoch:0 Step:1496 Training_loss:0.706759, Acc_avg:51.00% Training_loss_avg:0.697480
# Epoch:0 Step:1504 Training_loss:0.679849, Acc_avg:50.75% Training_loss_avg:0.697655
# Epoch:0 Step:1512 Training_loss:0.659783, Acc_avg:50.75% Training_loss_avg:0.696530
# Epoch:0 Step:1520 Training_loss:0.696043, Acc_avg:51.25% Training_loss_avg:0.695628
# Epoch:0 Step:1528 Training_loss:0.719745, Acc_avg:50.50% Training_loss_avg:0.698005
# Epoch:0 Step:1536 Training_loss:0.715756, Acc_avg:50.50% Training_loss_avg:0.697232
# Epoch:0 Step:1544 Training_loss:0.731629, Acc_avg:50.50% Training_loss_avg:0.697338
# Epoch:0 Step:1552 Training_loss:0.682797, Acc_avg:51.25% Training_loss_avg:0.695804
# Epoch:0 Step:1560 Training_loss:0.663552, Acc_avg:51.50% Training_loss_avg:0.695712
# Epoch:0 Step:1568 Training_loss:0.674497, Acc_avg:51.50% Training_loss_avg:0.695822
# Epoch:0 Step:1576 Training_loss:0.621093, Acc_avg:52.25% Training_loss_avg:0.693899
# Epoch:0 Step:1584 Training_loss:0.706741, Acc_avg:51.75% Training_loss_avg:0.694475
# Epoch:0 Step:1592 Training_loss:0.611992, Acc_avg:53.00% Training_loss_avg:0.691581
# Epoch:0 Step:1600 Training_loss:0.747961, Acc_avg:52.75% Training_loss_avg:0.692644
# Epoch:0 Step:1608 Training_loss:0.722188, Acc_avg:52.50% Training_loss_avg:0.693553
# Epoch:0 Step:1616 Training_loss:0.668953, Acc_avg:52.50% Training_loss_avg:0.693391
# Epoch:0 Step:1624 Training_loss:0.639175, Acc_avg:52.75% Training_loss_avg:0.692795
# Epoch:0 Step:1632 Training_loss:0.758199, Acc_avg:53.00% Training_loss_avg:0.693553
# Epoch:0 Step:1640 Training_loss:0.607817, Acc_avg:53.75% Training_loss_avg:0.690899
# Epoch:0 Step:1648 Training_loss:0.676495, Acc_avg:54.00% Training_loss_avg:0.690262
# Epoch:0 Step:1656 Training_loss:0.753181, Acc_avg:53.25% Training_loss_avg:0.691357
# Epoch:0 Step:1664 Training_loss:0.695822, Acc_avg:53.25% Training_loss_avg:0.691786
# Epoch:0 Step:1672 Training_loss:0.650964, Acc_avg:53.75% Training_loss_avg:0.691019
# Epoch:0 Step:1680 Training_loss:0.688585, Acc_avg:53.25% Training_loss_avg:0.691796
# Epoch:0 Step:1688 Training_loss:0.690257, Acc_avg:53.25% Training_loss_avg:0.691834
# Epoch:0 Step:1696 Training_loss:0.674038, Acc_avg:54.00% Training_loss_avg:0.690219
# Epoch:0 Step:1704 Training_loss:0.725955, Acc_avg:53.50% Training_loss_avg:0.691189
# Epoch:0 Step:1712 Training_loss:0.676245, Acc_avg:54.00% Training_loss_avg:0.690446
# Epoch:0 Step:1720 Training_loss:0.680548, Acc_avg:54.00% Training_loss_avg:0.690331
# Epoch:0 Step:1728 Training_loss:0.656671, Acc_avg:54.25% Training_loss_avg:0.689952
# Epoch:0 Step:1736 Training_loss:0.723809, Acc_avg:53.50% Training_loss_avg:0.691353
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1736 Val_loss:0.678306, Val_Acc_avg:58.00%
# Epoch:0 Step:1744 Training_loss:0.779880, Acc_avg:53.75% Training_loss_avg:0.691987
# Epoch:0 Step:1752 Training_loss:0.689600, Acc_avg:54.25% Training_loss_avg:0.691679
# Epoch:0 Step:1760 Training_loss:0.733140, Acc_avg:54.50% Training_loss_avg:0.691391
# Epoch:0 Step:1768 Training_loss:0.800727, Acc_avg:54.00% Training_loss_avg:0.693820
# Epoch:0 Step:1776 Training_loss:0.766003, Acc_avg:54.00% Training_loss_avg:0.694712
# Epoch:0 Step:1784 Training_loss:0.753635, Acc_avg:53.75% Training_loss_avg:0.696563
# Epoch:0 Step:1792 Training_loss:0.687685, Acc_avg:54.00% Training_loss_avg:0.695676
# Epoch:0 Step:1800 Training_loss:0.777971, Acc_avg:53.50% Training_loss_avg:0.697620
# Epoch:0 Step:1808 Training_loss:0.699054, Acc_avg:53.00% Training_loss_avg:0.698530
# Epoch:0 Step:1816 Training_loss:0.732111, Acc_avg:52.75% Training_loss_avg:0.699756
# Epoch:0 Step:1824 Training_loss:0.607270, Acc_avg:53.50% Training_loss_avg:0.697454
# Epoch:0 Step:1832 Training_loss:0.788561, Acc_avg:53.00% Training_loss_avg:0.698479
# Epoch:0 Step:1840 Training_loss:0.752897, Acc_avg:52.25% Training_loss_avg:0.700477
# Epoch:0 Step:1848 Training_loss:0.656340, Acc_avg:53.00% Training_loss_avg:0.698912
# Epoch:0 Step:1856 Training_loss:0.718517, Acc_avg:52.75% Training_loss_avg:0.699201
# Epoch:0 Step:1864 Training_loss:0.725980, Acc_avg:52.25% Training_loss_avg:0.700980
# Epoch:0 Step:1872 Training_loss:0.708082, Acc_avg:52.25% Training_loss_avg:0.701282
# Epoch:0 Step:1880 Training_loss:0.660573, Acc_avg:52.50% Training_loss_avg:0.700990
# Epoch:0 Step:1888 Training_loss:0.692033, Acc_avg:52.75% Training_loss_avg:0.700743
# Epoch:0 Step:1896 Training_loss:0.682731, Acc_avg:53.25% Training_loss_avg:0.700263
# Epoch:0 Step:1904 Training_loss:0.678321, Acc_avg:53.50% Training_loss_avg:0.700232
# Epoch:0 Step:1912 Training_loss:0.650206, Acc_avg:53.75% Training_loss_avg:0.700040
# Epoch:0 Step:1920 Training_loss:0.629961, Acc_avg:54.00% Training_loss_avg:0.698719
# Epoch:0 Step:1928 Training_loss:0.659685, Acc_avg:54.00% Training_loss_avg:0.697518
# Epoch:0 Step:1936 Training_loss:0.707463, Acc_avg:54.00% Training_loss_avg:0.697352
# Epoch:0 Step:1944 Training_loss:0.692779, Acc_avg:54.25% Training_loss_avg:0.696575
# Epoch:0 Step:1952 Training_loss:0.645053, Acc_avg:54.25% Training_loss_avg:0.695820
# Epoch:0 Step:1960 Training_loss:0.686006, Acc_avg:54.00% Training_loss_avg:0.696269
# Epoch:0 Step:1968 Training_loss:0.657829, Acc_avg:54.00% Training_loss_avg:0.695936
# Epoch:0 Step:1976 Training_loss:0.693662, Acc_avg:53.25% Training_loss_avg:0.697387
# Epoch:0 Step:1984 Training_loss:0.710586, Acc_avg:53.50% Training_loss_avg:0.697464
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1984 Val_loss:0.684305, Val_Acc_avg:54.00%
# Epoch:0 Step:1992 Training_loss:0.697175, Acc_avg:52.75% Training_loss_avg:0.699168
# Epoch:0 Step:2000 Training_loss:0.724545, Acc_avg:52.75% Training_loss_avg:0.698699
# Epoch:0 Step:2008 Training_loss:0.749952, Acc_avg:52.00% Training_loss_avg:0.699255
# Epoch:0 Step:2016 Training_loss:0.751934, Acc_avg:51.00% Training_loss_avg:0.700914
# Epoch:0 Step:2024 Training_loss:0.751000, Acc_avg:50.25% Training_loss_avg:0.703151
# Epoch:0 Step:2032 Training_loss:0.695019, Acc_avg:50.00% Training_loss_avg:0.701887
# Epoch:0 Step:2040 Training_loss:0.686285, Acc_avg:49.75% Training_loss_avg:0.703456
# Epoch:0 Step:2048 Training_loss:0.675537, Acc_avg:49.75% Training_loss_avg:0.703437
# Epoch:0 Step:2056 Training_loss:0.704538, Acc_avg:50.50% Training_loss_avg:0.702464
# Epoch:0 Step:2064 Training_loss:0.662984, Acc_avg:50.75% Training_loss_avg:0.701808
# Epoch:0 Step:2072 Training_loss:0.680114, Acc_avg:50.75% Training_loss_avg:0.702391
# Epoch:0 Step:2080 Training_loss:0.710068, Acc_avg:51.00% Training_loss_avg:0.702820
# Epoch:0 Step:2088 Training_loss:0.686759, Acc_avg:51.50% Training_loss_avg:0.702750
# Epoch:0 Step:2096 Training_loss:0.724946, Acc_avg:51.00% Training_loss_avg:0.703769
# Epoch:0 Step:2104 Training_loss:0.668162, Acc_avg:51.25% Training_loss_avg:0.702613
# Epoch:0 Step:2112 Training_loss:0.739467, Acc_avg:50.50% Training_loss_avg:0.703877
# Epoch:0 Step:2120 Training_loss:0.657908, Acc_avg:50.50% Training_loss_avg:0.703424
# Epoch:0 Step:2128 Training_loss:0.729388, Acc_avg:49.75% Training_loss_avg:0.704879
# Epoch:0 Step:2136 Training_loss:0.687306, Acc_avg:50.00% Training_loss_avg:0.704149
# Epoch:0 Step:2144 Training_loss:0.702521, Acc_avg:50.25% Training_loss_avg:0.702601
# Epoch:0 Step:2152 Training_loss:0.708828, Acc_avg:49.50% Training_loss_avg:0.702986
# Epoch:0 Step:2160 Training_loss:0.729839, Acc_avg:49.25% Training_loss_avg:0.702920
# Epoch:0 Step:2168 Training_loss:0.730951, Acc_avg:49.25% Training_loss_avg:0.701524
# Epoch:0 Step:2176 Training_loss:0.680985, Acc_avg:49.75% Training_loss_avg:0.699824
# Epoch:0 Step:2184 Training_loss:0.685341, Acc_avg:49.75% Training_loss_avg:0.698458
# Epoch:0 Step:2192 Training_loss:0.687495, Acc_avg:50.00% Training_loss_avg:0.698454
# Epoch:0 Step:2200 Training_loss:0.672046, Acc_avg:50.75% Training_loss_avg:0.696336
# Epoch:0 Step:2208 Training_loss:0.669098, Acc_avg:51.50% Training_loss_avg:0.695737
# Epoch:0 Step:2216 Training_loss:0.705256, Acc_avg:51.25% Training_loss_avg:0.695200
# Epoch:0 Step:2224 Training_loss:0.669213, Acc_avg:51.00% Training_loss_avg:0.696439
# Epoch:0 Step:2232 Training_loss:0.691012, Acc_avg:51.50% Training_loss_avg:0.694488
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2232 Val_loss:0.691218, Val_Acc_avg:50.00%
# Epoch:0 Step:2240 Training_loss:0.695827, Acc_avg:52.00% Training_loss_avg:0.693346
# Epoch:0 Step:2248 Training_loss:0.706299, Acc_avg:51.25% Training_loss_avg:0.694345
# Epoch:0 Step:2256 Training_loss:0.704832, Acc_avg:51.00% Training_loss_avg:0.694072
# Epoch:0 Step:2264 Training_loss:0.728139, Acc_avg:51.25% Training_loss_avg:0.694115
# Epoch:0 Step:2272 Training_loss:0.639662, Acc_avg:52.00% Training_loss_avg:0.692746
# Epoch:0 Step:2280 Training_loss:0.733537, Acc_avg:51.25% Training_loss_avg:0.694206
# Epoch:0 Step:2288 Training_loss:0.655031, Acc_avg:51.25% Training_loss_avg:0.693466
# Epoch:0 Step:2296 Training_loss:0.697527, Acc_avg:51.00% Training_loss_avg:0.693762
# Epoch:0 Step:2304 Training_loss:0.662824, Acc_avg:51.25% Training_loss_avg:0.693452
# Epoch:0 Step:2312 Training_loss:0.659902, Acc_avg:51.00% Training_loss_avg:0.693646
# Epoch:0 Step:2320 Training_loss:0.686111, Acc_avg:50.75% Training_loss_avg:0.694769
# Epoch:0 Step:2328 Training_loss:0.658680, Acc_avg:51.25% Training_loss_avg:0.694748
# Epoch:0 Step:2336 Training_loss:0.708797, Acc_avg:51.75% Training_loss_avg:0.694775
# Epoch:0 Step:2344 Training_loss:0.591606, Acc_avg:52.50% Training_loss_avg:0.692752
# Epoch:0 Step:2352 Training_loss:0.701319, Acc_avg:52.25% Training_loss_avg:0.693877
# Epoch:0 Step:2360 Training_loss:0.732652, Acc_avg:52.25% Training_loss_avg:0.694810
# Epoch:0 Step:2368 Training_loss:0.616761, Acc_avg:52.50% Training_loss_avg:0.693989
# Epoch:0 Step:2376 Training_loss:0.583696, Acc_avg:53.25% Training_loss_avg:0.691789
# Epoch:0 Step:2384 Training_loss:0.753999, Acc_avg:53.25% Training_loss_avg:0.692658
# Epoch:0 Step:2392 Training_loss:0.610768, Acc_avg:53.75% Training_loss_avg:0.690929
# Epoch:0 Step:2400 Training_loss:0.676939, Acc_avg:54.25% Training_loss_avg:0.689977
# Epoch:0 Step:2408 Training_loss:0.582155, Acc_avg:55.75% Training_loss_avg:0.686621
# Epoch:0 Step:2416 Training_loss:0.718793, Acc_avg:56.50% Training_loss_avg:0.685959
# Epoch:0 Step:2424 Training_loss:0.535971, Acc_avg:57.75% Training_loss_avg:0.681658
# Epoch:0 Step:2432 Training_loss:0.770006, Acc_avg:57.75% Training_loss_avg:0.683158
# Epoch:0 Step:2440 Training_loss:0.843085, Acc_avg:57.50% Training_loss_avg:0.686294
# Epoch:0 Step:2448 Training_loss:0.713905, Acc_avg:57.25% Training_loss_avg:0.687061
# Epoch:0 Step:2456 Training_loss:0.785849, Acc_avg:56.75% Training_loss_avg:0.688687
# Epoch:0 Step:2464 Training_loss:0.844969, Acc_avg:56.00% Training_loss_avg:0.692327
# Epoch:0 Step:2472 Training_loss:0.659385, Acc_avg:56.00% Training_loss_avg:0.691912
# Epoch:0 Step:2480 Training_loss:0.683618, Acc_avg:56.00% Training_loss_avg:0.691383
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:2480 Val_loss:0.678701, Val_Acc_avg:58.00%
# Epoch:0 Step:2488 Training_loss:0.625105, Acc_avg:55.75% Training_loss_avg:0.690150
# Epoch:0 Step:2496 Training_loss:0.716183, Acc_avg:55.75% Training_loss_avg:0.689975
# Epoch:0 Step:2504 Training_loss:0.630045, Acc_avg:56.00% Training_loss_avg:0.689213
# Epoch:0 Step:2512 Training_loss:0.586996, Acc_avg:56.50% Training_loss_avg:0.686163
# Epoch:0 Step:2520 Training_loss:0.760000, Acc_avg:56.00% Training_loss_avg:0.688205
# Epoch:0 Step:2528 Training_loss:0.715796, Acc_avg:56.50% Training_loss_avg:0.687933
# Epoch:0 Step:2536 Training_loss:0.690668, Acc_avg:56.25% Training_loss_avg:0.688000
# Epoch:0 Step:2544 Training_loss:0.726076, Acc_avg:56.00% Training_loss_avg:0.688472
# Epoch:0 Step:2552 Training_loss:0.705113, Acc_avg:56.50% Training_loss_avg:0.688397
# Epoch:0 Step:2560 Training_loss:0.797130, Acc_avg:56.50% Training_loss_avg:0.689743
# Epoch:0 Step:2568 Training_loss:0.708430, Acc_avg:56.75% Training_loss_avg:0.689293
# Epoch:0 Step:2576 Training_loss:0.663484, Acc_avg:57.00% Training_loss_avg:0.688943
# Epoch:0 Step:2584 Training_loss:0.647962, Acc_avg:57.25% Training_loss_avg:0.688195
# Epoch:0 Step:2592 Training_loss:0.617740, Acc_avg:57.50% Training_loss_avg:0.686800
# Epoch:0 Step:2600 Training_loss:0.764957, Acc_avg:57.00% Training_loss_avg:0.688658
# Epoch:0 Step:2608 Training_loss:0.600341, Acc_avg:57.25% Training_loss_avg:0.687283
# Epoch:0 Step:2616 Training_loss:0.684659, Acc_avg:57.50% Training_loss_avg:0.686871
# Epoch:0 Step:2624 Training_loss:0.769079, Acc_avg:56.75% Training_loss_avg:0.688868
# Epoch:0 Step:2632 Training_loss:0.643364, Acc_avg:57.00% Training_loss_avg:0.687915
# Epoch:0 Step:2640 Training_loss:0.650278, Acc_avg:57.50% Training_loss_avg:0.687005
# Epoch:0 Step:2648 Training_loss:0.718280, Acc_avg:57.25% Training_loss_avg:0.687244
# Epoch:0 Step:2656 Training_loss:0.612018, Acc_avg:58.00% Training_loss_avg:0.685388
# Epoch:0 Step:2664 Training_loss:0.721718, Acc_avg:58.00% Training_loss_avg:0.685259
# Epoch:0 Step:2672 Training_loss:0.667661, Acc_avg:57.25% Training_loss_avg:0.685819
# Epoch:0 Step:2680 Training_loss:0.697468, Acc_avg:57.50% Training_loss_avg:0.685098
# Epoch:0 Step:2688 Training_loss:0.694241, Acc_avg:57.50% Training_loss_avg:0.685882
# Epoch:0 Step:2696 Training_loss:0.698510, Acc_avg:57.50% Training_loss_avg:0.685902
# Epoch:0 Step:2704 Training_loss:0.685817, Acc_avg:57.00% Training_loss_avg:0.686362
# Epoch:0 Step:2712 Training_loss:0.741494, Acc_avg:57.00% Training_loss_avg:0.687994
# Epoch:0 Step:2720 Training_loss:0.736856, Acc_avg:56.50% Training_loss_avg:0.689008
# Epoch:0 Step:2728 Training_loss:0.688829, Acc_avg:55.75% Training_loss_avg:0.689611
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:2728 Val_loss:0.678243, Val_Acc_avg:58.00%
# Epoch:0 Step:2736 Training_loss:0.661609, Acc_avg:56.25% Training_loss_avg:0.688668
# Epoch:0 Step:2744 Training_loss:0.671255, Acc_avg:55.50% Training_loss_avg:0.690261
# Epoch:0 Step:2752 Training_loss:0.712522, Acc_avg:55.50% Training_loss_avg:0.690485
# Epoch:0 Step:2760 Training_loss:0.658475, Acc_avg:55.75% Training_loss_avg:0.689001
# Epoch:0 Step:2768 Training_loss:0.618445, Acc_avg:56.00% Training_loss_avg:0.689035
# Epoch:0 Step:2776 Training_loss:0.700710, Acc_avg:55.50% Training_loss_avg:0.691375
# Epoch:0 Step:2784 Training_loss:0.674972, Acc_avg:55.75% Training_loss_avg:0.689795
# Epoch:0 Step:2792 Training_loss:0.709919, Acc_avg:54.75% Training_loss_avg:0.691778
# Epoch:0 Step:2800 Training_loss:0.659484, Acc_avg:54.75% Training_loss_avg:0.691428
# Epoch:0 Step:2808 Training_loss:0.748234, Acc_avg:54.25% Training_loss_avg:0.694750
# Epoch:0 Step:2816 Training_loss:0.739063, Acc_avg:53.75% Training_loss_avg:0.695155
# Epoch:0 Step:2824 Training_loss:0.669508, Acc_avg:53.00% Training_loss_avg:0.697826
# Epoch:0 Step:2832 Training_loss:0.710053, Acc_avg:53.25% Training_loss_avg:0.696627
# Epoch:0 Step:2840 Training_loss:0.633295, Acc_avg:53.75% Training_loss_avg:0.692431
# Epoch:0 Step:2848 Training_loss:0.724989, Acc_avg:53.75% Training_loss_avg:0.692653
# Epoch:0 Step:2856 Training_loss:0.769075, Acc_avg:53.75% Training_loss_avg:0.692318
# Epoch:0 Step:2864 Training_loss:0.726237, Acc_avg:54.00% Training_loss_avg:0.689943
# Epoch:0 Step:2872 Training_loss:0.712692, Acc_avg:54.00% Training_loss_avg:0.691009
# Epoch:0 Step:2880 Training_loss:0.696740, Acc_avg:54.00% Training_loss_avg:0.691271
# Epoch:0 Step:2888 Training_loss:0.652493, Acc_avg:54.00% Training_loss_avg:0.691819
# Epoch:0 Step:2896 Training_loss:0.644011, Acc_avg:54.50% Training_loss_avg:0.690376
# Epoch:0 Step:2904 Training_loss:0.708939, Acc_avg:54.50% Training_loss_avg:0.691954
# Epoch:0 Step:2912 Training_loss:0.734186, Acc_avg:54.00% Training_loss_avg:0.694898
# Epoch:0 Step:2920 Training_loss:0.625876, Acc_avg:54.75% Training_loss_avg:0.692215
# Epoch:0 Step:2928 Training_loss:0.680715, Acc_avg:55.00% Training_loss_avg:0.691513
# Epoch:0 Step:2936 Training_loss:0.685701, Acc_avg:54.75% Training_loss_avg:0.691414
# Epoch:0 Step:2944 Training_loss:0.613512, Acc_avg:55.50% Training_loss_avg:0.689163
# Epoch:0 Step:2952 Training_loss:0.665963, Acc_avg:55.25% Training_loss_avg:0.688380
# Epoch:0 Step:2960 Training_loss:0.653465, Acc_avg:55.75% Training_loss_avg:0.685506
# Epoch:0 Step:2968 Training_loss:0.696455, Acc_avg:55.75% Training_loss_avg:0.685267
# Epoch:0 Step:2976 Training_loss:0.683963, Acc_avg:55.50% Training_loss_avg:0.685677
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2976 Val_loss:0.675806, Val_Acc_avg:56.00%
# Epoch:0 Step:2984 Training_loss:0.743009, Acc_avg:55.00% Training_loss_avg:0.687577
# Epoch:0 Step:2992 Training_loss:0.673597, Acc_avg:55.00% Training_loss_avg:0.688695
# Epoch:0 Step:3000 Training_loss:0.667579, Acc_avg:55.25% Training_loss_avg:0.686747
# Epoch:0 Step:3008 Training_loss:0.601250, Acc_avg:54.75% Training_loss_avg:0.686765
# Epoch:0 Step:3016 Training_loss:0.666080, Acc_avg:54.75% Training_loss_avg:0.686394
# Epoch:0 Step:3024 Training_loss:0.833701, Acc_avg:54.75% Training_loss_avg:0.687686
# Epoch:0 Step:3032 Training_loss:0.670953, Acc_avg:54.50% Training_loss_avg:0.688238
# Epoch:0 Step:3040 Training_loss:0.679020, Acc_avg:54.25% Training_loss_avg:0.688813
# Epoch:0 Step:3048 Training_loss:0.657554, Acc_avg:54.75% Training_loss_avg:0.687598
# Epoch:0 Step:3056 Training_loss:0.702115, Acc_avg:54.25% Training_loss_avg:0.689400
# Epoch:0 Step:3064 Training_loss:0.626259, Acc_avg:54.75% Training_loss_avg:0.687491
# Epoch:0 Step:3072 Training_loss:0.744321, Acc_avg:54.75% Training_loss_avg:0.689024
# Epoch:0 Step:3080 Training_loss:0.739729, Acc_avg:54.25% Training_loss_avg:0.689869
# Epoch:0 Step:3088 Training_loss:0.776643, Acc_avg:53.75% Training_loss_avg:0.691517
# Epoch:0 Step:3096 Training_loss:0.713812, Acc_avg:53.75% Training_loss_avg:0.691823
# Epoch:0 Step:3104 Training_loss:0.743830, Acc_avg:53.50% Training_loss_avg:0.692984
# Epoch:0 Step:3112 Training_loss:0.610918, Acc_avg:54.25% Training_loss_avg:0.690372
# Epoch:0 Step:3120 Training_loss:0.734310, Acc_avg:54.25% Training_loss_avg:0.690321
# Epoch:0 Step:3128 Training_loss:0.649479, Acc_avg:54.75% Training_loss_avg:0.689534
# Epoch:0 Step:3136 Training_loss:0.666646, Acc_avg:54.50% Training_loss_avg:0.689635
# Epoch:0 Step:3144 Training_loss:0.707436, Acc_avg:54.25% Training_loss_avg:0.690359
# Epoch:0 Step:3152 Training_loss:0.722912, Acc_avg:54.00% Training_loss_avg:0.690566
# Epoch:0 Step:3160 Training_loss:0.658710, Acc_avg:54.00% Training_loss_avg:0.690571
# Epoch:0 Step:3168 Training_loss:0.782742, Acc_avg:52.50% Training_loss_avg:0.693857
# Epoch:0 Step:3176 Training_loss:0.684829, Acc_avg:52.75% Training_loss_avg:0.693539
# Epoch:0 Step:3184 Training_loss:0.628400, Acc_avg:53.25% Training_loss_avg:0.692608
# Epoch:0 Step:3192 Training_loss:0.737748, Acc_avg:53.75% Training_loss_avg:0.693165
# Epoch:0 Step:3200 Training_loss:0.700123, Acc_avg:53.50% Training_loss_avg:0.693977
# Epoch:0 Step:3208 Training_loss:0.744894, Acc_avg:52.75% Training_loss_avg:0.693911
# Epoch:0 Step:3216 Training_loss:0.643268, Acc_avg:53.75% Training_loss_avg:0.691995
# Epoch:0 Step:3224 Training_loss:0.693626, Acc_avg:53.25% Training_loss_avg:0.692477
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:3224 Val_loss:0.681904, Val_Acc_avg:50.00%
# Epoch:0 Step:3232 Training_loss:0.661412, Acc_avg:53.75% Training_loss_avg:0.691504
# Epoch:0 Step:3240 Training_loss:0.693889, Acc_avg:53.75% Training_loss_avg:0.692716
# Epoch:0 Step:3248 Training_loss:0.701719, Acc_avg:53.50% Training_loss_avg:0.692251
# Epoch:0 Step:3256 Training_loss:0.691954, Acc_avg:54.00% Training_loss_avg:0.690708
# Epoch:0 Step:3264 Training_loss:0.679477, Acc_avg:54.75% Training_loss_avg:0.689773
# Epoch:0 Step:3272 Training_loss:0.743556, Acc_avg:54.00% Training_loss_avg:0.690390
# Epoch:0 Step:3280 Training_loss:0.680010, Acc_avg:54.50% Training_loss_avg:0.690056
# Epoch:0 Step:3288 Training_loss:0.663067, Acc_avg:54.50% Training_loss_avg:0.690267
# Epoch:0 Step:3296 Training_loss:0.616039, Acc_avg:55.25% Training_loss_avg:0.689708
# Epoch:0 Step:3304 Training_loss:0.692389, Acc_avg:55.00% Training_loss_avg:0.689377
# Epoch:0 Step:3312 Training_loss:0.702165, Acc_avg:55.25% Training_loss_avg:0.688736
# Epoch:0 Step:3320 Training_loss:0.644561, Acc_avg:55.25% Training_loss_avg:0.689110
# Epoch:0 Step:3328 Training_loss:0.705929, Acc_avg:55.33% Training_loss_avg:0.689614
# Epoch:1 Step:0 Training_loss:0.698568, Acc_avg:55.83% Training_loss_avg:0.689872
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:0 Val_loss:0.678708, Val_Acc_avg:54.00%
# Epoch:1 Step:8 Training_loss:0.721276, Acc_avg:55.33% Training_loss_avg:0.692027
# Epoch:1 Step:16 Training_loss:0.681346, Acc_avg:55.08% Training_loss_avg:0.692335
# Epoch:1 Step:24 Training_loss:0.792421, Acc_avg:54.58% Training_loss_avg:0.695114
# Epoch:1 Step:32 Training_loss:0.676067, Acc_avg:54.83% Training_loss_avg:0.694706
# Epoch:1 Step:40 Training_loss:0.809583, Acc_avg:54.08% Training_loss_avg:0.697218
# Epoch:1 Step:48 Training_loss:0.786921, Acc_avg:54.08% Training_loss_avg:0.698097
# Epoch:1 Step:56 Training_loss:0.613071, Acc_avg:54.33% Training_loss_avg:0.696886
# Epoch:1 Step:64 Training_loss:0.695493, Acc_avg:54.58% Training_loss_avg:0.697444
# Epoch:1 Step:72 Training_loss:0.639647, Acc_avg:54.58% Training_loss_avg:0.698212
# Epoch:1 Step:80 Training_loss:0.706604, Acc_avg:54.33% Training_loss_avg:0.699023
# Epoch:1 Step:88 Training_loss:0.681638, Acc_avg:55.33% Training_loss_avg:0.695982
# Epoch:1 Step:96 Training_loss:0.637673, Acc_avg:55.83% Training_loss_avg:0.695316
# Epoch:1 Step:104 Training_loss:0.731689, Acc_avg:55.33% Training_loss_avg:0.696369
# Epoch:1 Step:112 Training_loss:0.700779, Acc_avg:55.58% Training_loss_avg:0.697234
# Epoch:1 Step:120 Training_loss:0.706847, Acc_avg:55.58% Training_loss_avg:0.697328
# Epoch:1 Step:128 Training_loss:0.670823, Acc_avg:55.08% Training_loss_avg:0.698220
# Epoch:1 Step:136 Training_loss:0.721225, Acc_avg:54.58% Training_loss_avg:0.697758
# Epoch:1 Step:144 Training_loss:0.795329, Acc_avg:55.08% Training_loss_avg:0.698870
# Epoch:1 Step:152 Training_loss:0.766498, Acc_avg:55.33% Training_loss_avg:0.698667
# Epoch:1 Step:160 Training_loss:0.668866, Acc_avg:55.83% Training_loss_avg:0.697768
# Epoch:1 Step:168 Training_loss:0.718743, Acc_avg:55.83% Training_loss_avg:0.697266
# Epoch:1 Step:176 Training_loss:0.670642, Acc_avg:54.83% Training_loss_avg:0.698461
# Epoch:1 Step:184 Training_loss:0.734820, Acc_avg:55.08% Training_loss_avg:0.698471
# Epoch:1 Step:192 Training_loss:0.652007, Acc_avg:54.83% Training_loss_avg:0.698522
# Epoch:1 Step:200 Training_loss:0.743401, Acc_avg:54.33% Training_loss_avg:0.700057
# Epoch:1 Step:208 Training_loss:0.746784, Acc_avg:54.33% Training_loss_avg:0.700844
# Epoch:1 Step:216 Training_loss:0.673601, Acc_avg:54.83% Training_loss_avg:0.699857
# Epoch:1 Step:224 Training_loss:0.701964, Acc_avg:54.58% Training_loss_avg:0.700722
# Epoch:1 Step:232 Training_loss:0.717303, Acc_avg:55.08% Training_loss_avg:0.699414
# Epoch:1 Step:240 Training_loss:0.728609, Acc_avg:54.58% Training_loss_avg:0.700289
# Epoch:1 Step:248 Training_loss:0.657070, Acc_avg:54.33% Training_loss_avg:0.700863
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:1 Step:248 Val_loss:0.685116, Val_Acc_avg:56.00%
# Epoch:1 Step:256 Training_loss:0.750651, Acc_avg:53.58% Training_loss_avg:0.701121
# Epoch:1 Step:264 Training_loss:0.636281, Acc_avg:54.08% Training_loss_avg:0.699844
# Epoch:1 Step:272 Training_loss:0.675866, Acc_avg:54.58% Training_loss_avg:0.698463
# Epoch:1 Step:280 Training_loss:0.693916, Acc_avg:53.83% Training_loss_avg:0.699476
# Epoch:1 Step:288 Training_loss:0.695317, Acc_avg:53.83% Training_loss_avg:0.699510
# Epoch:1 Step:296 Training_loss:0.702424, Acc_avg:53.08% Training_loss_avg:0.700330
# Epoch:1 Step:304 Training_loss:0.670668, Acc_avg:52.83% Training_loss_avg:0.699866
# Epoch:1 Step:312 Training_loss:0.695245, Acc_avg:52.83% Training_loss_avg:0.699736
# Epoch:1 Step:320 Training_loss:0.696597, Acc_avg:52.83% Training_loss_avg:0.699829
# Epoch:1 Step:328 Training_loss:0.698755, Acc_avg:52.33% Training_loss_avg:0.700215
# Epoch:1 Step:336 Training_loss:0.665143, Acc_avg:53.33% Training_loss_avg:0.698647
# Epoch:1 Step:344 Training_loss:0.661932, Acc_avg:53.08% Training_loss_avg:0.698285
# Epoch:1 Step:352 Training_loss:0.681198, Acc_avg:52.83% Training_loss_avg:0.698648
# Epoch:1 Step:360 Training_loss:0.693568, Acc_avg:51.58% Training_loss_avg:0.700198
# Epoch:1 Step:368 Training_loss:0.661506, Acc_avg:51.83% Training_loss_avg:0.699581
# Epoch:1 Step:376 Training_loss:0.657636, Acc_avg:52.08% Training_loss_avg:0.698690
# Epoch:1 Step:384 Training_loss:0.666185, Acc_avg:52.08% Training_loss_avg:0.699123
# Epoch:1 Step:392 Training_loss:0.694227, Acc_avg:52.00% Training_loss_avg:0.698888
# Epoch:1 Step:400 Training_loss:0.651230, Acc_avg:52.50% Training_loss_avg:0.697942
# Epoch:1 Step:408 Training_loss:0.700229, Acc_avg:52.00% Training_loss_avg:0.697521
# Epoch:1 Step:416 Training_loss:0.684569, Acc_avg:52.50% Training_loss_avg:0.697585
# Epoch:1 Step:424 Training_loss:0.748728, Acc_avg:52.25% Training_loss_avg:0.696711
# Epoch:1 Step:432 Training_loss:0.676420, Acc_avg:52.00% Training_loss_avg:0.696718
# Epoch:1 Step:440 Training_loss:0.688600, Acc_avg:52.75% Training_loss_avg:0.694299
# Epoch:1 Step:448 Training_loss:0.731208, Acc_avg:52.75% Training_loss_avg:0.693185
# Epoch:1 Step:456 Training_loss:0.694492, Acc_avg:52.00% Training_loss_avg:0.694813
# Epoch:1 Step:464 Training_loss:0.756937, Acc_avg:51.00% Training_loss_avg:0.696042
# Epoch:1 Step:472 Training_loss:0.625241, Acc_avg:51.75% Training_loss_avg:0.695754
# Epoch:1 Step:480 Training_loss:0.693261, Acc_avg:52.00% Training_loss_avg:0.695487
# Epoch:1 Step:488 Training_loss:0.660650, Acc_avg:51.75% Training_loss_avg:0.695067
# Epoch:1 Step:496 Training_loss:0.703193, Acc_avg:51.00% Training_loss_avg:0.696377
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:1 Step:496 Val_loss:0.690152, Val_Acc_avg:54.00%
# Epoch:1 Step:504 Training_loss:0.727336, Acc_avg:50.75% Training_loss_avg:0.696290
# Epoch:1 Step:512 Training_loss:0.688945, Acc_avg:50.50% Training_loss_avg:0.696054
# Epoch:1 Step:520 Training_loss:0.661748, Acc_avg:50.75% Training_loss_avg:0.695152
# Epoch:1 Step:528 Training_loss:0.661928, Acc_avg:51.25% Training_loss_avg:0.694974
# Epoch:1 Step:536 Training_loss:0.711448, Acc_avg:51.50% Training_loss_avg:0.694778
# Epoch:1 Step:544 Training_loss:0.701978, Acc_avg:51.50% Training_loss_avg:0.692911
# Epoch:1 Step:552 Training_loss:0.675959, Acc_avg:51.50% Training_loss_avg:0.691101
# Epoch:1 Step:560 Training_loss:0.696941, Acc_avg:50.75% Training_loss_avg:0.691662
# Epoch:1 Step:568 Training_loss:0.647436, Acc_avg:51.50% Training_loss_avg:0.690236
# Epoch:1 Step:576 Training_loss:0.674580, Acc_avg:51.75% Training_loss_avg:0.690315
# Epoch:1 Step:584 Training_loss:0.647123, Acc_avg:52.75% Training_loss_avg:0.688561
# Epoch:1 Step:592 Training_loss:0.702846, Acc_avg:52.50% Training_loss_avg:0.689577
# Epoch:1 Step:600 Training_loss:0.674757, Acc_avg:53.00% Training_loss_avg:0.688205
# Epoch:1 Step:608 Training_loss:0.663223, Acc_avg:54.00% Training_loss_avg:0.686533
# Epoch:1 Step:616 Training_loss:0.693606, Acc_avg:53.75% Training_loss_avg:0.686934
# Epoch:1 Step:624 Training_loss:0.696966, Acc_avg:53.75% Training_loss_avg:0.686834
# Epoch:1 Step:632 Training_loss:0.628748, Acc_avg:55.00% Training_loss_avg:0.685062
# Epoch:1 Step:640 Training_loss:0.750103, Acc_avg:54.50% Training_loss_avg:0.685492
# Epoch:1 Step:648 Training_loss:0.661612, Acc_avg:54.50% Training_loss_avg:0.685583
# Epoch:1 Step:656 Training_loss:0.714451, Acc_avg:55.25% Training_loss_avg:0.684859
# Epoch:1 Step:664 Training_loss:0.740401, Acc_avg:54.75% Training_loss_avg:0.686942
# Epoch:1 Step:672 Training_loss:0.725143, Acc_avg:54.25% Training_loss_avg:0.687927
# Epoch:1 Step:680 Training_loss:0.725596, Acc_avg:54.50% Training_loss_avg:0.688561
# Epoch:1 Step:688 Training_loss:0.646653, Acc_avg:55.00% Training_loss_avg:0.687587
# Epoch:1 Step:696 Training_loss:0.639323, Acc_avg:56.00% Training_loss_avg:0.686325
# Epoch:1 Step:704 Training_loss:0.712475, Acc_avg:55.50% Training_loss_avg:0.687162
# Epoch:1 Step:712 Training_loss:0.659000, Acc_avg:56.25% Training_loss_avg:0.686437
# Epoch:1 Step:720 Training_loss:0.597723, Acc_avg:56.50% Training_loss_avg:0.684459
# Epoch:1 Step:728 Training_loss:0.627979, Acc_avg:56.75% Training_loss_avg:0.683044
# Epoch:1 Step:736 Training_loss:0.663704, Acc_avg:56.50% Training_loss_avg:0.683015
# Epoch:1 Step:744 Training_loss:0.722836, Acc_avg:56.00% Training_loss_avg:0.684233
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:1 Step:744 Val_loss:0.675323, Val_Acc_avg:58.00%
# Epoch:1 Step:752 Training_loss:0.711363, Acc_avg:56.00% Training_loss_avg:0.684836
# Epoch:1 Step:760 Training_loss:0.690406, Acc_avg:56.50% Training_loss_avg:0.684773
# Epoch:1 Step:768 Training_loss:0.686069, Acc_avg:56.50% Training_loss_avg:0.685264
# Epoch:1 Step:776 Training_loss:0.810539, Acc_avg:56.00% Training_loss_avg:0.688322
# Epoch:1 Step:784 Training_loss:0.733736, Acc_avg:55.25% Training_loss_avg:0.689673
# Epoch:1 Step:792 Training_loss:0.539272, Acc_avg:55.75% Training_loss_avg:0.686574
# Epoch:1 Step:800 Training_loss:0.703040, Acc_avg:55.25% Training_loss_avg:0.687610
# Epoch:1 Step:808 Training_loss:0.695647, Acc_avg:55.25% Training_loss_avg:0.687519
# Epoch:1 Step:816 Training_loss:0.659275, Acc_avg:55.00% Training_loss_avg:0.687013
# Epoch:1 Step:824 Training_loss:0.704318, Acc_avg:55.25% Training_loss_avg:0.686125
# Epoch:1 Step:832 Training_loss:0.692464, Acc_avg:55.50% Training_loss_avg:0.686446
# Epoch:1 Step:840 Training_loss:0.644345, Acc_avg:55.75% Training_loss_avg:0.685560
# Epoch:1 Step:848 Training_loss:0.745406, Acc_avg:55.75% Training_loss_avg:0.685844
# Epoch:1 Step:856 Training_loss:0.693525, Acc_avg:55.75% Training_loss_avg:0.685825
# Epoch:1 Step:864 Training_loss:0.686612, Acc_avg:57.00% Training_loss_avg:0.684419
# Epoch:1 Step:872 Training_loss:0.603943, Acc_avg:56.75% Training_loss_avg:0.683993
# Epoch:1 Step:880 Training_loss:0.622037, Acc_avg:57.25% Training_loss_avg:0.682568
# Epoch:1 Step:888 Training_loss:0.683903, Acc_avg:57.25% Training_loss_avg:0.683033
# Epoch:1 Step:896 Training_loss:0.691315, Acc_avg:57.50% Training_loss_avg:0.682796
# ...
# Epoch:4 Step:1872 Training_loss:0.504651, Acc_avg:64.00% Training_loss_avg:0.618045
# Epoch:4 Step:1880 Training_loss:0.397487, Acc_avg:64.00% Training_loss_avg:0.614631
# Epoch:4 Step:1888 Training_loss:0.371578, Acc_avg:64.75% Training_loss_avg:0.606362
# Epoch:4 Step:1896 Training_loss:0.554590, Acc_avg:65.25% Training_loss_avg:0.603674
# Epoch:4 Step:1904 Training_loss:0.719858, Acc_avg:65.50% Training_loss_avg:0.606769
# Epoch:4 Step:1912 Training_loss:0.548874, Acc_avg:65.25% Training_loss_avg:0.606284
# Epoch:4 Step:1920 Training_loss:0.410985, Acc_avg:65.75% Training_loss_avg:0.600503
# Epoch:4 Step:1928 Training_loss:0.708589, Acc_avg:65.75% Training_loss_avg:0.602496
# Epoch:4 Step:1936 Training_loss:0.527758, Acc_avg:65.75% Training_loss_avg:0.602350
# Epoch:4 Step:1944 Training_loss:0.331988, Acc_avg:66.25% Training_loss_avg:0.598098
# Epoch:4 Step:1952 Training_loss:0.364596, Acc_avg:66.75% Training_loss_avg:0.594443
# Epoch:4 Step:1960 Training_loss:0.717820, Acc_avg:66.75% Training_loss_avg:0.596302
# Epoch:4 Step:1968 Training_loss:0.590732, Acc_avg:66.50% Training_loss_avg:0.596096
# Epoch:4 Step:1976 Training_loss:0.751606, Acc_avg:66.50% Training_loss_avg:0.600012
# Epoch:4 Step:1984 Training_loss:0.722364, Acc_avg:66.75% Training_loss_avg:0.599980
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:1984 Val_loss:0.673607, Val_Acc_avg:58.00%
# Epoch:4 Step:1992 Training_loss:0.631366, Acc_avg:66.50% Training_loss_avg:0.601772
# Epoch:4 Step:2000 Training_loss:0.561189, Acc_avg:66.25% Training_loss_avg:0.602955
# Epoch:4 Step:2008 Training_loss:0.622604, Acc_avg:65.75% Training_loss_avg:0.605418
# Epoch:4 Step:2016 Training_loss:0.644250, Acc_avg:65.50% Training_loss_avg:0.607734
# Epoch:4 Step:2024 Training_loss:0.534695, Acc_avg:65.75% Training_loss_avg:0.604488
# Epoch:4 Step:2032 Training_loss:0.572538, Acc_avg:66.50% Training_loss_avg:0.603117
# Epoch:4 Step:2040 Training_loss:0.473181, Acc_avg:67.25% Training_loss_avg:0.593688
# Epoch:4 Step:2048 Training_loss:0.695173, Acc_avg:67.00% Training_loss_avg:0.595577
# Epoch:4 Step:2056 Training_loss:0.563282, Acc_avg:67.50% Training_loss_avg:0.591033
# Epoch:4 Step:2064 Training_loss:0.453964, Acc_avg:67.50% Training_loss_avg:0.591763
# Epoch:4 Step:2072 Training_loss:0.702762, Acc_avg:68.00% Training_loss_avg:0.588463
# Epoch:4 Step:2080 Training_loss:0.558195, Acc_avg:68.75% Training_loss_avg:0.587191
# Epoch:4 Step:2088 Training_loss:0.603215, Acc_avg:68.25% Training_loss_avg:0.588637
# Epoch:4 Step:2096 Training_loss:0.655972, Acc_avg:67.75% Training_loss_avg:0.590232
# Epoch:4 Step:2104 Training_loss:0.400956, Acc_avg:68.50% Training_loss_avg:0.585985
# Epoch:4 Step:2112 Training_loss:0.462188, Acc_avg:68.25% Training_loss_avg:0.585192
# Epoch:4 Step:2120 Training_loss:0.650177, Acc_avg:68.50% Training_loss_avg:0.584119
# Epoch:4 Step:2128 Training_loss:0.680621, Acc_avg:68.00% Training_loss_avg:0.586309
# Epoch:4 Step:2136 Training_loss:0.488663, Acc_avg:68.50% Training_loss_avg:0.586190
# Epoch:4 Step:2144 Training_loss:0.624253, Acc_avg:68.75% Training_loss_avg:0.587240
# Epoch:4 Step:2152 Training_loss:0.642449, Acc_avg:68.50% Training_loss_avg:0.586248
# Epoch:4 Step:2160 Training_loss:0.621086, Acc_avg:68.50% Training_loss_avg:0.586421
# Epoch:4 Step:2168 Training_loss:0.393016, Acc_avg:69.25% Training_loss_avg:0.581006
# Epoch:4 Step:2176 Training_loss:0.531384, Acc_avg:69.25% Training_loss_avg:0.577122
# Epoch:4 Step:2184 Training_loss:0.833244, Acc_avg:69.25% Training_loss_avg:0.579516
# Epoch:4 Step:2192 Training_loss:0.558717, Acc_avg:69.50% Training_loss_avg:0.577504
# Epoch:4 Step:2200 Training_loss:0.635536, Acc_avg:70.25% Training_loss_avg:0.575702
# Epoch:4 Step:2208 Training_loss:0.667608, Acc_avg:69.50% Training_loss_avg:0.576680
# Epoch:4 Step:2216 Training_loss:0.724659, Acc_avg:69.50% Training_loss_avg:0.576990
# Epoch:4 Step:2224 Training_loss:0.562278, Acc_avg:69.75% Training_loss_avg:0.574859
# Epoch:4 Step:2232 Training_loss:0.531210, Acc_avg:69.75% Training_loss_avg:0.573679
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2232 Val_loss:0.667526, Val_Acc_avg:58.00%
# Epoch:4 Step:2240 Training_loss:0.599392, Acc_avg:69.75% Training_loss_avg:0.574567
# Epoch:4 Step:2248 Training_loss:0.643544, Acc_avg:69.50% Training_loss_avg:0.573561
# Epoch:4 Step:2256 Training_loss:0.781051, Acc_avg:69.00% Training_loss_avg:0.581787
# Epoch:4 Step:2264 Training_loss:0.611804, Acc_avg:69.00% Training_loss_avg:0.582794
# Epoch:4 Step:2272 Training_loss:0.860749, Acc_avg:68.25% Training_loss_avg:0.589916
# Epoch:4 Step:2280 Training_loss:0.712030, Acc_avg:67.75% Training_loss_avg:0.596207
# Epoch:4 Step:2288 Training_loss:0.674811, Acc_avg:67.25% Training_loss_avg:0.602271
# Epoch:4 Step:2296 Training_loss:0.682528, Acc_avg:67.00% Training_loss_avg:0.604830
# Epoch:4 Step:2304 Training_loss:0.783360, Acc_avg:66.75% Training_loss_avg:0.606100
# Epoch:4 Step:2312 Training_loss:0.707480, Acc_avg:66.75% Training_loss_avg:0.609272
# Epoch:4 Step:2320 Training_loss:0.544816, Acc_avg:66.25% Training_loss_avg:0.611949
# Epoch:4 Step:2328 Training_loss:0.677934, Acc_avg:66.50% Training_loss_avg:0.611336
# Epoch:4 Step:2336 Training_loss:0.641038, Acc_avg:66.00% Training_loss_avg:0.613601
# Epoch:4 Step:2344 Training_loss:0.375872, Acc_avg:66.00% Training_loss_avg:0.614479
# Epoch:4 Step:2352 Training_loss:0.583669, Acc_avg:65.75% Training_loss_avg:0.618861
# Epoch:4 Step:2360 Training_loss:0.633818, Acc_avg:65.50% Training_loss_avg:0.617181
# Epoch:4 Step:2368 Training_loss:0.593432, Acc_avg:65.50% Training_loss_avg:0.617235
# Epoch:4 Step:2376 Training_loss:0.704954, Acc_avg:65.25% Training_loss_avg:0.616302
# Epoch:4 Step:2384 Training_loss:0.594627, Acc_avg:65.25% Training_loss_avg:0.613747
# Epoch:4 Step:2392 Training_loss:0.594038, Acc_avg:65.75% Training_loss_avg:0.613000
# Epoch:4 Step:2400 Training_loss:0.581556, Acc_avg:66.00% Training_loss_avg:0.613408
# Epoch:4 Step:2408 Training_loss:0.608949, Acc_avg:66.25% Training_loss_avg:0.613134
# Epoch:4 Step:2416 Training_loss:0.707721, Acc_avg:65.50% Training_loss_avg:0.614404
# Epoch:4 Step:2424 Training_loss:0.787036, Acc_avg:65.25% Training_loss_avg:0.619451
# Epoch:4 Step:2432 Training_loss:0.623902, Acc_avg:65.00% Training_loss_avg:0.620478
# Epoch:4 Step:2440 Training_loss:0.667930, Acc_avg:64.75% Training_loss_avg:0.624373
# Epoch:4 Step:2448 Training_loss:0.562939, Acc_avg:65.00% Training_loss_avg:0.621728
# Epoch:4 Step:2456 Training_loss:0.485305, Acc_avg:65.75% Training_loss_avg:0.620169
# Epoch:4 Step:2464 Training_loss:0.599564, Acc_avg:65.00% Training_loss_avg:0.623081
# Epoch:4 Step:2472 Training_loss:0.623156, Acc_avg:65.00% Training_loss_avg:0.621489
# Epoch:4 Step:2480 Training_loss:0.651353, Acc_avg:64.50% Training_loss_avg:0.623352
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2480 Val_loss:0.610115, Val_Acc_avg:48.00%
# Epoch:4 Step:2488 Training_loss:0.593864, Acc_avg:64.75% Training_loss_avg:0.623165
# Epoch:4 Step:2496 Training_loss:0.554610, Acc_avg:65.25% Training_loss_avg:0.621138
# Epoch:4 Step:2504 Training_loss:0.616277, Acc_avg:64.25% Training_loss_avg:0.625444
# Epoch:4 Step:2512 Training_loss:0.530847, Acc_avg:64.25% Training_loss_avg:0.626817
# Epoch:4 Step:2520 Training_loss:0.692956, Acc_avg:64.50% Training_loss_avg:0.627673
# Epoch:4 Step:2528 Training_loss:0.868759, Acc_avg:63.50% Training_loss_avg:0.631435
# Epoch:4 Step:2536 Training_loss:0.638038, Acc_avg:63.00% Training_loss_avg:0.634423
# Epoch:4 Step:2544 Training_loss:0.608844, Acc_avg:63.00% Training_loss_avg:0.634115
# Epoch:4 Step:2552 Training_loss:0.520663, Acc_avg:63.75% Training_loss_avg:0.631679
# Epoch:4 Step:2560 Training_loss:0.579088, Acc_avg:64.00% Training_loss_avg:0.630839
# Epoch:4 Step:2568 Training_loss:0.590518, Acc_avg:63.50% Training_loss_avg:0.634789
# Epoch:4 Step:2576 Training_loss:0.545201, Acc_avg:63.75% Training_loss_avg:0.635065
# Epoch:4 Step:2584 Training_loss:0.475166, Acc_avg:64.00% Training_loss_avg:0.627904
# Epoch:4 Step:2592 Training_loss:0.414827, Acc_avg:64.25% Training_loss_avg:0.625026
# Epoch:4 Step:2600 Training_loss:0.506983, Acc_avg:64.25% Training_loss_avg:0.622455
# Epoch:4 Step:2608 Training_loss:0.485843, Acc_avg:65.25% Training_loss_avg:0.618820
# Epoch:4 Step:2616 Training_loss:0.517042, Acc_avg:65.50% Training_loss_avg:0.614667
# Epoch:4 Step:2624 Training_loss:0.752053, Acc_avg:65.00% Training_loss_avg:0.618463
# Epoch:4 Step:2632 Training_loss:0.822453, Acc_avg:64.50% Training_loss_avg:0.624288
# Epoch:4 Step:2640 Training_loss:0.702652, Acc_avg:64.00% Training_loss_avg:0.626353
# Epoch:4 Step:2648 Training_loss:0.868448, Acc_avg:63.75% Training_loss_avg:0.630851
# Epoch:4 Step:2656 Training_loss:0.756602, Acc_avg:63.25% Training_loss_avg:0.630362
# Epoch:4 Step:2664 Training_loss:0.594979, Acc_avg:63.50% Training_loss_avg:0.630026
# Epoch:4 Step:2672 Training_loss:0.517361, Acc_avg:64.50% Training_loss_avg:0.623158
# Epoch:4 Step:2680 Training_loss:0.590263, Acc_avg:64.50% Training_loss_avg:0.620722
# Epoch:4 Step:2688 Training_loss:0.721687, Acc_avg:64.25% Training_loss_avg:0.621660
# Epoch:4 Step:2696 Training_loss:0.583203, Acc_avg:64.50% Training_loss_avg:0.619673
# Epoch:4 Step:2704 Training_loss:0.576956, Acc_avg:65.00% Training_loss_avg:0.615545
# Epoch:4 Step:2712 Training_loss:0.487230, Acc_avg:65.50% Training_loss_avg:0.611140
# Epoch:4 Step:2720 Training_loss:0.532955, Acc_avg:65.25% Training_loss_avg:0.610903
# Epoch:4 Step:2728 Training_loss:0.647154, Acc_avg:65.00% Training_loss_avg:0.610288
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2728 Val_loss:0.612235, Val_Acc_avg:54.00%
# Epoch:4 Step:2736 Training_loss:0.539447, Acc_avg:65.50% Training_loss_avg:0.608256
# Epoch:4 Step:2744 Training_loss:0.529305, Acc_avg:65.25% Training_loss_avg:0.611324
# Epoch:4 Step:2752 Training_loss:0.573081, Acc_avg:65.00% Training_loss_avg:0.611113
# Epoch:4 Step:2760 Training_loss:0.765467, Acc_avg:64.75% Training_loss_avg:0.613746
# Epoch:4 Step:2768 Training_loss:0.564825, Acc_avg:64.75% Training_loss_avg:0.613173
# Epoch:4 Step:2776 Training_loss:0.447913, Acc_avg:65.75% Training_loss_avg:0.608033
# Epoch:4 Step:2784 Training_loss:0.549314, Acc_avg:66.25% Training_loss_avg:0.607126
# Epoch:4 Step:2792 Training_loss:0.623063, Acc_avg:66.00% Training_loss_avg:0.607707
# Epoch:4 Step:2800 Training_loss:0.757162, Acc_avg:65.50% Training_loss_avg:0.611219
# Epoch:4 Step:2808 Training_loss:0.619737, Acc_avg:65.50% Training_loss_avg:0.611435
# Epoch:4 Step:2816 Training_loss:0.600429, Acc_avg:66.25% Training_loss_avg:0.609289
# Epoch:4 Step:2824 Training_loss:0.550377, Acc_avg:66.75% Training_loss_avg:0.604556
# Epoch:4 Step:2832 Training_loss:0.654236, Acc_avg:66.50% Training_loss_avg:0.605162
# Epoch:4 Step:2840 Training_loss:0.508835, Acc_avg:67.25% Training_loss_avg:0.601981
# Epoch:4 Step:2848 Training_loss:0.580204, Acc_avg:67.75% Training_loss_avg:0.602326
# Epoch:4 Step:2856 Training_loss:0.669288, Acc_avg:67.25% Training_loss_avg:0.606006
# Epoch:4 Step:2864 Training_loss:0.671558, Acc_avg:67.25% Training_loss_avg:0.607445
# Epoch:4 Step:2872 Training_loss:0.600179, Acc_avg:67.50% Training_loss_avg:0.606986
# Epoch:4 Step:2880 Training_loss:0.592989, Acc_avg:67.50% Training_loss_avg:0.605819
# Epoch:4 Step:2888 Training_loss:0.736283, Acc_avg:66.75% Training_loss_avg:0.608667
# Epoch:4 Step:2896 Training_loss:0.486297, Acc_avg:67.00% Training_loss_avg:0.607301
# Epoch:4 Step:2904 Training_loss:0.551219, Acc_avg:67.25% Training_loss_avg:0.606000
# Epoch:4 Step:2912 Training_loss:0.561783, Acc_avg:66.75% Training_loss_avg:0.606618
# Epoch:4 Step:2920 Training_loss:0.641423, Acc_avg:66.50% Training_loss_avg:0.605588
# Epoch:4 Step:2928 Training_loss:0.864698, Acc_avg:67.50% Training_loss_avg:0.605506
# Epoch:4 Step:2936 Training_loss:0.559401, Acc_avg:67.75% Training_loss_avg:0.603934
# Epoch:4 Step:2944 Training_loss:0.364681, Acc_avg:68.25% Training_loss_avg:0.599050
# Epoch:4 Step:2952 Training_loss:0.593069, Acc_avg:67.75% Training_loss_avg:0.600499
# Epoch:4 Step:2960 Training_loss:0.643065, Acc_avg:67.50% Training_loss_avg:0.601778
# Epoch:4 Step:2968 Training_loss:0.588773, Acc_avg:67.00% Training_loss_avg:0.601743
# Epoch:4 Step:2976 Training_loss:0.661694, Acc_avg:66.75% Training_loss_avg:0.604073
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2976 Val_loss:0.631534, Val_Acc_avg:52.00%
# Epoch:4 Step:2984 Training_loss:0.831910, Acc_avg:66.00% Training_loss_avg:0.611208
# Epoch:4 Step:2992 Training_loss:0.481054, Acc_avg:65.75% Training_loss_avg:0.612532
# Epoch:4 Step:3000 Training_loss:0.420478, Acc_avg:66.00% Training_loss_avg:0.610802
# Epoch:4 Step:3008 Training_loss:0.454510, Acc_avg:66.00% Training_loss_avg:0.610176
# Epoch:4 Step:3016 Training_loss:0.412283, Acc_avg:66.25% Training_loss_avg:0.608081
# Epoch:4 Step:3024 Training_loss:0.612662, Acc_avg:66.00% Training_loss_avg:0.605293
# Epoch:4 Step:3032 Training_loss:0.609820, Acc_avg:66.50% Training_loss_avg:0.601040
# Epoch:4 Step:3040 Training_loss:0.669935, Acc_avg:66.50% Training_loss_avg:0.600386
# Epoch:4 Step:3048 Training_loss:0.818671, Acc_avg:67.00% Training_loss_avg:0.599390
# Epoch:4 Step:3056 Training_loss:0.457971, Acc_avg:68.00% Training_loss_avg:0.593418
# Epoch:4 Step:3064 Training_loss:0.621092, Acc_avg:68.00% Training_loss_avg:0.593940
# Epoch:4 Step:3072 Training_loss:0.320367, Acc_avg:68.25% Training_loss_avg:0.590000
# Epoch:4 Step:3080 Training_loss:0.632966, Acc_avg:68.00% Training_loss_avg:0.590854
# Epoch:4 Step:3088 Training_loss:0.515690, Acc_avg:68.75% Training_loss_avg:0.586734
# Epoch:4 Step:3096 Training_loss:0.610588, Acc_avg:68.50% Training_loss_avg:0.587282
# Epoch:4 Step:3104 Training_loss:0.627362, Acc_avg:68.75% Training_loss_avg:0.588290
# Epoch:4 Step:3112 Training_loss:0.658838, Acc_avg:68.25% Training_loss_avg:0.591722
# Epoch:4 Step:3120 Training_loss:0.706456, Acc_avg:68.25% Training_loss_avg:0.595192
# Epoch:4 Step:3128 Training_loss:0.530054, Acc_avg:68.25% Training_loss_avg:0.592850
# Epoch:4 Step:3136 Training_loss:0.602083, Acc_avg:68.25% Training_loss_avg:0.594103
# Epoch:4 Step:3144 Training_loss:0.576686, Acc_avg:67.75% Training_loss_avg:0.595050
# Epoch:4 Step:3152 Training_loss:0.428532, Acc_avg:68.00% Training_loss_avg:0.592159
# Epoch:4 Step:3160 Training_loss:0.435524, Acc_avg:68.50% Training_loss_avg:0.585561
# Epoch:4 Step:3168 Training_loss:0.535736, Acc_avg:68.75% Training_loss_avg:0.584979
# Epoch:4 Step:3176 Training_loss:0.849165, Acc_avg:68.00% Training_loss_avg:0.593004
# Epoch:4 Step:3184 Training_loss:0.499191, Acc_avg:67.75% Training_loss_avg:0.592001
# Epoch:4 Step:3192 Training_loss:0.640924, Acc_avg:67.75% Training_loss_avg:0.592359
# Epoch:4 Step:3200 Training_loss:0.610929, Acc_avg:68.50% Training_loss_avg:0.589434
# Epoch:4 Step:3208 Training_loss:0.943658, Acc_avg:67.50% Training_loss_avg:0.595912
# Epoch:4 Step:3216 Training_loss:0.467149, Acc_avg:67.50% Training_loss_avg:0.593247
# Epoch:4 Step:3224 Training_loss:0.499810, Acc_avg:67.50% Training_loss_avg:0.592235
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:3224 Val_loss:0.616687, Val_Acc_avg:54.00%
# Epoch:4 Step:3232 Training_loss:0.479017, Acc_avg:68.00% Training_loss_avg:0.588731
# Epoch:4 Step:3240 Training_loss:0.649384, Acc_avg:67.75% Training_loss_avg:0.591542
# Epoch:4 Step:3248 Training_loss:0.830330, Acc_avg:66.50% Training_loss_avg:0.596544
# Epoch:4 Step:3256 Training_loss:0.769595, Acc_avg:65.75% Training_loss_avg:0.598551
# Epoch:4 Step:3264 Training_loss:0.555436, Acc_avg:66.00% Training_loss_avg:0.596228
# Epoch:4 Step:3272 Training_loss:0.592162, Acc_avg:65.75% Training_loss_avg:0.596068
# Epoch:4 Step:3280 Training_loss:0.385554, Acc_avg:66.00% Training_loss_avg:0.591919
# Epoch:4 Step:3288 Training_loss:0.606692, Acc_avg:66.75% Training_loss_avg:0.589327
# Epoch:4 Step:3296 Training_loss:0.425845, Acc_avg:66.50% Training_loss_avg:0.588118
# Epoch:4 Step:3304 Training_loss:0.583959, Acc_avg:66.50% Training_loss_avg:0.588773
# Epoch:4 Step:3312 Training_loss:0.590704, Acc_avg:66.25% Training_loss_avg:0.589352
# Epoch:4 Step:3320 Training_loss:0.854766, Acc_avg:66.25% Training_loss_avg:0.593618
# Epoch:4 Step:3328 Training_loss:0.740572, Acc_avg:66.58% Training_loss_avg:0.591136

# %%
print(dir_name)
# Out:
# codebert_finetune_runs/lr_5e-5 redo, 512 split with attention! custom model redo 3

# %%
def split_loader(run_dir):
    data_type = ['train', 'val', 'test']
    data_split_type = ['X', 'A', 'Y']

    split_list = []

    for data_type_id in data_type:
      for split_type in data_split_type:
          with open('{}/{}_{}.pickle'.format(run_dir,data_type_id, split_type), 'rb') as input_file:
            object_file = pickle.load(input_file)
          split_list.append(object_file)
    X_train, A_train, Y_train, X_val, A_val, Y_val, X_test, A_test, Y_test = split_list

    return (X_train, A_train, Y_train), (X_val, A_val, Y_val), (X_test, A_test, Y_test)

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """
    run_name = "lr_5e-6 redo, 512 split with attention! redo5"
    run_dir = "codebert_finetune_runs/{}".format(run_name)
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False
    load_splits = False
    save_data = True

    if load_splits:
      train_data, val_data, test_data = split_loader(run_dir)
      X_train, A_train, Y_train = train_data
      X_val, A_val, Y_val = val_data
      X_test, A_test, Y_test = test_data
      print("loaded data splits")

    else:
      print("generating data splits")

      code_df = preprocess_data(file_loc='code_dataset.jsonl')
      train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

      X_train, A_train, Y_train = train_data
      X_val, A_val, Y_val = val_data
      X_test, A_test, Y_test = test_data

      data_type = ['train', 'val', 'test']
      data_split_type = ['X', 'A', 'Y']

      print(X_train.shape)
    # Creating dir to save logs and checkpoints, re
    dir_name = "{}".format(run_dir)
    if os.path.exists(dir_name):
        input("run name already exists, press Enter to overwrite")
    else:
        os.makedirs(dir_name)


    if save_data:
      print("saving data splits")

      data_all = [train_data, val_data, test_data]
      for i, data in enumerate(data_all):
        for j, split in enumerate(data):
          with open('{}/{}_{}.pickle'.format(run_dir,data_type[i], data_split_type[j]), 'wb') as handle:
            pickle.dump(split, handle)


    print(train_data[0].shape)
    print("Data points: {}".format(len(train_data)))

    # Loading model from checkpoint if location provided
    if online:
        print("loading model from online")
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        print("loading model from local repo")

        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        print("loading model from checkpoint: {}".format(checkpoint_location))
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=5e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="lr_5e-6 redo, 256 split, saving splits")

# %%
torch.cuda.empty_cache()
main()
# Out:
# generating data splits
# Insecure code counts: 3729, Total code counts: 8000, Proportion 0.466125
# Data points: 8000
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# torch.Size([3331, 512])
# saving data splits
# torch.Size([3331, 512])
# Data points: 3
# loading model from local repo
# Some weights of the model checkpoint at codebert-base were not used when initializing RobertaForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at codebert-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:0 Step:0 Training_loss:0.717449, Acc_avg:25.00% Training_loss_avg:0.717449
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:0 Val_loss:0.687055, Val_Acc_avg:56.50%
# Epoch:0 Step:8 Training_loss:0.715828, Acc_avg:31.25% Training_loss_avg:0.716639
# Epoch:0 Step:16 Training_loss:0.662689, Acc_avg:41.67% Training_loss_avg:0.698655
# Epoch:0 Step:24 Training_loss:0.699397, Acc_avg:40.62% Training_loss_avg:0.698841
# Epoch:0 Step:32 Training_loss:0.648268, Acc_avg:47.50% Training_loss_avg:0.688726
# Epoch:0 Step:40 Training_loss:0.686468, Acc_avg:50.00% Training_loss_avg:0.688350
# Epoch:0 Step:48 Training_loss:0.697716, Acc_avg:50.00% Training_loss_avg:0.689688
# Epoch:0 Step:56 Training_loss:0.725654, Acc_avg:50.00% Training_loss_avg:0.694184
# Epoch:0 Step:64 Training_loss:0.696265, Acc_avg:50.00% Training_loss_avg:0.694415
# Epoch:0 Step:72 Training_loss:0.737185, Acc_avg:47.50% Training_loss_avg:0.698692
# Epoch:0 Step:80 Training_loss:0.734309, Acc_avg:46.59% Training_loss_avg:0.701930
# Epoch:0 Step:88 Training_loss:0.726634, Acc_avg:45.83% Training_loss_avg:0.703989
# Epoch:0 Step:96 Training_loss:0.702518, Acc_avg:47.12% Training_loss_avg:0.703875
# Epoch:0 Step:104 Training_loss:0.739683, Acc_avg:45.54% Training_loss_avg:0.706433
# Epoch:0 Step:112 Training_loss:0.680019, Acc_avg:45.83% Training_loss_avg:0.704672
# Epoch:0 Step:120 Training_loss:0.694543, Acc_avg:46.09% Training_loss_avg:0.704039
# Epoch:0 Step:128 Training_loss:0.666255, Acc_avg:47.06% Training_loss_avg:0.701816
# Epoch:0 Step:136 Training_loss:0.735923, Acc_avg:45.14% Training_loss_avg:0.703711
# Epoch:0 Step:144 Training_loss:0.687919, Acc_avg:46.71% Training_loss_avg:0.702880
# Epoch:0 Step:152 Training_loss:0.765228, Acc_avg:46.88% Training_loss_avg:0.705998
# Epoch:0 Step:160 Training_loss:0.715306, Acc_avg:47.02% Training_loss_avg:0.706441
# Epoch:0 Step:168 Training_loss:0.740036, Acc_avg:46.02% Training_loss_avg:0.707968
# Epoch:0 Step:176 Training_loss:0.696825, Acc_avg:46.20% Training_loss_avg:0.707483
# Epoch:0 Step:184 Training_loss:0.646334, Acc_avg:46.35% Training_loss_avg:0.704935
# Epoch:0 Step:192 Training_loss:0.606973, Acc_avg:48.00% Training_loss_avg:0.701017
# Epoch:0 Step:200 Training_loss:0.694538, Acc_avg:48.56% Training_loss_avg:0.700768
# Epoch:0 Step:208 Training_loss:0.724955, Acc_avg:47.69% Training_loss_avg:0.701664
# Epoch:0 Step:216 Training_loss:0.725629, Acc_avg:47.32% Training_loss_avg:0.702519
# Epoch:0 Step:224 Training_loss:0.668197, Acc_avg:47.41% Training_loss_avg:0.701336
# Epoch:0 Step:232 Training_loss:0.676200, Acc_avg:47.92% Training_loss_avg:0.700498
# Epoch:0 Step:240 Training_loss:0.646027, Acc_avg:48.79% Training_loss_avg:0.698741
# Epoch:0 Step:248 Training_loss:0.628537, Acc_avg:49.22% Training_loss_avg:0.696547
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:248 Val_loss:0.687222, Val_Acc_avg:56.75%
# Epoch:0 Step:256 Training_loss:0.608659, Acc_avg:50.38% Training_loss_avg:0.693884
# Epoch:0 Step:264 Training_loss:0.709334, Acc_avg:50.37% Training_loss_avg:0.694338
# Epoch:0 Step:272 Training_loss:0.715710, Acc_avg:50.00% Training_loss_avg:0.694949
# Epoch:0 Step:280 Training_loss:0.667320, Acc_avg:50.00% Training_loss_avg:0.694181
# Epoch:0 Step:288 Training_loss:0.706716, Acc_avg:50.00% Training_loss_avg:0.694520
# Epoch:0 Step:296 Training_loss:0.676820, Acc_avg:50.99% Training_loss_avg:0.694054
# Epoch:0 Step:304 Training_loss:0.646579, Acc_avg:51.60% Training_loss_avg:0.692837
# Epoch:0 Step:312 Training_loss:0.720837, Acc_avg:51.56% Training_loss_avg:0.693537
# Epoch:0 Step:320 Training_loss:0.728157, Acc_avg:50.61% Training_loss_avg:0.694381
# Epoch:0 Step:328 Training_loss:0.676708, Acc_avg:50.89% Training_loss_avg:0.693961
# Epoch:0 Step:336 Training_loss:0.676730, Acc_avg:51.16% Training_loss_avg:0.693560
# Epoch:0 Step:344 Training_loss:0.705414, Acc_avg:51.70% Training_loss_avg:0.693829
# Epoch:0 Step:352 Training_loss:0.618319, Acc_avg:52.22% Training_loss_avg:0.692151
# Epoch:0 Step:360 Training_loss:0.656572, Acc_avg:52.45% Training_loss_avg:0.691378
# Epoch:0 Step:368 Training_loss:0.666315, Acc_avg:52.39% Training_loss_avg:0.690845
# Epoch:0 Step:376 Training_loss:0.616476, Acc_avg:52.60% Training_loss_avg:0.689295
# Epoch:0 Step:384 Training_loss:0.572460, Acc_avg:53.57% Training_loss_avg:0.686911
# Epoch:0 Step:392 Training_loss:0.615352, Acc_avg:54.00% Training_loss_avg:0.685480
# Epoch:0 Step:400 Training_loss:0.643061, Acc_avg:54.75% Training_loss_avg:0.683992
# Epoch:0 Step:408 Training_loss:0.724909, Acc_avg:54.75% Training_loss_avg:0.684174
# Epoch:0 Step:416 Training_loss:0.747802, Acc_avg:54.50% Training_loss_avg:0.685876
# Epoch:0 Step:424 Training_loss:0.699798, Acc_avg:54.75% Training_loss_avg:0.685884
# Epoch:0 Step:432 Training_loss:0.779471, Acc_avg:54.00% Training_loss_avg:0.688508
# Epoch:0 Step:440 Training_loss:0.761207, Acc_avg:53.50% Training_loss_avg:0.690003
# Epoch:0 Step:448 Training_loss:0.654990, Acc_avg:53.75% Training_loss_avg:0.689148
# Epoch:0 Step:456 Training_loss:0.555472, Acc_avg:54.50% Training_loss_avg:0.685745
# Epoch:0 Step:464 Training_loss:0.773980, Acc_avg:54.50% Training_loss_avg:0.687299
# Epoch:0 Step:472 Training_loss:0.700729, Acc_avg:55.25% Training_loss_avg:0.686570
# Epoch:0 Step:480 Training_loss:0.726679, Acc_avg:55.25% Training_loss_avg:0.686417
# Epoch:0 Step:488 Training_loss:0.667846, Acc_avg:55.50% Training_loss_avg:0.685241
# Epoch:0 Step:496 Training_loss:0.650051, Acc_avg:55.50% Training_loss_avg:0.684192
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:496 Val_loss:0.685410, Val_Acc_avg:56.00%
# Epoch:0 Step:504 Training_loss:0.643047, Acc_avg:56.25% Training_loss_avg:0.682259
# Epoch:0 Step:512 Training_loss:0.720236, Acc_avg:56.25% Training_loss_avg:0.683064
# Epoch:0 Step:520 Training_loss:0.643785, Acc_avg:56.75% Training_loss_avg:0.682048
# Epoch:0 Step:528 Training_loss:0.687666, Acc_avg:56.25% Training_loss_avg:0.682477
# Epoch:0 Step:536 Training_loss:0.553736, Acc_avg:57.75% Training_loss_avg:0.678833
# Epoch:0 Step:544 Training_loss:0.776075, Acc_avg:57.25% Training_loss_avg:0.680596
# Epoch:0 Step:552 Training_loss:0.590756, Acc_avg:58.00% Training_loss_avg:0.677107
# Epoch:0 Step:560 Training_loss:0.633909, Acc_avg:58.25% Training_loss_avg:0.675479
# Epoch:0 Step:568 Training_loss:0.644201, Acc_avg:59.25% Training_loss_avg:0.673562
# Epoch:0 Step:576 Training_loss:0.808083, Acc_avg:58.75% Training_loss_avg:0.675787
# Epoch:0 Step:584 Training_loss:0.678407, Acc_avg:59.00% Training_loss_avg:0.676429
# Epoch:0 Step:592 Training_loss:0.727826, Acc_avg:58.00% Training_loss_avg:0.678846
# Epoch:0 Step:600 Training_loss:0.648745, Acc_avg:58.25% Training_loss_avg:0.677930
# Epoch:0 Step:608 Training_loss:0.731108, Acc_avg:58.75% Training_loss_avg:0.678053
# Epoch:0 Step:616 Training_loss:0.851687, Acc_avg:58.25% Training_loss_avg:0.680574
# Epoch:0 Step:624 Training_loss:0.789629, Acc_avg:58.25% Training_loss_avg:0.683003
# Epoch:0 Step:632 Training_loss:0.648528, Acc_avg:58.50% Training_loss_avg:0.682449
# Epoch:0 Step:640 Training_loss:0.779897, Acc_avg:57.75% Training_loss_avg:0.685127
# Epoch:0 Step:648 Training_loss:0.702292, Acc_avg:57.75% Training_loss_avg:0.686602
# Epoch:0 Step:656 Training_loss:0.687618, Acc_avg:57.50% Training_loss_avg:0.688181
# Epoch:0 Step:664 Training_loss:0.681167, Acc_avg:58.00% Training_loss_avg:0.687618
# Epoch:0 Step:672 Training_loss:0.726139, Acc_avg:58.00% Training_loss_avg:0.687826
# Epoch:0 Step:680 Training_loss:0.694508, Acc_avg:58.00% Training_loss_avg:0.688370
# Epoch:0 Step:688 Training_loss:0.685744, Acc_avg:58.25% Training_loss_avg:0.687950
# Epoch:0 Step:696 Training_loss:0.664080, Acc_avg:58.00% Training_loss_avg:0.687696
# Epoch:0 Step:704 Training_loss:0.686516, Acc_avg:57.50% Training_loss_avg:0.688494
# Epoch:0 Step:712 Training_loss:0.709998, Acc_avg:57.25% Training_loss_avg:0.688278
# Epoch:0 Step:720 Training_loss:0.686846, Acc_avg:57.75% Training_loss_avg:0.687451
# Epoch:0 Step:728 Training_loss:0.772644, Acc_avg:57.25% Training_loss_avg:0.689370
# Epoch:0 Step:736 Training_loss:0.649263, Acc_avg:57.50% Training_loss_avg:0.688821
# Epoch:0 Step:744 Training_loss:0.752979, Acc_avg:57.00% Training_loss_avg:0.689772
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:744 Val_loss:0.686264, Val_Acc_avg:56.75%
# Epoch:0 Step:752 Training_loss:0.639110, Acc_avg:57.25% Training_loss_avg:0.690188
# Epoch:0 Step:760 Training_loss:0.700001, Acc_avg:57.25% Training_loss_avg:0.691057
# Epoch:0 Step:768 Training_loss:0.663938, Acc_avg:57.75% Training_loss_avg:0.691009
# Epoch:0 Step:776 Training_loss:0.669895, Acc_avg:57.75% Training_loss_avg:0.692077
# Epoch:0 Step:784 Training_loss:0.677190, Acc_avg:56.75% Training_loss_avg:0.694172
# Epoch:0 Step:792 Training_loss:0.709374, Acc_avg:56.50% Training_loss_avg:0.696052
# Epoch:0 Step:800 Training_loss:0.740091, Acc_avg:56.00% Training_loss_avg:0.697993
# Epoch:0 Step:808 Training_loss:0.669749, Acc_avg:56.75% Training_loss_avg:0.696890
# Epoch:0 Step:816 Training_loss:0.711397, Acc_avg:56.75% Training_loss_avg:0.696162
# Epoch:0 Step:824 Training_loss:0.678199, Acc_avg:57.25% Training_loss_avg:0.695730
# Epoch:0 Step:832 Training_loss:0.792253, Acc_avg:57.00% Training_loss_avg:0.695985
# Epoch:0 Step:840 Training_loss:0.621787, Acc_avg:57.75% Training_loss_avg:0.693197
# Epoch:0 Step:848 Training_loss:0.679191, Acc_avg:57.75% Training_loss_avg:0.693681
# Epoch:0 Step:856 Training_loss:0.688896, Acc_avg:57.00% Training_loss_avg:0.696349
# Epoch:0 Step:864 Training_loss:0.677246, Acc_avg:57.00% Training_loss_avg:0.694415
# Epoch:0 Step:872 Training_loss:0.651963, Acc_avg:57.00% Training_loss_avg:0.693439
# Epoch:0 Step:880 Training_loss:0.668537, Acc_avg:57.00% Training_loss_avg:0.692277
# Epoch:0 Step:888 Training_loss:0.689385, Acc_avg:56.75% Training_loss_avg:0.692707
# Epoch:0 Step:896 Training_loss:0.665836, Acc_avg:56.50% Training_loss_avg:0.693023
# Epoch:0 Step:904 Training_loss:0.682845, Acc_avg:56.25% Training_loss_avg:0.693819
# Epoch:0 Step:912 Training_loss:0.676312, Acc_avg:56.50% Training_loss_avg:0.692941
# Epoch:0 Step:920 Training_loss:0.708493, Acc_avg:55.75% Training_loss_avg:0.694235
# Epoch:0 Step:928 Training_loss:0.651494, Acc_avg:56.50% Training_loss_avg:0.693511
# Epoch:0 Step:936 Training_loss:0.711212, Acc_avg:55.75% Training_loss_avg:0.696661
# Epoch:0 Step:944 Training_loss:0.696733, Acc_avg:56.25% Training_loss_avg:0.695074
# Epoch:0 Step:952 Training_loss:0.678347, Acc_avg:55.75% Training_loss_avg:0.696826
# Epoch:0 Step:960 Training_loss:0.731953, Acc_avg:55.50% Training_loss_avg:0.698787
# Epoch:0 Step:968 Training_loss:0.724137, Acc_avg:54.50% Training_loss_avg:0.700385
# Epoch:0 Step:976 Training_loss:0.677379, Acc_avg:55.00% Training_loss_avg:0.697771
# Epoch:0 Step:984 Training_loss:0.719136, Acc_avg:54.75% Training_loss_avg:0.698586
# Epoch:0 Step:992 Training_loss:0.672690, Acc_avg:55.25% Training_loss_avg:0.697483
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:992 Val_loss:0.683721, Val_Acc_avg:56.00%
# Epoch:0 Step:1000 Training_loss:0.660755, Acc_avg:55.00% Training_loss_avg:0.697723
# Epoch:0 Step:1008 Training_loss:0.674299, Acc_avg:55.50% Training_loss_avg:0.696587
# Epoch:0 Step:1016 Training_loss:0.693143, Acc_avg:56.00% Training_loss_avg:0.693416
# Epoch:0 Step:1024 Training_loss:0.727477, Acc_avg:55.50% Training_loss_avg:0.692173
# Epoch:0 Step:1032 Training_loss:0.675692, Acc_avg:55.00% Training_loss_avg:0.692717
# Epoch:0 Step:1040 Training_loss:0.622910, Acc_avg:55.50% Training_loss_avg:0.689577
# Epoch:0 Step:1048 Training_loss:0.646731, Acc_avg:55.75% Training_loss_avg:0.688466
# Epoch:0 Step:1056 Training_loss:0.666067, Acc_avg:55.25% Training_loss_avg:0.688035
# Epoch:0 Step:1064 Training_loss:0.784648, Acc_avg:54.75% Training_loss_avg:0.690104
# Epoch:0 Step:1072 Training_loss:0.565588, Acc_avg:56.00% Training_loss_avg:0.686893
# Epoch:0 Step:1080 Training_loss:0.673248, Acc_avg:56.25% Training_loss_avg:0.686468
# Epoch:0 Step:1088 Training_loss:0.795877, Acc_avg:55.25% Training_loss_avg:0.688671
# Epoch:0 Step:1096 Training_loss:0.545675, Acc_avg:55.50% Training_loss_avg:0.686302
# Epoch:0 Step:1104 Training_loss:0.714264, Acc_avg:55.50% Training_loss_avg:0.686857
# Epoch:0 Step:1112 Training_loss:0.604366, Acc_avg:56.25% Training_loss_avg:0.684745
# Epoch:0 Step:1120 Training_loss:0.600510, Acc_avg:57.00% Training_loss_avg:0.683018
# Epoch:0 Step:1128 Training_loss:0.692395, Acc_avg:57.25% Training_loss_avg:0.681413
# Epoch:0 Step:1136 Training_loss:0.607963, Acc_avg:57.25% Training_loss_avg:0.680587
# Epoch:0 Step:1144 Training_loss:0.687700, Acc_avg:57.25% Training_loss_avg:0.679281
# Epoch:0 Step:1152 Training_loss:0.708799, Acc_avg:56.50% Training_loss_avg:0.680675
# Epoch:0 Step:1160 Training_loss:0.782814, Acc_avg:56.25% Training_loss_avg:0.682332
# Epoch:0 Step:1168 Training_loss:0.555747, Acc_avg:56.50% Training_loss_avg:0.680168
# Epoch:0 Step:1176 Training_loss:0.631800, Acc_avg:56.50% Training_loss_avg:0.679406
# Epoch:0 Step:1184 Training_loss:0.711069, Acc_avg:56.50% Training_loss_avg:0.680083
# Epoch:0 Step:1192 Training_loss:0.616405, Acc_avg:56.75% Training_loss_avg:0.678224
# Epoch:0 Step:1200 Training_loss:0.771593, Acc_avg:56.75% Training_loss_avg:0.678854
# Epoch:0 Step:1208 Training_loss:0.594695, Acc_avg:56.75% Training_loss_avg:0.677353
# Epoch:0 Step:1216 Training_loss:0.579340, Acc_avg:57.00% Training_loss_avg:0.674712
# Epoch:0 Step:1224 Training_loss:0.592503, Acc_avg:57.00% Training_loss_avg:0.672998
# Epoch:0 Step:1232 Training_loss:0.551033, Acc_avg:58.00% Training_loss_avg:0.668174
# Epoch:0 Step:1240 Training_loss:0.733632, Acc_avg:57.50% Training_loss_avg:0.670410
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1240 Val_loss:0.694643, Val_Acc_avg:56.00%
# Epoch:0 Step:1248 Training_loss:0.751404, Acc_avg:57.25% Training_loss_avg:0.671855
# Epoch:0 Step:1256 Training_loss:0.602939, Acc_avg:57.75% Training_loss_avg:0.670136
# Epoch:0 Step:1264 Training_loss:0.764007, Acc_avg:57.50% Training_loss_avg:0.671871
# Epoch:0 Step:1272 Training_loss:0.588339, Acc_avg:57.75% Training_loss_avg:0.670598
# Epoch:0 Step:1280 Training_loss:0.698767, Acc_avg:58.00% Training_loss_avg:0.671203
# Epoch:0 Step:1288 Training_loss:0.601909, Acc_avg:58.75% Training_loss_avg:0.669453
# Epoch:0 Step:1296 Training_loss:0.668582, Acc_avg:59.00% Training_loss_avg:0.669508
# Epoch:0 Step:1304 Training_loss:0.706978, Acc_avg:59.00% Training_loss_avg:0.669991
# Epoch:0 Step:1312 Training_loss:0.686734, Acc_avg:58.75% Training_loss_avg:0.670199
# Epoch:0 Step:1320 Training_loss:0.767153, Acc_avg:59.00% Training_loss_avg:0.671373
# Epoch:0 Step:1328 Training_loss:0.498783, Acc_avg:59.50% Training_loss_avg:0.668318
# Epoch:0 Step:1336 Training_loss:0.603074, Acc_avg:60.00% Training_loss_avg:0.666156
# Epoch:0 Step:1344 Training_loss:0.823595, Acc_avg:59.25% Training_loss_avg:0.668693
# Epoch:0 Step:1352 Training_loss:0.703333, Acc_avg:59.00% Training_loss_avg:0.669193
# Epoch:0 Step:1360 Training_loss:0.638392, Acc_avg:59.25% Training_loss_avg:0.667321
# Epoch:0 Step:1368 Training_loss:0.711036, Acc_avg:60.00% Training_loss_avg:0.667059
# Epoch:0 Step:1376 Training_loss:0.601706, Acc_avg:60.50% Training_loss_avg:0.665546
# Epoch:0 Step:1384 Training_loss:0.781866, Acc_avg:60.25% Training_loss_avg:0.666801
# Epoch:0 Step:1392 Training_loss:0.754322, Acc_avg:60.00% Training_loss_avg:0.668433
# Epoch:0 Step:1400 Training_loss:0.630228, Acc_avg:60.00% Training_loss_avg:0.667823
# Epoch:0 Step:1408 Training_loss:0.608016, Acc_avg:60.00% Training_loss_avg:0.666497
# Epoch:0 Step:1416 Training_loss:0.677144, Acc_avg:60.50% Training_loss_avg:0.666177
# Epoch:0 Step:1424 Training_loss:0.615629, Acc_avg:61.00% Training_loss_avg:0.663940
# Epoch:0 Step:1432 Training_loss:0.798692, Acc_avg:60.50% Training_loss_avg:0.666400
# Epoch:0 Step:1440 Training_loss:0.645725, Acc_avg:60.25% Training_loss_avg:0.666856
# Epoch:0 Step:1448 Training_loss:0.923890, Acc_avg:59.25% Training_loss_avg:0.672400
# Epoch:0 Step:1456 Training_loss:0.683878, Acc_avg:59.50% Training_loss_avg:0.672756
# Epoch:0 Step:1464 Training_loss:0.693084, Acc_avg:59.50% Training_loss_avg:0.670924
# Epoch:0 Step:1472 Training_loss:0.738410, Acc_avg:58.75% Training_loss_avg:0.674381
# Epoch:0 Step:1480 Training_loss:0.752188, Acc_avg:58.25% Training_loss_avg:0.675960
# Epoch:0 Step:1488 Training_loss:0.787600, Acc_avg:58.25% Training_loss_avg:0.675794
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1488 Val_loss:0.681458, Val_Acc_avg:56.00%
# Epoch:0 Step:1496 Training_loss:0.657977, Acc_avg:57.75% Training_loss_avg:0.678040
# Epoch:0 Step:1504 Training_loss:0.796338, Acc_avg:57.50% Training_loss_avg:0.679682
# Epoch:0 Step:1512 Training_loss:0.698041, Acc_avg:57.00% Training_loss_avg:0.681555
# Epoch:0 Step:1520 Training_loss:0.712959, Acc_avg:56.25% Training_loss_avg:0.683804
# Epoch:0 Step:1528 Training_loss:0.665778, Acc_avg:56.50% Training_loss_avg:0.683272
# Epoch:0 Step:1536 Training_loss:0.732907, Acc_avg:55.25% Training_loss_avg:0.685771
# Epoch:0 Step:1544 Training_loss:0.666655, Acc_avg:55.75% Training_loss_avg:0.685350
# Epoch:0 Step:1552 Training_loss:0.655627, Acc_avg:56.25% Training_loss_avg:0.684286
# Epoch:0 Step:1560 Training_loss:0.755158, Acc_avg:56.00% Training_loss_avg:0.683733
# Epoch:0 Step:1568 Training_loss:0.697854, Acc_avg:55.25% Training_loss_avg:0.686575
# Epoch:0 Step:1576 Training_loss:0.671135, Acc_avg:55.00% Training_loss_avg:0.687362
# Epoch:0 Step:1584 Training_loss:0.701598, Acc_avg:54.75% Training_loss_avg:0.687173
# Epoch:0 Step:1592 Training_loss:0.706638, Acc_avg:54.25% Training_loss_avg:0.688977
# Epoch:0 Step:1600 Training_loss:0.663480, Acc_avg:55.25% Training_loss_avg:0.686815
# Epoch:0 Step:1608 Training_loss:0.740551, Acc_avg:54.50% Training_loss_avg:0.689732
# Epoch:0 Step:1616 Training_loss:0.721821, Acc_avg:54.25% Training_loss_avg:0.692582
# Epoch:0 Step:1624 Training_loss:0.689337, Acc_avg:53.50% Training_loss_avg:0.694518
# Epoch:0 Step:1632 Training_loss:0.706374, Acc_avg:53.00% Training_loss_avg:0.697625
# Epoch:0 Step:1640 Training_loss:0.690644, Acc_avg:53.25% Training_loss_avg:0.696766
# Epoch:0 Step:1648 Training_loss:0.693323, Acc_avg:53.75% Training_loss_avg:0.695604
# Epoch:0 Step:1656 Training_loss:0.664898, Acc_avg:54.00% Training_loss_avg:0.696843
# Epoch:0 Step:1664 Training_loss:0.707287, Acc_avg:54.25% Training_loss_avg:0.695709
# Epoch:0 Step:1672 Training_loss:0.641733, Acc_avg:54.00% Training_loss_avg:0.696777
# Epoch:0 Step:1680 Training_loss:0.705443, Acc_avg:53.75% Training_loss_avg:0.696910
# Epoch:0 Step:1688 Training_loss:0.706019, Acc_avg:53.25% Training_loss_avg:0.698992
# Epoch:0 Step:1696 Training_loss:0.650725, Acc_avg:53.50% Training_loss_avg:0.698635
# Epoch:0 Step:1704 Training_loss:0.674574, Acc_avg:54.00% Training_loss_avg:0.697987
# Epoch:0 Step:1712 Training_loss:0.707508, Acc_avg:54.25% Training_loss_avg:0.698403
# Epoch:0 Step:1720 Training_loss:0.667693, Acc_avg:54.25% Training_loss_avg:0.696413
# Epoch:0 Step:1728 Training_loss:0.676049, Acc_avg:53.50% Training_loss_avg:0.699959
# Epoch:0 Step:1736 Training_loss:0.721901, Acc_avg:53.50% Training_loss_avg:0.702335
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1736 Val_loss:0.680742, Val_Acc_avg:56.50%
# Epoch:0 Step:1744 Training_loss:0.662957, Acc_avg:54.00% Training_loss_avg:0.699122
# Epoch:0 Step:1752 Training_loss:0.674963, Acc_avg:54.00% Training_loss_avg:0.698555
# Epoch:0 Step:1760 Training_loss:0.664203, Acc_avg:54.00% Training_loss_avg:0.699071
# Epoch:0 Step:1768 Training_loss:0.635423, Acc_avg:54.25% Training_loss_avg:0.697559
# Epoch:0 Step:1776 Training_loss:0.657496, Acc_avg:53.75% Training_loss_avg:0.698675
# Epoch:0 Step:1784 Training_loss:0.685832, Acc_avg:53.75% Training_loss_avg:0.696754
# Epoch:0 Step:1792 Training_loss:0.785633, Acc_avg:53.25% Training_loss_avg:0.697380
# Epoch:0 Step:1800 Training_loss:0.771549, Acc_avg:52.75% Training_loss_avg:0.700207
# Epoch:0 Step:1808 Training_loss:0.677451, Acc_avg:52.50% Training_loss_avg:0.701595
# Epoch:0 Step:1816 Training_loss:0.711757, Acc_avg:52.25% Training_loss_avg:0.702288
# Epoch:0 Step:1824 Training_loss:0.592360, Acc_avg:52.50% Training_loss_avg:0.701822
# Epoch:0 Step:1832 Training_loss:0.716763, Acc_avg:52.75% Training_loss_avg:0.700184
# Epoch:0 Step:1840 Training_loss:0.694288, Acc_avg:52.75% Training_loss_avg:0.701155
# Epoch:0 Step:1848 Training_loss:0.680089, Acc_avg:53.25% Training_loss_avg:0.696279
# Epoch:0 Step:1856 Training_loss:0.647636, Acc_avg:53.25% Training_loss_avg:0.695554
# Epoch:0 Step:1864 Training_loss:0.706722, Acc_avg:53.25% Training_loss_avg:0.695827
# Epoch:0 Step:1872 Training_loss:0.697704, Acc_avg:53.25% Training_loss_avg:0.695013
# Epoch:0 Step:1880 Training_loss:0.664629, Acc_avg:53.50% Training_loss_avg:0.693262
# Epoch:0 Step:1888 Training_loss:0.798797, Acc_avg:54.00% Training_loss_avg:0.693486
# Epoch:0 Step:1896 Training_loss:0.688722, Acc_avg:53.75% Training_loss_avg:0.694100
# Epoch:0 Step:1904 Training_loss:0.719207, Acc_avg:53.75% Training_loss_avg:0.692558
# Epoch:0 Step:1912 Training_loss:0.579216, Acc_avg:54.50% Training_loss_avg:0.690181
# Epoch:0 Step:1920 Training_loss:0.707140, Acc_avg:54.75% Training_loss_avg:0.690065
# Epoch:0 Step:1928 Training_loss:0.644209, Acc_avg:55.00% Training_loss_avg:0.689634
# Epoch:0 Step:1936 Training_loss:0.590883, Acc_avg:56.50% Training_loss_avg:0.686793
# Epoch:0 Step:1944 Training_loss:0.581636, Acc_avg:56.75% Training_loss_avg:0.685093
# Epoch:0 Step:1952 Training_loss:0.767342, Acc_avg:56.00% Training_loss_avg:0.687327
# Epoch:0 Step:1960 Training_loss:0.728783, Acc_avg:56.25% Training_loss_avg:0.686799
# Epoch:0 Step:1968 Training_loss:0.572618, Acc_avg:57.00% Training_loss_avg:0.684295
# Epoch:0 Step:1976 Training_loss:0.722529, Acc_avg:57.00% Training_loss_avg:0.685323
# Epoch:0 Step:1984 Training_loss:0.556957, Acc_avg:58.00% Training_loss_avg:0.682430
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1984 Val_loss:0.686190, Val_Acc_avg:56.00%
# Epoch:0 Step:1992 Training_loss:0.740846, Acc_avg:58.00% Training_loss_avg:0.683114
# Epoch:0 Step:2000 Training_loss:0.496577, Acc_avg:58.25% Training_loss_avg:0.679776
# Epoch:0 Step:2008 Training_loss:0.728198, Acc_avg:58.50% Training_loss_avg:0.679529
# Epoch:0 Step:2016 Training_loss:0.748792, Acc_avg:58.50% Training_loss_avg:0.680068
# Epoch:0 Step:2024 Training_loss:0.667805, Acc_avg:59.00% Training_loss_avg:0.679638
# Epoch:0 Step:2032 Training_loss:0.535557, Acc_avg:59.75% Training_loss_avg:0.676221
# Epoch:0 Step:2040 Training_loss:0.657938, Acc_avg:59.75% Training_loss_avg:0.675567
# Epoch:0 Step:2048 Training_loss:0.668196, Acc_avg:59.50% Training_loss_avg:0.675065
# Epoch:0 Step:2056 Training_loss:0.809075, Acc_avg:58.50% Training_loss_avg:0.677948
# Epoch:0 Step:2064 Training_loss:0.566436, Acc_avg:59.00% Training_loss_avg:0.675131
# Epoch:0 Step:2072 Training_loss:0.746047, Acc_avg:58.75% Training_loss_avg:0.677217
# Epoch:0 Step:2080 Training_loss:0.594049, Acc_avg:59.25% Training_loss_avg:0.674990
# Epoch:0 Step:2088 Training_loss:0.767226, Acc_avg:59.00% Training_loss_avg:0.676214
# Epoch:0 Step:2096 Training_loss:0.760127, Acc_avg:58.50% Training_loss_avg:0.678402
# Epoch:0 Step:2104 Training_loss:0.673995, Acc_avg:58.25% Training_loss_avg:0.678390
# Epoch:0 Step:2112 Training_loss:0.625354, Acc_avg:58.50% Training_loss_avg:0.676747
# Epoch:0 Step:2120 Training_loss:0.797395, Acc_avg:58.25% Training_loss_avg:0.679341
# Epoch:0 Step:2128 Training_loss:0.482591, Acc_avg:58.75% Training_loss_avg:0.675472
# Epoch:0 Step:2136 Training_loss:0.605302, Acc_avg:58.75% Training_loss_avg:0.673140
# Epoch:0 Step:2144 Training_loss:0.753950, Acc_avg:58.50% Training_loss_avg:0.674960
# Epoch:0 Step:2152 Training_loss:0.822550, Acc_avg:58.25% Training_loss_avg:0.677912
# Epoch:0 Step:2160 Training_loss:0.593247, Acc_avg:58.50% Training_loss_avg:0.676492
# Epoch:0 Step:2168 Training_loss:0.700328, Acc_avg:58.25% Training_loss_avg:0.677791
# Epoch:0 Step:2176 Training_loss:0.698522, Acc_avg:58.25% Training_loss_avg:0.678611
# Epoch:0 Step:2184 Training_loss:0.754387, Acc_avg:58.50% Training_loss_avg:0.679982
# Epoch:0 Step:2192 Training_loss:0.736139, Acc_avg:59.00% Training_loss_avg:0.678992
# Epoch:0 Step:2200 Training_loss:0.576090, Acc_avg:59.75% Training_loss_avg:0.675083
# Epoch:0 Step:2208 Training_loss:0.674748, Acc_avg:59.75% Training_loss_avg:0.675029
# Epoch:0 Step:2216 Training_loss:0.648035, Acc_avg:60.00% Training_loss_avg:0.673755
# Epoch:0 Step:2224 Training_loss:0.770838, Acc_avg:59.50% Training_loss_avg:0.677324
# Epoch:0 Step:2232 Training_loss:0.650998, Acc_avg:60.00% Training_loss_avg:0.676009
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2232 Val_loss:0.687215, Val_Acc_avg:56.00%
# Epoch:0 Step:2240 Training_loss:0.735511, Acc_avg:60.25% Training_loss_avg:0.676833
# Epoch:0 Step:2248 Training_loss:0.612006, Acc_avg:60.50% Training_loss_avg:0.675472
# Epoch:0 Step:2256 Training_loss:0.946209, Acc_avg:59.25% Training_loss_avg:0.681443
# Epoch:0 Step:2264 Training_loss:0.697034, Acc_avg:59.25% Training_loss_avg:0.681249
# Epoch:0 Step:2272 Training_loss:0.612506, Acc_avg:59.50% Training_loss_avg:0.679545
# Epoch:0 Step:2280 Training_loss:0.637340, Acc_avg:60.00% Training_loss_avg:0.679000
# Epoch:0 Step:2288 Training_loss:0.728105, Acc_avg:60.25% Training_loss_avg:0.677586
# Epoch:0 Step:2296 Training_loss:0.736109, Acc_avg:60.00% Training_loss_avg:0.678534
# Epoch:0 Step:2304 Training_loss:0.642898, Acc_avg:60.50% Training_loss_avg:0.677007
# Epoch:0 Step:2312 Training_loss:0.707942, Acc_avg:60.00% Training_loss_avg:0.679582
# Epoch:0 Step:2320 Training_loss:0.752346, Acc_avg:60.00% Training_loss_avg:0.680486
# Epoch:0 Step:2328 Training_loss:0.661750, Acc_avg:59.50% Training_loss_avg:0.680837
# Epoch:0 Step:2336 Training_loss:0.618067, Acc_avg:59.25% Training_loss_avg:0.681381
# Epoch:0 Step:2344 Training_loss:0.715153, Acc_avg:58.25% Training_loss_avg:0.684051
# Epoch:0 Step:2352 Training_loss:0.646456, Acc_avg:58.75% Training_loss_avg:0.681633
# Epoch:0 Step:2360 Training_loss:0.708341, Acc_avg:58.50% Training_loss_avg:0.681224
# Epoch:0 Step:2368 Training_loss:0.693451, Acc_avg:58.00% Training_loss_avg:0.683641
# Epoch:0 Step:2376 Training_loss:0.646070, Acc_avg:58.50% Training_loss_avg:0.682112
# Epoch:0 Step:2384 Training_loss:0.622187, Acc_avg:58.25% Training_loss_avg:0.683416
# Epoch:0 Step:2392 Training_loss:0.719573, Acc_avg:58.00% Training_loss_avg:0.682991
# Epoch:0 Step:2400 Training_loss:0.699292, Acc_avg:56.75% Training_loss_avg:0.687045
# Epoch:0 Step:2408 Training_loss:0.684012, Acc_avg:56.75% Training_loss_avg:0.686162
# Epoch:0 Step:2416 Training_loss:0.707763, Acc_avg:57.00% Training_loss_avg:0.685341
# Epoch:0 Step:2424 Training_loss:0.677333, Acc_avg:56.75% Training_loss_avg:0.685532
# Epoch:0 Step:2432 Training_loss:0.666776, Acc_avg:56.25% Training_loss_avg:0.688156
# Epoch:0 Step:2440 Training_loss:0.706282, Acc_avg:55.75% Training_loss_avg:0.689123
# Epoch:0 Step:2448 Training_loss:0.763857, Acc_avg:55.25% Training_loss_avg:0.691036
# Epoch:0 Step:2456 Training_loss:0.669950, Acc_avg:55.75% Training_loss_avg:0.688254
# Epoch:0 Step:2464 Training_loss:0.651595, Acc_avg:55.50% Training_loss_avg:0.689957
# Epoch:0 Step:2472 Training_loss:0.770842, Acc_avg:55.00% Training_loss_avg:0.690453
# Epoch:0 Step:2480 Training_loss:0.636766, Acc_avg:55.25% Training_loss_avg:0.691307
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2480 Val_loss:0.680126, Val_Acc_avg:56.25%
# Epoch:0 Step:2488 Training_loss:0.696653, Acc_avg:55.50% Training_loss_avg:0.689895
# Epoch:0 Step:2496 Training_loss:0.721766, Acc_avg:55.50% Training_loss_avg:0.689128
# Epoch:0 Step:2504 Training_loss:0.721152, Acc_avg:55.25% Training_loss_avg:0.690071
# Epoch:0 Step:2512 Training_loss:0.710010, Acc_avg:54.50% Training_loss_avg:0.691765
# Epoch:0 Step:2520 Training_loss:0.604106, Acc_avg:55.25% Training_loss_avg:0.687899
# Epoch:0 Step:2528 Training_loss:0.683268, Acc_avg:54.75% Training_loss_avg:0.691912
# Epoch:0 Step:2536 Training_loss:0.746571, Acc_avg:54.00% Training_loss_avg:0.694738
# Epoch:0 Step:2544 Training_loss:0.574940, Acc_avg:54.75% Training_loss_avg:0.691157
# Epoch:0 Step:2552 Training_loss:0.652931, Acc_avg:55.25% Training_loss_avg:0.687765
# Epoch:0 Step:2560 Training_loss:0.688611, Acc_avg:55.00% Training_loss_avg:0.689672
# Epoch:0 Step:2568 Training_loss:0.650764, Acc_avg:55.00% Training_loss_avg:0.688681
# Epoch:0 Step:2576 Training_loss:0.708178, Acc_avg:55.00% Training_loss_avg:0.688874
# Epoch:0 Step:2584 Training_loss:0.679675, Acc_avg:55.00% Training_loss_avg:0.687380
# Epoch:0 Step:2592 Training_loss:0.736924, Acc_avg:55.00% Training_loss_avg:0.687396
# Epoch:0 Step:2600 Training_loss:0.659844, Acc_avg:55.00% Training_loss_avg:0.689071
# Epoch:0 Step:2608 Training_loss:0.623050, Acc_avg:55.25% Training_loss_avg:0.688037
# Epoch:0 Step:2616 Training_loss:0.693594, Acc_avg:55.25% Training_loss_avg:0.688948
# Epoch:0 Step:2624 Training_loss:0.638405, Acc_avg:55.75% Training_loss_avg:0.686299
# Epoch:0 Step:2632 Training_loss:0.730166, Acc_avg:55.25% Training_loss_avg:0.687883
# Epoch:0 Step:2640 Training_loss:0.626193, Acc_avg:55.50% Training_loss_avg:0.685696
# Epoch:0 Step:2648 Training_loss:0.671789, Acc_avg:55.25% Training_loss_avg:0.686892
# Epoch:0 Step:2656 Training_loss:0.715041, Acc_avg:56.25% Training_loss_avg:0.682269
# Epoch:0 Step:2664 Training_loss:0.625859, Acc_avg:57.00% Training_loss_avg:0.680845
# Epoch:0 Step:2672 Training_loss:0.747023, Acc_avg:56.25% Training_loss_avg:0.683535
# Epoch:0 Step:2680 Training_loss:0.736057, Acc_avg:55.50% Training_loss_avg:0.685510
# Epoch:0 Step:2688 Training_loss:0.618509, Acc_avg:55.75% Training_loss_avg:0.683318
# Epoch:0 Step:2696 Training_loss:0.619014, Acc_avg:56.75% Training_loss_avg:0.680976
# Epoch:0 Step:2704 Training_loss:0.748758, Acc_avg:56.25% Training_loss_avg:0.683093
# Epoch:0 Step:2712 Training_loss:0.701259, Acc_avg:56.00% Training_loss_avg:0.682959
# Epoch:0 Step:2720 Training_loss:0.818406, Acc_avg:55.25% Training_loss_avg:0.684281
# Epoch:0 Step:2728 Training_loss:0.650156, Acc_avg:55.75% Training_loss_avg:0.684049
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2728 Val_loss:0.678390, Val_Acc_avg:57.25%
# Epoch:0 Step:2736 Training_loss:0.627504, Acc_avg:56.00% Training_loss_avg:0.684238
# Epoch:0 Step:2744 Training_loss:0.645955, Acc_avg:56.50% Training_loss_avg:0.682854
# Epoch:0 Step:2752 Training_loss:0.715727, Acc_avg:56.25% Training_loss_avg:0.684239
# Epoch:0 Step:2760 Training_loss:0.624524, Acc_avg:56.75% Training_loss_avg:0.682563
# Epoch:0 Step:2768 Training_loss:0.714952, Acc_avg:56.50% Training_loss_avg:0.682993
# Epoch:0 Step:2776 Training_loss:0.726510, Acc_avg:55.50% Training_loss_avg:0.684601
# Epoch:0 Step:2784 Training_loss:0.697274, Acc_avg:55.00% Training_loss_avg:0.686103
# Epoch:0 Step:2792 Training_loss:0.630217, Acc_avg:56.00% Training_loss_avg:0.684316
# Epoch:0 Step:2800 Training_loss:0.618836, Acc_avg:57.00% Training_loss_avg:0.682707
# Epoch:0 Step:2808 Training_loss:0.649629, Acc_avg:57.75% Training_loss_avg:0.682019
# Epoch:0 Step:2816 Training_loss:0.678952, Acc_avg:57.75% Training_loss_avg:0.681443
# Epoch:0 Step:2824 Training_loss:0.625026, Acc_avg:58.00% Training_loss_avg:0.680397
# Epoch:0 Step:2832 Training_loss:0.779076, Acc_avg:57.25% Training_loss_avg:0.682643
# Epoch:0 Step:2840 Training_loss:0.664941, Acc_avg:57.75% Training_loss_avg:0.681816
# Epoch:0 Step:2848 Training_loss:0.700294, Acc_avg:57.75% Training_loss_avg:0.680545
# Epoch:0 Step:2856 Training_loss:0.695635, Acc_avg:57.50% Training_loss_avg:0.681059
# Epoch:0 Step:2864 Training_loss:0.749288, Acc_avg:56.75% Training_loss_avg:0.683012
# Epoch:0 Step:2872 Training_loss:0.761359, Acc_avg:56.75% Training_loss_avg:0.682823
# Epoch:0 Step:2880 Training_loss:0.648252, Acc_avg:56.75% Training_loss_avg:0.683052
# Epoch:0 Step:2888 Training_loss:0.740682, Acc_avg:56.75% Training_loss_avg:0.683933
# Epoch:0 Step:2896 Training_loss:0.662816, Acc_avg:57.00% Training_loss_avg:0.682754
# Epoch:0 Step:2904 Training_loss:0.693111, Acc_avg:57.25% Training_loss_avg:0.682193
# Epoch:0 Step:2912 Training_loss:0.679708, Acc_avg:57.75% Training_loss_avg:0.681587
# Epoch:0 Step:2920 Training_loss:0.678600, Acc_avg:57.25% Training_loss_avg:0.683077
# Epoch:0 Step:2928 Training_loss:0.779719, Acc_avg:57.00% Training_loss_avg:0.685006
# Epoch:0 Step:2936 Training_loss:0.646653, Acc_avg:57.75% Training_loss_avg:0.683008
# Epoch:0 Step:2944 Training_loss:0.643335, Acc_avg:57.50% Training_loss_avg:0.684376
# Epoch:0 Step:2952 Training_loss:0.752179, Acc_avg:56.75% Training_loss_avg:0.686361
# Epoch:0 Step:2960 Training_loss:0.663432, Acc_avg:56.75% Training_loss_avg:0.685857
# Epoch:0 Step:2968 Training_loss:0.691315, Acc_avg:56.25% Training_loss_avg:0.686668
# Epoch:0 Step:2976 Training_loss:0.736858, Acc_avg:55.50% Training_loss_avg:0.687242
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2976 Val_loss:0.681356, Val_Acc_avg:56.75%
# Epoch:0 Step:2984 Training_loss:0.624297, Acc_avg:56.00% Training_loss_avg:0.686134
# Epoch:0 Step:2992 Training_loss:0.692513, Acc_avg:56.00% Training_loss_avg:0.685246
# Epoch:0 Step:3000 Training_loss:0.690765, Acc_avg:55.25% Training_loss_avg:0.685864
# Epoch:0 Step:3008 Training_loss:0.686234, Acc_avg:55.00% Training_loss_avg:0.687128
# Epoch:0 Step:3016 Training_loss:0.701379, Acc_avg:54.75% Training_loss_avg:0.687284
# Epoch:0 Step:3024 Training_loss:0.727869, Acc_avg:54.50% Training_loss_avg:0.689073
# Epoch:0 Step:3032 Training_loss:0.649080, Acc_avg:55.00% Training_loss_avg:0.687451
# Epoch:0 Step:3040 Training_loss:0.652567, Acc_avg:54.75% Training_loss_avg:0.687979
# Epoch:0 Step:3048 Training_loss:0.710327, Acc_avg:54.25% Training_loss_avg:0.688749
# Epoch:0 Step:3056 Training_loss:0.777309, Acc_avg:54.00% Training_loss_avg:0.689995
# Epoch:0 Step:3064 Training_loss:0.671688, Acc_avg:53.25% Training_loss_avg:0.690911
# Epoch:0 Step:3072 Training_loss:0.629764, Acc_avg:54.00% Training_loss_avg:0.688566
# Epoch:0 Step:3080 Training_loss:0.641002, Acc_avg:54.50% Training_loss_avg:0.686665
# Epoch:0 Step:3088 Training_loss:0.715713, Acc_avg:54.25% Training_loss_avg:0.688609
# Epoch:0 Step:3096 Training_loss:0.632044, Acc_avg:54.00% Training_loss_avg:0.688870
# Epoch:0 Step:3104 Training_loss:0.652388, Acc_avg:54.75% Training_loss_avg:0.686942
# Epoch:0 Step:3112 Training_loss:0.581817, Acc_avg:55.50% Training_loss_avg:0.684554
# Epoch:0 Step:3120 Training_loss:0.690276, Acc_avg:56.25% Training_loss_avg:0.681991
# Epoch:0 Step:3128 Training_loss:0.659051, Acc_avg:55.75% Training_loss_avg:0.682169
# Epoch:0 Step:3136 Training_loss:0.668191, Acc_avg:55.50% Training_loss_avg:0.682983
# Epoch:0 Step:3144 Training_loss:0.715837, Acc_avg:55.00% Training_loss_avg:0.684380
# Epoch:0 Step:3152 Training_loss:0.722281, Acc_avg:55.25% Training_loss_avg:0.684511
# Epoch:0 Step:3160 Training_loss:0.587911, Acc_avg:55.25% Training_loss_avg:0.683779
# Epoch:0 Step:3168 Training_loss:0.732896, Acc_avg:55.25% Training_loss_avg:0.684138
# Epoch:0 Step:3176 Training_loss:0.680070, Acc_avg:55.75% Training_loss_avg:0.683209
# Epoch:0 Step:3184 Training_loss:0.625604, Acc_avg:56.25% Training_loss_avg:0.681776
# Epoch:0 Step:3192 Training_loss:0.694646, Acc_avg:56.00% Training_loss_avg:0.683064
# Epoch:0 Step:3200 Training_loss:0.615358, Acc_avg:55.75% Training_loss_avg:0.682995
# Epoch:0 Step:3208 Training_loss:0.716976, Acc_avg:54.75% Training_loss_avg:0.684342
# Epoch:0 Step:3216 Training_loss:0.676285, Acc_avg:54.75% Training_loss_avg:0.684288
# Epoch:0 Step:3224 Training_loss:0.719055, Acc_avg:54.50% Training_loss_avg:0.686169
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:3224 Val_loss:0.673632, Val_Acc_avg:58.25%
# Epoch:0 Step:3232 Training_loss:0.620965, Acc_avg:55.25% Training_loss_avg:0.683007
# Epoch:0 Step:3240 Training_loss:0.603717, Acc_avg:55.75% Training_loss_avg:0.681782
# Epoch:0 Step:3248 Training_loss:0.834247, Acc_avg:55.50% Training_loss_avg:0.684461
# Epoch:0 Step:3256 Training_loss:0.840662, Acc_avg:54.75% Training_loss_avg:0.687362
# Epoch:0 Step:3264 Training_loss:0.571840, Acc_avg:56.00% Training_loss_avg:0.683813
# Epoch:0 Step:3272 Training_loss:0.743902, Acc_avg:56.50% Training_loss_avg:0.683464
# Epoch:0 Step:3280 Training_loss:0.764528, Acc_avg:55.75% Training_loss_avg:0.685789
# Epoch:0 Step:3288 Training_loss:0.695405, Acc_avg:56.25% Training_loss_avg:0.684884
# Epoch:0 Step:3296 Training_loss:0.624538, Acc_avg:56.75% Training_loss_avg:0.684118
# Epoch:0 Step:3304 Training_loss:0.730971, Acc_avg:56.50% Training_loss_avg:0.684875
# Epoch:0 Step:3312 Training_loss:0.670354, Acc_avg:56.50% Training_loss_avg:0.684688
# Epoch:0 Step:3320 Training_loss:0.657281, Acc_avg:56.75% Training_loss_avg:0.684262
# Epoch:0 Step:3328 Training_loss:0.685984, Acc_avg:56.42% Training_loss_avg:0.682387
# Epoch:1 Step:0 Training_loss:0.793772, Acc_avg:55.67% Training_loss_avg:0.685330
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:0 Val_loss:0.674877, Val_Acc_avg:58.00%
# Epoch:1 Step:8 Training_loss:0.682059, Acc_avg:55.67% Training_loss_avg:0.686104
# Epoch:1 Step:16 Training_loss:0.616148, Acc_avg:56.67% Training_loss_avg:0.683383
# Epoch:1 Step:24 Training_loss:0.656142, Acc_avg:56.42% Training_loss_avg:0.683238
# Epoch:1 Step:32 Training_loss:0.722931, Acc_avg:56.67% Training_loss_avg:0.683870
# Epoch:1 Step:40 Training_loss:0.759030, Acc_avg:57.17% Training_loss_avg:0.684313
# Epoch:1 Step:48 Training_loss:0.723478, Acc_avg:56.17% Training_loss_avg:0.686297
# Epoch:1 Step:56 Training_loss:0.737444, Acc_avg:55.92% Training_loss_avg:0.687196
# Epoch:1 Step:64 Training_loss:0.703319, Acc_avg:55.92% Training_loss_avg:0.687447
# Epoch:1 Step:72 Training_loss:0.645380, Acc_avg:56.17% Training_loss_avg:0.686630
# Epoch:1 Step:80 Training_loss:0.641313, Acc_avg:56.67% Training_loss_avg:0.685428
# Epoch:1 Step:88 Training_loss:0.672121, Acc_avg:56.42% Training_loss_avg:0.684313
# Epoch:1 Step:96 Training_loss:0.659939, Acc_avg:56.67% Training_loss_avg:0.684531
# Epoch:1 Step:104 Training_loss:0.649677, Acc_avg:56.92% Training_loss_avg:0.684473
# Epoch:1 Step:112 Training_loss:0.607579, Acc_avg:58.17% Training_loss_avg:0.682418
# Epoch:1 Step:120 Training_loss:0.763894, Acc_avg:58.17% Training_loss_avg:0.682149
# Epoch:1 Step:128 Training_loss:0.641390, Acc_avg:58.67% Training_loss_avg:0.681543
# Epoch:1 Step:136 Training_loss:0.664747, Acc_avg:58.42% Training_loss_avg:0.682243
# Epoch:1 Step:144 Training_loss:0.672206, Acc_avg:58.17% Training_loss_avg:0.682867
# Epoch:1 Step:152 Training_loss:0.603604, Acc_avg:58.92% Training_loss_avg:0.680625
# Epoch:1 Step:160 Training_loss:0.798748, Acc_avg:57.67% Training_loss_avg:0.683959
# Epoch:1 Step:168 Training_loss:0.731909, Acc_avg:57.17% Training_loss_avg:0.685550
# Epoch:1 Step:176 Training_loss:0.613400, Acc_avg:56.67% Training_loss_avg:0.686181
# Epoch:1 Step:184 Training_loss:0.730364, Acc_avg:56.42% Training_loss_avg:0.686983
# Epoch:1 Step:192 Training_loss:0.679520, Acc_avg:56.42% Training_loss_avg:0.687392
# Epoch:1 Step:200 Training_loss:0.573206, Acc_avg:56.67% Training_loss_avg:0.685493
# Epoch:1 Step:208 Training_loss:0.647930, Acc_avg:57.17% Training_loss_avg:0.684135
# Epoch:1 Step:216 Training_loss:0.670701, Acc_avg:56.92% Training_loss_avg:0.683103
# Epoch:1 Step:224 Training_loss:0.652211, Acc_avg:57.17% Training_loss_avg:0.684389
# Epoch:1 Step:232 Training_loss:0.651975, Acc_avg:57.67% Training_loss_avg:0.682771
# Epoch:1 Step:240 Training_loss:0.686860, Acc_avg:57.92% Training_loss_avg:0.682906
# Epoch:1 Step:248 Training_loss:0.773134, Acc_avg:57.42% Training_loss_avg:0.685857
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:248 Val_loss:0.675613, Val_Acc_avg:59.25%
# Epoch:1 Step:256 Training_loss:0.753333, Acc_avg:56.67% Training_loss_avg:0.687031
# Epoch:1 Step:264 Training_loss:0.822795, Acc_avg:55.67% Training_loss_avg:0.691179
# Epoch:1 Step:272 Training_loss:0.603464, Acc_avg:56.67% Training_loss_avg:0.688909
# Epoch:1 Step:280 Training_loss:0.687121, Acc_avg:56.42% Training_loss_avg:0.689126
# Epoch:1 Step:288 Training_loss:0.678989, Acc_avg:56.17% Training_loss_avg:0.688325
# Epoch:1 Step:296 Training_loss:0.686378, Acc_avg:55.92% Training_loss_avg:0.689633
# Epoch:1 Step:304 Training_loss:0.661019, Acc_avg:55.42% Training_loss_avg:0.690779
# Epoch:1 Step:312 Training_loss:0.661585, Acc_avg:56.42% Training_loss_avg:0.687326
# Epoch:1 Step:320 Training_loss:0.599056, Acc_avg:57.92% Training_loss_avg:0.682494
# Epoch:1 Step:328 Training_loss:0.604034, Acc_avg:57.67% Training_loss_avg:0.683137
# Epoch:1 Step:336 Training_loss:0.678279, Acc_avg:57.67% Training_loss_avg:0.681825
# Epoch:1 Step:344 Training_loss:0.714689, Acc_avg:57.92% Training_loss_avg:0.680828
# Epoch:1 Step:352 Training_loss:0.724030, Acc_avg:57.17% Training_loss_avg:0.681401
# Epoch:1 Step:360 Training_loss:0.678815, Acc_avg:56.67% Training_loss_avg:0.682486
# Epoch:1 Step:368 Training_loss:0.641923, Acc_avg:57.17% Training_loss_avg:0.680705
# Epoch:1 Step:376 Training_loss:0.769857, Acc_avg:56.42% Training_loss_avg:0.682695
# Epoch:1 Step:384 Training_loss:0.717531, Acc_avg:55.92% Training_loss_avg:0.683900
# Epoch:1 Step:392 Training_loss:0.599869, Acc_avg:57.00% Training_loss_avg:0.682178
# Epoch:1 Step:400 Training_loss:0.756197, Acc_avg:57.00% Training_loss_avg:0.681426
# Epoch:1 Step:408 Training_loss:0.592291, Acc_avg:57.25% Training_loss_avg:0.679631
# Epoch:1 Step:416 Training_loss:0.704797, Acc_avg:56.50% Training_loss_avg:0.681404
# Epoch:1 Step:424 Training_loss:0.735794, Acc_avg:56.25% Training_loss_avg:0.682997
# Epoch:1 Step:432 Training_loss:0.678981, Acc_avg:56.25% Training_loss_avg:0.682118
# Epoch:1 Step:440 Training_loss:0.584499, Acc_avg:57.25% Training_loss_avg:0.678628
# Epoch:1 Step:448 Training_loss:0.694751, Acc_avg:58.00% Training_loss_avg:0.678053
# Epoch:1 Step:456 Training_loss:0.659004, Acc_avg:58.75% Training_loss_avg:0.676484
# Epoch:1 Step:464 Training_loss:0.655795, Acc_avg:59.00% Training_loss_avg:0.675534
# Epoch:1 Step:472 Training_loss:0.601413, Acc_avg:59.25% Training_loss_avg:0.674654
# Epoch:1 Step:480 Training_loss:0.627243, Acc_avg:59.00% Training_loss_avg:0.674373
# Epoch:1 Step:488 Training_loss:0.724281, Acc_avg:59.25% Training_loss_avg:0.675416
# Epoch:1 Step:496 Training_loss:0.754528, Acc_avg:58.50% Training_loss_avg:0.677308
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:496 Val_loss:0.670837, Val_Acc_avg:61.00%
# Epoch:1 Step:504 Training_loss:0.703397, Acc_avg:58.25% Training_loss_avg:0.678382
# Epoch:1 Step:512 Training_loss:0.677681, Acc_avg:57.75% Training_loss_avg:0.679784
# Epoch:1 Step:520 Training_loss:0.645546, Acc_avg:58.25% Training_loss_avg:0.677417
# Epoch:1 Step:528 Training_loss:0.731281, Acc_avg:58.00% Training_loss_avg:0.679215
# Epoch:1 Step:536 Training_loss:0.647427, Acc_avg:58.25% Training_loss_avg:0.678869
# Epoch:1 Step:544 Training_loss:0.631616, Acc_avg:58.50% Training_loss_avg:0.678057
# Epoch:1 Step:552 Training_loss:0.666355, Acc_avg:58.00% Training_loss_avg:0.679312
# Epoch:1 Step:560 Training_loss:0.682600, Acc_avg:58.75% Training_loss_avg:0.676989
# Epoch:1 Step:568 Training_loss:0.764378, Acc_avg:58.50% Training_loss_avg:0.677638
# Epoch:1 Step:576 Training_loss:0.700676, Acc_avg:58.50% Training_loss_avg:0.679384
# Epoch:1 Step:584 Training_loss:0.794473, Acc_avg:58.50% Training_loss_avg:0.680666
# Epoch:1 Step:592 Training_loss:0.618405, Acc_avg:59.00% Training_loss_avg:0.679444
# Epoch:1 Step:600 Training_loss:0.689606, Acc_avg:58.75% Training_loss_avg:0.681772
# Epoch:1 Step:608 Training_loss:0.674104, Acc_avg:58.50% Training_loss_avg:0.682295
# Epoch:1 Step:616 Training_loss:0.583068, Acc_avg:59.00% Training_loss_avg:0.680543
# Epoch:1 Step:624 Training_loss:0.697815, Acc_avg:58.75% Training_loss_avg:0.681455
# Epoch:1 Step:632 Training_loss:0.717861, Acc_avg:58.50% Training_loss_avg:0.682772
# Epoch:1 Step:640 Training_loss:0.656718, Acc_avg:58.75% Training_loss_avg:0.682170
# Epoch:1 Step:648 Training_loss:0.646945, Acc_avg:59.00% Training_loss_avg:0.679646
# Epoch:1 Step:656 Training_loss:0.705759, Acc_avg:59.00% Training_loss_avg:0.678694
# Epoch:1 Step:664 Training_loss:0.723604, Acc_avg:59.00% Training_loss_avg:0.676711
# Epoch:1 Step:672 Training_loss:0.683771, Acc_avg:58.25% Training_loss_avg:0.678317
# Epoch:1 Step:680 Training_loss:0.720161, Acc_avg:58.00% Training_loss_avg:0.678978
# Epoch:1 Step:688 Training_loss:0.687865, Acc_avg:58.00% Training_loss_avg:0.679155
# Epoch:1 Step:696 Training_loss:0.642716, Acc_avg:58.00% Training_loss_avg:0.678282
# Epoch:1 Step:704 Training_loss:0.620071, Acc_avg:58.25% Training_loss_avg:0.677463
# Epoch:1 Step:712 Training_loss:0.757665, Acc_avg:57.50% Training_loss_avg:0.679384
# Epoch:1 Step:720 Training_loss:0.583588, Acc_avg:57.50% Training_loss_avg:0.679075
# Epoch:1 Step:728 Training_loss:0.614183, Acc_avg:57.50% Training_loss_avg:0.679278
# Epoch:1 Step:736 Training_loss:0.698353, Acc_avg:57.50% Training_loss_avg:0.679680
# Epoch:1 Step:744 Training_loss:0.656180, Acc_avg:57.75% Training_loss_avg:0.678509
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:744 Val_loss:0.669965, Val_Acc_avg:60.50%
# Epoch:1 Step:752 Training_loss:0.560207, Acc_avg:58.50% Training_loss_avg:0.675233
# Epoch:1 Step:760 Training_loss:0.649976, Acc_avg:58.50% Training_loss_avg:0.674656
# Epoch:1 Step:768 Training_loss:0.730511, Acc_avg:58.00% Training_loss_avg:0.676428
# Epoch:1 Step:776 Training_loss:0.743073, Acc_avg:58.75% Training_loss_avg:0.675892
# Epoch:1 Step:784 Training_loss:0.646999, Acc_avg:59.25% Training_loss_avg:0.674482
# Epoch:1 Step:792 Training_loss:0.595444, Acc_avg:59.00% Training_loss_avg:0.674393
# Epoch:1 Step:800 Training_loss:0.677523, Acc_avg:59.50% Training_loss_avg:0.672820
# Epoch:1 Step:808 Training_loss:0.584278, Acc_avg:59.25% Training_loss_avg:0.672659
# Epoch:1 Step:816 Training_loss:0.595277, Acc_avg:59.75% Training_loss_avg:0.670469
# Epoch:1 Step:824 Training_loss:0.579292, Acc_avg:60.25% Training_loss_avg:0.667339
# Epoch:1 Step:832 Training_loss:0.629330, Acc_avg:60.50% Training_loss_avg:0.666346
# Epoch:1 Step:840 Training_loss:0.750634, Acc_avg:60.00% Training_loss_avg:0.669669
# Epoch:1 Step:848 Training_loss:0.578000, Acc_avg:60.25% Training_loss_avg:0.667334
# Epoch:1 Step:856 Training_loss:0.654345, Acc_avg:59.75% Training_loss_avg:0.667240
# Epoch:1 Step:864 Training_loss:0.555746, Acc_avg:60.25% Training_loss_avg:0.665239
# Epoch:1 Step:872 Training_loss:0.498561, Acc_avg:60.25% Training_loss_avg:0.663182
# Epoch:1 Step:880 Training_loss:0.448977, Acc_avg:60.75% Training_loss_avg:0.659617
# ...
# Epoch:4 Step:1872 Training_loss:0.859514, Acc_avg:71.75% Training_loss_avg:0.565716
# Epoch:4 Step:1880 Training_loss:0.762548, Acc_avg:71.25% Training_loss_avg:0.568230
# Epoch:4 Step:1888 Training_loss:0.631336, Acc_avg:71.50% Training_loss_avg:0.568283
# Epoch:4 Step:1896 Training_loss:0.444122, Acc_avg:71.75% Training_loss_avg:0.566148
# Epoch:4 Step:1904 Training_loss:0.676313, Acc_avg:70.75% Training_loss_avg:0.569445
# Epoch:4 Step:1912 Training_loss:0.504100, Acc_avg:71.00% Training_loss_avg:0.568770
# Epoch:4 Step:1920 Training_loss:0.612002, Acc_avg:71.00% Training_loss_avg:0.568764
# Epoch:4 Step:1928 Training_loss:0.508771, Acc_avg:70.25% Training_loss_avg:0.571486
# Epoch:4 Step:1936 Training_loss:0.569062, Acc_avg:70.00% Training_loss_avg:0.570687
# Epoch:4 Step:1944 Training_loss:0.441594, Acc_avg:70.25% Training_loss_avg:0.568730
# Epoch:4 Step:1952 Training_loss:0.774944, Acc_avg:70.25% Training_loss_avg:0.571607
# Epoch:4 Step:1960 Training_loss:0.587041, Acc_avg:69.75% Training_loss_avg:0.573374
# Epoch:4 Step:1968 Training_loss:0.426946, Acc_avg:69.75% Training_loss_avg:0.570096
# Epoch:4 Step:1976 Training_loss:0.476299, Acc_avg:69.75% Training_loss_avg:0.567461
# Epoch:4 Step:1984 Training_loss:0.488462, Acc_avg:70.00% Training_loss_avg:0.564301
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:1984 Val_loss:0.656382, Val_Acc_avg:59.50%
# Epoch:4 Step:1992 Training_loss:0.570090, Acc_avg:70.00% Training_loss_avg:0.561632
# Epoch:4 Step:2000 Training_loss:0.618051, Acc_avg:70.25% Training_loss_avg:0.557726
# Epoch:4 Step:2008 Training_loss:0.494761, Acc_avg:70.25% Training_loss_avg:0.557153
# Epoch:4 Step:2016 Training_loss:0.639872, Acc_avg:70.25% Training_loss_avg:0.559689
# Epoch:4 Step:2024 Training_loss:0.478655, Acc_avg:71.50% Training_loss_avg:0.553617
# Epoch:4 Step:2032 Training_loss:0.880246, Acc_avg:71.50% Training_loss_avg:0.553733
# Epoch:4 Step:2040 Training_loss:0.557663, Acc_avg:71.25% Training_loss_avg:0.549845
# Epoch:4 Step:2048 Training_loss:0.632489, Acc_avg:70.75% Training_loss_avg:0.551949
# Epoch:4 Step:2056 Training_loss:0.336113, Acc_avg:71.50% Training_loss_avg:0.545204
# Epoch:4 Step:2064 Training_loss:0.482532, Acc_avg:71.75% Training_loss_avg:0.545989
# Epoch:4 Step:2072 Training_loss:0.487521, Acc_avg:71.75% Training_loss_avg:0.546601
# Epoch:4 Step:2080 Training_loss:0.457180, Acc_avg:71.50% Training_loss_avg:0.546598
# Epoch:4 Step:2088 Training_loss:0.830619, Acc_avg:70.50% Training_loss_avg:0.555248
# Epoch:4 Step:2096 Training_loss:0.617304, Acc_avg:70.50% Training_loss_avg:0.554706
# Epoch:4 Step:2104 Training_loss:0.259365, Acc_avg:70.50% Training_loss_avg:0.552006
# Epoch:4 Step:2112 Training_loss:0.404045, Acc_avg:70.00% Training_loss_avg:0.554869
# Epoch:4 Step:2120 Training_loss:0.579232, Acc_avg:70.50% Training_loss_avg:0.550791
# Epoch:4 Step:2128 Training_loss:0.566432, Acc_avg:71.25% Training_loss_avg:0.546393
# Epoch:4 Step:2136 Training_loss:0.498353, Acc_avg:71.25% Training_loss_avg:0.543907
# Epoch:4 Step:2144 Training_loss:0.477249, Acc_avg:71.50% Training_loss_avg:0.544203
# Epoch:4 Step:2152 Training_loss:0.544389, Acc_avg:71.00% Training_loss_avg:0.549396
# Epoch:4 Step:2160 Training_loss:0.610110, Acc_avg:71.00% Training_loss_avg:0.546202
# Epoch:4 Step:2168 Training_loss:0.700215, Acc_avg:71.25% Training_loss_avg:0.544021
# Epoch:4 Step:2176 Training_loss:0.536778, Acc_avg:71.25% Training_loss_avg:0.543270
# Epoch:4 Step:2184 Training_loss:0.438767, Acc_avg:71.00% Training_loss_avg:0.542667
# Epoch:4 Step:2192 Training_loss:0.533795, Acc_avg:70.25% Training_loss_avg:0.546798
# Epoch:4 Step:2200 Training_loss:0.579376, Acc_avg:69.75% Training_loss_avg:0.553919
# Epoch:4 Step:2208 Training_loss:0.595698, Acc_avg:69.25% Training_loss_avg:0.553695
# Epoch:4 Step:2216 Training_loss:0.594409, Acc_avg:69.50% Training_loss_avg:0.550295
# Epoch:4 Step:2224 Training_loss:0.649925, Acc_avg:69.00% Training_loss_avg:0.556848
# Epoch:4 Step:2232 Training_loss:0.646809, Acc_avg:68.50% Training_loss_avg:0.563309
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2232 Val_loss:0.675878, Val_Acc_avg:60.00%
# Epoch:4 Step:2240 Training_loss:0.596178, Acc_avg:69.00% Training_loss_avg:0.555810
# Epoch:4 Step:2248 Training_loss:0.598761, Acc_avg:68.75% Training_loss_avg:0.555949
# Epoch:4 Step:2256 Training_loss:0.574389, Acc_avg:68.50% Training_loss_avg:0.559985
# Epoch:4 Step:2264 Training_loss:0.744761, Acc_avg:67.00% Training_loss_avg:0.571504
# Epoch:4 Step:2272 Training_loss:0.710473, Acc_avg:67.00% Training_loss_avg:0.568523
# Epoch:4 Step:2280 Training_loss:0.402906, Acc_avg:67.75% Training_loss_avg:0.561330
# Epoch:4 Step:2288 Training_loss:0.724565, Acc_avg:66.75% Training_loss_avg:0.563195
# Epoch:4 Step:2296 Training_loss:0.501804, Acc_avg:66.75% Training_loss_avg:0.564348
# Epoch:4 Step:2304 Training_loss:0.348924, Acc_avg:67.75% Training_loss_avg:0.557801
# Epoch:4 Step:2312 Training_loss:0.749912, Acc_avg:67.25% Training_loss_avg:0.562717
# Epoch:4 Step:2320 Training_loss:0.402280, Acc_avg:67.50% Training_loss_avg:0.558522
# Epoch:4 Step:2328 Training_loss:0.382269, Acc_avg:68.00% Training_loss_avg:0.555992
# Epoch:4 Step:2336 Training_loss:0.582187, Acc_avg:68.50% Training_loss_avg:0.556255
# Epoch:4 Step:2344 Training_loss:0.639414, Acc_avg:68.25% Training_loss_avg:0.560211
# Epoch:4 Step:2352 Training_loss:0.974719, Acc_avg:68.00% Training_loss_avg:0.564207
# Epoch:4 Step:2360 Training_loss:0.686406, Acc_avg:68.25% Training_loss_avg:0.566194
# Epoch:4 Step:2368 Training_loss:0.925372, Acc_avg:67.25% Training_loss_avg:0.576163
# Epoch:4 Step:2376 Training_loss:0.785215, Acc_avg:66.50% Training_loss_avg:0.582341
# Epoch:4 Step:2384 Training_loss:0.699584, Acc_avg:66.00% Training_loss_avg:0.586563
# Epoch:4 Step:2392 Training_loss:0.382832, Acc_avg:66.25% Training_loss_avg:0.582818
# Epoch:4 Step:2400 Training_loss:0.664180, Acc_avg:66.25% Training_loss_avg:0.583741
# Epoch:4 Step:2408 Training_loss:0.477167, Acc_avg:66.25% Training_loss_avg:0.583389
# Epoch:4 Step:2416 Training_loss:0.683681, Acc_avg:65.75% Training_loss_avg:0.584265
# Epoch:4 Step:2424 Training_loss:0.598163, Acc_avg:65.50% Training_loss_avg:0.586655
# Epoch:4 Step:2432 Training_loss:0.382617, Acc_avg:66.50% Training_loss_avg:0.576703
# Epoch:4 Step:2440 Training_loss:0.434405, Acc_avg:66.75% Training_loss_avg:0.574237
# Epoch:4 Step:2448 Training_loss:0.707436, Acc_avg:66.75% Training_loss_avg:0.575736
# Epoch:4 Step:2456 Training_loss:0.583971, Acc_avg:66.25% Training_loss_avg:0.580694
# Epoch:4 Step:2464 Training_loss:0.551480, Acc_avg:66.25% Training_loss_avg:0.582072
# Epoch:4 Step:2472 Training_loss:0.501101, Acc_avg:66.25% Training_loss_avg:0.582344
# Epoch:4 Step:2480 Training_loss:0.511203, Acc_avg:66.00% Training_loss_avg:0.583425
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:4 Step:2480 Val_loss:0.649705, Val_Acc_avg:61.50%
# Epoch:4 Step:2488 Training_loss:0.418148, Acc_avg:67.00% Training_loss_avg:0.575175
# Epoch:4 Step:2496 Training_loss:0.575109, Acc_avg:67.00% Training_loss_avg:0.574331
# Epoch:4 Step:2504 Training_loss:0.627776, Acc_avg:66.25% Training_loss_avg:0.581699
# Epoch:4 Step:2512 Training_loss:0.562599, Acc_avg:66.00% Training_loss_avg:0.584870
# Epoch:4 Step:2520 Training_loss:0.576953, Acc_avg:66.25% Training_loss_avg:0.584825
# Epoch:4 Step:2528 Training_loss:0.513832, Acc_avg:66.25% Training_loss_avg:0.583773
# Epoch:4 Step:2536 Training_loss:0.476720, Acc_avg:66.50% Training_loss_avg:0.583340
# Epoch:4 Step:2544 Training_loss:0.374891, Acc_avg:67.00% Training_loss_avg:0.581293
# Epoch:4 Step:2552 Training_loss:0.611504, Acc_avg:66.75% Training_loss_avg:0.582635
# Epoch:4 Step:2560 Training_loss:0.441608, Acc_avg:67.25% Training_loss_avg:0.579265
# Epoch:4 Step:2568 Training_loss:0.722141, Acc_avg:66.75% Training_loss_avg:0.579704
# Epoch:4 Step:2576 Training_loss:0.662309, Acc_avg:66.50% Training_loss_avg:0.582214
# Epoch:4 Step:2584 Training_loss:0.341091, Acc_avg:66.75% Training_loss_avg:0.580261
# Epoch:4 Step:2592 Training_loss:0.467058, Acc_avg:67.25% Training_loss_avg:0.578926
# Epoch:4 Step:2600 Training_loss:0.572528, Acc_avg:66.75% Training_loss_avg:0.578789
# Epoch:4 Step:2608 Training_loss:0.463031, Acc_avg:67.50% Training_loss_avg:0.576136
# Epoch:4 Step:2616 Training_loss:0.712289, Acc_avg:67.50% Training_loss_avg:0.578494
# Epoch:4 Step:2624 Training_loss:0.413138, Acc_avg:67.75% Training_loss_avg:0.573758
# Epoch:4 Step:2632 Training_loss:0.755073, Acc_avg:67.50% Training_loss_avg:0.575923
# Epoch:4 Step:2640 Training_loss:0.734853, Acc_avg:67.25% Training_loss_avg:0.578697
# Epoch:4 Step:2648 Training_loss:0.691526, Acc_avg:67.25% Training_loss_avg:0.580552
# Epoch:4 Step:2656 Training_loss:0.681690, Acc_avg:67.00% Training_loss_avg:0.582698
# Epoch:4 Step:2664 Training_loss:0.591624, Acc_avg:67.75% Training_loss_avg:0.579635
# Epoch:4 Step:2672 Training_loss:0.564818, Acc_avg:68.00% Training_loss_avg:0.576722
# Epoch:4 Step:2680 Training_loss:0.559490, Acc_avg:68.00% Training_loss_avg:0.579854
# Epoch:4 Step:2688 Training_loss:0.610720, Acc_avg:68.50% Training_loss_avg:0.577577
# Epoch:4 Step:2696 Training_loss:0.398997, Acc_avg:69.00% Training_loss_avg:0.575521
# Epoch:4 Step:2704 Training_loss:0.614194, Acc_avg:68.50% Training_loss_avg:0.580826
# Epoch:4 Step:2712 Training_loss:0.764817, Acc_avg:68.50% Training_loss_avg:0.581124
# Epoch:4 Step:2720 Training_loss:0.653229, Acc_avg:68.25% Training_loss_avg:0.586143
# Epoch:4 Step:2728 Training_loss:0.713844, Acc_avg:67.50% Training_loss_avg:0.592775
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2728 Val_loss:0.649943, Val_Acc_avg:58.75%
# Epoch:4 Step:2736 Training_loss:0.263467, Acc_avg:68.00% Training_loss_avg:0.586400
# Epoch:4 Step:2744 Training_loss:0.700553, Acc_avg:67.75% Training_loss_avg:0.587623
# Epoch:4 Step:2752 Training_loss:0.393567, Acc_avg:68.75% Training_loss_avg:0.576000
# Epoch:4 Step:2760 Training_loss:0.514447, Acc_avg:68.75% Training_loss_avg:0.572561
# Epoch:4 Step:2768 Training_loss:0.885084, Acc_avg:68.50% Training_loss_avg:0.571755
# Epoch:4 Step:2776 Training_loss:0.334351, Acc_avg:69.25% Training_loss_avg:0.562738
# Epoch:4 Step:2784 Training_loss:0.365829, Acc_avg:70.25% Training_loss_avg:0.556063
# Epoch:4 Step:2792 Training_loss:0.517371, Acc_avg:69.50% Training_loss_avg:0.558753
# Epoch:4 Step:2800 Training_loss:0.607387, Acc_avg:69.75% Training_loss_avg:0.557618
# Epoch:4 Step:2808 Training_loss:0.594127, Acc_avg:69.75% Training_loss_avg:0.559957
# Epoch:4 Step:2816 Training_loss:0.508931, Acc_avg:70.00% Training_loss_avg:0.556462
# Epoch:4 Step:2824 Training_loss:0.521379, Acc_avg:70.25% Training_loss_avg:0.554926
# Epoch:4 Step:2832 Training_loss:0.678971, Acc_avg:69.75% Training_loss_avg:0.560853
# Epoch:4 Step:2840 Training_loss:0.421307, Acc_avg:69.75% Training_loss_avg:0.560591
# Epoch:4 Step:2848 Training_loss:0.498209, Acc_avg:69.75% Training_loss_avg:0.556407
# Epoch:4 Step:2856 Training_loss:0.365917, Acc_avg:70.00% Training_loss_avg:0.552046
# Epoch:4 Step:2864 Training_loss:0.512520, Acc_avg:70.00% Training_loss_avg:0.551266
# Epoch:4 Step:2872 Training_loss:0.530200, Acc_avg:69.75% Training_loss_avg:0.551848
# Epoch:4 Step:2880 Training_loss:0.639427, Acc_avg:70.00% Training_loss_avg:0.554413
# Epoch:4 Step:2888 Training_loss:0.552850, Acc_avg:69.75% Training_loss_avg:0.557107
# Epoch:4 Step:2896 Training_loss:0.652272, Acc_avg:69.25% Training_loss_avg:0.558650
# Epoch:4 Step:2904 Training_loss:0.679797, Acc_avg:69.25% Training_loss_avg:0.559691
# Epoch:4 Step:2912 Training_loss:0.356288, Acc_avg:69.75% Training_loss_avg:0.555564
# Epoch:4 Step:2920 Training_loss:0.664933, Acc_avg:69.25% Training_loss_avg:0.557324
# Epoch:4 Step:2928 Training_loss:0.498089, Acc_avg:69.50% Training_loss_avg:0.557009
# Epoch:4 Step:2936 Training_loss:0.346271, Acc_avg:69.75% Training_loss_avg:0.554400
# Epoch:4 Step:2944 Training_loss:0.819978, Acc_avg:68.75% Training_loss_avg:0.563302
# Epoch:4 Step:2952 Training_loss:0.740169, Acc_avg:68.50% Training_loss_avg:0.565875
# Epoch:4 Step:2960 Training_loss:0.696474, Acc_avg:68.00% Training_loss_avg:0.570973
# Epoch:4 Step:2968 Training_loss:0.660082, Acc_avg:68.50% Training_loss_avg:0.569731
# Epoch:4 Step:2976 Training_loss:0.490801, Acc_avg:68.75% Training_loss_avg:0.566301
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:4 Step:2976 Val_loss:0.661207, Val_Acc_avg:63.25%
# Epoch:4 Step:2984 Training_loss:0.743741, Acc_avg:68.25% Training_loss_avg:0.574354
# Epoch:4 Step:2992 Training_loss:0.401419, Acc_avg:68.50% Training_loss_avg:0.573041
# Epoch:4 Step:3000 Training_loss:0.638137, Acc_avg:69.00% Training_loss_avg:0.574354
# Epoch:4 Step:3008 Training_loss:0.469935, Acc_avg:69.25% Training_loss_avg:0.574492
# Epoch:4 Step:3016 Training_loss:0.629365, Acc_avg:69.00% Training_loss_avg:0.572833
# Epoch:4 Step:3024 Training_loss:0.473024, Acc_avg:69.00% Training_loss_avg:0.574031
# Epoch:4 Step:3032 Training_loss:0.455103, Acc_avg:69.25% Training_loss_avg:0.568032
# Epoch:4 Step:3040 Training_loss:0.512412, Acc_avg:69.75% Training_loss_avg:0.563583
# Epoch:4 Step:3048 Training_loss:0.599136, Acc_avg:70.25% Training_loss_avg:0.561735
# Epoch:4 Step:3056 Training_loss:0.573720, Acc_avg:70.75% Training_loss_avg:0.559576
# Epoch:4 Step:3064 Training_loss:0.361666, Acc_avg:71.25% Training_loss_avg:0.554976
# Epoch:4 Step:3072 Training_loss:0.386978, Acc_avg:71.50% Training_loss_avg:0.551420
# Epoch:4 Step:3080 Training_loss:0.410857, Acc_avg:71.50% Training_loss_avg:0.548447
# Epoch:4 Step:3088 Training_loss:0.647436, Acc_avg:71.50% Training_loss_avg:0.549181
# Epoch:4 Step:3096 Training_loss:0.593789, Acc_avg:71.00% Training_loss_avg:0.553077
# Epoch:4 Step:3104 Training_loss:0.697783, Acc_avg:70.50% Training_loss_avg:0.554749
# Epoch:4 Step:3112 Training_loss:0.492571, Acc_avg:71.00% Training_loss_avg:0.549304
# Epoch:4 Step:3120 Training_loss:0.641086, Acc_avg:71.00% Training_loss_avg:0.549061
# Epoch:4 Step:3128 Training_loss:0.274237, Acc_avg:72.00% Training_loss_avg:0.540269
# Epoch:4 Step:3136 Training_loss:0.489248, Acc_avg:71.25% Training_loss_avg:0.544785
# Epoch:4 Step:3144 Training_loss:0.519934, Acc_avg:71.75% Training_loss_avg:0.541172
# Epoch:4 Step:3152 Training_loss:0.702498, Acc_avg:70.75% Training_loss_avg:0.547351
# Epoch:4 Step:3160 Training_loss:0.714960, Acc_avg:70.75% Training_loss_avg:0.551361
# Epoch:4 Step:3168 Training_loss:0.390433, Acc_avg:72.25% Training_loss_avg:0.541468
# Epoch:4 Step:3176 Training_loss:0.500060, Acc_avg:72.25% Training_loss_avg:0.544782
# Epoch:4 Step:3184 Training_loss:0.568152, Acc_avg:71.50% Training_loss_avg:0.548829
# Epoch:4 Step:3192 Training_loss:0.355753, Acc_avg:72.25% Training_loss_avg:0.545596
# Epoch:4 Step:3200 Training_loss:0.646459, Acc_avg:72.00% Training_loss_avg:0.546378
# Epoch:4 Step:3208 Training_loss:0.306426, Acc_avg:72.25% Training_loss_avg:0.540624
# Epoch:4 Step:3216 Training_loss:0.582559, Acc_avg:72.00% Training_loss_avg:0.542096
# Epoch:4 Step:3224 Training_loss:0.324205, Acc_avg:72.00% Training_loss_avg:0.538153
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:3224 Val_loss:0.680723, Val_Acc_avg:62.50%
# Epoch:4 Step:3232 Training_loss:0.470278, Acc_avg:72.75% Training_loss_avg:0.533979
# Epoch:4 Step:3240 Training_loss:0.667614, Acc_avg:72.00% Training_loss_avg:0.538905
# Epoch:4 Step:3248 Training_loss:0.584908, Acc_avg:72.25% Training_loss_avg:0.540639
# Epoch:4 Step:3256 Training_loss:0.419002, Acc_avg:72.25% Training_loss_avg:0.541701
# Epoch:4 Step:3264 Training_loss:0.601236, Acc_avg:72.00% Training_loss_avg:0.543475
# Epoch:4 Step:3272 Training_loss:0.678155, Acc_avg:72.00% Training_loss_avg:0.546434
# Epoch:4 Step:3280 Training_loss:0.534536, Acc_avg:71.75% Training_loss_avg:0.544336
# Epoch:4 Step:3288 Training_loss:0.441876, Acc_avg:71.75% Training_loss_avg:0.542117
# Epoch:4 Step:3296 Training_loss:0.364218, Acc_avg:72.75% Training_loss_avg:0.536356
# Epoch:4 Step:3304 Training_loss:0.443095, Acc_avg:73.25% Training_loss_avg:0.531622
# Epoch:4 Step:3312 Training_loss:0.235256, Acc_avg:73.50% Training_loss_avg:0.529201
# Epoch:4 Step:3320 Training_loss:0.476631, Acc_avg:74.25% Training_loss_avg:0.525435
# Epoch:4 Step:3328 Training_loss:0.522390, Acc_avg:73.83% Training_loss_avg:0.525921

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """
    run_name = "lr_5e-6 redo, 512 split with attention! redo 6"
    run_dir = "codebert_finetune_runs/{}".format(run_name)
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False
    load_splits = False
    save_data = True

    if load_splits:
      train_data, val_data, test_data = split_loader(run_dir)
      X_train, A_train, Y_train = train_data
      X_val, A_val, Y_val = val_data
      X_test, A_test, Y_test = test_data
      print("loaded data splits")

    else:
      print("generating data splits")

      code_df = preprocess_data(file_loc='code_dataset.jsonl')
      train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

      X_train, A_train, Y_train = train_data
      X_val, A_val, Y_val = val_data
      X_test, A_test, Y_test = test_data

      data_type = ['train', 'val', 'test']
      data_split_type = ['X', 'A', 'Y']

      print(X_train.shape)
    # Creating dir to save logs and checkpoints, re
    dir_name = "{}".format(run_dir)
    if os.path.exists(dir_name):
        input("run name already exists, press Enter to overwrite")
    else:
        os.makedirs(dir_name)


    if save_data:
      print("saving data splits")

      data_all = [train_data, val_data, test_data]
      for i, data in enumerate(data_all):
        for j, split in enumerate(data):
          with open('{}/{}_{}.pickle'.format(run_dir,data_type[i], data_split_type[j]), 'wb') as handle:
            pickle.dump(split, handle)


    print(train_data[0].shape)
    print("Data points: {}".format(len(train_data)))

    # Loading model from checkpoint if location provided
    if online:
        print("loading model from online")
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        print("loading model from local repo")

        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        print("loading model from checkpoint: {}".format(checkpoint_location))
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=3e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="lr_3e-6 redo, 256 split, saving splits")

# %%
torch.cuda.empty_cache()
main()
# Out:
# generating data splits
# Insecure code counts: 3729, Total code counts: 8000, Proportion 0.466125
# Data points: 8000
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# torch.Size([3331, 512])
# saving data splits
# torch.Size([3331, 512])
# Data points: 3
# loading model from local repo
# Some weights of the model checkpoint at codebert-base were not used when initializing RobertaForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at codebert-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:0 Step:0 Training_loss:0.667126, Acc_avg:62.50% Training_loss_avg:0.667126
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:0 Val_loss:0.690983, Val_Acc_avg:54.25%
# Epoch:0 Step:8 Training_loss:0.709088, Acc_avg:56.25% Training_loss_avg:0.688107
# Epoch:0 Step:16 Training_loss:0.698459, Acc_avg:50.00% Training_loss_avg:0.691558
# Epoch:0 Step:24 Training_loss:0.712653, Acc_avg:50.00% Training_loss_avg:0.696832
# Epoch:0 Step:32 Training_loss:0.704778, Acc_avg:50.00% Training_loss_avg:0.698421
# Epoch:0 Step:40 Training_loss:0.653642, Acc_avg:52.08% Training_loss_avg:0.690958
# Epoch:0 Step:48 Training_loss:0.751974, Acc_avg:46.43% Training_loss_avg:0.699674
# Epoch:0 Step:56 Training_loss:0.725819, Acc_avg:45.31% Training_loss_avg:0.702942
# Epoch:0 Step:64 Training_loss:0.710670, Acc_avg:44.44% Training_loss_avg:0.703801
# Epoch:0 Step:72 Training_loss:0.696412, Acc_avg:43.75% Training_loss_avg:0.703062
# Epoch:0 Step:80 Training_loss:0.657638, Acc_avg:46.59% Training_loss_avg:0.698933
# Epoch:0 Step:88 Training_loss:0.711821, Acc_avg:46.88% Training_loss_avg:0.700007
# Epoch:0 Step:96 Training_loss:0.676815, Acc_avg:48.08% Training_loss_avg:0.698223
# Epoch:0 Step:104 Training_loss:0.636117, Acc_avg:50.00% Training_loss_avg:0.693787
# Epoch:0 Step:112 Training_loss:0.710238, Acc_avg:50.00% Training_loss_avg:0.694883
# Epoch:0 Step:120 Training_loss:0.715967, Acc_avg:49.22% Training_loss_avg:0.696201
# Epoch:0 Step:128 Training_loss:0.680687, Acc_avg:49.26% Training_loss_avg:0.695289
# Epoch:0 Step:136 Training_loss:0.653389, Acc_avg:50.69% Training_loss_avg:0.692961
# Epoch:0 Step:144 Training_loss:0.776704, Acc_avg:48.68% Training_loss_avg:0.697368
# Epoch:0 Step:152 Training_loss:0.650662, Acc_avg:50.00% Training_loss_avg:0.695033
# Epoch:0 Step:160 Training_loss:0.718119, Acc_avg:50.00% Training_loss_avg:0.696132
# Epoch:0 Step:168 Training_loss:0.694935, Acc_avg:50.00% Training_loss_avg:0.696078
# Epoch:0 Step:176 Training_loss:0.673737, Acc_avg:49.46% Training_loss_avg:0.695107
# Epoch:0 Step:184 Training_loss:0.717532, Acc_avg:48.96% Training_loss_avg:0.696041
# Epoch:0 Step:192 Training_loss:0.680488, Acc_avg:49.50% Training_loss_avg:0.695419
# Epoch:0 Step:200 Training_loss:0.774863, Acc_avg:48.08% Training_loss_avg:0.698474
# Epoch:0 Step:208 Training_loss:0.684817, Acc_avg:48.61% Training_loss_avg:0.697969
# Epoch:0 Step:216 Training_loss:0.703649, Acc_avg:48.66% Training_loss_avg:0.698171
# Epoch:0 Step:224 Training_loss:0.749787, Acc_avg:47.84% Training_loss_avg:0.699951
# Epoch:0 Step:232 Training_loss:0.674122, Acc_avg:48.33% Training_loss_avg:0.699090
# Epoch:0 Step:240 Training_loss:0.674545, Acc_avg:48.79% Training_loss_avg:0.698298
# Epoch:0 Step:248 Training_loss:0.697448, Acc_avg:48.44% Training_loss_avg:0.698272
# Validating:
# 52it [00:07,  6.57it/s]
# Epoch:0 Step:248 Val_loss:0.690797, Val_Acc_avg:54.25%
# Epoch:0 Step:256 Training_loss:0.639177, Acc_avg:48.86% Training_loss_avg:0.696481
# Epoch:0 Step:264 Training_loss:0.659795, Acc_avg:49.26% Training_loss_avg:0.695402
# Epoch:0 Step:272 Training_loss:0.683633, Acc_avg:49.64% Training_loss_avg:0.695066
# Epoch:0 Step:280 Training_loss:0.683068, Acc_avg:49.31% Training_loss_avg:0.694733
# Epoch:0 Step:288 Training_loss:0.679893, Acc_avg:49.32% Training_loss_avg:0.694332
# Epoch:0 Step:296 Training_loss:0.683900, Acc_avg:49.34% Training_loss_avg:0.694057
# Epoch:0 Step:304 Training_loss:0.712757, Acc_avg:49.68% Training_loss_avg:0.694537
# Epoch:0 Step:312 Training_loss:0.654668, Acc_avg:50.00% Training_loss_avg:0.693540
# Epoch:0 Step:320 Training_loss:0.713921, Acc_avg:49.70% Training_loss_avg:0.694037
# Epoch:0 Step:328 Training_loss:0.645714, Acc_avg:50.60% Training_loss_avg:0.692886
# Epoch:0 Step:336 Training_loss:0.744353, Acc_avg:50.00% Training_loss_avg:0.694083
# Epoch:0 Step:344 Training_loss:0.695591, Acc_avg:50.28% Training_loss_avg:0.694118
# Epoch:0 Step:352 Training_loss:0.662329, Acc_avg:50.56% Training_loss_avg:0.693411
# Epoch:0 Step:360 Training_loss:0.690531, Acc_avg:50.27% Training_loss_avg:0.693349
# Epoch:0 Step:368 Training_loss:0.674364, Acc_avg:50.53% Training_loss_avg:0.692945
# Epoch:0 Step:376 Training_loss:0.666342, Acc_avg:50.52% Training_loss_avg:0.692390
# Epoch:0 Step:384 Training_loss:0.730749, Acc_avg:50.51% Training_loss_avg:0.693173
# Epoch:0 Step:392 Training_loss:0.688377, Acc_avg:50.25% Training_loss_avg:0.693077
# Epoch:0 Step:400 Training_loss:0.705118, Acc_avg:49.75% Training_loss_avg:0.693837
# Epoch:0 Step:408 Training_loss:0.658678, Acc_avg:49.75% Training_loss_avg:0.692829
# Epoch:0 Step:416 Training_loss:0.663114, Acc_avg:50.50% Training_loss_avg:0.692122
# Epoch:0 Step:424 Training_loss:0.738441, Acc_avg:49.75% Training_loss_avg:0.692638
# Epoch:0 Step:432 Training_loss:0.640437, Acc_avg:50.25% Training_loss_avg:0.691351
# Epoch:0 Step:440 Training_loss:0.664240, Acc_avg:50.50% Training_loss_avg:0.691563
# Epoch:0 Step:448 Training_loss:0.617511, Acc_avg:52.25% Training_loss_avg:0.688874
# Epoch:0 Step:456 Training_loss:0.718396, Acc_avg:52.50% Training_loss_avg:0.688725
# Epoch:0 Step:464 Training_loss:0.723021, Acc_avg:52.75% Training_loss_avg:0.688972
# Epoch:0 Step:472 Training_loss:0.766129, Acc_avg:52.75% Training_loss_avg:0.690367
# Epoch:0 Step:480 Training_loss:0.666408, Acc_avg:52.25% Training_loss_avg:0.690542
# Epoch:0 Step:488 Training_loss:0.701173, Acc_avg:52.50% Training_loss_avg:0.690329
# Epoch:0 Step:496 Training_loss:0.719129, Acc_avg:52.25% Training_loss_avg:0.691175
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:496 Val_loss:0.692195, Val_Acc_avg:54.25%
# Epoch:0 Step:504 Training_loss:0.779638, Acc_avg:51.25% Training_loss_avg:0.694046
# Epoch:0 Step:512 Training_loss:0.771046, Acc_avg:51.00% Training_loss_avg:0.695262
# Epoch:0 Step:520 Training_loss:0.715992, Acc_avg:51.25% Training_loss_avg:0.695262
# Epoch:0 Step:528 Training_loss:0.717990, Acc_avg:51.00% Training_loss_avg:0.696008
# Epoch:0 Step:536 Training_loss:0.695787, Acc_avg:50.75% Training_loss_avg:0.696856
# Epoch:0 Step:544 Training_loss:0.734413, Acc_avg:51.25% Training_loss_avg:0.696011
# Epoch:0 Step:552 Training_loss:0.723202, Acc_avg:50.75% Training_loss_avg:0.697461
# Epoch:0 Step:560 Training_loss:0.690388, Acc_avg:51.00% Training_loss_avg:0.696907
# Epoch:0 Step:568 Training_loss:0.652499, Acc_avg:51.75% Training_loss_avg:0.696058
# Epoch:0 Step:576 Training_loss:0.705798, Acc_avg:52.50% Training_loss_avg:0.696699
# Epoch:0 Step:584 Training_loss:0.717432, Acc_avg:52.75% Training_loss_avg:0.696697
# Epoch:0 Step:592 Training_loss:0.654566, Acc_avg:53.25% Training_loss_avg:0.696179
# Epoch:0 Step:600 Training_loss:0.703374, Acc_avg:54.00% Training_loss_avg:0.694749
# Epoch:0 Step:608 Training_loss:0.673122, Acc_avg:54.00% Training_loss_avg:0.694515
# Epoch:0 Step:616 Training_loss:0.709993, Acc_avg:54.25% Training_loss_avg:0.694642
# Epoch:0 Step:624 Training_loss:0.730033, Acc_avg:54.25% Training_loss_avg:0.694247
# Epoch:0 Step:632 Training_loss:0.665412, Acc_avg:54.25% Training_loss_avg:0.694073
# Epoch:0 Step:640 Training_loss:0.654414, Acc_avg:54.25% Training_loss_avg:0.693670
# Epoch:0 Step:648 Training_loss:0.664360, Acc_avg:54.75% Training_loss_avg:0.693008
# Epoch:0 Step:656 Training_loss:0.724048, Acc_avg:54.50% Training_loss_avg:0.694706
# Epoch:0 Step:664 Training_loss:0.723935, Acc_avg:54.00% Training_loss_avg:0.695989
# Epoch:0 Step:672 Training_loss:0.709566, Acc_avg:53.75% Training_loss_avg:0.696507
# Epoch:0 Step:680 Training_loss:0.660755, Acc_avg:54.50% Training_loss_avg:0.696061
# Epoch:0 Step:688 Training_loss:0.712077, Acc_avg:54.75% Training_loss_avg:0.696705
# Epoch:0 Step:696 Training_loss:0.745258, Acc_avg:54.50% Training_loss_avg:0.697932
# Epoch:0 Step:704 Training_loss:0.679565, Acc_avg:54.25% Training_loss_avg:0.697268
# Epoch:0 Step:712 Training_loss:0.706767, Acc_avg:53.75% Training_loss_avg:0.698310
# Epoch:0 Step:720 Training_loss:0.629951, Acc_avg:54.75% Training_loss_avg:0.696631
# Epoch:0 Step:728 Training_loss:0.706720, Acc_avg:53.75% Training_loss_avg:0.697851
# Epoch:0 Step:736 Training_loss:0.645401, Acc_avg:54.75% Training_loss_avg:0.695872
# Epoch:0 Step:744 Training_loss:0.650989, Acc_avg:54.75% Training_loss_avg:0.694980
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:0 Step:744 Val_loss:0.690270, Val_Acc_avg:54.25%
# Epoch:0 Step:752 Training_loss:0.687889, Acc_avg:54.75% Training_loss_avg:0.695491
# Epoch:0 Step:760 Training_loss:0.675476, Acc_avg:55.25% Training_loss_avg:0.695190
# Epoch:0 Step:768 Training_loss:0.657793, Acc_avg:55.50% Training_loss_avg:0.694858
# Epoch:0 Step:776 Training_loss:0.780609, Acc_avg:54.75% Training_loss_avg:0.697144
# Epoch:0 Step:784 Training_loss:0.739204, Acc_avg:54.50% Training_loss_avg:0.697313
# Epoch:0 Step:792 Training_loss:0.694461, Acc_avg:54.50% Training_loss_avg:0.697434
# Epoch:0 Step:800 Training_loss:0.670850, Acc_avg:55.00% Training_loss_avg:0.696749
# Epoch:0 Step:808 Training_loss:0.685063, Acc_avg:55.00% Training_loss_avg:0.697277
# Epoch:0 Step:816 Training_loss:0.684592, Acc_avg:54.50% Training_loss_avg:0.697706
# Epoch:0 Step:824 Training_loss:0.655563, Acc_avg:55.75% Training_loss_avg:0.696049
# Epoch:0 Step:832 Training_loss:0.684246, Acc_avg:55.25% Training_loss_avg:0.696925
# Epoch:0 Step:840 Training_loss:0.735103, Acc_avg:54.75% Training_loss_avg:0.698342
# Epoch:0 Step:848 Training_loss:0.687743, Acc_avg:53.50% Training_loss_avg:0.699747
# Epoch:0 Step:856 Training_loss:0.721380, Acc_avg:53.25% Training_loss_avg:0.699807
# Epoch:0 Step:864 Training_loss:0.660185, Acc_avg:53.75% Training_loss_avg:0.698550
# Epoch:0 Step:872 Training_loss:0.740884, Acc_avg:53.75% Training_loss_avg:0.698045
# Epoch:0 Step:880 Training_loss:0.635847, Acc_avg:54.25% Training_loss_avg:0.697434
# Epoch:0 Step:888 Training_loss:0.659666, Acc_avg:54.25% Training_loss_avg:0.696604
# Epoch:0 Step:896 Training_loss:0.718018, Acc_avg:54.00% Training_loss_avg:0.696581
# Epoch:0 Step:904 Training_loss:0.679792, Acc_avg:54.50% Training_loss_avg:0.694584
# Epoch:0 Step:912 Training_loss:0.670392, Acc_avg:55.25% Training_loss_avg:0.692571
# Epoch:0 Step:920 Training_loss:0.742091, Acc_avg:55.00% Training_loss_avg:0.693093
# Epoch:0 Step:928 Training_loss:0.688377, Acc_avg:55.25% Training_loss_avg:0.692501
# Epoch:0 Step:936 Training_loss:0.647109, Acc_avg:55.50% Training_loss_avg:0.691527
# Epoch:0 Step:944 Training_loss:0.663157, Acc_avg:56.25% Training_loss_avg:0.690102
# Epoch:0 Step:952 Training_loss:0.618769, Acc_avg:57.00% Training_loss_avg:0.688014
# Epoch:0 Step:960 Training_loss:0.659057, Acc_avg:57.00% Training_loss_avg:0.687387
# Epoch:0 Step:968 Training_loss:0.676336, Acc_avg:56.50% Training_loss_avg:0.687864
# Epoch:0 Step:976 Training_loss:0.749049, Acc_avg:55.50% Training_loss_avg:0.688729
# Epoch:0 Step:984 Training_loss:0.730390, Acc_avg:55.25% Training_loss_avg:0.688988
# Epoch:0 Step:992 Training_loss:0.763948, Acc_avg:54.50% Training_loss_avg:0.691176
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:992 Val_loss:0.690323, Val_Acc_avg:54.25%
# Epoch:0 Step:1000 Training_loss:0.704868, Acc_avg:54.25% Training_loss_avg:0.691205
# Epoch:0 Step:1008 Training_loss:0.760311, Acc_avg:53.75% Training_loss_avg:0.692949
# Epoch:0 Step:1016 Training_loss:0.663617, Acc_avg:54.00% Training_loss_avg:0.692022
# Epoch:0 Step:1024 Training_loss:0.626859, Acc_avg:55.00% Training_loss_avg:0.689958
# Epoch:0 Step:1032 Training_loss:0.701577, Acc_avg:54.75% Training_loss_avg:0.690682
# Epoch:0 Step:1040 Training_loss:0.684964, Acc_avg:54.50% Training_loss_avg:0.691293
# Epoch:0 Step:1048 Training_loss:0.785079, Acc_avg:53.50% Training_loss_avg:0.693707
# Epoch:0 Step:1056 Training_loss:0.796933, Acc_avg:53.00% Training_loss_avg:0.695165
# Epoch:0 Step:1064 Training_loss:0.638338, Acc_avg:53.75% Training_loss_avg:0.693453
# Epoch:0 Step:1072 Training_loss:0.676239, Acc_avg:53.50% Training_loss_avg:0.692786
# Epoch:0 Step:1080 Training_loss:0.735108, Acc_avg:52.75% Training_loss_avg:0.694273
# Epoch:0 Step:1088 Training_loss:0.686658, Acc_avg:52.50% Training_loss_avg:0.693765
# Epoch:0 Step:1096 Training_loss:0.713477, Acc_avg:52.50% Training_loss_avg:0.693129
# Epoch:0 Step:1104 Training_loss:0.693382, Acc_avg:52.50% Training_loss_avg:0.693406
# Epoch:0 Step:1112 Training_loss:0.683532, Acc_avg:52.50% Training_loss_avg:0.692941
# Epoch:0 Step:1120 Training_loss:0.714411, Acc_avg:51.75% Training_loss_avg:0.694630
# Epoch:0 Step:1128 Training_loss:0.763603, Acc_avg:51.75% Training_loss_avg:0.695768
# Epoch:0 Step:1136 Training_loss:0.651477, Acc_avg:51.75% Training_loss_avg:0.695889
# Epoch:0 Step:1144 Training_loss:0.714077, Acc_avg:51.25% Training_loss_avg:0.697151
# Epoch:0 Step:1152 Training_loss:0.681611, Acc_avg:51.25% Training_loss_avg:0.697025
# Epoch:0 Step:1160 Training_loss:0.705450, Acc_avg:51.00% Training_loss_avg:0.697625
# Epoch:0 Step:1168 Training_loss:0.684031, Acc_avg:50.50% Training_loss_avg:0.698150
# Epoch:0 Step:1176 Training_loss:0.716574, Acc_avg:51.00% Training_loss_avg:0.696869
# Epoch:0 Step:1184 Training_loss:0.684839, Acc_avg:51.25% Training_loss_avg:0.695782
# Epoch:0 Step:1192 Training_loss:0.734735, Acc_avg:51.00% Training_loss_avg:0.696587
# Epoch:0 Step:1200 Training_loss:0.696767, Acc_avg:50.75% Training_loss_avg:0.697106
# Epoch:0 Step:1208 Training_loss:0.705919, Acc_avg:50.25% Training_loss_avg:0.697523
# Epoch:0 Step:1216 Training_loss:0.677897, Acc_avg:50.25% Training_loss_avg:0.697389
# Epoch:0 Step:1224 Training_loss:0.683727, Acc_avg:49.75% Training_loss_avg:0.697952
# Epoch:0 Step:1232 Training_loss:0.688717, Acc_avg:49.75% Training_loss_avg:0.698041
# Epoch:0 Step:1240 Training_loss:0.718756, Acc_avg:49.25% Training_loss_avg:0.697714
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:1240 Val_loss:0.689286, Val_Acc_avg:55.00%
# Epoch:0 Step:1248 Training_loss:0.687899, Acc_avg:49.50% Training_loss_avg:0.697718
# Epoch:0 Step:1256 Training_loss:0.753435, Acc_avg:49.25% Training_loss_avg:0.698359
# Epoch:0 Step:1264 Training_loss:0.668964, Acc_avg:49.00% Training_loss_avg:0.698534
# Epoch:0 Step:1272 Training_loss:0.666846, Acc_avg:49.50% Training_loss_avg:0.697053
# Epoch:0 Step:1280 Training_loss:0.640887, Acc_avg:49.75% Training_loss_avg:0.697154
# Epoch:0 Step:1288 Training_loss:0.672051, Acc_avg:49.75% Training_loss_avg:0.697402
# Epoch:0 Step:1296 Training_loss:0.680093, Acc_avg:49.75% Training_loss_avg:0.696643
# Epoch:0 Step:1304 Training_loss:0.671291, Acc_avg:49.75% Training_loss_avg:0.696473
# Epoch:0 Step:1312 Training_loss:0.690046, Acc_avg:49.00% Training_loss_avg:0.696867
# Epoch:0 Step:1320 Training_loss:0.671963, Acc_avg:49.25% Training_loss_avg:0.695464
# Epoch:0 Step:1328 Training_loss:0.692886, Acc_avg:49.25% Training_loss_avg:0.695554
# Epoch:0 Step:1336 Training_loss:0.672374, Acc_avg:49.25% Training_loss_avg:0.696059
# Epoch:0 Step:1344 Training_loss:0.663047, Acc_avg:49.00% Training_loss_avg:0.696057
# Epoch:0 Step:1352 Training_loss:0.706969, Acc_avg:48.00% Training_loss_avg:0.697821
# Epoch:0 Step:1360 Training_loss:0.707247, Acc_avg:47.75% Training_loss_avg:0.698785
# Epoch:0 Step:1368 Training_loss:0.707068, Acc_avg:47.25% Training_loss_avg:0.699400
# Epoch:0 Step:1376 Training_loss:0.670006, Acc_avg:48.00% Training_loss_avg:0.697819
# Epoch:0 Step:1384 Training_loss:0.713686, Acc_avg:48.25% Training_loss_avg:0.697485
# Epoch:0 Step:1392 Training_loss:0.743718, Acc_avg:47.75% Training_loss_avg:0.697080
# Epoch:0 Step:1400 Training_loss:0.733524, Acc_avg:48.00% Training_loss_avg:0.697653
# Epoch:0 Step:1408 Training_loss:0.704719, Acc_avg:48.25% Training_loss_avg:0.696541
# Epoch:0 Step:1416 Training_loss:0.672086, Acc_avg:48.50% Training_loss_avg:0.696711
# Epoch:0 Step:1424 Training_loss:0.678581, Acc_avg:48.25% Training_loss_avg:0.697745
# Epoch:0 Step:1432 Training_loss:0.719025, Acc_avg:48.25% Training_loss_avg:0.698094
# Epoch:0 Step:1440 Training_loss:0.725401, Acc_avg:48.25% Training_loss_avg:0.698903
# Epoch:0 Step:1448 Training_loss:0.680880, Acc_avg:49.50% Training_loss_avg:0.696819
# Epoch:0 Step:1456 Training_loss:0.679538, Acc_avg:50.25% Training_loss_avg:0.694471
# Epoch:0 Step:1464 Training_loss:0.742161, Acc_avg:49.50% Training_loss_avg:0.696548
# Epoch:0 Step:1472 Training_loss:0.695986, Acc_avg:49.75% Training_loss_avg:0.696943
# Epoch:0 Step:1480 Training_loss:0.644521, Acc_avg:50.50% Training_loss_avg:0.695131
# Epoch:0 Step:1488 Training_loss:0.744235, Acc_avg:50.00% Training_loss_avg:0.696282
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1488 Val_loss:0.692307, Val_Acc_avg:50.00%
# Epoch:0 Step:1496 Training_loss:0.662567, Acc_avg:50.75% Training_loss_avg:0.695264
# Epoch:0 Step:1504 Training_loss:0.636968, Acc_avg:51.50% Training_loss_avg:0.694136
# Epoch:0 Step:1512 Training_loss:0.659263, Acc_avg:52.00% Training_loss_avg:0.693650
# Epoch:0 Step:1520 Training_loss:0.719982, Acc_avg:52.00% Training_loss_avg:0.693762
# Epoch:0 Step:1528 Training_loss:0.660740, Acc_avg:52.25% Training_loss_avg:0.691705
# Epoch:0 Step:1536 Training_loss:0.765842, Acc_avg:51.25% Training_loss_avg:0.693992
# Epoch:0 Step:1544 Training_loss:0.736984, Acc_avg:51.25% Training_loss_avg:0.694450
# Epoch:0 Step:1552 Training_loss:0.713422, Acc_avg:50.75% Training_loss_avg:0.695086
# Epoch:0 Step:1560 Training_loss:0.748109, Acc_avg:50.75% Training_loss_avg:0.695939
# Epoch:0 Step:1568 Training_loss:0.738721, Acc_avg:50.75% Training_loss_avg:0.697033
# Epoch:0 Step:1576 Training_loss:0.714442, Acc_avg:51.00% Training_loss_avg:0.696991
# Epoch:0 Step:1584 Training_loss:0.684199, Acc_avg:50.75% Training_loss_avg:0.696978
# Epoch:0 Step:1592 Training_loss:0.687607, Acc_avg:51.25% Training_loss_avg:0.696035
# Epoch:0 Step:1600 Training_loss:0.673058, Acc_avg:51.25% Training_loss_avg:0.695561
# Epoch:0 Step:1608 Training_loss:0.670626, Acc_avg:51.75% Training_loss_avg:0.694855
# Epoch:0 Step:1616 Training_loss:0.689091, Acc_avg:52.00% Training_loss_avg:0.695079
# Epoch:0 Step:1624 Training_loss:0.728754, Acc_avg:52.00% Training_loss_avg:0.695980
# Epoch:0 Step:1632 Training_loss:0.751658, Acc_avg:51.25% Training_loss_avg:0.697238
# Epoch:0 Step:1640 Training_loss:0.663455, Acc_avg:52.25% Training_loss_avg:0.696132
# Epoch:0 Step:1648 Training_loss:0.664396, Acc_avg:53.00% Training_loss_avg:0.695662
# Epoch:0 Step:1656 Training_loss:0.736038, Acc_avg:53.00% Training_loss_avg:0.695314
# Epoch:0 Step:1664 Training_loss:0.704313, Acc_avg:52.75% Training_loss_avg:0.696021
# Epoch:0 Step:1672 Training_loss:0.669802, Acc_avg:52.50% Training_loss_avg:0.696081
# Epoch:0 Step:1680 Training_loss:0.632443, Acc_avg:52.00% Training_loss_avg:0.695912
# Epoch:0 Step:1688 Training_loss:0.594507, Acc_avg:52.75% Training_loss_avg:0.694361
# Epoch:0 Step:1696 Training_loss:0.713359, Acc_avg:53.00% Training_loss_avg:0.695026
# Epoch:0 Step:1704 Training_loss:0.656519, Acc_avg:53.25% Training_loss_avg:0.694731
# Epoch:0 Step:1712 Training_loss:0.709342, Acc_avg:53.50% Training_loss_avg:0.695117
# Epoch:0 Step:1720 Training_loss:0.692801, Acc_avg:53.75% Training_loss_avg:0.695533
# Epoch:0 Step:1728 Training_loss:0.772296, Acc_avg:53.50% Training_loss_avg:0.697122
# Epoch:0 Step:1736 Training_loss:0.747919, Acc_avg:52.75% Training_loss_avg:0.698632
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1736 Val_loss:0.693396, Val_Acc_avg:54.25%
# Epoch:0 Step:1744 Training_loss:0.732753, Acc_avg:52.25% Training_loss_avg:0.700027
# Epoch:0 Step:1752 Training_loss:0.668196, Acc_avg:52.75% Training_loss_avg:0.699251
# Epoch:0 Step:1760 Training_loss:0.681245, Acc_avg:53.00% Training_loss_avg:0.698731
# Epoch:0 Step:1768 Training_loss:0.724025, Acc_avg:53.00% Training_loss_avg:0.699070
# Epoch:0 Step:1776 Training_loss:0.656047, Acc_avg:53.00% Training_loss_avg:0.698791
# Epoch:0 Step:1784 Training_loss:0.618944, Acc_avg:53.25% Training_loss_avg:0.696896
# Epoch:0 Step:1792 Training_loss:0.664094, Acc_avg:53.75% Training_loss_avg:0.695304
# Epoch:0 Step:1800 Training_loss:0.656349, Acc_avg:53.75% Training_loss_avg:0.693760
# Epoch:0 Step:1808 Training_loss:0.687555, Acc_avg:54.00% Training_loss_avg:0.693417
# Epoch:0 Step:1816 Training_loss:0.580544, Acc_avg:54.00% Training_loss_avg:0.691586
# Epoch:0 Step:1824 Training_loss:0.732315, Acc_avg:53.50% Training_loss_avg:0.692661
# Epoch:0 Step:1832 Training_loss:0.619497, Acc_avg:54.00% Training_loss_avg:0.690670
# Epoch:0 Step:1840 Training_loss:0.759416, Acc_avg:54.00% Training_loss_avg:0.691350
# Epoch:0 Step:1848 Training_loss:0.620920, Acc_avg:54.00% Training_loss_avg:0.690151
# Epoch:0 Step:1856 Training_loss:0.609182, Acc_avg:54.25% Training_loss_avg:0.688744
# Epoch:0 Step:1864 Training_loss:0.663757, Acc_avg:54.75% Training_loss_avg:0.687176
# Epoch:0 Step:1872 Training_loss:0.624654, Acc_avg:55.00% Training_loss_avg:0.685749
# Epoch:0 Step:1880 Training_loss:0.626009, Acc_avg:55.00% Training_loss_avg:0.685379
# Epoch:0 Step:1888 Training_loss:0.672718, Acc_avg:55.75% Training_loss_avg:0.683949
# Epoch:0 Step:1896 Training_loss:0.702720, Acc_avg:55.25% Training_loss_avg:0.684752
# Epoch:0 Step:1904 Training_loss:0.649967, Acc_avg:54.75% Training_loss_avg:0.685012
# Epoch:0 Step:1912 Training_loss:0.671410, Acc_avg:54.75% Training_loss_avg:0.685255
# Epoch:0 Step:1920 Training_loss:0.702830, Acc_avg:55.00% Training_loss_avg:0.684912
# Epoch:0 Step:1928 Training_loss:0.711058, Acc_avg:55.00% Training_loss_avg:0.685918
# Epoch:0 Step:1936 Training_loss:0.585734, Acc_avg:56.25% Training_loss_avg:0.682316
# Epoch:0 Step:1944 Training_loss:0.705230, Acc_avg:56.50% Training_loss_avg:0.681681
# Epoch:0 Step:1952 Training_loss:0.581033, Acc_avg:57.25% Training_loss_avg:0.679033
# Epoch:0 Step:1960 Training_loss:0.709469, Acc_avg:57.25% Training_loss_avg:0.678260
# Epoch:0 Step:1968 Training_loss:0.653710, Acc_avg:57.50% Training_loss_avg:0.676560
# Epoch:0 Step:1976 Training_loss:0.731731, Acc_avg:57.50% Training_loss_avg:0.676906
# Epoch:0 Step:1984 Training_loss:0.753253, Acc_avg:57.75% Training_loss_avg:0.678287
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:1984 Val_loss:0.698229, Val_Acc_avg:54.25%
# Epoch:0 Step:1992 Training_loss:0.717185, Acc_avg:57.75% Training_loss_avg:0.678878
# Epoch:0 Step:2000 Training_loss:0.699202, Acc_avg:57.75% Training_loss_avg:0.679401
# Epoch:0 Step:2008 Training_loss:0.647020, Acc_avg:57.75% Training_loss_avg:0.678929
# Epoch:0 Step:2016 Training_loss:0.666064, Acc_avg:57.75% Training_loss_avg:0.678469
# Epoch:0 Step:2024 Training_loss:0.636378, Acc_avg:58.00% Training_loss_avg:0.676621
# Epoch:0 Step:2032 Training_loss:0.699803, Acc_avg:58.75% Training_loss_avg:0.675584
# Epoch:0 Step:2040 Training_loss:0.683920, Acc_avg:58.50% Training_loss_avg:0.675993
# Epoch:0 Step:2048 Training_loss:0.673218, Acc_avg:58.00% Training_loss_avg:0.676170
# Epoch:0 Step:2056 Training_loss:0.633516, Acc_avg:58.75% Training_loss_avg:0.674119
# Epoch:0 Step:2064 Training_loss:0.621562, Acc_avg:59.00% Training_loss_avg:0.672464
# Epoch:0 Step:2072 Training_loss:0.647833, Acc_avg:59.25% Training_loss_avg:0.672025
# Epoch:0 Step:2080 Training_loss:0.703805, Acc_avg:59.25% Training_loss_avg:0.673452
# Epoch:0 Step:2088 Training_loss:0.677708, Acc_avg:58.25% Training_loss_avg:0.675116
# Epoch:0 Step:2096 Training_loss:0.613395, Acc_avg:58.75% Training_loss_avg:0.673117
# Epoch:0 Step:2104 Training_loss:0.770720, Acc_avg:58.25% Training_loss_avg:0.675401
# Epoch:0 Step:2112 Training_loss:0.709282, Acc_avg:58.25% Training_loss_avg:0.675400
# Epoch:0 Step:2120 Training_loss:0.663692, Acc_avg:58.50% Training_loss_avg:0.674818
# Epoch:0 Step:2128 Training_loss:0.609825, Acc_avg:59.25% Training_loss_avg:0.671568
# Epoch:0 Step:2136 Training_loss:0.733340, Acc_avg:59.25% Training_loss_avg:0.671277
# Epoch:0 Step:2144 Training_loss:0.774522, Acc_avg:59.25% Training_loss_avg:0.672112
# Epoch:0 Step:2152 Training_loss:0.592217, Acc_avg:59.75% Training_loss_avg:0.670592
# Epoch:0 Step:2160 Training_loss:0.633871, Acc_avg:60.00% Training_loss_avg:0.669645
# Epoch:0 Step:2168 Training_loss:0.584806, Acc_avg:61.00% Training_loss_avg:0.666861
# Epoch:0 Step:2176 Training_loss:0.714038, Acc_avg:60.75% Training_loss_avg:0.668020
# Epoch:0 Step:2184 Training_loss:0.654580, Acc_avg:60.75% Training_loss_avg:0.668733
# Epoch:0 Step:2192 Training_loss:0.682082, Acc_avg:61.00% Training_loss_avg:0.669093
# Epoch:0 Step:2200 Training_loss:0.680775, Acc_avg:61.25% Training_loss_avg:0.669581
# Epoch:0 Step:2208 Training_loss:0.692043, Acc_avg:61.00% Training_loss_avg:0.669671
# Epoch:0 Step:2216 Training_loss:0.592726, Acc_avg:60.75% Training_loss_avg:0.669915
# Epoch:0 Step:2224 Training_loss:0.822243, Acc_avg:60.75% Training_loss_avg:0.671713
# Epoch:0 Step:2232 Training_loss:0.710921, Acc_avg:60.50% Training_loss_avg:0.673542
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2232 Val_loss:0.692016, Val_Acc_avg:54.25%
# Epoch:0 Step:2240 Training_loss:0.664030, Acc_avg:60.75% Training_loss_avg:0.671634
# Epoch:0 Step:2248 Training_loss:0.653604, Acc_avg:60.50% Training_loss_avg:0.672288
# Epoch:0 Step:2256 Training_loss:0.786957, Acc_avg:59.75% Training_loss_avg:0.675843
# Epoch:0 Step:2264 Training_loss:0.573664, Acc_avg:60.25% Training_loss_avg:0.674041
# Epoch:0 Step:2272 Training_loss:0.746483, Acc_avg:59.75% Training_loss_avg:0.676478
# Epoch:0 Step:2280 Training_loss:0.574257, Acc_avg:59.75% Training_loss_avg:0.675443
# Epoch:0 Step:2288 Training_loss:0.655523, Acc_avg:59.75% Training_loss_avg:0.675099
# Epoch:0 Step:2296 Training_loss:0.685692, Acc_avg:60.00% Training_loss_avg:0.674759
# Epoch:0 Step:2304 Training_loss:0.610059, Acc_avg:60.25% Training_loss_avg:0.673960
# Epoch:0 Step:2312 Training_loss:0.663568, Acc_avg:60.25% Training_loss_avg:0.673804
# Epoch:0 Step:2320 Training_loss:0.809603, Acc_avg:59.50% Training_loss_avg:0.675939
# Epoch:0 Step:2328 Training_loss:0.666414, Acc_avg:59.75% Training_loss_avg:0.675046
# Epoch:0 Step:2336 Training_loss:0.636611, Acc_avg:59.50% Training_loss_avg:0.676064
# Epoch:0 Step:2344 Training_loss:0.565000, Acc_avg:60.25% Training_loss_avg:0.673259
# Epoch:0 Step:2352 Training_loss:0.687076, Acc_avg:60.00% Training_loss_avg:0.675380
# Epoch:0 Step:2360 Training_loss:0.755917, Acc_avg:60.00% Training_loss_avg:0.676309
# Epoch:0 Step:2368 Training_loss:0.746133, Acc_avg:59.50% Training_loss_avg:0.678157
# Epoch:0 Step:2376 Training_loss:0.633611, Acc_avg:59.75% Training_loss_avg:0.676195
# Epoch:0 Step:2384 Training_loss:0.601339, Acc_avg:60.00% Training_loss_avg:0.673157
# Epoch:0 Step:2392 Training_loss:0.663452, Acc_avg:60.00% Training_loss_avg:0.672082
# Epoch:0 Step:2400 Training_loss:0.696734, Acc_avg:60.00% Training_loss_avg:0.672033
# Epoch:0 Step:2408 Training_loss:0.768860, Acc_avg:59.75% Training_loss_avg:0.674469
# Epoch:0 Step:2416 Training_loss:0.643720, Acc_avg:59.75% Training_loss_avg:0.674023
# Epoch:0 Step:2424 Training_loss:0.671435, Acc_avg:60.00% Training_loss_avg:0.674724
# Epoch:0 Step:2432 Training_loss:0.651469, Acc_avg:60.25% Training_loss_avg:0.673757
# Epoch:0 Step:2440 Training_loss:0.762909, Acc_avg:60.00% Training_loss_avg:0.675337
# Epoch:0 Step:2448 Training_loss:0.598182, Acc_avg:60.50% Training_loss_avg:0.673836
# Epoch:0 Step:2456 Training_loss:0.792798, Acc_avg:59.75% Training_loss_avg:0.677022
# Epoch:0 Step:2464 Training_loss:0.662435, Acc_avg:59.75% Training_loss_avg:0.677839
# Epoch:0 Step:2472 Training_loss:0.684028, Acc_avg:59.50% Training_loss_avg:0.678563
# Epoch:0 Step:2480 Training_loss:0.727959, Acc_avg:59.25% Training_loss_avg:0.679046
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:2480 Val_loss:0.686342, Val_Acc_avg:54.25%
# Epoch:0 Step:2488 Training_loss:0.769699, Acc_avg:58.75% Training_loss_avg:0.680886
# Epoch:0 Step:2496 Training_loss:0.570042, Acc_avg:58.75% Training_loss_avg:0.680019
# Epoch:0 Step:2504 Training_loss:0.683044, Acc_avg:59.25% Training_loss_avg:0.678265
# Epoch:0 Step:2512 Training_loss:0.774515, Acc_avg:58.75% Training_loss_avg:0.679570
# Epoch:0 Step:2520 Training_loss:0.779217, Acc_avg:57.75% Training_loss_avg:0.681881
# Epoch:0 Step:2528 Training_loss:0.657010, Acc_avg:57.50% Training_loss_avg:0.682824
# Epoch:0 Step:2536 Training_loss:0.690758, Acc_avg:58.00% Training_loss_avg:0.681973
# Epoch:0 Step:2544 Training_loss:0.664261, Acc_avg:58.25% Training_loss_avg:0.679767
# Epoch:0 Step:2552 Training_loss:0.689363, Acc_avg:57.50% Training_loss_avg:0.681710
# Epoch:0 Step:2560 Training_loss:0.617043, Acc_avg:57.75% Training_loss_avg:0.681374
# Epoch:0 Step:2568 Training_loss:0.772235, Acc_avg:56.50% Training_loss_avg:0.685122
# Epoch:0 Step:2576 Training_loss:0.655308, Acc_avg:56.75% Training_loss_avg:0.683948
# Epoch:0 Step:2584 Training_loss:0.697630, Acc_avg:56.50% Training_loss_avg:0.684809
# Epoch:0 Step:2592 Training_loss:0.727982, Acc_avg:56.25% Training_loss_avg:0.685727
# Epoch:0 Step:2600 Training_loss:0.626677, Acc_avg:56.50% Training_loss_avg:0.684645
# Epoch:0 Step:2608 Training_loss:0.647002, Acc_avg:56.75% Training_loss_avg:0.683744
# Epoch:0 Step:2616 Training_loss:0.701886, Acc_avg:56.25% Training_loss_avg:0.685927
# Epoch:0 Step:2624 Training_loss:0.683443, Acc_avg:56.50% Training_loss_avg:0.683151
# Epoch:0 Step:2632 Training_loss:0.586268, Acc_avg:57.00% Training_loss_avg:0.680658
# Epoch:0 Step:2640 Training_loss:0.663248, Acc_avg:57.25% Training_loss_avg:0.680642
# Epoch:0 Step:2648 Training_loss:0.578761, Acc_avg:57.75% Training_loss_avg:0.679146
# Epoch:0 Step:2656 Training_loss:0.612200, Acc_avg:58.50% Training_loss_avg:0.675650
# Epoch:0 Step:2664 Training_loss:0.681933, Acc_avg:58.00% Training_loss_avg:0.677816
# Epoch:0 Step:2672 Training_loss:0.685120, Acc_avg:58.50% Training_loss_avg:0.676589
# Epoch:0 Step:2680 Training_loss:0.773491, Acc_avg:57.50% Training_loss_avg:0.680573
# Epoch:0 Step:2688 Training_loss:0.624732, Acc_avg:57.50% Training_loss_avg:0.679957
# Epoch:0 Step:2696 Training_loss:0.657779, Acc_avg:57.50% Training_loss_avg:0.679399
# Epoch:0 Step:2704 Training_loss:0.563930, Acc_avg:57.75% Training_loss_avg:0.678477
# Epoch:0 Step:2712 Training_loss:0.639648, Acc_avg:58.00% Training_loss_avg:0.677998
# Epoch:0 Step:2720 Training_loss:0.787165, Acc_avg:58.00% Training_loss_avg:0.677549
# Epoch:0 Step:2728 Training_loss:0.762331, Acc_avg:57.50% Training_loss_avg:0.679468
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:0 Step:2728 Val_loss:0.681944, Val_Acc_avg:54.25%
# Epoch:0 Step:2736 Training_loss:0.629830, Acc_avg:57.25% Training_loss_avg:0.679332
# Epoch:0 Step:2744 Training_loss:0.721622, Acc_avg:56.50% Training_loss_avg:0.682465
# Epoch:0 Step:2752 Training_loss:0.634984, Acc_avg:56.75% Training_loss_avg:0.681423
# Epoch:0 Step:2760 Training_loss:0.695734, Acc_avg:56.50% Training_loss_avg:0.680219
# Epoch:0 Step:2768 Training_loss:0.551426, Acc_avg:57.75% Training_loss_avg:0.676325
# Epoch:0 Step:2776 Training_loss:0.655806, Acc_avg:57.75% Training_loss_avg:0.676769
# Epoch:0 Step:2784 Training_loss:0.741671, Acc_avg:57.50% Training_loss_avg:0.679575
# Epoch:0 Step:2792 Training_loss:0.661364, Acc_avg:57.75% Training_loss_avg:0.679534
# Epoch:0 Step:2800 Training_loss:0.591551, Acc_avg:58.50% Training_loss_avg:0.677430
# Epoch:0 Step:2808 Training_loss:0.651149, Acc_avg:59.00% Training_loss_avg:0.675076
# Epoch:0 Step:2816 Training_loss:0.702690, Acc_avg:58.75% Training_loss_avg:0.676255
# Epoch:0 Step:2824 Training_loss:0.634845, Acc_avg:58.50% Training_loss_avg:0.675523
# Epoch:0 Step:2832 Training_loss:0.570949, Acc_avg:59.00% Training_loss_avg:0.673913
# Epoch:0 Step:2840 Training_loss:0.694537, Acc_avg:59.00% Training_loss_avg:0.672546
# Epoch:0 Step:2848 Training_loss:0.594469, Acc_avg:58.50% Training_loss_avg:0.672471
# Epoch:0 Step:2856 Training_loss:0.712038, Acc_avg:58.75% Training_loss_avg:0.670856
# Epoch:0 Step:2864 Training_loss:0.670290, Acc_avg:58.50% Training_loss_avg:0.671013
# Epoch:0 Step:2872 Training_loss:0.664151, Acc_avg:58.75% Training_loss_avg:0.670616
# Epoch:0 Step:2880 Training_loss:0.706568, Acc_avg:58.75% Training_loss_avg:0.670188
# Epoch:0 Step:2888 Training_loss:0.780068, Acc_avg:59.00% Training_loss_avg:0.670395
# Epoch:0 Step:2896 Training_loss:0.801847, Acc_avg:58.25% Training_loss_avg:0.675031
# Epoch:0 Step:2904 Training_loss:0.702609, Acc_avg:58.00% Training_loss_avg:0.675423
# Epoch:0 Step:2912 Training_loss:0.665837, Acc_avg:58.75% Training_loss_avg:0.673249
# Epoch:0 Step:2920 Training_loss:0.762935, Acc_avg:59.00% Training_loss_avg:0.672923
# Epoch:0 Step:2928 Training_loss:0.839662, Acc_avg:58.25% Training_loss_avg:0.676577
# Epoch:0 Step:2936 Training_loss:0.752899, Acc_avg:57.75% Training_loss_avg:0.677819
# Epoch:0 Step:2944 Training_loss:0.727091, Acc_avg:58.00% Training_loss_avg:0.679076
# Epoch:0 Step:2952 Training_loss:0.618041, Acc_avg:58.50% Training_loss_avg:0.677649
# Epoch:0 Step:2960 Training_loss:0.692020, Acc_avg:57.75% Training_loss_avg:0.679149
# Epoch:0 Step:2968 Training_loss:0.692656, Acc_avg:58.25% Training_loss_avg:0.677557
# Epoch:0 Step:2976 Training_loss:0.576076, Acc_avg:58.75% Training_loss_avg:0.675973
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:0 Step:2976 Val_loss:0.676247, Val_Acc_avg:55.25%
# Epoch:0 Step:2984 Training_loss:0.604634, Acc_avg:59.25% Training_loss_avg:0.674113
# Epoch:0 Step:2992 Training_loss:0.732145, Acc_avg:59.00% Training_loss_avg:0.674196
# Epoch:0 Step:3000 Training_loss:0.649335, Acc_avg:59.00% Training_loss_avg:0.674649
# Epoch:0 Step:3008 Training_loss:0.676626, Acc_avg:58.75% Training_loss_avg:0.675242
# Epoch:0 Step:3016 Training_loss:0.648138, Acc_avg:58.75% Training_loss_avg:0.674167
# Epoch:0 Step:3024 Training_loss:0.672988, Acc_avg:59.00% Training_loss_avg:0.673958
# Epoch:0 Step:3032 Training_loss:0.657001, Acc_avg:58.25% Training_loss_avg:0.675372
# Epoch:0 Step:3040 Training_loss:0.672864, Acc_avg:57.75% Training_loss_avg:0.675565
# Epoch:0 Step:3048 Training_loss:0.677571, Acc_avg:57.50% Training_loss_avg:0.677541
# Epoch:0 Step:3056 Training_loss:0.667523, Acc_avg:57.50% Training_loss_avg:0.678647
# Epoch:0 Step:3064 Training_loss:0.653846, Acc_avg:57.50% Training_loss_avg:0.678086
# Epoch:0 Step:3072 Training_loss:0.602088, Acc_avg:58.00% Training_loss_avg:0.676425
# Epoch:0 Step:3080 Training_loss:0.743037, Acc_avg:58.50% Training_loss_avg:0.675816
# Epoch:0 Step:3088 Training_loss:0.626597, Acc_avg:58.75% Training_loss_avg:0.675853
# Epoch:0 Step:3096 Training_loss:0.776316, Acc_avg:58.00% Training_loss_avg:0.678224
# Epoch:0 Step:3104 Training_loss:0.610664, Acc_avg:57.75% Training_loss_avg:0.679159
# Epoch:0 Step:3112 Training_loss:0.669706, Acc_avg:57.25% Training_loss_avg:0.679760
# Epoch:0 Step:3120 Training_loss:0.542499, Acc_avg:58.50% Training_loss_avg:0.674867
# Epoch:0 Step:3128 Training_loss:0.630332, Acc_avg:59.25% Training_loss_avg:0.672227
# Epoch:0 Step:3136 Training_loss:0.664335, Acc_avg:59.25% Training_loss_avg:0.672917
# Epoch:0 Step:3144 Training_loss:0.630585, Acc_avg:59.50% Training_loss_avg:0.671096
# Epoch:0 Step:3152 Training_loss:0.627867, Acc_avg:59.50% Training_loss_avg:0.670954
# Epoch:0 Step:3160 Training_loss:0.573150, Acc_avg:60.25% Training_loss_avg:0.668502
# Epoch:0 Step:3168 Training_loss:0.687762, Acc_avg:59.25% Training_loss_avg:0.671229
# Epoch:0 Step:3176 Training_loss:0.758826, Acc_avg:58.75% Training_loss_avg:0.673289
# Epoch:0 Step:3184 Training_loss:0.760715, Acc_avg:58.50% Training_loss_avg:0.673670
# Epoch:0 Step:3192 Training_loss:0.782032, Acc_avg:58.25% Training_loss_avg:0.676083
# Epoch:0 Step:3200 Training_loss:0.700712, Acc_avg:57.75% Training_loss_avg:0.678266
# Epoch:0 Step:3208 Training_loss:0.583237, Acc_avg:58.00% Training_loss_avg:0.676908
# Epoch:0 Step:3216 Training_loss:0.728575, Acc_avg:58.00% Training_loss_avg:0.677426
# Epoch:0 Step:3224 Training_loss:0.641669, Acc_avg:58.00% Training_loss_avg:0.677562
# Validating:
# 52it [00:07,  6.57it/s]
# Epoch:0 Step:3224 Val_loss:0.682713, Val_Acc_avg:54.25%
# Epoch:0 Step:3232 Training_loss:0.762462, Acc_avg:57.00% Training_loss_avg:0.681393
# Epoch:0 Step:3240 Training_loss:0.783243, Acc_avg:56.75% Training_loss_avg:0.683167
# Epoch:0 Step:3248 Training_loss:0.658195, Acc_avg:56.50% Training_loss_avg:0.684441
# Epoch:0 Step:3256 Training_loss:0.675787, Acc_avg:57.00% Training_loss_avg:0.683716
# Epoch:0 Step:3264 Training_loss:0.760467, Acc_avg:56.75% Training_loss_avg:0.685520
# Epoch:0 Step:3272 Training_loss:0.892978, Acc_avg:55.50% Training_loss_avg:0.690096
# Epoch:0 Step:3280 Training_loss:0.660688, Acc_avg:56.00% Training_loss_avg:0.689179
# Epoch:0 Step:3288 Training_loss:0.629079, Acc_avg:56.75% Training_loss_avg:0.686159
# Epoch:0 Step:3296 Training_loss:0.712955, Acc_avg:56.75% Training_loss_avg:0.684381
# Epoch:0 Step:3304 Training_loss:0.734077, Acc_avg:56.25% Training_loss_avg:0.685011
# Epoch:0 Step:3312 Training_loss:0.654644, Acc_avg:56.25% Training_loss_avg:0.684787
# Epoch:0 Step:3320 Training_loss:0.639662, Acc_avg:56.75% Training_loss_avg:0.682321
# Epoch:0 Step:3328 Training_loss:0.777090, Acc_avg:56.25% Training_loss_avg:0.681070
# Epoch:1 Step:0 Training_loss:0.651894, Acc_avg:57.00% Training_loss_avg:0.679050
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:1 Step:0 Val_loss:0.670451, Val_Acc_avg:60.00%
# Epoch:1 Step:8 Training_loss:0.762153, Acc_avg:56.00% Training_loss_avg:0.679751
# Epoch:1 Step:16 Training_loss:0.649430, Acc_avg:55.75% Training_loss_avg:0.680379
# Epoch:1 Step:24 Training_loss:0.700613, Acc_avg:55.50% Training_loss_avg:0.680551
# Epoch:1 Step:32 Training_loss:0.694600, Acc_avg:55.50% Training_loss_avg:0.680589
# Epoch:1 Step:40 Training_loss:0.712103, Acc_avg:54.75% Training_loss_avg:0.683310
# Epoch:1 Step:48 Training_loss:0.676327, Acc_avg:54.75% Training_loss_avg:0.684744
# Epoch:1 Step:56 Training_loss:0.733625, Acc_avg:55.00% Training_loss_avg:0.684773
# Epoch:1 Step:64 Training_loss:0.681229, Acc_avg:54.75% Training_loss_avg:0.685411
# Epoch:1 Step:72 Training_loss:0.659606, Acc_avg:55.25% Training_loss_avg:0.685071
# Epoch:1 Step:80 Training_loss:0.719031, Acc_avg:55.00% Training_loss_avg:0.686489
# Epoch:1 Step:88 Training_loss:0.711947, Acc_avg:55.00% Training_loss_avg:0.687268
# Epoch:1 Step:96 Training_loss:0.693179, Acc_avg:55.00% Training_loss_avg:0.687991
# Epoch:1 Step:104 Training_loss:0.699460, Acc_avg:55.00% Training_loss_avg:0.688523
# Epoch:1 Step:112 Training_loss:0.661387, Acc_avg:54.50% Training_loss_avg:0.688200
# Epoch:1 Step:120 Training_loss:0.680328, Acc_avg:54.00% Training_loss_avg:0.688456
# Epoch:1 Step:128 Training_loss:0.617655, Acc_avg:54.25% Training_loss_avg:0.687732
# Epoch:1 Step:136 Training_loss:0.694907, Acc_avg:53.50% Training_loss_avg:0.689588
# Epoch:1 Step:144 Training_loss:0.646489, Acc_avg:54.25% Training_loss_avg:0.687657
# Epoch:1 Step:152 Training_loss:0.701566, Acc_avg:53.75% Training_loss_avg:0.689157
# Epoch:1 Step:160 Training_loss:0.629491, Acc_avg:54.75% Training_loss_avg:0.686220
# Epoch:1 Step:168 Training_loss:0.646655, Acc_avg:54.50% Training_loss_avg:0.686940
# Epoch:1 Step:176 Training_loss:0.731497, Acc_avg:54.00% Training_loss_avg:0.688176
# Epoch:1 Step:184 Training_loss:0.681352, Acc_avg:53.50% Training_loss_avg:0.690953
# Epoch:1 Step:192 Training_loss:0.709921, Acc_avg:52.75% Training_loss_avg:0.692545
# Epoch:1 Step:200 Training_loss:0.759925, Acc_avg:52.00% Training_loss_avg:0.694457
# Epoch:1 Step:208 Training_loss:0.711289, Acc_avg:51.50% Training_loss_avg:0.696071
# Epoch:1 Step:216 Training_loss:0.705638, Acc_avg:51.25% Training_loss_avg:0.697626
# Epoch:1 Step:224 Training_loss:0.667677, Acc_avg:50.75% Training_loss_avg:0.699517
# Epoch:1 Step:232 Training_loss:0.763040, Acc_avg:50.25% Training_loss_avg:0.701022
# Epoch:1 Step:240 Training_loss:0.640125, Acc_avg:51.00% Training_loss_avg:0.698648
# Epoch:1 Step:248 Training_loss:0.704990, Acc_avg:51.50% Training_loss_avg:0.697534
# Validating:
# 52it [00:07,  6.58it/s]
# Epoch:1 Step:248 Val_loss:0.671532, Val_Acc_avg:56.75%
# Epoch:1 Step:256 Training_loss:0.641922, Acc_avg:51.75% Training_loss_avg:0.694731
# Epoch:1 Step:264 Training_loss:0.751185, Acc_avg:51.50% Training_loss_avg:0.695741
# Epoch:1 Step:272 Training_loss:0.631033, Acc_avg:51.50% Training_loss_avg:0.696697
# Epoch:1 Step:280 Training_loss:0.671111, Acc_avg:51.50% Training_loss_avg:0.695548
# Epoch:1 Step:288 Training_loss:0.669972, Acc_avg:51.50% Training_loss_avg:0.696114
# Epoch:1 Step:296 Training_loss:0.605534, Acc_avg:52.50% Training_loss_avg:0.692975
# Epoch:1 Step:304 Training_loss:0.619874, Acc_avg:52.75% Training_loss_avg:0.689708
# Epoch:1 Step:312 Training_loss:0.713186, Acc_avg:52.75% Training_loss_avg:0.690807
# Epoch:1 Step:320 Training_loss:0.655328, Acc_avg:52.75% Training_loss_avg:0.690398
# Epoch:1 Step:328 Training_loss:0.656796, Acc_avg:53.25% Training_loss_avg:0.688325
# Epoch:1 Step:336 Training_loss:0.633863, Acc_avg:54.25% Training_loss_avg:0.683143
# Epoch:1 Step:344 Training_loss:0.704142, Acc_avg:53.50% Training_loss_avg:0.684012
# Epoch:1 Step:352 Training_loss:0.693701, Acc_avg:52.75% Training_loss_avg:0.685304
# Epoch:1 Step:360 Training_loss:0.687590, Acc_avg:53.00% Training_loss_avg:0.684797
# Epoch:1 Step:368 Training_loss:0.679997, Acc_avg:53.50% Training_loss_avg:0.683715
# Epoch:1 Step:376 Training_loss:0.651498, Acc_avg:53.25% Training_loss_avg:0.683652
# Epoch:1 Step:384 Training_loss:0.671647, Acc_avg:53.50% Training_loss_avg:0.684292
# Epoch:1 Step:392 Training_loss:0.651311, Acc_avg:54.75% Training_loss_avg:0.681776
# Epoch:1 Step:400 Training_loss:0.676032, Acc_avg:54.25% Training_loss_avg:0.682259
# Epoch:1 Step:408 Training_loss:0.611610, Acc_avg:55.25% Training_loss_avg:0.679248
# Epoch:1 Step:416 Training_loss:0.633602, Acc_avg:55.25% Training_loss_avg:0.678932
# Epoch:1 Step:424 Training_loss:0.693425, Acc_avg:55.75% Training_loss_avg:0.678788
# Epoch:1 Step:432 Training_loss:0.737612, Acc_avg:55.75% Training_loss_avg:0.679648
# Epoch:1 Step:440 Training_loss:0.698826, Acc_avg:55.75% Training_loss_avg:0.679383
# Epoch:1 Step:448 Training_loss:0.763049, Acc_avg:55.25% Training_loss_avg:0.681117
# Epoch:1 Step:456 Training_loss:0.784034, Acc_avg:55.25% Training_loss_avg:0.682125
# Epoch:1 Step:464 Training_loss:0.692462, Acc_avg:55.00% Training_loss_avg:0.682350
# Epoch:1 Step:472 Training_loss:0.732601, Acc_avg:54.25% Training_loss_avg:0.683810
# Epoch:1 Step:480 Training_loss:0.620976, Acc_avg:55.00% Training_loss_avg:0.681849
# Epoch:1 Step:488 Training_loss:0.678877, Acc_avg:55.00% Training_loss_avg:0.681187
# Epoch:1 Step:496 Training_loss:0.671418, Acc_avg:54.75% Training_loss_avg:0.680752
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:1 Step:496 Val_loss:0.665729, Val_Acc_avg:60.00%
# Epoch:1 Step:504 Training_loss:0.626830, Acc_avg:55.00% Training_loss_avg:0.679300
# Epoch:1 Step:512 Training_loss:0.746700, Acc_avg:54.75% Training_loss_avg:0.681006
# Epoch:1 Step:520 Training_loss:0.709882, Acc_avg:54.75% Training_loss_avg:0.681597
# Epoch:1 Step:528 Training_loss:0.733729, Acc_avg:54.00% Training_loss_avg:0.683918
# Epoch:1 Step:536 Training_loss:0.701561, Acc_avg:53.75% Training_loss_avg:0.684051
# Epoch:1 Step:544 Training_loss:0.683487, Acc_avg:53.25% Training_loss_avg:0.684791
# Epoch:1 Step:552 Training_loss:0.682271, Acc_avg:53.25% Training_loss_avg:0.684405
# Epoch:1 Step:560 Training_loss:0.635309, Acc_avg:53.25% Training_loss_avg:0.684522
# Epoch:1 Step:568 Training_loss:0.638315, Acc_avg:53.50% Training_loss_avg:0.684355
# Epoch:1 Step:576 Training_loss:0.703765, Acc_avg:53.50% Training_loss_avg:0.683800
# Epoch:1 Step:584 Training_loss:0.665943, Acc_avg:53.00% Training_loss_avg:0.683492
# Epoch:1 Step:592 Training_loss:0.686822, Acc_avg:53.50% Training_loss_avg:0.683030
# Epoch:1 Step:600 Training_loss:0.602114, Acc_avg:54.25% Training_loss_avg:0.679874
# Epoch:1 Step:608 Training_loss:0.796130, Acc_avg:54.00% Training_loss_avg:0.681571
# Epoch:1 Step:616 Training_loss:0.727051, Acc_avg:53.75% Training_loss_avg:0.681999
# Epoch:1 Step:624 Training_loss:0.650769, Acc_avg:54.50% Training_loss_avg:0.681661
# Epoch:1 Step:632 Training_loss:0.802573, Acc_avg:54.50% Training_loss_avg:0.682452
# Epoch:1 Step:640 Training_loss:0.743973, Acc_avg:53.50% Training_loss_avg:0.684529
# Epoch:1 Step:648 Training_loss:0.647944, Acc_avg:53.75% Training_loss_avg:0.683388
# Epoch:1 Step:656 Training_loss:0.647287, Acc_avg:53.75% Training_loss_avg:0.683495
# Epoch:1 Step:664 Training_loss:0.679942, Acc_avg:53.75% Training_loss_avg:0.682070
# Epoch:1 Step:672 Training_loss:0.629765, Acc_avg:53.75% Training_loss_avg:0.682045
# Epoch:1 Step:680 Training_loss:0.713370, Acc_avg:53.75% Training_loss_avg:0.682890
# Epoch:1 Step:688 Training_loss:0.710082, Acc_avg:53.75% Training_loss_avg:0.683692
# Epoch:1 Step:696 Training_loss:0.641907, Acc_avg:53.25% Training_loss_avg:0.684420
# Epoch:1 Step:704 Training_loss:0.633885, Acc_avg:53.75% Training_loss_avg:0.684700
# Epoch:1 Step:712 Training_loss:0.654986, Acc_avg:54.00% Training_loss_avg:0.683536
# Epoch:1 Step:720 Training_loss:0.727195, Acc_avg:53.75% Training_loss_avg:0.684973
# Epoch:1 Step:728 Training_loss:0.692121, Acc_avg:53.50% Training_loss_avg:0.685680
# Epoch:1 Step:736 Training_loss:0.664659, Acc_avg:54.00% Training_loss_avg:0.686296
# Epoch:1 Step:744 Training_loss:0.680926, Acc_avg:54.50% Training_loss_avg:0.685831
# Validating:
# 52it [00:07,  6.59it/s]
# Epoch:1 Step:744 Val_loss:0.665088, Val_Acc_avg:59.50%
# Epoch:1 Step:752 Training_loss:0.643999, Acc_avg:54.75% Training_loss_avg:0.684837
# Epoch:1 Step:760 Training_loss:0.688733, Acc_avg:54.75% Training_loss_avg:0.684860
# Epoch:1 Step:768 Training_loss:0.579722, Acc_avg:55.25% Training_loss_avg:0.682855
# Epoch:1 Step:776 Training_loss:0.729722, Acc_avg:54.75% Training_loss_avg:0.684419
# Epoch:1 Step:784 Training_loss:0.615396, Acc_avg:54.75% Training_loss_avg:0.683294
# Epoch:1 Step:792 Training_loss:0.674422, Acc_avg:54.50% Training_loss_avg:0.683756
# Epoch:1 Step:800 Training_loss:0.667595, Acc_avg:54.25% Training_loss_avg:0.683587
# Epoch:1 Step:808 Training_loss:0.597201, Acc_avg:54.75% Training_loss_avg:0.683299
# Epoch:1 Step:816 Training_loss:0.583679, Acc_avg:55.00% Training_loss_avg:0.682301
# Epoch:1 Step:824 Training_loss:0.592321, Acc_avg:55.00% Training_loss_avg:0.680279
# Epoch:1 Step:832 Training_loss:0.569303, Acc_avg:55.75% Training_loss_avg:0.676913
# Epoch:1 Step:840 Training_loss:0.757449, Acc_avg:55.75% Training_loss_avg:0.678085
# Epoch:1 Step:848 Training_loss:0.627085, Acc_avg:56.00% Training_loss_avg:0.675366
# Epoch:1 Step:856 Training_loss:0.789307, Acc_avg:55.75% Training_loss_avg:0.675471
# Epoch:1 Step:864 Training_loss:0.666706, Acc_avg:56.00% Training_loss_avg:0.674956
# Epoch:1 Step:872 Training_loss:0.626248, Acc_avg:56.75% Training_loss_avg:0.672829
# Epoch:1 Step:880 Training_loss:0.742782, Acc_avg:55.75% Training_loss_avg:0.675265
# ...
# Epoch:4 Step:1872 Training_loss:0.662506, Acc_avg:67.75% Training_loss_avg:0.574520
# Epoch:4 Step:1880 Training_loss:0.591137, Acc_avg:67.50% Training_loss_avg:0.576896
# Epoch:4 Step:1888 Training_loss:0.551500, Acc_avg:67.25% Training_loss_avg:0.577464
# Epoch:4 Step:1896 Training_loss:0.582965, Acc_avg:67.00% Training_loss_avg:0.577483
# Epoch:4 Step:1904 Training_loss:0.689423, Acc_avg:67.00% Training_loss_avg:0.580460
# Epoch:4 Step:1912 Training_loss:0.465565, Acc_avg:67.75% Training_loss_avg:0.579816
# Epoch:4 Step:1920 Training_loss:0.608575, Acc_avg:67.50% Training_loss_avg:0.580696
# Epoch:4 Step:1928 Training_loss:0.659543, Acc_avg:67.50% Training_loss_avg:0.580324
# Epoch:4 Step:1936 Training_loss:0.601506, Acc_avg:67.75% Training_loss_avg:0.580296
# Epoch:4 Step:1944 Training_loss:0.638602, Acc_avg:67.50% Training_loss_avg:0.583147
# Epoch:4 Step:1952 Training_loss:0.523582, Acc_avg:67.00% Training_loss_avg:0.585664
# Epoch:4 Step:1960 Training_loss:0.601845, Acc_avg:67.25% Training_loss_avg:0.583936
# Epoch:4 Step:1968 Training_loss:0.656533, Acc_avg:67.50% Training_loss_avg:0.581128
# Epoch:4 Step:1976 Training_loss:0.626469, Acc_avg:67.25% Training_loss_avg:0.583479
# Epoch:4 Step:1984 Training_loss:0.491758, Acc_avg:67.50% Training_loss_avg:0.581868
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:1984 Val_loss:0.598995, Val_Acc_avg:65.00%
# Epoch:4 Step:1992 Training_loss:0.467304, Acc_avg:67.00% Training_loss_avg:0.587400
# Epoch:4 Step:2000 Training_loss:0.388438, Acc_avg:66.75% Training_loss_avg:0.588253
# Epoch:4 Step:2008 Training_loss:0.506624, Acc_avg:67.50% Training_loss_avg:0.582989
# Epoch:4 Step:2016 Training_loss:0.538349, Acc_avg:67.75% Training_loss_avg:0.581183
# Epoch:4 Step:2024 Training_loss:0.603880, Acc_avg:67.75% Training_loss_avg:0.580733
# Epoch:4 Step:2032 Training_loss:0.374009, Acc_avg:68.25% Training_loss_avg:0.577851
# Epoch:4 Step:2040 Training_loss:0.697298, Acc_avg:68.25% Training_loss_avg:0.580994
# Epoch:4 Step:2048 Training_loss:0.784366, Acc_avg:67.50% Training_loss_avg:0.584646
# Epoch:4 Step:2056 Training_loss:0.506725, Acc_avg:68.00% Training_loss_avg:0.583594
# Epoch:4 Step:2064 Training_loss:0.617442, Acc_avg:67.75% Training_loss_avg:0.584871
# Epoch:4 Step:2072 Training_loss:0.544316, Acc_avg:67.75% Training_loss_avg:0.584154
# Epoch:4 Step:2080 Training_loss:0.556199, Acc_avg:67.50% Training_loss_avg:0.584372
# Epoch:4 Step:2088 Training_loss:0.548449, Acc_avg:67.25% Training_loss_avg:0.584033
# Epoch:4 Step:2096 Training_loss:0.489917, Acc_avg:67.25% Training_loss_avg:0.583160
# Epoch:4 Step:2104 Training_loss:0.720652, Acc_avg:67.25% Training_loss_avg:0.582870
# Epoch:4 Step:2112 Training_loss:0.493601, Acc_avg:68.00% Training_loss_avg:0.579385
# Epoch:4 Step:2120 Training_loss:0.486634, Acc_avg:68.75% Training_loss_avg:0.570024
# Epoch:4 Step:2128 Training_loss:0.406957, Acc_avg:69.25% Training_loss_avg:0.569260
# Epoch:4 Step:2136 Training_loss:0.411044, Acc_avg:69.25% Training_loss_avg:0.565668
# Epoch:4 Step:2144 Training_loss:0.421719, Acc_avg:70.50% Training_loss_avg:0.557188
# Epoch:4 Step:2152 Training_loss:0.464768, Acc_avg:71.25% Training_loss_avg:0.551857
# Epoch:4 Step:2160 Training_loss:0.778871, Acc_avg:70.75% Training_loss_avg:0.555535
# Epoch:4 Step:2168 Training_loss:0.644353, Acc_avg:70.25% Training_loss_avg:0.562150
# Epoch:4 Step:2176 Training_loss:0.778768, Acc_avg:70.00% Training_loss_avg:0.564930
# Epoch:4 Step:2184 Training_loss:0.528733, Acc_avg:70.50% Training_loss_avg:0.558604
# Epoch:4 Step:2192 Training_loss:0.394029, Acc_avg:71.00% Training_loss_avg:0.554752
# Epoch:4 Step:2200 Training_loss:0.517296, Acc_avg:71.00% Training_loss_avg:0.554973
# Epoch:4 Step:2208 Training_loss:0.446039, Acc_avg:70.75% Training_loss_avg:0.556923
# Epoch:4 Step:2216 Training_loss:0.528604, Acc_avg:70.50% Training_loss_avg:0.557634
# Epoch:4 Step:2224 Training_loss:0.671803, Acc_avg:70.50% Training_loss_avg:0.559968
# Epoch:4 Step:2232 Training_loss:0.357575, Acc_avg:70.75% Training_loss_avg:0.557823
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2232 Val_loss:0.621288, Val_Acc_avg:64.00%
# Epoch:4 Step:2240 Training_loss:0.403571, Acc_avg:71.00% Training_loss_avg:0.554293
# Epoch:4 Step:2248 Training_loss:0.561531, Acc_avg:70.75% Training_loss_avg:0.555164
# Epoch:4 Step:2256 Training_loss:0.422216, Acc_avg:70.75% Training_loss_avg:0.552019
# Epoch:4 Step:2264 Training_loss:0.494383, Acc_avg:70.75% Training_loss_avg:0.550159
# Epoch:4 Step:2272 Training_loss:0.491439, Acc_avg:71.25% Training_loss_avg:0.546738
# Epoch:4 Step:2280 Training_loss:0.558225, Acc_avg:71.00% Training_loss_avg:0.546080
# Epoch:4 Step:2288 Training_loss:0.721873, Acc_avg:71.00% Training_loss_avg:0.549487
# Epoch:4 Step:2296 Training_loss:0.323733, Acc_avg:71.75% Training_loss_avg:0.544303
# Epoch:4 Step:2304 Training_loss:0.546959, Acc_avg:72.00% Training_loss_avg:0.541453
# Epoch:4 Step:2312 Training_loss:0.869623, Acc_avg:71.00% Training_loss_avg:0.549535
# Epoch:4 Step:2320 Training_loss:0.691724, Acc_avg:71.25% Training_loss_avg:0.551198
# Epoch:4 Step:2328 Training_loss:0.498293, Acc_avg:71.50% Training_loss_avg:0.547973
# Epoch:4 Step:2336 Training_loss:0.528207, Acc_avg:71.50% Training_loss_avg:0.546507
# Epoch:4 Step:2344 Training_loss:0.656186, Acc_avg:71.50% Training_loss_avg:0.546858
# Epoch:4 Step:2352 Training_loss:0.358629, Acc_avg:72.00% Training_loss_avg:0.543559
# Epoch:4 Step:2360 Training_loss:0.752585, Acc_avg:71.75% Training_loss_avg:0.546574
# Epoch:4 Step:2368 Training_loss:0.607881, Acc_avg:71.75% Training_loss_avg:0.545601
# Epoch:4 Step:2376 Training_loss:0.342325, Acc_avg:72.75% Training_loss_avg:0.539918
# Epoch:4 Step:2384 Training_loss:0.405935, Acc_avg:72.75% Training_loss_avg:0.538202
# Epoch:4 Step:2392 Training_loss:0.694045, Acc_avg:72.50% Training_loss_avg:0.542736
# Epoch:4 Step:2400 Training_loss:0.571429, Acc_avg:72.00% Training_loss_avg:0.546396
# Epoch:4 Step:2408 Training_loss:0.675456, Acc_avg:72.00% Training_loss_avg:0.549773
# Epoch:4 Step:2416 Training_loss:0.535518, Acc_avg:71.75% Training_loss_avg:0.549716
# Epoch:4 Step:2424 Training_loss:0.632867, Acc_avg:71.50% Training_loss_avg:0.550296
# Epoch:4 Step:2432 Training_loss:0.620099, Acc_avg:70.75% Training_loss_avg:0.555218
# Epoch:4 Step:2440 Training_loss:0.386853, Acc_avg:71.50% Training_loss_avg:0.549009
# Epoch:4 Step:2448 Training_loss:0.577597, Acc_avg:72.00% Training_loss_avg:0.544874
# Epoch:4 Step:2456 Training_loss:0.580856, Acc_avg:72.00% Training_loss_avg:0.546356
# Epoch:4 Step:2464 Training_loss:0.637596, Acc_avg:72.25% Training_loss_avg:0.546759
# Epoch:4 Step:2472 Training_loss:0.392263, Acc_avg:72.50% Training_loss_avg:0.543718
# Epoch:4 Step:2480 Training_loss:0.522751, Acc_avg:72.75% Training_loss_avg:0.543049
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2480 Val_loss:0.643476, Val_Acc_avg:64.25%
# Epoch:4 Step:2488 Training_loss:0.398714, Acc_avg:73.25% Training_loss_avg:0.540055
# Epoch:4 Step:2496 Training_loss:0.800660, Acc_avg:72.50% Training_loss_avg:0.546269
# Epoch:4 Step:2504 Training_loss:0.589434, Acc_avg:72.75% Training_loss_avg:0.543645
# Epoch:4 Step:2512 Training_loss:0.573930, Acc_avg:72.25% Training_loss_avg:0.545252
# Epoch:4 Step:2520 Training_loss:0.473756, Acc_avg:72.50% Training_loss_avg:0.544994
# Epoch:4 Step:2528 Training_loss:0.935882, Acc_avg:71.50% Training_loss_avg:0.555572
# Epoch:4 Step:2536 Training_loss:0.603663, Acc_avg:71.25% Training_loss_avg:0.559425
# Epoch:4 Step:2544 Training_loss:0.903989, Acc_avg:70.00% Training_loss_avg:0.569070
# Epoch:4 Step:2552 Training_loss:0.631433, Acc_avg:69.75% Training_loss_avg:0.572404
# Epoch:4 Step:2560 Training_loss:0.685410, Acc_avg:69.50% Training_loss_avg:0.570534
# Epoch:4 Step:2568 Training_loss:0.315708, Acc_avg:70.25% Training_loss_avg:0.563961
# Epoch:4 Step:2576 Training_loss:0.706709, Acc_avg:70.25% Training_loss_avg:0.562520
# Epoch:4 Step:2584 Training_loss:0.718286, Acc_avg:70.00% Training_loss_avg:0.566311
# Epoch:4 Step:2592 Training_loss:0.270864, Acc_avg:70.00% Training_loss_avg:0.563848
# Epoch:4 Step:2600 Training_loss:0.384065, Acc_avg:70.50% Training_loss_avg:0.561183
# Epoch:4 Step:2608 Training_loss:0.620732, Acc_avg:70.00% Training_loss_avg:0.564677
# Epoch:4 Step:2616 Training_loss:0.626143, Acc_avg:70.25% Training_loss_avg:0.566628
# Epoch:4 Step:2624 Training_loss:0.326197, Acc_avg:70.75% Training_loss_avg:0.559716
# Epoch:4 Step:2632 Training_loss:0.614221, Acc_avg:70.25% Training_loss_avg:0.564849
# Epoch:4 Step:2640 Training_loss:0.390500, Acc_avg:70.25% Training_loss_avg:0.564587
# Epoch:4 Step:2648 Training_loss:0.312221, Acc_avg:70.50% Training_loss_avg:0.559601
# Epoch:4 Step:2656 Training_loss:0.353031, Acc_avg:71.00% Training_loss_avg:0.558218
# Epoch:4 Step:2664 Training_loss:0.647048, Acc_avg:70.75% Training_loss_avg:0.561271
# Epoch:4 Step:2672 Training_loss:0.462053, Acc_avg:71.00% Training_loss_avg:0.560683
# Epoch:4 Step:2680 Training_loss:0.630266, Acc_avg:71.00% Training_loss_avg:0.562124
# Epoch:4 Step:2688 Training_loss:0.509913, Acc_avg:71.00% Training_loss_avg:0.557885
# Epoch:4 Step:2696 Training_loss:0.615859, Acc_avg:70.00% Training_loss_avg:0.563727
# Epoch:4 Step:2704 Training_loss:0.744042, Acc_avg:69.50% Training_loss_avg:0.567669
# Epoch:4 Step:2712 Training_loss:0.525105, Acc_avg:70.00% Training_loss_avg:0.560779
# Epoch:4 Step:2720 Training_loss:0.813808, Acc_avg:69.75% Training_loss_avg:0.563220
# Epoch:4 Step:2728 Training_loss:0.613514, Acc_avg:70.00% Training_loss_avg:0.565525
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:2728 Val_loss:0.607856, Val_Acc_avg:66.00%
# Epoch:4 Step:2736 Training_loss:0.583592, Acc_avg:69.75% Training_loss_avg:0.566632
# Epoch:4 Step:2744 Training_loss:0.831829, Acc_avg:69.50% Training_loss_avg:0.570145
# Epoch:4 Step:2752 Training_loss:0.421502, Acc_avg:69.25% Training_loss_avg:0.571403
# Epoch:4 Step:2760 Training_loss:0.699395, Acc_avg:69.50% Training_loss_avg:0.570339
# Epoch:4 Step:2768 Training_loss:0.506170, Acc_avg:70.00% Training_loss_avg:0.568305
# Epoch:4 Step:2776 Training_loss:0.426973, Acc_avg:69.50% Training_loss_avg:0.569998
# Epoch:4 Step:2784 Training_loss:0.293821, Acc_avg:70.00% Training_loss_avg:0.567755
# Epoch:4 Step:2792 Training_loss:0.795251, Acc_avg:70.25% Training_loss_avg:0.569779
# Epoch:4 Step:2800 Training_loss:0.606037, Acc_avg:69.75% Training_loss_avg:0.570472
# Epoch:4 Step:2808 Training_loss:0.929869, Acc_avg:69.25% Training_loss_avg:0.575560
# Epoch:4 Step:2816 Training_loss:0.326508, Acc_avg:69.75% Training_loss_avg:0.571380
# Epoch:4 Step:2824 Training_loss:0.350165, Acc_avg:70.50% Training_loss_avg:0.565726
# Epoch:4 Step:2832 Training_loss:0.413574, Acc_avg:70.75% Training_loss_avg:0.561595
# Epoch:4 Step:2840 Training_loss:0.632084, Acc_avg:70.25% Training_loss_avg:0.566500
# Epoch:4 Step:2848 Training_loss:0.494412, Acc_avg:70.50% Training_loss_avg:0.564836
# Epoch:4 Step:2856 Training_loss:0.320323, Acc_avg:71.00% Training_loss_avg:0.559625
# Epoch:4 Step:2864 Training_loss:0.358357, Acc_avg:71.50% Training_loss_avg:0.554041
# Epoch:4 Step:2872 Training_loss:0.400672, Acc_avg:71.75% Training_loss_avg:0.554209
# Epoch:4 Step:2880 Training_loss:0.530484, Acc_avg:71.75% Training_loss_avg:0.554363
# Epoch:4 Step:2888 Training_loss:0.597013, Acc_avg:71.25% Training_loss_avg:0.558329
# Epoch:4 Step:2896 Training_loss:0.680125, Acc_avg:71.75% Training_loss_avg:0.555919
# Epoch:4 Step:2904 Training_loss:0.480474, Acc_avg:71.75% Training_loss_avg:0.553740
# Epoch:4 Step:2912 Training_loss:0.760831, Acc_avg:71.50% Training_loss_avg:0.557478
# Epoch:4 Step:2920 Training_loss:0.522089, Acc_avg:71.25% Training_loss_avg:0.558444
# Epoch:4 Step:2928 Training_loss:0.581666, Acc_avg:71.75% Training_loss_avg:0.551360
# Epoch:4 Step:2936 Training_loss:0.579846, Acc_avg:71.50% Training_loss_avg:0.550884
# Epoch:4 Step:2944 Training_loss:0.733895, Acc_avg:72.00% Training_loss_avg:0.547482
# Epoch:4 Step:2952 Training_loss:0.657730, Acc_avg:71.75% Training_loss_avg:0.548008
# Epoch:4 Step:2960 Training_loss:0.590742, Acc_avg:72.25% Training_loss_avg:0.546114
# Epoch:4 Step:2968 Training_loss:0.623912, Acc_avg:71.50% Training_loss_avg:0.552278
# Epoch:4 Step:2976 Training_loss:0.592246, Acc_avg:71.75% Training_loss_avg:0.549989
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2976 Val_loss:0.596453, Val_Acc_avg:67.25%
# Epoch:4 Step:2984 Training_loss:0.546762, Acc_avg:72.50% Training_loss_avg:0.546559
# Epoch:4 Step:2992 Training_loss:0.468825, Acc_avg:72.00% Training_loss_avg:0.550518
# Epoch:4 Step:3000 Training_loss:0.762902, Acc_avg:71.25% Training_loss_avg:0.558095
# Epoch:4 Step:3008 Training_loss:0.446309, Acc_avg:71.75% Training_loss_avg:0.554606
# Epoch:4 Step:3016 Training_loss:0.682584, Acc_avg:71.25% Training_loss_avg:0.555735
# Epoch:4 Step:3024 Training_loss:0.399476, Acc_avg:71.00% Training_loss_avg:0.557200
# Epoch:4 Step:3032 Training_loss:0.581398, Acc_avg:71.00% Training_loss_avg:0.556544
# Epoch:4 Step:3040 Training_loss:0.401827, Acc_avg:71.00% Training_loss_avg:0.556771
# Epoch:4 Step:3048 Training_loss:0.803543, Acc_avg:70.75% Training_loss_avg:0.566597
# Epoch:4 Step:3056 Training_loss:0.820118, Acc_avg:69.75% Training_loss_avg:0.575939
# Epoch:4 Step:3064 Training_loss:0.607218, Acc_avg:70.25% Training_loss_avg:0.575142
# Epoch:4 Step:3072 Training_loss:0.762473, Acc_avg:69.75% Training_loss_avg:0.581151
# Epoch:4 Step:3080 Training_loss:0.562003, Acc_avg:69.75% Training_loss_avg:0.579785
# Epoch:4 Step:3088 Training_loss:0.491520, Acc_avg:69.75% Training_loss_avg:0.579417
# Epoch:4 Step:3096 Training_loss:0.646724, Acc_avg:70.25% Training_loss_avg:0.580035
# Epoch:4 Step:3104 Training_loss:0.474426, Acc_avg:70.50% Training_loss_avg:0.574642
# Epoch:4 Step:3112 Training_loss:0.716374, Acc_avg:70.00% Training_loss_avg:0.578468
# Epoch:4 Step:3120 Training_loss:0.407983, Acc_avg:70.75% Training_loss_avg:0.570351
# Epoch:4 Step:3128 Training_loss:0.506905, Acc_avg:70.75% Training_loss_avg:0.568219
# Epoch:4 Step:3136 Training_loss:0.371330, Acc_avg:71.50% Training_loss_avg:0.563974
# Epoch:4 Step:3144 Training_loss:0.486427, Acc_avg:72.00% Training_loss_avg:0.557066
# Epoch:4 Step:3152 Training_loss:0.571827, Acc_avg:71.50% Training_loss_avg:0.560072
# Epoch:4 Step:3160 Training_loss:0.628059, Acc_avg:71.50% Training_loss_avg:0.558646
# Epoch:4 Step:3168 Training_loss:0.778943, Acc_avg:70.50% Training_loss_avg:0.564101
# Epoch:4 Step:3176 Training_loss:0.786257, Acc_avg:70.00% Training_loss_avg:0.571287
# Epoch:4 Step:3184 Training_loss:0.490919, Acc_avg:69.50% Training_loss_avg:0.575229
# Epoch:4 Step:3192 Training_loss:0.887993, Acc_avg:69.00% Training_loss_avg:0.577084
# Epoch:4 Step:3200 Training_loss:0.664954, Acc_avg:69.25% Training_loss_avg:0.578262
# Epoch:4 Step:3208 Training_loss:0.487987, Acc_avg:69.75% Training_loss_avg:0.569424
# Epoch:4 Step:3216 Training_loss:0.496743, Acc_avg:69.25% Training_loss_avg:0.572829
# Epoch:4 Step:3224 Training_loss:0.454739, Acc_avg:69.50% Training_loss_avg:0.574920
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:4 Step:3224 Val_loss:0.613616, Val_Acc_avg:63.75%
# Epoch:4 Step:3232 Training_loss:0.580986, Acc_avg:69.00% Training_loss_avg:0.578269
# Epoch:4 Step:3240 Training_loss:0.838321, Acc_avg:68.50% Training_loss_avg:0.582393
# Epoch:4 Step:3248 Training_loss:0.584132, Acc_avg:68.50% Training_loss_avg:0.584188
# Epoch:4 Step:3256 Training_loss:0.773404, Acc_avg:67.50% Training_loss_avg:0.593249
# Epoch:4 Step:3264 Training_loss:0.456495, Acc_avg:67.50% Training_loss_avg:0.595212
# Epoch:4 Step:3272 Training_loss:0.729953, Acc_avg:67.00% Training_loss_avg:0.601798
# Epoch:4 Step:3280 Training_loss:0.616288, Acc_avg:66.50% Training_loss_avg:0.603514
# Epoch:4 Step:3288 Training_loss:0.567872, Acc_avg:66.50% Training_loss_avg:0.602931
# Epoch:4 Step:3296 Training_loss:0.597734, Acc_avg:66.25% Training_loss_avg:0.601283
# Epoch:4 Step:3304 Training_loss:0.517985, Acc_avg:66.50% Training_loss_avg:0.602033
# Epoch:4 Step:3312 Training_loss:0.518588, Acc_avg:66.75% Training_loss_avg:0.597189
# Epoch:4 Step:3320 Training_loss:0.641240, Acc_avg:66.50% Training_loss_avg:0.599572
# Epoch:4 Step:3328 Training_loss:0.884229, Acc_avg:66.33% Training_loss_avg:0.605623

# %%
def main():
    """
    Main configuration function for a given finetune run
    :return: None
    """
    run_name = "lr_5e-6 redo, 512 split with attention!"
    run_dir = "codebert_finetune_runs/{}".format(run_name)
    model_name = 'codebert-base'
    checkpoint_location = None
    online = False
    load_splits = False
    save_data = True

    if load_splits:
      train_data, val_data, test_data = split_loader(run_dir)
      X_train, A_train, Y_train = train_data
      X_val, A_val, Y_val = val_data
      X_test, A_test, Y_test = test_data
      print("loaded data splits")

    else:
      print("generating data splits")

      code_df = preprocess_data(file_loc='code_dataset.jsonl')
      train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

      X_train, A_train, Y_train = train_data
      X_val, A_val, Y_val = val_data
      X_test, A_test, Y_test = test_data

      data_type = ['train', 'val', 'test']
      data_split_type = ['X', 'A', 'Y']

    
    # Creating dir to save logs and checkpoints, re
    dir_name = "{}".format(run_dir)
    if os.path.exists(dir_name):
        input("run name already exists, press Enter to overwrite")
    else:
        os.makedirs(dir_name)


    if save_data:
      print("saving data splits")

      data_all = [train_data, val_data, test_data]
      for i, data in enumerate(data_all):
        for j, split in enumerate(data):
          with open('{}/{}_{}.pickle'.format(run_dir,data_type[i], data_split_type[j]), 'wb') as handle:
            pickle.dump(split, handle)


    print(train_data[0].shape)
    print("Data points: {}".format(len(train_data)))

    # Loading model from checkpoint if location provided
    if online:
        print("loading model from online")
        model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
    elif checkpoint_location is None:
        print("loading model from local repo")

        model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
    else:
        print("loading model from checkpoint: {}".format(checkpoint_location))
        model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)

    train(model=model,
          train_data=train_data,
          val_data=val_data,
          epochs=5,
          batch_size=8,
          learning_rate=5e-6,
          validate_per=250,
          run_name=run_name,
          run_descrption="lr_5e-6 redo, 512 split, saving splits")

# %%
torch.cuda.empty_cache()
main()
# Out:
# generating data splits
# Insecure code counts: 3729, Total code counts: 8000, Proportion 0.466125
# Data points: 8000
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# saving data splits
# torch.Size([3331, 512])
# Data points: 3
# loading model from local repo
# Some weights of the model checkpoint at codebert-base were not used when initializing RobertaForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at codebert-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# run name already exists, exiting to prevent overwriting
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:0 Step:0 Training_loss:0.686342, Acc_avg:37.50% Training_loss_avg:0.686342
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:0 Val_loss:0.702853, Val_Acc_avg:43.25%
# Epoch:0 Step:8 Training_loss:0.686846, Acc_avg:56.25% Training_loss_avg:0.686594
# Epoch:0 Step:16 Training_loss:0.732139, Acc_avg:50.00% Training_loss_avg:0.701776
# Epoch:0 Step:24 Training_loss:0.702062, Acc_avg:46.88% Training_loss_avg:0.701848
# Epoch:0 Step:32 Training_loss:0.624708, Acc_avg:57.50% Training_loss_avg:0.686420
# Epoch:0 Step:40 Training_loss:0.693738, Acc_avg:58.33% Training_loss_avg:0.687639
# Epoch:0 Step:48 Training_loss:0.719046, Acc_avg:55.36% Training_loss_avg:0.692126
# Epoch:0 Step:56 Training_loss:0.701266, Acc_avg:53.12% Training_loss_avg:0.693268
# Epoch:0 Step:64 Training_loss:0.699633, Acc_avg:51.39% Training_loss_avg:0.693976
# Epoch:0 Step:72 Training_loss:0.716591, Acc_avg:51.25% Training_loss_avg:0.696237
# Epoch:0 Step:80 Training_loss:0.683150, Acc_avg:52.27% Training_loss_avg:0.695047
# Epoch:0 Step:88 Training_loss:0.710724, Acc_avg:51.04% Training_loss_avg:0.696354
# Epoch:0 Step:96 Training_loss:0.720085, Acc_avg:50.00% Training_loss_avg:0.698179
# Epoch:0 Step:104 Training_loss:0.649881, Acc_avg:50.89% Training_loss_avg:0.694729
# Epoch:0 Step:112 Training_loss:0.662266, Acc_avg:51.67% Training_loss_avg:0.692565
# Epoch:0 Step:120 Training_loss:0.666966, Acc_avg:52.34% Training_loss_avg:0.690965
# Epoch:0 Step:128 Training_loss:0.675231, Acc_avg:52.21% Training_loss_avg:0.690040
# Epoch:0 Step:136 Training_loss:0.639524, Acc_avg:52.78% Training_loss_avg:0.687233
# Epoch:0 Step:144 Training_loss:0.730814, Acc_avg:52.63% Training_loss_avg:0.689527
# Epoch:0 Step:152 Training_loss:0.677733, Acc_avg:53.75% Training_loss_avg:0.688937
# Epoch:0 Step:160 Training_loss:0.694696, Acc_avg:54.17% Training_loss_avg:0.689211
# Epoch:0 Step:168 Training_loss:0.664132, Acc_avg:55.11% Training_loss_avg:0.688071
# Epoch:0 Step:176 Training_loss:0.655955, Acc_avg:55.43% Training_loss_avg:0.686675
# Epoch:0 Step:184 Training_loss:0.724981, Acc_avg:54.17% Training_loss_avg:0.688271
# Epoch:0 Step:192 Training_loss:0.707632, Acc_avg:53.50% Training_loss_avg:0.689046
# Epoch:0 Step:200 Training_loss:0.673998, Acc_avg:53.37% Training_loss_avg:0.688467
# Epoch:0 Step:208 Training_loss:0.702389, Acc_avg:53.70% Training_loss_avg:0.688982
# Epoch:0 Step:216 Training_loss:0.640277, Acc_avg:54.91% Training_loss_avg:0.687243
# Epoch:0 Step:224 Training_loss:0.661406, Acc_avg:55.17% Training_loss_avg:0.686352
# Epoch:0 Step:232 Training_loss:0.665238, Acc_avg:55.83% Training_loss_avg:0.685648
# Epoch:0 Step:240 Training_loss:0.753955, Acc_avg:55.24% Training_loss_avg:0.687852
# Epoch:0 Step:248 Training_loss:0.662790, Acc_avg:55.47% Training_loss_avg:0.687069
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:248 Val_loss:0.687149, Val_Acc_avg:56.00%
# Epoch:0 Step:256 Training_loss:0.672887, Acc_avg:55.30% Training_loss_avg:0.686639
# Epoch:0 Step:264 Training_loss:0.701342, Acc_avg:55.15% Training_loss_avg:0.687071
# Epoch:0 Step:272 Training_loss:0.686413, Acc_avg:55.00% Training_loss_avg:0.687052
# Epoch:0 Step:280 Training_loss:0.692700, Acc_avg:54.86% Training_loss_avg:0.687209
# Epoch:0 Step:288 Training_loss:0.729866, Acc_avg:54.39% Training_loss_avg:0.688362
# Epoch:0 Step:296 Training_loss:0.714574, Acc_avg:53.95% Training_loss_avg:0.689052
# Epoch:0 Step:304 Training_loss:0.725544, Acc_avg:53.53% Training_loss_avg:0.689988
# Epoch:0 Step:312 Training_loss:0.738837, Acc_avg:53.75% Training_loss_avg:0.691209
# Epoch:0 Step:320 Training_loss:0.686281, Acc_avg:53.35% Training_loss_avg:0.691089
# Epoch:0 Step:328 Training_loss:0.643361, Acc_avg:53.57% Training_loss_avg:0.689952
# Epoch:0 Step:336 Training_loss:0.683200, Acc_avg:53.49% Training_loss_avg:0.689795
# Epoch:0 Step:344 Training_loss:0.726372, Acc_avg:52.84% Training_loss_avg:0.690627
# Epoch:0 Step:352 Training_loss:0.661959, Acc_avg:53.06% Training_loss_avg:0.689990
# Epoch:0 Step:360 Training_loss:0.709120, Acc_avg:52.99% Training_loss_avg:0.690405
# Epoch:0 Step:368 Training_loss:0.665316, Acc_avg:53.46% Training_loss_avg:0.689872
# Epoch:0 Step:376 Training_loss:0.631329, Acc_avg:54.17% Training_loss_avg:0.688652
# Epoch:0 Step:384 Training_loss:0.652555, Acc_avg:54.85% Training_loss_avg:0.687915
# Epoch:0 Step:392 Training_loss:0.737742, Acc_avg:54.50% Training_loss_avg:0.688912
# Epoch:0 Step:400 Training_loss:0.732656, Acc_avg:54.50% Training_loss_avg:0.689838
# Epoch:0 Step:408 Training_loss:0.744475, Acc_avg:53.50% Training_loss_avg:0.690991
# Epoch:0 Step:416 Training_loss:0.744663, Acc_avg:53.00% Training_loss_avg:0.691241
# Epoch:0 Step:424 Training_loss:0.703249, Acc_avg:53.00% Training_loss_avg:0.691265
# Epoch:0 Step:432 Training_loss:0.704680, Acc_avg:51.75% Training_loss_avg:0.692864
# Epoch:0 Step:440 Training_loss:0.653838, Acc_avg:52.00% Training_loss_avg:0.692066
# Epoch:0 Step:448 Training_loss:0.678681, Acc_avg:52.25% Training_loss_avg:0.691259
# Epoch:0 Step:456 Training_loss:0.685888, Acc_avg:52.75% Training_loss_avg:0.690951
# Epoch:0 Step:464 Training_loss:0.715702, Acc_avg:52.75% Training_loss_avg:0.691273
# Epoch:0 Step:472 Training_loss:0.661696, Acc_avg:53.25% Training_loss_avg:0.690175
# Epoch:0 Step:480 Training_loss:0.680757, Acc_avg:53.25% Training_loss_avg:0.690127
# Epoch:0 Step:488 Training_loss:0.667135, Acc_avg:53.75% Training_loss_avg:0.689255
# Epoch:0 Step:496 Training_loss:0.703528, Acc_avg:53.50% Training_loss_avg:0.688924
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:496 Val_loss:0.692361, Val_Acc_avg:51.00%
# Epoch:0 Step:504 Training_loss:0.693638, Acc_avg:53.50% Training_loss_avg:0.689799
# Epoch:0 Step:512 Training_loss:0.703834, Acc_avg:53.25% Training_loss_avg:0.690631
# Epoch:0 Step:520 Training_loss:0.666999, Acc_avg:53.25% Training_loss_avg:0.690631
# Epoch:0 Step:528 Training_loss:0.625619, Acc_avg:53.75% Training_loss_avg:0.689639
# Epoch:0 Step:536 Training_loss:0.700659, Acc_avg:53.50% Training_loss_avg:0.690862
# Epoch:0 Step:544 Training_loss:0.660008, Acc_avg:54.00% Training_loss_avg:0.689446
# Epoch:0 Step:552 Training_loss:0.739076, Acc_avg:54.00% Training_loss_avg:0.690673
# Epoch:0 Step:560 Training_loss:0.730489, Acc_avg:53.25% Training_loss_avg:0.691388
# Epoch:0 Step:568 Training_loss:0.733346, Acc_avg:52.25% Training_loss_avg:0.692773
# Epoch:0 Step:576 Training_loss:0.685395, Acc_avg:52.25% Training_loss_avg:0.693362
# Epoch:0 Step:584 Training_loss:0.678999, Acc_avg:53.00% Training_loss_avg:0.692442
# Epoch:0 Step:592 Training_loss:0.718979, Acc_avg:52.75% Training_loss_avg:0.692669
# Epoch:0 Step:600 Training_loss:0.728028, Acc_avg:52.50% Training_loss_avg:0.693749
# Epoch:0 Step:608 Training_loss:0.746641, Acc_avg:52.00% Training_loss_avg:0.694634
# Epoch:0 Step:616 Training_loss:0.711951, Acc_avg:51.25% Training_loss_avg:0.696068
# Epoch:0 Step:624 Training_loss:0.639456, Acc_avg:51.50% Training_loss_avg:0.695629
# Epoch:0 Step:632 Training_loss:0.704005, Acc_avg:50.75% Training_loss_avg:0.696404
# Epoch:0 Step:640 Training_loss:0.700136, Acc_avg:51.00% Training_loss_avg:0.695328
# Epoch:0 Step:648 Training_loss:0.605959, Acc_avg:51.25% Training_loss_avg:0.694191
# Epoch:0 Step:656 Training_loss:0.687765, Acc_avg:51.25% Training_loss_avg:0.694489
# Epoch:0 Step:664 Training_loss:0.609334, Acc_avg:51.75% Training_loss_avg:0.692649
# Epoch:0 Step:672 Training_loss:0.745448, Acc_avg:51.75% Training_loss_avg:0.693829
# Epoch:0 Step:680 Training_loss:0.698234, Acc_avg:51.75% Training_loss_avg:0.693940
# Epoch:0 Step:688 Training_loss:0.634359, Acc_avg:52.25% Training_loss_avg:0.692030
# Epoch:0 Step:696 Training_loss:0.779780, Acc_avg:52.00% Training_loss_avg:0.693334
# Epoch:0 Step:704 Training_loss:0.571960, Acc_avg:52.75% Training_loss_avg:0.690262
# Epoch:0 Step:712 Training_loss:0.786730, Acc_avg:52.00% Training_loss_avg:0.691220
# Epoch:0 Step:720 Training_loss:0.756881, Acc_avg:52.00% Training_loss_avg:0.692632
# Epoch:0 Step:728 Training_loss:0.724147, Acc_avg:51.75% Training_loss_avg:0.694248
# Epoch:0 Step:736 Training_loss:0.717013, Acc_avg:51.50% Training_loss_avg:0.694924
# Epoch:0 Step:744 Training_loss:0.741171, Acc_avg:51.75% Training_loss_avg:0.695220
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:744 Val_loss:0.682478, Val_Acc_avg:56.75%
# Epoch:0 Step:752 Training_loss:0.579665, Acc_avg:52.25% Training_loss_avg:0.693574
# Epoch:0 Step:760 Training_loss:0.587760, Acc_avg:53.00% Training_loss_avg:0.691147
# Epoch:0 Step:768 Training_loss:0.599693, Acc_avg:53.25% Training_loss_avg:0.689835
# Epoch:0 Step:776 Training_loss:0.664791, Acc_avg:52.75% Training_loss_avg:0.690504
# Epoch:0 Step:784 Training_loss:0.777641, Acc_avg:51.50% Training_loss_avg:0.693006
# Epoch:0 Step:792 Training_loss:0.687991, Acc_avg:51.75% Training_loss_avg:0.692011
# Epoch:0 Step:800 Training_loss:0.783083, Acc_avg:51.25% Training_loss_avg:0.693019
# Epoch:0 Step:808 Training_loss:0.681606, Acc_avg:51.75% Training_loss_avg:0.691762
# Epoch:0 Step:816 Training_loss:0.740076, Acc_avg:52.00% Training_loss_avg:0.691670
# Epoch:0 Step:824 Training_loss:0.658406, Acc_avg:52.50% Training_loss_avg:0.690773
# Epoch:0 Step:832 Training_loss:0.657484, Acc_avg:53.00% Training_loss_avg:0.689829
# Epoch:0 Step:840 Training_loss:0.634789, Acc_avg:53.00% Training_loss_avg:0.689448
# Epoch:0 Step:848 Training_loss:0.711540, Acc_avg:52.75% Training_loss_avg:0.690105
# Epoch:0 Step:856 Training_loss:0.715097, Acc_avg:52.25% Training_loss_avg:0.690690
# Epoch:0 Step:864 Training_loss:0.723697, Acc_avg:52.50% Training_loss_avg:0.690850
# Epoch:0 Step:872 Training_loss:0.673571, Acc_avg:52.00% Training_loss_avg:0.691087
# Epoch:0 Step:880 Training_loss:0.691586, Acc_avg:52.00% Training_loss_avg:0.691304
# Epoch:0 Step:888 Training_loss:0.692569, Acc_avg:52.00% Training_loss_avg:0.691812
# Epoch:0 Step:896 Training_loss:0.658830, Acc_avg:52.75% Training_loss_avg:0.690918
# Epoch:0 Step:904 Training_loss:0.783265, Acc_avg:51.75% Training_loss_avg:0.692711
# Epoch:0 Step:912 Training_loss:0.722476, Acc_avg:51.50% Training_loss_avg:0.693084
# Epoch:0 Step:920 Training_loss:0.688835, Acc_avg:51.50% Training_loss_avg:0.693520
# Epoch:0 Step:928 Training_loss:0.712196, Acc_avg:50.75% Training_loss_avg:0.695252
# Epoch:0 Step:936 Training_loss:0.726490, Acc_avg:50.50% Training_loss_avg:0.695769
# Epoch:0 Step:944 Training_loss:0.645983, Acc_avg:50.50% Training_loss_avg:0.695488
# Epoch:0 Step:952 Training_loss:0.641276, Acc_avg:50.50% Training_loss_avg:0.693532
# Epoch:0 Step:960 Training_loss:0.706216, Acc_avg:50.75% Training_loss_avg:0.693047
# Epoch:0 Step:968 Training_loss:0.638103, Acc_avg:51.75% Training_loss_avg:0.691142
# Epoch:0 Step:976 Training_loss:0.632381, Acc_avg:52.50% Training_loss_avg:0.690081
# Epoch:0 Step:984 Training_loss:0.626979, Acc_avg:53.00% Training_loss_avg:0.689041
# Epoch:0 Step:992 Training_loss:0.721997, Acc_avg:53.25% Training_loss_avg:0.689101
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:992 Val_loss:0.684027, Val_Acc_avg:57.50%
# Epoch:0 Step:1000 Training_loss:0.742666, Acc_avg:53.50% Training_loss_avg:0.689394
# Epoch:0 Step:1008 Training_loss:0.695131, Acc_avg:53.75% Training_loss_avg:0.688364
# Epoch:0 Step:1016 Training_loss:0.726107, Acc_avg:53.75% Training_loss_avg:0.688647
# Epoch:0 Step:1024 Training_loss:0.694181, Acc_avg:53.50% Training_loss_avg:0.689742
# Epoch:0 Step:1032 Training_loss:0.664683, Acc_avg:54.25% Training_loss_avg:0.688955
# Epoch:0 Step:1040 Training_loss:0.723574, Acc_avg:54.00% Training_loss_avg:0.689424
# Epoch:0 Step:1048 Training_loss:0.659806, Acc_avg:53.75% Training_loss_avg:0.690501
# Epoch:0 Step:1056 Training_loss:0.641882, Acc_avg:54.00% Training_loss_avg:0.689583
# Epoch:0 Step:1064 Training_loss:0.703656, Acc_avg:53.25% Training_loss_avg:0.691470
# Epoch:0 Step:1072 Training_loss:0.663331, Acc_avg:53.50% Training_loss_avg:0.689827
# Epoch:0 Step:1080 Training_loss:0.668947, Acc_avg:54.00% Training_loss_avg:0.689242
# Epoch:0 Step:1088 Training_loss:0.690701, Acc_avg:53.50% Training_loss_avg:0.690368
# Epoch:0 Step:1096 Training_loss:0.700430, Acc_avg:54.50% Training_loss_avg:0.688781
# Epoch:0 Step:1104 Training_loss:0.725373, Acc_avg:53.75% Training_loss_avg:0.691850
# Epoch:0 Step:1112 Training_loss:0.670390, Acc_avg:54.50% Training_loss_avg:0.689523
# Epoch:0 Step:1120 Training_loss:0.658918, Acc_avg:55.25% Training_loss_avg:0.687564
# Epoch:0 Step:1128 Training_loss:0.656761, Acc_avg:55.75% Training_loss_avg:0.686216
# Epoch:0 Step:1136 Training_loss:0.782251, Acc_avg:55.50% Training_loss_avg:0.687521
# Epoch:0 Step:1144 Training_loss:0.699340, Acc_avg:56.00% Training_loss_avg:0.686684
# Epoch:0 Step:1152 Training_loss:0.697234, Acc_avg:55.00% Training_loss_avg:0.689035
# Epoch:0 Step:1160 Training_loss:0.685865, Acc_avg:54.50% Training_loss_avg:0.690998
# Epoch:0 Step:1168 Training_loss:0.760726, Acc_avg:53.50% Training_loss_avg:0.694218
# Epoch:0 Step:1176 Training_loss:0.713420, Acc_avg:53.25% Training_loss_avg:0.695191
# Epoch:0 Step:1184 Training_loss:0.656119, Acc_avg:54.00% Training_loss_avg:0.692760
# Epoch:0 Step:1192 Training_loss:0.691734, Acc_avg:54.25% Training_loss_avg:0.692835
# Epoch:0 Step:1200 Training_loss:0.683415, Acc_avg:55.25% Training_loss_avg:0.690842
# Epoch:0 Step:1208 Training_loss:0.602632, Acc_avg:56.00% Training_loss_avg:0.689262
# Epoch:0 Step:1216 Training_loss:0.655616, Acc_avg:56.50% Training_loss_avg:0.687573
# Epoch:0 Step:1224 Training_loss:0.587233, Acc_avg:57.25% Training_loss_avg:0.686150
# Epoch:0 Step:1232 Training_loss:0.692060, Acc_avg:56.75% Training_loss_avg:0.686841
# Epoch:0 Step:1240 Training_loss:0.732642, Acc_avg:55.75% Training_loss_avg:0.688798
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1240 Val_loss:0.684373, Val_Acc_avg:56.75%
# Epoch:0 Step:1248 Training_loss:0.695780, Acc_avg:56.00% Training_loss_avg:0.688483
# Epoch:0 Step:1256 Training_loss:0.647460, Acc_avg:56.50% Training_loss_avg:0.687130
# Epoch:0 Step:1264 Training_loss:0.639407, Acc_avg:57.00% Training_loss_avg:0.685445
# Epoch:0 Step:1272 Training_loss:0.650423, Acc_avg:57.25% Training_loss_avg:0.684982
# Epoch:0 Step:1280 Training_loss:0.655698, Acc_avg:57.50% Training_loss_avg:0.684264
# Epoch:0 Step:1288 Training_loss:0.654152, Acc_avg:57.25% Training_loss_avg:0.683495
# Epoch:0 Step:1296 Training_loss:0.675169, Acc_avg:57.00% Training_loss_avg:0.683822
# Epoch:0 Step:1304 Training_loss:0.702343, Acc_avg:57.75% Training_loss_avg:0.682204
# Epoch:0 Step:1312 Training_loss:0.656873, Acc_avg:58.25% Training_loss_avg:0.680892
# Epoch:0 Step:1320 Training_loss:0.637846, Acc_avg:58.25% Training_loss_avg:0.679872
# Epoch:0 Step:1328 Training_loss:0.655496, Acc_avg:59.00% Training_loss_avg:0.678738
# Epoch:0 Step:1336 Training_loss:0.694075, Acc_avg:59.25% Training_loss_avg:0.678090
# Epoch:0 Step:1344 Training_loss:0.684356, Acc_avg:58.75% Training_loss_avg:0.678857
# Epoch:0 Step:1352 Training_loss:0.648629, Acc_avg:58.50% Training_loss_avg:0.679004
# Epoch:0 Step:1360 Training_loss:0.646070, Acc_avg:59.00% Training_loss_avg:0.677801
# Epoch:0 Step:1368 Training_loss:0.645208, Acc_avg:58.75% Training_loss_avg:0.677943
# Epoch:0 Step:1376 Training_loss:0.729055, Acc_avg:57.75% Training_loss_avg:0.679877
# Epoch:0 Step:1384 Training_loss:0.598367, Acc_avg:57.50% Training_loss_avg:0.679305
# Epoch:0 Step:1392 Training_loss:0.674863, Acc_avg:58.00% Training_loss_avg:0.678362
# Epoch:0 Step:1400 Training_loss:0.699745, Acc_avg:58.00% Training_loss_avg:0.677503
# Epoch:0 Step:1408 Training_loss:0.802633, Acc_avg:57.75% Training_loss_avg:0.679654
# Epoch:0 Step:1416 Training_loss:0.632492, Acc_avg:58.25% Training_loss_avg:0.677781
# Epoch:0 Step:1424 Training_loss:0.870686, Acc_avg:57.25% Training_loss_avg:0.681311
# Epoch:0 Step:1432 Training_loss:0.830246, Acc_avg:56.25% Training_loss_avg:0.684623
# Epoch:0 Step:1440 Training_loss:0.887984, Acc_avg:56.00% Training_loss_avg:0.687911
# Epoch:0 Step:1448 Training_loss:0.675258, Acc_avg:56.00% Training_loss_avg:0.688220
# Epoch:0 Step:1456 Training_loss:0.574629, Acc_avg:56.25% Training_loss_avg:0.686875
# Epoch:0 Step:1464 Training_loss:0.765313, Acc_avg:56.25% Training_loss_avg:0.688108
# Epoch:0 Step:1472 Training_loss:0.756514, Acc_avg:56.00% Training_loss_avg:0.689972
# Epoch:0 Step:1480 Training_loss:0.692722, Acc_avg:55.75% Training_loss_avg:0.690447
# Epoch:0 Step:1488 Training_loss:0.563776, Acc_avg:56.75% Training_loss_avg:0.687909
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1488 Val_loss:0.683190, Val_Acc_avg:56.75%
# Epoch:0 Step:1496 Training_loss:0.679065, Acc_avg:56.50% Training_loss_avg:0.687481
# Epoch:0 Step:1504 Training_loss:0.669561, Acc_avg:57.00% Training_loss_avg:0.686365
# Epoch:0 Step:1512 Training_loss:0.634266, Acc_avg:57.25% Training_loss_avg:0.685643
# Epoch:0 Step:1520 Training_loss:0.685757, Acc_avg:56.75% Training_loss_avg:0.686179
# Epoch:0 Step:1528 Training_loss:0.676810, Acc_avg:56.75% Training_loss_avg:0.686580
# Epoch:0 Step:1536 Training_loss:0.591102, Acc_avg:57.75% Training_loss_avg:0.682757
# Epoch:0 Step:1544 Training_loss:0.610615, Acc_avg:58.00% Training_loss_avg:0.680983
# Epoch:0 Step:1552 Training_loss:0.662957, Acc_avg:58.50% Training_loss_avg:0.680297
# Epoch:0 Step:1560 Training_loss:0.758877, Acc_avg:57.75% Training_loss_avg:0.681757
# Epoch:0 Step:1568 Training_loss:0.717519, Acc_avg:58.00% Training_loss_avg:0.680893
# Epoch:0 Step:1576 Training_loss:0.694922, Acc_avg:58.00% Training_loss_avg:0.680523
# Epoch:0 Step:1584 Training_loss:0.611473, Acc_avg:58.50% Training_loss_avg:0.679630
# Epoch:0 Step:1592 Training_loss:0.633349, Acc_avg:59.00% Training_loss_avg:0.678463
# Epoch:0 Step:1600 Training_loss:0.711968, Acc_avg:58.75% Training_loss_avg:0.679034
# Epoch:0 Step:1608 Training_loss:0.719982, Acc_avg:58.00% Training_loss_avg:0.681381
# Epoch:0 Step:1616 Training_loss:0.636025, Acc_avg:58.50% Training_loss_avg:0.680989
# Epoch:0 Step:1624 Training_loss:0.706560, Acc_avg:57.75% Training_loss_avg:0.683376
# Epoch:0 Step:1632 Training_loss:0.713147, Acc_avg:57.75% Training_loss_avg:0.683797
# Epoch:0 Step:1640 Training_loss:0.735904, Acc_avg:57.75% Training_loss_avg:0.683863
# Epoch:0 Step:1648 Training_loss:0.680107, Acc_avg:57.50% Training_loss_avg:0.683549
# Epoch:0 Step:1656 Training_loss:0.697232, Acc_avg:57.25% Training_loss_avg:0.684545
# Epoch:0 Step:1664 Training_loss:0.763512, Acc_avg:56.25% Training_loss_avg:0.687027
# Epoch:0 Step:1672 Training_loss:0.604556, Acc_avg:56.50% Training_loss_avg:0.686109
# Epoch:0 Step:1680 Training_loss:0.699810, Acc_avg:56.00% Training_loss_avg:0.686992
# Epoch:0 Step:1688 Training_loss:0.678477, Acc_avg:56.25% Training_loss_avg:0.687478
# Epoch:0 Step:1696 Training_loss:0.693760, Acc_avg:56.25% Training_loss_avg:0.687850
# Epoch:0 Step:1704 Training_loss:0.757106, Acc_avg:56.25% Training_loss_avg:0.688945
# Epoch:0 Step:1712 Training_loss:0.773983, Acc_avg:55.75% Training_loss_avg:0.691287
# Epoch:0 Step:1720 Training_loss:0.691110, Acc_avg:55.75% Training_loss_avg:0.692353
# Epoch:0 Step:1728 Training_loss:0.578485, Acc_avg:56.00% Training_loss_avg:0.690812
# Epoch:0 Step:1736 Training_loss:0.697227, Acc_avg:55.75% Training_loss_avg:0.690875
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1736 Val_loss:0.678570, Val_Acc_avg:58.00%
# Epoch:0 Step:1744 Training_loss:0.602189, Acc_avg:56.50% Training_loss_avg:0.689232
# Epoch:0 Step:1752 Training_loss:0.636324, Acc_avg:56.75% Training_loss_avg:0.688986
# Epoch:0 Step:1760 Training_loss:0.625652, Acc_avg:57.00% Training_loss_avg:0.688578
# Epoch:0 Step:1768 Training_loss:0.645852, Acc_avg:57.00% Training_loss_avg:0.688590
# Epoch:0 Step:1776 Training_loss:0.675028, Acc_avg:56.75% Training_loss_avg:0.687510
# Epoch:0 Step:1784 Training_loss:0.734251, Acc_avg:55.75% Training_loss_avg:0.690228
# Epoch:0 Step:1792 Training_loss:0.598457, Acc_avg:56.25% Training_loss_avg:0.688699
# Epoch:0 Step:1800 Training_loss:0.734482, Acc_avg:56.50% Training_loss_avg:0.689394
# Epoch:0 Step:1808 Training_loss:0.654426, Acc_avg:57.00% Training_loss_avg:0.686430
# Epoch:0 Step:1816 Training_loss:0.636995, Acc_avg:56.75% Training_loss_avg:0.686520
# Epoch:0 Step:1824 Training_loss:0.746303, Acc_avg:57.50% Training_loss_avg:0.684032
# Epoch:0 Step:1832 Training_loss:0.819671, Acc_avg:57.50% Training_loss_avg:0.683821
# Epoch:0 Step:1840 Training_loss:0.588846, Acc_avg:58.75% Training_loss_avg:0.677838
# Epoch:0 Step:1848 Training_loss:0.556826, Acc_avg:59.00% Training_loss_avg:0.675470
# Epoch:0 Step:1856 Training_loss:0.727046, Acc_avg:58.50% Training_loss_avg:0.678518
# Epoch:0 Step:1864 Training_loss:0.779319, Acc_avg:58.75% Training_loss_avg:0.678798
# Epoch:0 Step:1872 Training_loss:0.718339, Acc_avg:58.75% Training_loss_avg:0.678035
# Epoch:0 Step:1880 Training_loss:0.731311, Acc_avg:58.50% Training_loss_avg:0.678806
# Epoch:0 Step:1888 Training_loss:0.585158, Acc_avg:58.25% Training_loss_avg:0.679234
# Epoch:0 Step:1896 Training_loss:0.657575, Acc_avg:58.25% Training_loss_avg:0.678804
# Epoch:0 Step:1904 Training_loss:0.663566, Acc_avg:58.25% Training_loss_avg:0.678684
# Epoch:0 Step:1912 Training_loss:0.697177, Acc_avg:57.75% Training_loss_avg:0.679942
# Epoch:0 Step:1920 Training_loss:0.816005, Acc_avg:57.50% Training_loss_avg:0.682547
# Epoch:0 Step:1928 Training_loss:0.657010, Acc_avg:57.00% Training_loss_avg:0.682151
# Epoch:0 Step:1936 Training_loss:0.709874, Acc_avg:56.25% Training_loss_avg:0.684527
# Epoch:0 Step:1944 Training_loss:0.688456, Acc_avg:56.00% Training_loss_avg:0.686084
# Epoch:0 Step:1952 Training_loss:0.704926, Acc_avg:56.00% Training_loss_avg:0.686923
# Epoch:0 Step:1960 Training_loss:0.641575, Acc_avg:57.00% Training_loss_avg:0.684577
# Epoch:0 Step:1968 Training_loss:0.646709, Acc_avg:57.50% Training_loss_avg:0.683161
# Epoch:0 Step:1976 Training_loss:0.837776, Acc_avg:57.00% Training_loss_avg:0.686018
# Epoch:0 Step:1984 Training_loss:0.724353, Acc_avg:56.25% Training_loss_avg:0.688276
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:1984 Val_loss:0.679165, Val_Acc_avg:57.00%
# Epoch:0 Step:1992 Training_loss:0.802993, Acc_avg:55.00% Training_loss_avg:0.691668
# Epoch:0 Step:2000 Training_loss:0.638228, Acc_avg:55.25% Training_loss_avg:0.690194
# Epoch:0 Step:2008 Training_loss:0.664689, Acc_avg:55.50% Training_loss_avg:0.689088
# Epoch:0 Step:2016 Training_loss:0.671690, Acc_avg:55.25% Training_loss_avg:0.689801
# Epoch:0 Step:2024 Training_loss:0.685809, Acc_avg:55.25% Training_loss_avg:0.689386
# Epoch:0 Step:2032 Training_loss:0.707991, Acc_avg:55.50% Training_loss_avg:0.689283
# Epoch:0 Step:2040 Training_loss:0.665923, Acc_avg:56.25% Training_loss_avg:0.687883
# Epoch:0 Step:2048 Training_loss:0.619772, Acc_avg:57.00% Training_loss_avg:0.686677
# Epoch:0 Step:2056 Training_loss:0.647221, Acc_avg:57.25% Training_loss_avg:0.685676
# Epoch:0 Step:2064 Training_loss:0.724065, Acc_avg:57.50% Training_loss_avg:0.684887
# Epoch:0 Step:2072 Training_loss:0.707461, Acc_avg:57.00% Training_loss_avg:0.686946
# Epoch:0 Step:2080 Training_loss:0.670627, Acc_avg:57.50% Training_loss_avg:0.686362
# Epoch:0 Step:2088 Training_loss:0.691215, Acc_avg:57.25% Training_loss_avg:0.686617
# Epoch:0 Step:2096 Training_loss:0.682556, Acc_avg:57.50% Training_loss_avg:0.686393
# Epoch:0 Step:2104 Training_loss:0.661306, Acc_avg:58.00% Training_loss_avg:0.684477
# Epoch:0 Step:2112 Training_loss:0.859860, Acc_avg:57.75% Training_loss_avg:0.686194
# Epoch:0 Step:2120 Training_loss:0.681096, Acc_avg:57.50% Training_loss_avg:0.685994
# Epoch:0 Step:2128 Training_loss:0.692686, Acc_avg:56.75% Training_loss_avg:0.688278
# Epoch:0 Step:2136 Training_loss:0.649491, Acc_avg:57.25% Training_loss_avg:0.687323
# Epoch:0 Step:2144 Training_loss:0.680717, Acc_avg:56.50% Training_loss_avg:0.688894
# Epoch:0 Step:2152 Training_loss:0.682509, Acc_avg:56.00% Training_loss_avg:0.689817
# Epoch:0 Step:2160 Training_loss:0.651310, Acc_avg:55.75% Training_loss_avg:0.690331
# Epoch:0 Step:2168 Training_loss:0.712717, Acc_avg:55.50% Training_loss_avg:0.691668
# Epoch:0 Step:2176 Training_loss:0.675924, Acc_avg:55.75% Training_loss_avg:0.691686
# Epoch:0 Step:2184 Training_loss:0.618613, Acc_avg:56.75% Training_loss_avg:0.689373
# Epoch:0 Step:2192 Training_loss:0.706937, Acc_avg:55.75% Training_loss_avg:0.691543
# Epoch:0 Step:2200 Training_loss:0.754393, Acc_avg:54.75% Training_loss_avg:0.691941
# Epoch:0 Step:2208 Training_loss:0.659028, Acc_avg:54.75% Training_loss_avg:0.692033
# Epoch:0 Step:2216 Training_loss:0.721437, Acc_avg:54.25% Training_loss_avg:0.693722
# Epoch:0 Step:2224 Training_loss:0.752989, Acc_avg:53.75% Training_loss_avg:0.693855
# Epoch:0 Step:2232 Training_loss:0.675499, Acc_avg:54.00% Training_loss_avg:0.690972
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:2232 Val_loss:0.680527, Val_Acc_avg:58.75%
# Epoch:0 Step:2240 Training_loss:0.640884, Acc_avg:53.75% Training_loss_avg:0.692013
# Epoch:0 Step:2248 Training_loss:0.649412, Acc_avg:53.75% Training_loss_avg:0.693864
# Epoch:0 Step:2256 Training_loss:0.668064, Acc_avg:54.00% Training_loss_avg:0.692685
# Epoch:0 Step:2264 Training_loss:0.675619, Acc_avg:54.50% Training_loss_avg:0.690611
# Epoch:0 Step:2272 Training_loss:0.688091, Acc_avg:54.50% Training_loss_avg:0.690006
# Epoch:0 Step:2280 Training_loss:0.669856, Acc_avg:54.50% Training_loss_avg:0.688777
# Epoch:0 Step:2288 Training_loss:0.696181, Acc_avg:54.25% Training_loss_avg:0.690997
# Epoch:0 Step:2296 Training_loss:0.737689, Acc_avg:54.00% Training_loss_avg:0.692600
# Epoch:0 Step:2304 Training_loss:0.723578, Acc_avg:53.50% Training_loss_avg:0.693800
# Epoch:0 Step:2312 Training_loss:0.706991, Acc_avg:53.75% Training_loss_avg:0.693996
# Epoch:0 Step:2320 Training_loss:0.720902, Acc_avg:53.75% Training_loss_avg:0.692094
# Epoch:0 Step:2328 Training_loss:0.679129, Acc_avg:53.75% Training_loss_avg:0.692536
# Epoch:0 Step:2336 Training_loss:0.683284, Acc_avg:54.00% Training_loss_avg:0.692005
# Epoch:0 Step:2344 Training_loss:0.668761, Acc_avg:54.00% Training_loss_avg:0.691611
# Epoch:0 Step:2352 Training_loss:0.661630, Acc_avg:53.50% Training_loss_avg:0.690745
# Epoch:0 Step:2360 Training_loss:0.734831, Acc_avg:52.50% Training_loss_avg:0.692610
# Epoch:0 Step:2368 Training_loss:0.706549, Acc_avg:52.00% Training_loss_avg:0.693807
# Epoch:0 Step:2376 Training_loss:0.724947, Acc_avg:52.25% Training_loss_avg:0.691550
# Epoch:0 Step:2384 Training_loss:0.698183, Acc_avg:52.25% Training_loss_avg:0.691027
# Epoch:0 Step:2392 Training_loss:0.701816, Acc_avg:52.75% Training_loss_avg:0.689003
# Epoch:0 Step:2400 Training_loss:0.715492, Acc_avg:52.25% Training_loss_avg:0.690548
# Epoch:0 Step:2408 Training_loss:0.656700, Acc_avg:52.25% Training_loss_avg:0.690389
# Epoch:0 Step:2416 Training_loss:0.630674, Acc_avg:52.75% Training_loss_avg:0.689568
# Epoch:0 Step:2424 Training_loss:0.763568, Acc_avg:51.75% Training_loss_avg:0.691123
# Epoch:0 Step:2432 Training_loss:0.729683, Acc_avg:51.50% Training_loss_avg:0.691557
# Epoch:0 Step:2440 Training_loss:0.720276, Acc_avg:51.00% Training_loss_avg:0.692644
# Epoch:0 Step:2448 Training_loss:0.676193, Acc_avg:50.75% Training_loss_avg:0.693773
# Epoch:0 Step:2456 Training_loss:0.708223, Acc_avg:50.50% Training_loss_avg:0.694993
# Epoch:0 Step:2464 Training_loss:0.697106, Acc_avg:50.75% Training_loss_avg:0.694454
# Epoch:0 Step:2472 Training_loss:0.711381, Acc_avg:50.50% Training_loss_avg:0.694532
# Epoch:0 Step:2480 Training_loss:0.586962, Acc_avg:50.75% Training_loss_avg:0.692859
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:0 Step:2480 Val_loss:0.681564, Val_Acc_avg:57.75%
# Epoch:0 Step:2488 Training_loss:0.712447, Acc_avg:51.00% Training_loss_avg:0.693283
# Epoch:0 Step:2496 Training_loss:0.676482, Acc_avg:51.00% Training_loss_avg:0.693162
# Epoch:0 Step:2504 Training_loss:0.667493, Acc_avg:50.75% Training_loss_avg:0.693286
# Epoch:0 Step:2512 Training_loss:0.666137, Acc_avg:51.25% Training_loss_avg:0.689411
# Epoch:0 Step:2520 Training_loss:0.720680, Acc_avg:51.25% Training_loss_avg:0.690203
# Epoch:0 Step:2528 Training_loss:0.730893, Acc_avg:50.50% Training_loss_avg:0.690967
# Epoch:0 Step:2536 Training_loss:0.671071, Acc_avg:50.75% Training_loss_avg:0.691399
# Epoch:0 Step:2544 Training_loss:0.633031, Acc_avg:51.00% Training_loss_avg:0.690445
# Epoch:0 Step:2552 Training_loss:0.707764, Acc_avg:51.25% Training_loss_avg:0.690950
# Epoch:0 Step:2560 Training_loss:0.693178, Acc_avg:51.00% Training_loss_avg:0.691787
# Epoch:0 Step:2568 Training_loss:0.700455, Acc_avg:51.25% Training_loss_avg:0.691542
# Epoch:0 Step:2576 Training_loss:0.715727, Acc_avg:51.00% Training_loss_avg:0.692338
# Epoch:0 Step:2584 Training_loss:0.725527, Acc_avg:50.50% Training_loss_avg:0.694476
# Epoch:0 Step:2592 Training_loss:0.574462, Acc_avg:51.50% Training_loss_avg:0.691827
# Epoch:0 Step:2600 Training_loss:0.664667, Acc_avg:52.25% Training_loss_avg:0.690032
# Epoch:0 Step:2608 Training_loss:0.790850, Acc_avg:51.50% Training_loss_avg:0.692669
# Epoch:0 Step:2616 Training_loss:0.700027, Acc_avg:51.50% Training_loss_avg:0.692241
# Epoch:0 Step:2624 Training_loss:0.778467, Acc_avg:51.75% Training_loss_avg:0.692750
# Epoch:0 Step:2632 Training_loss:0.701886, Acc_avg:52.25% Training_loss_avg:0.693278
# Epoch:0 Step:2640 Training_loss:0.655694, Acc_avg:52.00% Training_loss_avg:0.693574
# Epoch:0 Step:2648 Training_loss:0.735942, Acc_avg:51.25% Training_loss_avg:0.695305
# Epoch:0 Step:2656 Training_loss:0.664048, Acc_avg:51.25% Training_loss_avg:0.695225
# Epoch:0 Step:2664 Training_loss:0.739743, Acc_avg:50.75% Training_loss_avg:0.696507
# Epoch:0 Step:2672 Training_loss:0.671466, Acc_avg:50.75% Training_loss_avg:0.696175
# Epoch:0 Step:2680 Training_loss:0.689982, Acc_avg:50.50% Training_loss_avg:0.696577
# Epoch:0 Step:2688 Training_loss:0.658146, Acc_avg:50.50% Training_loss_avg:0.695816
# Epoch:0 Step:2696 Training_loss:0.687285, Acc_avg:51.00% Training_loss_avg:0.694808
# Epoch:0 Step:2704 Training_loss:0.659699, Acc_avg:51.75% Training_loss_avg:0.693531
# Epoch:0 Step:2712 Training_loss:0.680961, Acc_avg:51.50% Training_loss_avg:0.693010
# Epoch:0 Step:2720 Training_loss:0.665268, Acc_avg:51.75% Training_loss_avg:0.691897
# Epoch:0 Step:2728 Training_loss:0.674439, Acc_avg:52.00% Training_loss_avg:0.691804
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:2728 Val_loss:0.684117, Val_Acc_avg:56.50%
# Epoch:0 Step:2736 Training_loss:0.668095, Acc_avg:52.00% Training_loss_avg:0.691500
# Epoch:0 Step:2744 Training_loss:0.697412, Acc_avg:51.75% Training_loss_avg:0.692073
# Epoch:0 Step:2752 Training_loss:0.715872, Acc_avg:52.00% Training_loss_avg:0.693158
# Epoch:0 Step:2760 Training_loss:0.688613, Acc_avg:52.50% Training_loss_avg:0.692233
# Epoch:0 Step:2768 Training_loss:0.633020, Acc_avg:52.75% Training_loss_avg:0.690763
# Epoch:0 Step:2776 Training_loss:0.742272, Acc_avg:52.25% Training_loss_avg:0.691109
# Epoch:0 Step:2784 Training_loss:0.678095, Acc_avg:52.25% Training_loss_avg:0.690707
# Epoch:0 Step:2792 Training_loss:0.681414, Acc_avg:52.25% Training_loss_avg:0.690299
# Epoch:0 Step:2800 Training_loss:0.688416, Acc_avg:52.25% Training_loss_avg:0.689758
# Epoch:0 Step:2808 Training_loss:0.731677, Acc_avg:52.00% Training_loss_avg:0.691257
# Epoch:0 Step:2816 Training_loss:0.731145, Acc_avg:51.25% Training_loss_avg:0.693267
# Epoch:0 Step:2824 Training_loss:0.663306, Acc_avg:52.25% Training_loss_avg:0.691262
# Epoch:0 Step:2832 Training_loss:0.713952, Acc_avg:52.50% Training_loss_avg:0.690947
# Epoch:0 Step:2840 Training_loss:0.694616, Acc_avg:52.75% Training_loss_avg:0.690434
# Epoch:0 Step:2848 Training_loss:0.707765, Acc_avg:52.50% Training_loss_avg:0.691065
# Epoch:0 Step:2856 Training_loss:0.681911, Acc_avg:52.75% Training_loss_avg:0.690539
# Epoch:0 Step:2864 Training_loss:0.677138, Acc_avg:53.00% Training_loss_avg:0.690140
# Epoch:0 Step:2872 Training_loss:0.669711, Acc_avg:53.50% Training_loss_avg:0.689306
# Epoch:0 Step:2880 Training_loss:0.698891, Acc_avg:52.50% Training_loss_avg:0.691545
# Epoch:0 Step:2888 Training_loss:0.688334, Acc_avg:52.25% Training_loss_avg:0.691063
# Epoch:0 Step:2896 Training_loss:0.654318, Acc_avg:52.00% Training_loss_avg:0.690619
# Epoch:0 Step:2904 Training_loss:0.691403, Acc_avg:51.75% Training_loss_avg:0.691098
# Epoch:0 Step:2912 Training_loss:0.734656, Acc_avg:51.25% Training_loss_avg:0.692468
# Epoch:0 Step:2920 Training_loss:0.680757, Acc_avg:51.00% Training_loss_avg:0.691669
# Epoch:0 Step:2928 Training_loss:0.686541, Acc_avg:51.75% Training_loss_avg:0.690782
# Epoch:0 Step:2936 Training_loss:0.658070, Acc_avg:51.50% Training_loss_avg:0.690522
# Epoch:0 Step:2944 Training_loss:0.658980, Acc_avg:51.75% Training_loss_avg:0.691041
# Epoch:0 Step:2952 Training_loss:0.629905, Acc_avg:52.00% Training_loss_avg:0.689484
# Epoch:0 Step:2960 Training_loss:0.707928, Acc_avg:52.25% Training_loss_avg:0.689779
# Epoch:0 Step:2968 Training_loss:0.697613, Acc_avg:52.00% Training_loss_avg:0.689722
# Epoch:0 Step:2976 Training_loss:0.500960, Acc_avg:53.25% Training_loss_avg:0.685427
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:2976 Val_loss:0.682047, Val_Acc_avg:57.50%
# Epoch:0 Step:2984 Training_loss:0.623523, Acc_avg:53.50% Training_loss_avg:0.683387
# Epoch:0 Step:2992 Training_loss:0.650054, Acc_avg:53.25% Training_loss_avg:0.684899
# Epoch:0 Step:3000 Training_loss:0.724778, Acc_avg:53.25% Training_loss_avg:0.686101
# Epoch:0 Step:3008 Training_loss:0.750019, Acc_avg:53.75% Training_loss_avg:0.685284
# Epoch:0 Step:3016 Training_loss:0.990269, Acc_avg:53.25% Training_loss_avg:0.691089
# Epoch:0 Step:3024 Training_loss:0.615470, Acc_avg:54.00% Training_loss_avg:0.687829
# Epoch:0 Step:3032 Training_loss:0.620715, Acc_avg:54.00% Training_loss_avg:0.686206
# Epoch:0 Step:3040 Training_loss:0.632329, Acc_avg:54.25% Training_loss_avg:0.685739
# Epoch:0 Step:3048 Training_loss:0.679889, Acc_avg:54.75% Training_loss_avg:0.684617
# Epoch:0 Step:3056 Training_loss:0.889357, Acc_avg:53.75% Training_loss_avg:0.689124
# Epoch:0 Step:3064 Training_loss:0.591778, Acc_avg:54.25% Training_loss_avg:0.686164
# Epoch:0 Step:3072 Training_loss:0.785705, Acc_avg:54.25% Training_loss_avg:0.688449
# Epoch:0 Step:3080 Training_loss:0.733897, Acc_avg:54.50% Training_loss_avg:0.689327
# Epoch:0 Step:3088 Training_loss:0.824659, Acc_avg:54.00% Training_loss_avg:0.692658
# Epoch:0 Step:3096 Training_loss:0.639593, Acc_avg:53.75% Training_loss_avg:0.691704
# Epoch:0 Step:3104 Training_loss:0.608356, Acc_avg:53.50% Training_loss_avg:0.690677
# Epoch:0 Step:3112 Training_loss:0.631864, Acc_avg:53.75% Training_loss_avg:0.689695
# Epoch:0 Step:3120 Training_loss:0.731171, Acc_avg:53.75% Training_loss_avg:0.691013
# Epoch:0 Step:3128 Training_loss:0.643269, Acc_avg:54.00% Training_loss_avg:0.690390
# Epoch:0 Step:3136 Training_loss:0.831910, Acc_avg:53.75% Training_loss_avg:0.693666
# Epoch:0 Step:3144 Training_loss:0.671216, Acc_avg:53.75% Training_loss_avg:0.693142
# Epoch:0 Step:3152 Training_loss:0.788113, Acc_avg:53.25% Training_loss_avg:0.694587
# Epoch:0 Step:3160 Training_loss:0.608222, Acc_avg:53.75% Training_loss_avg:0.692979
# Epoch:0 Step:3168 Training_loss:0.715101, Acc_avg:53.50% Training_loss_avg:0.694621
# Epoch:0 Step:3176 Training_loss:0.726435, Acc_avg:54.25% Training_loss_avg:0.694304
# Epoch:0 Step:3184 Training_loss:0.675465, Acc_avg:54.75% Training_loss_avg:0.694251
# Epoch:0 Step:3192 Training_loss:0.713943, Acc_avg:54.75% Training_loss_avg:0.694902
# Epoch:0 Step:3200 Training_loss:0.643507, Acc_avg:55.25% Training_loss_avg:0.694004
# Epoch:0 Step:3208 Training_loss:0.687798, Acc_avg:55.25% Training_loss_avg:0.693126
# Epoch:0 Step:3216 Training_loss:0.719240, Acc_avg:55.25% Training_loss_avg:0.692888
# Epoch:0 Step:3224 Training_loss:0.579495, Acc_avg:56.00% Training_loss_avg:0.691212
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:0 Step:3224 Val_loss:0.679808, Val_Acc_avg:57.75%
# Epoch:0 Step:3232 Training_loss:0.671561, Acc_avg:56.25% Training_loss_avg:0.690364
# Epoch:0 Step:3240 Training_loss:0.728871, Acc_avg:56.00% Training_loss_avg:0.691049
# Epoch:0 Step:3248 Training_loss:0.691867, Acc_avg:56.25% Training_loss_avg:0.690731
# Epoch:0 Step:3256 Training_loss:0.692300, Acc_avg:56.25% Training_loss_avg:0.690939
# Epoch:0 Step:3264 Training_loss:0.674849, Acc_avg:56.00% Training_loss_avg:0.690893
# Epoch:0 Step:3272 Training_loss:0.712065, Acc_avg:55.75% Training_loss_avg:0.691740
# Epoch:0 Step:3280 Training_loss:0.711570, Acc_avg:56.25% Training_loss_avg:0.691994
# Epoch:0 Step:3288 Training_loss:0.715425, Acc_avg:56.25% Training_loss_avg:0.692536
# Epoch:0 Step:3296 Training_loss:0.675201, Acc_avg:56.50% Training_loss_avg:0.692953
# Epoch:0 Step:3304 Training_loss:0.713094, Acc_avg:56.25% Training_loss_avg:0.693387
# Epoch:0 Step:3312 Training_loss:0.702504, Acc_avg:57.00% Training_loss_avg:0.692744
# Epoch:0 Step:3320 Training_loss:0.654609, Acc_avg:57.75% Training_loss_avg:0.692221
# Epoch:0 Step:3328 Training_loss:0.711289, Acc_avg:58.08% Training_loss_avg:0.692716
# Epoch:1 Step:0 Training_loss:0.764512, Acc_avg:57.33% Training_loss_avg:0.694845
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:0 Val_loss:0.679753, Val_Acc_avg:58.00%
# Epoch:1 Step:8 Training_loss:0.669820, Acc_avg:57.33% Training_loss_avg:0.695062
# Epoch:1 Step:16 Training_loss:0.695409, Acc_avg:56.58% Training_loss_avg:0.696372
# Epoch:1 Step:24 Training_loss:0.716063, Acc_avg:55.83% Training_loss_avg:0.696534
# Epoch:1 Step:32 Training_loss:0.658311, Acc_avg:56.33% Training_loss_avg:0.695748
# Epoch:1 Step:40 Training_loss:0.708178, Acc_avg:55.58% Training_loss_avg:0.699893
# Epoch:1 Step:48 Training_loss:0.668886, Acc_avg:55.58% Training_loss_avg:0.700800
# Epoch:1 Step:56 Training_loss:0.706617, Acc_avg:55.08% Training_loss_avg:0.701931
# Epoch:1 Step:64 Training_loss:0.725719, Acc_avg:54.83% Training_loss_avg:0.701950
# Epoch:1 Step:72 Training_loss:0.696446, Acc_avg:54.58% Training_loss_avg:0.700879
# Epoch:1 Step:80 Training_loss:0.646704, Acc_avg:55.33% Training_loss_avg:0.694007
# Epoch:1 Step:88 Training_loss:0.653356, Acc_avg:55.33% Training_loss_avg:0.694765
# Epoch:1 Step:96 Training_loss:0.734315, Acc_avg:55.08% Training_loss_avg:0.697037
# Epoch:1 Step:104 Training_loss:0.685052, Acc_avg:54.83% Training_loss_avg:0.698092
# Epoch:1 Step:112 Training_loss:0.701114, Acc_avg:54.83% Training_loss_avg:0.698516
# Epoch:1 Step:120 Training_loss:0.666598, Acc_avg:55.83% Training_loss_avg:0.694061
# Epoch:1 Step:128 Training_loss:0.676603, Acc_avg:55.58% Training_loss_avg:0.695757
# Epoch:1 Step:136 Training_loss:0.668909, Acc_avg:56.08% Training_loss_avg:0.693421
# Epoch:1 Step:144 Training_loss:0.644572, Acc_avg:56.08% Training_loss_avg:0.691635
# Epoch:1 Step:152 Training_loss:0.686402, Acc_avg:56.08% Training_loss_avg:0.688870
# Epoch:1 Step:160 Training_loss:0.677131, Acc_avg:56.08% Training_loss_avg:0.689621
# Epoch:1 Step:168 Training_loss:0.646159, Acc_avg:56.58% Training_loss_avg:0.690377
# Epoch:1 Step:176 Training_loss:0.661118, Acc_avg:56.58% Training_loss_avg:0.690962
# Epoch:1 Step:184 Training_loss:0.727285, Acc_avg:56.08% Training_loss_avg:0.690884
# Epoch:1 Step:192 Training_loss:0.663430, Acc_avg:56.08% Training_loss_avg:0.691287
# Epoch:1 Step:200 Training_loss:0.651133, Acc_avg:56.83% Training_loss_avg:0.687672
# Epoch:1 Step:208 Training_loss:0.676353, Acc_avg:57.08% Training_loss_avg:0.687774
# Epoch:1 Step:216 Training_loss:0.685191, Acc_avg:57.58% Training_loss_avg:0.685716
# Epoch:1 Step:224 Training_loss:0.754205, Acc_avg:56.33% Training_loss_avg:0.688636
# Epoch:1 Step:232 Training_loss:0.698297, Acc_avg:56.08% Training_loss_avg:0.688300
# Epoch:1 Step:240 Training_loss:0.691183, Acc_avg:56.08% Training_loss_avg:0.687595
# Epoch:1 Step:248 Training_loss:0.626036, Acc_avg:56.08% Training_loss_avg:0.686606
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:248 Val_loss:0.677581, Val_Acc_avg:61.75%
# Epoch:1 Step:256 Training_loss:0.673558, Acc_avg:56.08% Training_loss_avg:0.685798
# Epoch:1 Step:264 Training_loss:0.685789, Acc_avg:55.83% Training_loss_avg:0.686644
# Epoch:1 Step:272 Training_loss:0.706111, Acc_avg:55.83% Training_loss_avg:0.687010
# Epoch:1 Step:280 Training_loss:0.704994, Acc_avg:55.58% Training_loss_avg:0.686725
# Epoch:1 Step:288 Training_loss:0.705012, Acc_avg:54.58% Training_loss_avg:0.689236
# Epoch:1 Step:296 Training_loss:0.667170, Acc_avg:54.58% Training_loss_avg:0.689148
# Epoch:1 Step:304 Training_loss:0.693152, Acc_avg:55.08% Training_loss_avg:0.688433
# Epoch:1 Step:312 Training_loss:0.687792, Acc_avg:55.08% Training_loss_avg:0.688352
# Epoch:1 Step:320 Training_loss:0.665653, Acc_avg:55.08% Training_loss_avg:0.687819
# Epoch:1 Step:328 Training_loss:0.687806, Acc_avg:55.08% Training_loss_avg:0.688078
# Epoch:1 Step:336 Training_loss:0.654936, Acc_avg:55.33% Training_loss_avg:0.686936
# Epoch:1 Step:344 Training_loss:0.547428, Acc_avg:55.83% Training_loss_avg:0.683653
# Epoch:1 Step:352 Training_loss:0.684487, Acc_avg:55.83% Training_loss_avg:0.683034
# Epoch:1 Step:360 Training_loss:0.707943, Acc_avg:55.58% Training_loss_avg:0.683689
# Epoch:1 Step:368 Training_loss:0.676024, Acc_avg:55.83% Training_loss_avg:0.682947
# Epoch:1 Step:376 Training_loss:0.607301, Acc_avg:56.33% Training_loss_avg:0.681043
# Epoch:1 Step:384 Training_loss:0.735939, Acc_avg:55.58% Training_loss_avg:0.682670
# Epoch:1 Step:392 Training_loss:0.680016, Acc_avg:55.50% Training_loss_avg:0.682044
# Epoch:1 Step:400 Training_loss:0.785570, Acc_avg:55.75% Training_loss_avg:0.682466
# Epoch:1 Step:408 Training_loss:0.659355, Acc_avg:55.50% Training_loss_avg:0.682256
# Epoch:1 Step:416 Training_loss:0.596314, Acc_avg:56.25% Training_loss_avg:0.680274
# Epoch:1 Step:424 Training_loss:0.622833, Acc_avg:57.25% Training_loss_avg:0.678410
# Epoch:1 Step:432 Training_loss:0.741598, Acc_avg:56.75% Training_loss_avg:0.680076
# Epoch:1 Step:440 Training_loss:0.599150, Acc_avg:56.75% Training_loss_avg:0.677895
# Epoch:1 Step:448 Training_loss:0.744671, Acc_avg:56.25% Training_loss_avg:0.679411
# Epoch:1 Step:456 Training_loss:0.792504, Acc_avg:56.00% Training_loss_avg:0.681128
# Epoch:1 Step:464 Training_loss:0.657616, Acc_avg:56.75% Training_loss_avg:0.679766
# Epoch:1 Step:472 Training_loss:0.746056, Acc_avg:57.00% Training_loss_avg:0.680759
# Epoch:1 Step:480 Training_loss:0.726636, Acc_avg:57.00% Training_loss_avg:0.682357
# Epoch:1 Step:488 Training_loss:0.784260, Acc_avg:56.25% Training_loss_avg:0.684975
# Epoch:1 Step:496 Training_loss:0.642976, Acc_avg:56.50% Training_loss_avg:0.683148
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:1 Step:496 Val_loss:0.678151, Val_Acc_avg:58.00%
# Epoch:1 Step:504 Training_loss:0.496980, Acc_avg:57.25% Training_loss_avg:0.679387
# Epoch:1 Step:512 Training_loss:0.684079, Acc_avg:57.25% Training_loss_avg:0.679046
# Epoch:1 Step:520 Training_loss:0.668672, Acc_avg:57.00% Training_loss_avg:0.679088
# Epoch:1 Step:528 Training_loss:0.644888, Acc_avg:57.00% Training_loss_avg:0.678454
# Epoch:1 Step:536 Training_loss:0.743718, Acc_avg:56.50% Training_loss_avg:0.679950
# Epoch:1 Step:544 Training_loss:0.704625, Acc_avg:56.50% Training_loss_avg:0.681151
# Epoch:1 Step:552 Training_loss:0.636903, Acc_avg:57.25% Training_loss_avg:0.680161
# Epoch:1 Step:560 Training_loss:0.638226, Acc_avg:57.25% Training_loss_avg:0.679383
# Epoch:1 Step:568 Training_loss:0.656710, Acc_avg:56.75% Training_loss_avg:0.679594
# Epoch:1 Step:576 Training_loss:0.740176, Acc_avg:56.50% Training_loss_avg:0.681175
# Epoch:1 Step:584 Training_loss:0.784135, Acc_avg:56.50% Training_loss_avg:0.682312
# Epoch:1 Step:592 Training_loss:0.661646, Acc_avg:56.25% Training_loss_avg:0.682276
# Epoch:1 Step:600 Training_loss:0.645727, Acc_avg:56.00% Training_loss_avg:0.682168
# Epoch:1 Step:608 Training_loss:0.751623, Acc_avg:55.50% Training_loss_avg:0.683673
# Epoch:1 Step:616 Training_loss:0.784408, Acc_avg:55.25% Training_loss_avg:0.685658
# Epoch:1 Step:624 Training_loss:0.655412, Acc_avg:56.00% Training_loss_avg:0.683682
# Epoch:1 Step:632 Training_loss:0.716774, Acc_avg:56.00% Training_loss_avg:0.684051
# Epoch:1 Step:640 Training_loss:0.668885, Acc_avg:56.25% Training_loss_avg:0.683605
# Epoch:1 Step:648 Training_loss:0.722437, Acc_avg:55.50% Training_loss_avg:0.685534
# Epoch:1 Step:656 Training_loss:0.658552, Acc_avg:55.75% Training_loss_avg:0.685233
# Epoch:1 Step:664 Training_loss:0.645104, Acc_avg:55.75% Training_loss_avg:0.684420
# Epoch:1 Step:672 Training_loss:0.682530, Acc_avg:55.75% Training_loss_avg:0.683948
# Epoch:1 Step:680 Training_loss:0.691623, Acc_avg:56.25% Training_loss_avg:0.683681
# Epoch:1 Step:688 Training_loss:0.684502, Acc_avg:56.25% Training_loss_avg:0.683270
# Epoch:1 Step:696 Training_loss:0.652299, Acc_avg:56.25% Training_loss_avg:0.682973
# Epoch:1 Step:704 Training_loss:0.656648, Acc_avg:56.00% Training_loss_avg:0.682243
# Epoch:1 Step:712 Training_loss:0.680326, Acc_avg:55.75% Training_loss_avg:0.682094
# Epoch:1 Step:720 Training_loss:0.673818, Acc_avg:55.75% Training_loss_avg:0.682257
# Epoch:1 Step:728 Training_loss:0.623473, Acc_avg:56.25% Training_loss_avg:0.680970
# Epoch:1 Step:736 Training_loss:0.665031, Acc_avg:56.50% Training_loss_avg:0.681172
# Epoch:1 Step:744 Training_loss:0.681243, Acc_avg:55.75% Training_loss_avg:0.683848
# Validating:
# 52it [00:07,  6.60it/s]
# Epoch:1 Step:744 Val_loss:0.672608, Val_Acc_avg:59.00%
# Epoch:1 Step:752 Training_loss:0.694678, Acc_avg:55.75% Training_loss_avg:0.684052
# Epoch:1 Step:760 Training_loss:0.657191, Acc_avg:55.75% Training_loss_avg:0.683037
# Epoch:1 Step:768 Training_loss:0.648368, Acc_avg:56.25% Training_loss_avg:0.682484
# Epoch:1 Step:776 Training_loss:0.627514, Acc_avg:55.75% Training_loss_avg:0.682888
# Epoch:1 Step:784 Training_loss:0.664413, Acc_avg:56.25% Training_loss_avg:0.681458
# Epoch:1 Step:792 Training_loss:0.670897, Acc_avg:56.25% Training_loss_avg:0.681275
# Epoch:1 Step:800 Training_loss:0.633956, Acc_avg:57.50% Training_loss_avg:0.678243
# Epoch:1 Step:808 Training_loss:0.723413, Acc_avg:57.00% Training_loss_avg:0.679524
# Epoch:1 Step:816 Training_loss:0.704214, Acc_avg:56.25% Training_loss_avg:0.681682
# Epoch:1 Step:824 Training_loss:0.735647, Acc_avg:55.50% Training_loss_avg:0.683939
# Epoch:1 Step:832 Training_loss:0.673160, Acc_avg:55.75% Training_loss_avg:0.682570
# Epoch:1 Step:840 Training_loss:0.640762, Acc_avg:56.00% Training_loss_avg:0.683402
# Epoch:1 Step:848 Training_loss:0.734117, Acc_avg:56.25% Training_loss_avg:0.683191
# Epoch:1 Step:856 Training_loss:0.634039, Acc_avg:57.25% Training_loss_avg:0.680022
# Epoch:1 Step:864 Training_loss:0.724740, Acc_avg:56.50% Training_loss_avg:0.681364
# Epoch:1 Step:872 Training_loss:0.660508, Acc_avg:56.75% Training_loss_avg:0.679653
# Epoch:1 Step:880 Training_loss:0.641827, Acc_avg:57.25% Training_loss_avg:0.677957
# ...
# Epoch:4 Step:1872 Training_loss:0.489252, Acc_avg:63.50% Training_loss_avg:0.589567
# Epoch:4 Step:1880 Training_loss:0.732051, Acc_avg:63.75% Training_loss_avg:0.589769
# Epoch:4 Step:1888 Training_loss:0.901552, Acc_avg:63.75% Training_loss_avg:0.595235
# Epoch:4 Step:1896 Training_loss:0.451220, Acc_avg:63.75% Training_loss_avg:0.594357
# Epoch:4 Step:1904 Training_loss:0.563493, Acc_avg:63.50% Training_loss_avg:0.593382
# Epoch:4 Step:1912 Training_loss:0.513755, Acc_avg:63.50% Training_loss_avg:0.593091
# Epoch:4 Step:1920 Training_loss:0.776551, Acc_avg:64.00% Training_loss_avg:0.595211
# Epoch:4 Step:1928 Training_loss:0.389705, Acc_avg:64.00% Training_loss_avg:0.591848
# Epoch:4 Step:1936 Training_loss:0.582072, Acc_avg:64.00% Training_loss_avg:0.592905
# Epoch:4 Step:1944 Training_loss:0.574484, Acc_avg:64.75% Training_loss_avg:0.590405
# Epoch:4 Step:1952 Training_loss:0.404220, Acc_avg:65.50% Training_loss_avg:0.587139
# Epoch:4 Step:1960 Training_loss:0.436000, Acc_avg:65.75% Training_loss_avg:0.580808
# Epoch:4 Step:1968 Training_loss:0.604585, Acc_avg:66.25% Training_loss_avg:0.580119
# Epoch:4 Step:1976 Training_loss:0.854694, Acc_avg:65.75% Training_loss_avg:0.588102
# Epoch:4 Step:1984 Training_loss:0.589372, Acc_avg:66.00% Training_loss_avg:0.587017
# Validating:
# 52it [00:07,  6.62it/s]
# Epoch:4 Step:1984 Val_loss:0.629526, Val_Acc_avg:64.75%
# Epoch:4 Step:1992 Training_loss:0.373773, Acc_avg:66.50% Training_loss_avg:0.584129
# Epoch:4 Step:2000 Training_loss:0.555970, Acc_avg:66.50% Training_loss_avg:0.583412
# Epoch:4 Step:2008 Training_loss:0.620238, Acc_avg:67.25% Training_loss_avg:0.578438
# Epoch:4 Step:2016 Training_loss:0.577521, Acc_avg:67.25% Training_loss_avg:0.579131
# Epoch:4 Step:2024 Training_loss:0.582737, Acc_avg:67.75% Training_loss_avg:0.577316
# Epoch:4 Step:2032 Training_loss:0.887284, Acc_avg:67.50% Training_loss_avg:0.581029
# Epoch:4 Step:2040 Training_loss:0.402805, Acc_avg:68.00% Training_loss_avg:0.576511
# Epoch:4 Step:2048 Training_loss:0.498354, Acc_avg:68.00% Training_loss_avg:0.577370
# Epoch:4 Step:2056 Training_loss:0.253584, Acc_avg:69.00% Training_loss_avg:0.569220
# Epoch:4 Step:2064 Training_loss:0.639850, Acc_avg:69.25% Training_loss_avg:0.566683
# Epoch:4 Step:2072 Training_loss:0.722888, Acc_avg:68.25% Training_loss_avg:0.572853
# Epoch:4 Step:2080 Training_loss:0.419546, Acc_avg:68.50% Training_loss_avg:0.568680
# Epoch:4 Step:2088 Training_loss:0.393642, Acc_avg:68.00% Training_loss_avg:0.567733
# Epoch:4 Step:2096 Training_loss:0.591170, Acc_avg:68.75% Training_loss_avg:0.563853
# Epoch:4 Step:2104 Training_loss:0.502891, Acc_avg:68.50% Training_loss_avg:0.563140
# Epoch:4 Step:2112 Training_loss:0.522932, Acc_avg:69.00% Training_loss_avg:0.558988
# Epoch:4 Step:2120 Training_loss:0.774395, Acc_avg:68.25% Training_loss_avg:0.563795
# Epoch:4 Step:2128 Training_loss:0.489917, Acc_avg:69.00% Training_loss_avg:0.559409
# Epoch:4 Step:2136 Training_loss:0.387333, Acc_avg:68.75% Training_loss_avg:0.560016
# Epoch:4 Step:2144 Training_loss:0.269223, Acc_avg:69.25% Training_loss_avg:0.553626
# Epoch:4 Step:2152 Training_loss:0.464788, Acc_avg:69.50% Training_loss_avg:0.551750
# Epoch:4 Step:2160 Training_loss:0.437639, Acc_avg:69.50% Training_loss_avg:0.550379
# Epoch:4 Step:2168 Training_loss:0.709593, Acc_avg:69.25% Training_loss_avg:0.554166
# Epoch:4 Step:2176 Training_loss:0.709492, Acc_avg:69.50% Training_loss_avg:0.555021
# Epoch:4 Step:2184 Training_loss:0.355597, Acc_avg:69.50% Training_loss_avg:0.555987
# Epoch:4 Step:2192 Training_loss:0.810138, Acc_avg:68.50% Training_loss_avg:0.562435
# Epoch:4 Step:2200 Training_loss:1.006912, Acc_avg:67.75% Training_loss_avg:0.568798
# Epoch:4 Step:2208 Training_loss:0.792726, Acc_avg:67.50% Training_loss_avg:0.572287
# Epoch:4 Step:2216 Training_loss:0.647599, Acc_avg:67.50% Training_loss_avg:0.573991
# Epoch:4 Step:2224 Training_loss:0.356706, Acc_avg:67.75% Training_loss_avg:0.571470
# Epoch:4 Step:2232 Training_loss:0.403452, Acc_avg:68.25% Training_loss_avg:0.569771
# Validating:
# 52it [00:07,  6.62it/s]
# Epoch:4 Step:2232 Val_loss:0.604483, Val_Acc_avg:63.50%
# Epoch:4 Step:2240 Training_loss:0.613777, Acc_avg:69.00% Training_loss_avg:0.569708
# Epoch:4 Step:2248 Training_loss:0.461491, Acc_avg:69.25% Training_loss_avg:0.567021
# Epoch:4 Step:2256 Training_loss:0.708992, Acc_avg:69.75% Training_loss_avg:0.566373
# Epoch:4 Step:2264 Training_loss:0.387136, Acc_avg:70.00% Training_loss_avg:0.563902
# Epoch:4 Step:2272 Training_loss:0.472057, Acc_avg:70.00% Training_loss_avg:0.563558
# Epoch:4 Step:2280 Training_loss:0.544062, Acc_avg:70.50% Training_loss_avg:0.559798
# Epoch:4 Step:2288 Training_loss:0.553678, Acc_avg:71.00% Training_loss_avg:0.552841
# Epoch:4 Step:2296 Training_loss:0.575683, Acc_avg:70.75% Training_loss_avg:0.555330
# Epoch:4 Step:2304 Training_loss:0.779561, Acc_avg:70.50% Training_loss_avg:0.559651
# Epoch:4 Step:2312 Training_loss:0.565871, Acc_avg:70.50% Training_loss_avg:0.560694
# Epoch:4 Step:2320 Training_loss:0.674511, Acc_avg:70.50% Training_loss_avg:0.558653
# Epoch:4 Step:2328 Training_loss:0.804789, Acc_avg:69.75% Training_loss_avg:0.566955
# Epoch:4 Step:2336 Training_loss:0.683455, Acc_avg:69.00% Training_loss_avg:0.568982
# Epoch:4 Step:2344 Training_loss:0.529694, Acc_avg:69.25% Training_loss_avg:0.568086
# Epoch:4 Step:2352 Training_loss:0.535094, Acc_avg:68.50% Training_loss_avg:0.570704
# Epoch:4 Step:2360 Training_loss:0.662464, Acc_avg:68.00% Training_loss_avg:0.575233
# Epoch:4 Step:2368 Training_loss:0.609575, Acc_avg:67.50% Training_loss_avg:0.575333
# Epoch:4 Step:2376 Training_loss:0.438295, Acc_avg:68.25% Training_loss_avg:0.567005
# Epoch:4 Step:2384 Training_loss:0.462739, Acc_avg:68.50% Training_loss_avg:0.564472
# Epoch:4 Step:2392 Training_loss:0.754485, Acc_avg:67.50% Training_loss_avg:0.572087
# Epoch:4 Step:2400 Training_loss:0.710061, Acc_avg:67.00% Training_loss_avg:0.575168
# Epoch:4 Step:2408 Training_loss:0.494976, Acc_avg:67.75% Training_loss_avg:0.572663
# Epoch:4 Step:2416 Training_loss:0.660924, Acc_avg:67.00% Training_loss_avg:0.574331
# Epoch:4 Step:2424 Training_loss:0.563407, Acc_avg:66.25% Training_loss_avg:0.573945
# Epoch:4 Step:2432 Training_loss:0.718327, Acc_avg:66.25% Training_loss_avg:0.570566
# Epoch:4 Step:2440 Training_loss:0.621592, Acc_avg:65.75% Training_loss_avg:0.574941
# Epoch:4 Step:2448 Training_loss:0.701231, Acc_avg:65.00% Training_loss_avg:0.578999
# Epoch:4 Step:2456 Training_loss:0.589470, Acc_avg:64.25% Training_loss_avg:0.585717
# Epoch:4 Step:2464 Training_loss:0.689078, Acc_avg:63.75% Training_loss_avg:0.586701
# Epoch:4 Step:2472 Training_loss:0.534876, Acc_avg:64.50% Training_loss_avg:0.582941
# Epoch:4 Step:2480 Training_loss:0.495068, Acc_avg:64.25% Training_loss_avg:0.584451
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2480 Val_loss:0.606368, Val_Acc_avg:64.00%
# Epoch:4 Step:2488 Training_loss:0.577913, Acc_avg:64.25% Training_loss_avg:0.588137
# Epoch:4 Step:2496 Training_loss:0.599376, Acc_avg:64.25% Training_loss_avg:0.588301
# Epoch:4 Step:2504 Training_loss:0.518147, Acc_avg:64.25% Training_loss_avg:0.588606
# Epoch:4 Step:2512 Training_loss:0.360588, Acc_avg:64.50% Training_loss_avg:0.585359
# Epoch:4 Step:2520 Training_loss:0.643441, Acc_avg:64.75% Training_loss_avg:0.582740
# Epoch:4 Step:2528 Training_loss:0.587112, Acc_avg:64.00% Training_loss_avg:0.584684
# Epoch:4 Step:2536 Training_loss:0.647556, Acc_avg:63.25% Training_loss_avg:0.589888
# Epoch:4 Step:2544 Training_loss:0.359687, Acc_avg:63.00% Training_loss_avg:0.591698
# Epoch:4 Step:2552 Training_loss:0.575264, Acc_avg:62.50% Training_loss_avg:0.593907
# Epoch:4 Step:2560 Training_loss:0.428746, Acc_avg:63.00% Training_loss_avg:0.593729
# Epoch:4 Step:2568 Training_loss:0.561245, Acc_avg:63.00% Training_loss_avg:0.590762
# Epoch:4 Step:2576 Training_loss:0.489074, Acc_avg:63.50% Training_loss_avg:0.586354
# Epoch:4 Step:2584 Training_loss:0.715028, Acc_avg:62.50% Training_loss_avg:0.593543
# Epoch:4 Step:2592 Training_loss:0.635055, Acc_avg:63.25% Training_loss_avg:0.590041
# Epoch:4 Step:2600 Training_loss:0.648240, Acc_avg:63.50% Training_loss_avg:0.582867
# Epoch:4 Step:2608 Training_loss:0.518839, Acc_avg:64.00% Training_loss_avg:0.577390
# Epoch:4 Step:2616 Training_loss:0.473270, Acc_avg:64.25% Training_loss_avg:0.573903
# Epoch:4 Step:2624 Training_loss:0.518972, Acc_avg:64.25% Training_loss_avg:0.577149
# Epoch:4 Step:2632 Training_loss:0.699170, Acc_avg:63.25% Training_loss_avg:0.583063
# Epoch:4 Step:2640 Training_loss:0.509518, Acc_avg:63.25% Training_loss_avg:0.580978
# Epoch:4 Step:2648 Training_loss:0.602323, Acc_avg:62.75% Training_loss_avg:0.583794
# Epoch:4 Step:2656 Training_loss:0.508387, Acc_avg:63.25% Training_loss_avg:0.579782
# Epoch:4 Step:2664 Training_loss:0.571573, Acc_avg:63.00% Training_loss_avg:0.583471
# Epoch:4 Step:2672 Training_loss:0.641258, Acc_avg:62.75% Training_loss_avg:0.586855
# Epoch:4 Step:2680 Training_loss:0.521965, Acc_avg:62.75% Training_loss_avg:0.586413
# Epoch:4 Step:2688 Training_loss:0.470164, Acc_avg:63.00% Training_loss_avg:0.584743
# Epoch:4 Step:2696 Training_loss:0.661607, Acc_avg:63.50% Training_loss_avg:0.586461
# Epoch:4 Step:2704 Training_loss:0.477630, Acc_avg:64.00% Training_loss_avg:0.580423
# Epoch:4 Step:2712 Training_loss:0.841024, Acc_avg:63.25% Training_loss_avg:0.585926
# Epoch:4 Step:2720 Training_loss:0.609623, Acc_avg:63.75% Training_loss_avg:0.584628
# Epoch:4 Step:2728 Training_loss:0.794164, Acc_avg:64.25% Training_loss_avg:0.584415
# Validating:
# 52it [00:07,  6.62it/s]
# Epoch:4 Step:2728 Val_loss:0.613492, Val_Acc_avg:62.25%
# Epoch:4 Step:2736 Training_loss:0.675986, Acc_avg:64.75% Training_loss_avg:0.584266
# Epoch:4 Step:2744 Training_loss:0.490294, Acc_avg:64.75% Training_loss_avg:0.583478
# Epoch:4 Step:2752 Training_loss:0.333614, Acc_avg:65.25% Training_loss_avg:0.579448
# Epoch:4 Step:2760 Training_loss:0.540486, Acc_avg:65.50% Training_loss_avg:0.577009
# Epoch:4 Step:2768 Training_loss:0.316952, Acc_avg:66.50% Training_loss_avg:0.571156
# Epoch:4 Step:2776 Training_loss:0.438694, Acc_avg:66.50% Training_loss_avg:0.571164
# Epoch:4 Step:2784 Training_loss:0.465745, Acc_avg:66.50% Training_loss_avg:0.571224
# Epoch:4 Step:2792 Training_loss:0.420821, Acc_avg:67.25% Training_loss_avg:0.564551
# Epoch:4 Step:2800 Training_loss:0.633117, Acc_avg:67.75% Training_loss_avg:0.563012
# Epoch:4 Step:2808 Training_loss:0.894070, Acc_avg:66.75% Training_loss_avg:0.570994
# Epoch:4 Step:2816 Training_loss:0.432145, Acc_avg:67.50% Training_loss_avg:0.566419
# Epoch:4 Step:2824 Training_loss:0.341698, Acc_avg:68.75% Training_loss_avg:0.561984
# Epoch:4 Step:2832 Training_loss:0.587296, Acc_avg:69.25% Training_loss_avg:0.559364
# Epoch:4 Step:2840 Training_loss:0.749938, Acc_avg:69.00% Training_loss_avg:0.561931
# Epoch:4 Step:2848 Training_loss:0.585709, Acc_avg:69.50% Training_loss_avg:0.559620
# Epoch:4 Step:2856 Training_loss:0.858133, Acc_avg:69.50% Training_loss_avg:0.564994
# Epoch:4 Step:2864 Training_loss:0.519295, Acc_avg:70.00% Training_loss_avg:0.561598
# Epoch:4 Step:2872 Training_loss:0.386766, Acc_avg:70.25% Training_loss_avg:0.558636
# Epoch:4 Step:2880 Training_loss:0.511372, Acc_avg:70.25% Training_loss_avg:0.558962
# Epoch:4 Step:2888 Training_loss:0.674020, Acc_avg:70.25% Training_loss_avg:0.560884
# Epoch:4 Step:2896 Training_loss:0.622073, Acc_avg:70.50% Training_loss_avg:0.561338
# Epoch:4 Step:2904 Training_loss:0.622401, Acc_avg:70.00% Training_loss_avg:0.563423
# Epoch:4 Step:2912 Training_loss:0.475781, Acc_avg:70.00% Training_loss_avg:0.565727
# Epoch:4 Step:2920 Training_loss:0.717406, Acc_avg:70.25% Training_loss_avg:0.567206
# Epoch:4 Step:2928 Training_loss:0.667412, Acc_avg:70.25% Training_loss_avg:0.568812
# Epoch:4 Step:2936 Training_loss:0.693337, Acc_avg:70.25% Training_loss_avg:0.569728
# Epoch:4 Step:2944 Training_loss:0.456423, Acc_avg:70.00% Training_loss_avg:0.571662
# Epoch:4 Step:2952 Training_loss:0.567369, Acc_avg:70.50% Training_loss_avg:0.571505
# Epoch:4 Step:2960 Training_loss:0.551568, Acc_avg:70.00% Training_loss_avg:0.573961
# Epoch:4 Step:2968 Training_loss:0.516282, Acc_avg:70.50% Training_loss_avg:0.573062
# Epoch:4 Step:2976 Training_loss:0.626717, Acc_avg:69.75% Training_loss_avg:0.575815
# Validating:
# 52it [00:07,  6.61it/s]
# Epoch:4 Step:2976 Val_loss:0.627388, Val_Acc_avg:61.75%
# Epoch:4 Step:2984 Training_loss:0.679367, Acc_avg:70.50% Training_loss_avg:0.575101
# Epoch:4 Step:2992 Training_loss:0.418711, Acc_avg:70.50% Training_loss_avg:0.570775
# Epoch:4 Step:3000 Training_loss:0.326063, Acc_avg:71.75% Training_loss_avg:0.564331
# Epoch:4 Step:3008 Training_loss:0.496098, Acc_avg:71.75% Training_loss_avg:0.563876
# Epoch:4 Step:3016 Training_loss:0.577549, Acc_avg:72.00% Training_loss_avg:0.565962
# Epoch:4 Step:3024 Training_loss:0.836364, Acc_avg:71.50% Training_loss_avg:0.572310
# Epoch:4 Step:3032 Training_loss:0.520748, Acc_avg:72.25% Training_loss_avg:0.568741
# Epoch:4 Step:3040 Training_loss:0.412200, Acc_avg:72.25% Training_loss_avg:0.566795
# Epoch:4 Step:3048 Training_loss:0.821325, Acc_avg:71.50% Training_loss_avg:0.571175
# Epoch:4 Step:3056 Training_loss:0.576077, Acc_avg:71.00% Training_loss_avg:0.572529
# Epoch:4 Step:3064 Training_loss:0.509429, Acc_avg:71.50% Training_loss_avg:0.571286
# Epoch:4 Step:3072 Training_loss:0.518594, Acc_avg:71.50% Training_loss_avg:0.568832
# Epoch:4 Step:3080 Training_loss:0.730937, Acc_avg:71.00% Training_loss_avg:0.573012
# Epoch:4 Step:3088 Training_loss:0.576389, Acc_avg:70.50% Training_loss_avg:0.575136
# Epoch:4 Step:3096 Training_loss:0.523535, Acc_avg:70.50% Training_loss_avg:0.572375
# Epoch:4 Step:3104 Training_loss:0.593436, Acc_avg:70.25% Training_loss_avg:0.574691
# Epoch:4 Step:3112 Training_loss:0.720466, Acc_avg:70.50% Training_loss_avg:0.572280
# Epoch:4 Step:3120 Training_loss:0.467248, Acc_avg:70.50% Training_loss_avg:0.569432
# Epoch:4 Step:3128 Training_loss:0.554357, Acc_avg:70.50% Training_loss_avg:0.564636
# Epoch:4 Step:3136 Training_loss:0.499456, Acc_avg:71.00% Training_loss_avg:0.561106
# Epoch:4 Step:3144 Training_loss:0.973722, Acc_avg:70.50% Training_loss_avg:0.570774
# Epoch:4 Step:3152 Training_loss:0.659108, Acc_avg:70.00% Training_loss_avg:0.577284
# Epoch:4 Step:3160 Training_loss:0.662923, Acc_avg:69.75% Training_loss_avg:0.579733
# Epoch:4 Step:3168 Training_loss:0.759016, Acc_avg:68.75% Training_loss_avg:0.588574
# Epoch:4 Step:3176 Training_loss:0.873543, Acc_avg:68.00% Training_loss_avg:0.597271
# Epoch:4 Step:3184 Training_loss:0.540764, Acc_avg:67.50% Training_loss_avg:0.598772
# Epoch:4 Step:3192 Training_loss:0.617290, Acc_avg:67.50% Training_loss_avg:0.602701
# Epoch:4 Step:3200 Training_loss:0.709426, Acc_avg:67.00% Training_loss_avg:0.604227
# Epoch:4 Step:3208 Training_loss:0.648735, Acc_avg:66.75% Training_loss_avg:0.599320
# Epoch:4 Step:3216 Training_loss:0.797781, Acc_avg:66.25% Training_loss_avg:0.606633
# Epoch:4 Step:3224 Training_loss:0.722462, Acc_avg:65.00% Training_loss_avg:0.614248
# Validating:
# 52it [00:07,  6.62it/s]
# Epoch:4 Step:3224 Val_loss:0.642445, Val_Acc_avg:60.00%
# Epoch:4 Step:3232 Training_loss:0.868251, Acc_avg:64.75% Training_loss_avg:0.619867
# Epoch:4 Step:3240 Training_loss:0.633377, Acc_avg:65.00% Training_loss_avg:0.617536
# Epoch:4 Step:3248 Training_loss:0.658400, Acc_avg:64.75% Training_loss_avg:0.618990
# Epoch:4 Step:3256 Training_loss:0.483797, Acc_avg:64.75% Training_loss_avg:0.611503
# Epoch:4 Step:3264 Training_loss:0.455788, Acc_avg:65.50% Training_loss_avg:0.610233
# Epoch:4 Step:3272 Training_loss:0.694596, Acc_avg:64.75% Training_loss_avg:0.616390
# Epoch:4 Step:3280 Training_loss:0.668522, Acc_avg:64.50% Training_loss_avg:0.619533
# Epoch:4 Step:3288 Training_loss:0.491824, Acc_avg:65.00% Training_loss_avg:0.615889
# Epoch:4 Step:3296 Training_loss:0.522814, Acc_avg:65.00% Training_loss_avg:0.613904
# Epoch:4 Step:3304 Training_loss:0.501287, Acc_avg:65.75% Training_loss_avg:0.611481
# Epoch:4 Step:3312 Training_loss:0.601969, Acc_avg:65.25% Training_loss_avg:0.614005
# Epoch:4 Step:3320 Training_loss:0.394202, Acc_avg:66.00% Training_loss_avg:0.607541
# Epoch:4 Step:3328 Training_loss:0.650513, Acc_avg:66.33% Training_loss_avg:0.607203

# %%
class BERT_Arch(nn.Module):

    def __init__(self, bert):
      
      super(BERT_Arch, self).__init__()

      self.bert = bert 
      
      # dropout layer
      self.dropout = nn.Dropout(0.1)
      
      # relu activation function
      self.relu =  nn.ReLU()

      # dense layer 1
      self.fc1 = nn.Linear(512,512)
      
      # dense layer 2 (Output layer)
      self.fc2 = nn.Linear(512,2)

      #softmax activation function
      self.softmax = nn.LogSoftmax(dim=1)

    #define the forward pass
    def forward(self, sent_id, mask):

      #pass the inputs to the model  
      cls_hs = self.bert(sent_id, attention_mask=mask)

      x = self.fc1(cls_hs.logits)

      x = self.relu(x)

      x = self.dropout(x)

      # output layer
      x = self.fc2(x)
      
      # apply softmax activation
      x = self.softmax(x)

      return x

# %%
"""
Main configuration function for a given finetune run
:return: None
"""
run_name = "lr_5e-5 redo, 512 split with attention! custom model redo 3"
run_dir = "codebert_finetune_runs/{}".format(run_name)
model_name = 'codebert-base'
checkpoint_location = None
online = False
load_splits = False
save_data = True

print("generating data splits")

code_df = preprocess_data(file_loc='code_dataset.jsonl')
train_data, val_data, test_data = tokenize(code_df, model_name=model_name)

X_train, A_train, Y_train = train_data
X_val, A_val, Y_val = val_data
X_test, A_test, Y_test = test_data

data_type = ['train', 'val', 'test']
data_split_type = ['X', 'A', 'Y']


# Creating dir to save logs and checkpoints, re
dir_name = "{}".format(run_dir)
if os.path.exists(dir_name):
  input("run name already exists, press Enter to overwrite")
else:
  os.makedirs(dir_name)

if save_data:
  print("saving data splits")

  data_all = [train_data, val_data, test_data]
  for i, data in enumerate(data_all):
    for j, split in enumerate(data):
      with open('{}/{}_{}.pickle'.format(run_dir,data_type[i], data_split_type[j]), 'wb') as handle:
        pickle.dump(split, handle)

# Loading model from checkpoint if location provided
if online:
  print("loading model from online")
  model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base")
elif checkpoint_location is None:
  print("loading model from local repo")

  model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=512)
else:
  print("loading model from checkpoint: {}".format(checkpoint_location))
  model = AutoModelForSequenceClassification.from_pretrained(checkpoint_location)
# Out:
# generating data splits
# Insecure code counts: 3729, Total code counts: 8000, Proportion 0.466125
# Data points: 8000
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# saving data splits
# loading model from local repo
# Some weights of the model checkpoint at codebert-base were not used when initializing RobertaForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at codebert-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# freeze all the parameters
for param in model.parameters():
    param.requires_grad = False

custom_model = BERT_Arch(model)

# %%
custom_model = custom_model.to(device)

# %%
def train_custom(model, train_data, val_data, epochs=5, batch_size=16, learning_rate=2e-5, validate_per=500,
          run_name="temp", run_descrption=None):
    """
    Main fine-tuning training loop for the provided model

    :param model: model loaded with predefined weights
    :param train_data: tuple of X_train, A_train, Y_train (X = inputs, A = attention, Y = target)
    :param val_data: tuple X_val, A_val, Y_val
    :param epochs: number of epochs for training
    :param batch_size: batch size (see note below about batch_hack)
    :param learning_rate: optimizer learning rate
    :param validate_per: number of weight updates before validation occurs
                            (notes: - if batch_size = 32, and validate_per = 32, validation will occur every batch
                                    - this is wrt the start of each epoch
                                    - validation will always occour at the start of each epoch (step 0))
    :param run_name: name used to saving checkpoints and log files within codebert_finetune_runs
    :param run_descrption: string that is saved to info.txt describing the run


    :return: None (models are saved in checkpoints along with log data)
    """


    # Saving run description.txt
    if run_descrption is not None:
        with open("{}/info.txt".format(dir_name), "a+") as f:
            f.write(run_descrption)

    # Unpacking data
    X_train, A_train, Y_train = train_data
    X_val, A_val, Y_val = val_data


    batch_hack = batch_size  # See note below regarding limited GPU memory

    # Initializing arrays for tracking loss
    train_loss_hist = []
    val_loss_hist = []
    train_pred_hist = []
    # Counter to track batches (see note below related to GPU memory)
    batch_count = 0
    # validate_per_batch = int(validate_per/batch_hack)

    # Moving model to GPU if configured
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = AdamW(model.parameters(), lr=learning_rate)

    validate_per = int(validate_per/batch_size)

    cross_entropy  = nn.NLLLoss() 
    for epoch in range(epochs):

        # Generating random index for manual shuffling of data each epoch as note using DataLoaders
        permutation = torch.randperm(X_train.shape[0])

        # Note here that only a single element is loaded at each iteration (batch size = 1) due to GPU memory constraint
        for batch_id, i in enumerate(range(0, X_train.shape[0], batch_hack)):

            # Loading batch and moving to device
            indices = permutation[i:i + batch_hack]
            batch_X, batch_Y, batch_A = X_train[indices].to(device), Y_train[indices].to(device), A_train[indices].to(device)


            batch_Y_one_hot = torch.nn.functional.one_hot(batch_Y, num_classes= 2)

            model.train()

            # Forward pass
            #outputs = model(batch_X,labels=batch_Y, attention_mask=batch_A)
            outputs = model(batch_X, batch_A)

            #loss = criterion(loss_clsf.float(), batch_Y_one_hot.float())
            #loss = outputs.loss

            loss = cross_entropy(outputs, batch_Y)


            # Clip params
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)


            # Backward pass
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            loss_clsf = nn.Softmax(dim=1)(outputs)
            acc = np.average(torch.eq(batch_Y.cpu(), loss_clsf.argmax(axis=1).cpu()))
            #rint(correct)

            # Tracking loss
            train_loss_hist.append(float(loss.item()))
            train_pred_hist.append(acc)

            # Training output
            train_output = "Epoch:{} Step:{} Training_loss:{:.6f}, Acc_avg:{:.2f}%".format(epoch, i, loss.item(), np.sum(100*train_pred_hist[-50:])/min(len(train_pred_hist), 50))
            print(train_output+" Training_loss_avg:{:.6f}".format(np.average(train_loss_hist[-50:])))
            with open("{}/train_loss.txt".format(dir_name), "a+") as f:
                f.write(train_output+"\n")

            # Validation
            if batch_id % validate_per == 0:
                val_loss_total = 0
                model.eval()
                print("Validating:")
                val_acc = []
                for val_badtch_id, j in tqdm(enumerate(range(0, X_val.shape[0], batch_hack))):
                    # Loading singular validation data (overwrites train data as can only load 1 intp GPU)
                    batch_X, batch_Y, batch_A = X_val[j:j+batch_hack].to(device), Y_val[j:j+batch_hack].to(device), A_val[j:j+batch_hack].to(device)

                    with torch.no_grad():
                        outputs = model(batch_X, batch_A)

                    val_loss = cross_entropy(outputs, batch_Y)
                    val_loss_total += float(val_loss)

                    
                    val_clsf = nn.Softmax(dim=1)(outputs)
                    val_acc.append(np.average(torch.eq(batch_Y.cpu(), val_clsf.argmax(axis=1).cpu())))

                    del batch_X
                    del batch_Y

                # Adding average loss to tracker
                val_average = val_loss_total / (val_badtch_id+1)
                val_loss_hist.append(val_average)

                # Validation output and logging
                val_output = "Epoch:{} Step:{} Val_loss:{:.6f}, Val_Acc_avg:{:.2f}%".format(epoch, i, val_average, np.sum(100*val_acc[-50:])/min(len(val_acc), 50))
                print(val_output)
                with open("{}/val_los.txt".format(dir_name), "a+") as f:
                    f.write(val_output+"\n")

        # End of epoch checkpoint
        #model.save_pretrained("{}/epoch_{}".format(dir_name, epoch + 1))
        torch.save(model, "{}/epoch_{}".format(dir_name, epoch + 1))

# %%
train_custom(model=custom_model,
      train_data=train_data,
      val_data=val_data,
      epochs=10,
      batch_size=8,
      learning_rate=5e-5,
      validate_per=250,
      run_name=run_name,
      run_descrption="lr_5e-5 redo")

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
